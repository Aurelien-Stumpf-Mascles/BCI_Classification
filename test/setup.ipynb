# %%
import torch

def format_pytorch_version(version):
    return version.split("+")[0]


TORCH_version = torch.__version__
TORCH = format_pytorch_version(TORCH_version)


def format_cuda_version(version):
    return "cu" + version.replace(".", "")


CUDA_version = torch.version.cuda
CUDA = format_cuda_version(CUDA_version)

# !pip install torch-scatter     -f https://pytorch-geometric.com/whl/torch-{TORCH}+{CUDA}.html
# !pip install torch-sparse      -f https://pytorch-geometric.com/whl/torch-{TORCH}+{CUDA}.html
# !pip install torch-cluster     -f https://pytorch-geometric.com/whl/torch-{TORCH}+{CUDA}.html
# !pip install torch-spline-conv -f https://pytorch-geometric.com/whl/torch-{TORCH}+{CUDA}.html
# !pip install torch-geometric
# Out:
# Looking in links: https://pytorch-geometric.com/whl/torch-2.3.1+cu121.html
# Collecting torch-scatter
#   Using cached torch_scatter-2.1.2.tar.gz (108 kB)
# Building wheels for collected packages: torch-scatter
#   Building wheel for torch-scatter (setup.py) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /home/aurelien.stumpf/Development/BCI_Classification/eeg_env/bin/python3 -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-x92ewz9w/torch-scatter/setup.py'"'"'; __file__='"'"'/tmp/pip-install-x92ewz9w/torch-scatter/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /tmp/pip-wheel-ctl6x5vp
#        cwd: /tmp/pip-install-x92ewz9w/torch-scatter/
#   Complete output (6 lines):
#   usage: setup.py [global_opts] cmd1 [cmd1_opts] [cmd2 [cmd2_opts] ...]
#      or: setup.py --help [cmd1 cmd2 ...]
#      or: setup.py --help-commands
#      or: setup.py cmd --help
#
#   error: invalid command 'bdist_wheel'
#   ----------------------------------------
#   ERROR: Failed building wheel for torch-scatter
#   Running setup.py clean for torch-scatter
# Failed to build torch-scatter
# Installing collected packages: torch-scatter
#     Running setup.py install for torch-scatter ... done
# Successfully installed torch-scatter-2.1.2
# Looking in links: https://pytorch-geometric.com/whl/torch-2.3.1+cu121.html
# Collecting torch-sparse
#   Downloading torch_sparse-0.6.18.tar.gz (209 kB)
#      |████████████████████████████████| 209 kB 5.8 MB/s eta 0:00:01
# Requirement already satisfied: scipy in /home/aurelien.stumpf/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages (from torch-sparse) (1.10.1)
# Requirement already satisfied: numpy<1.27.0,>=1.19.5 in /home/aurelien.stumpf/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages (from scipy->torch-sparse) (1.24.4)
# Building wheels for collected packages: torch-sparse
#   Building wheel for torch-sparse (setup.py) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /home/aurelien.stumpf/Development/BCI_Classification/eeg_env/bin/python3 -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-zwoq2d2g/torch-sparse/setup.py'"'"'; __file__='"'"'/tmp/pip-install-zwoq2d2g/torch-sparse/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /tmp/pip-wheel-g8luto04
#        cwd: /tmp/pip-install-zwoq2d2g/torch-sparse/
#   Complete output (6 lines):
#   usage: setup.py [global_opts] cmd1 [cmd1_opts] [cmd2 [cmd2_opts] ...]
#      or: setup.py --help [cmd1 cmd2 ...]
#      or: setup.py --help-commands
#      or: setup.py cmd --help
#
#   error: invalid command 'bdist_wheel'
#   ----------------------------------------
#   ERROR: Failed building wheel for torch-sparse
#   Running setup.py clean for torch-sparse
# Failed to build torch-sparse
# Installing collected packages: torch-sparse
#     Running setup.py install for torch-sparse ... done
# Successfully installed torch-sparse-0.6.18
# Looking in links: https://pytorch-geometric.com/whl/torch-2.3.1+cu121.html
# Collecting torch-cluster
#   Downloading torch_cluster-1.6.3.tar.gz (54 kB)
#      |████████████████████████████████| 54 kB 2.3 MB/s eta 0:00:011
# Requirement already satisfied: scipy in /home/aurelien.stumpf/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages (from torch-cluster) (1.10.1)
# Requirement already satisfied: numpy<1.27.0,>=1.19.5 in /home/aurelien.stumpf/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages (from scipy->torch-cluster) (1.24.4)
# Building wheels for collected packages: torch-cluster
#   Building wheel for torch-cluster (setup.py) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /home/aurelien.stumpf/Development/BCI_Classification/eeg_env/bin/python3 -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-cila4_8c/torch-cluster/setup.py'"'"'; __file__='"'"'/tmp/pip-install-cila4_8c/torch-cluster/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /tmp/pip-wheel-7w97yrv0
#        cwd: /tmp/pip-install-cila4_8c/torch-cluster/
#   Complete output (6 lines):
#   usage: setup.py [global_opts] cmd1 [cmd1_opts] [cmd2 [cmd2_opts] ...]
#      or: setup.py --help [cmd1 cmd2 ...]
#      or: setup.py --help-commands
#      or: setup.py cmd --help
#
#   error: invalid command 'bdist_wheel'
#   ----------------------------------------
#   ERROR: Failed building wheel for torch-cluster
#   Running setup.py clean for torch-cluster
# Failed to build torch-cluster
# Installing collected packages: torch-cluster
#     Running setup.py install for torch-cluster ... done
# Successfully installed torch-cluster-1.6.3
# Looking in links: https://pytorch-geometric.com/whl/torch-2.3.1+cu121.html
# Collecting torch-spline-conv
#   Downloading torch_spline_conv-1.2.2.tar.gz (25 kB)
# Building wheels for collected packages: torch-spline-conv
#   Building wheel for torch-spline-conv (setup.py) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /home/aurelien.stumpf/Development/BCI_Classification/eeg_env/bin/python3 -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-9fwf7hpc/torch-spline-conv/setup.py'"'"'; __file__='"'"'/tmp/pip-install-9fwf7hpc/torch-spline-conv/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /tmp/pip-wheel-qmfnb2_c
#        cwd: /tmp/pip-install-9fwf7hpc/torch-spline-conv/
#   Complete output (6 lines):
#   usage: setup.py [global_opts] cmd1 [cmd1_opts] [cmd2 [cmd2_opts] ...]
#      or: setup.py --help [cmd1 cmd2 ...]
#      or: setup.py --help-commands
#      or: setup.py cmd --help
#
#   error: invalid command 'bdist_wheel'
#   ----------------------------------------
#   ERROR: Failed building wheel for torch-spline-conv
#   Running setup.py clean for torch-spline-conv
# Failed to build torch-spline-conv
# Installing collected packages: torch-spline-conv
#     Running setup.py install for torch-spline-conv ... done
# Successfully installed torch-spline-conv-1.2.2
# Collecting torch-geometric
#   Using cached torch_geometric-2.5.3-py3-none-any.whl (1.1 MB)
# Requirement already satisfied: jinja2 in /home/aurelien.stumpf/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages (from torch-geometric) (3.1.4)
# Requirement already satisfied: pyparsing in /home/aurelien.stumpf/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages (from torch-geometric) (3.1.2)
# Requirement already satisfied: scikit-learn in /home/aurelien.stumpf/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages (from torch-geometric) (1.3.2)
# Requirement already satisfied: fsspec in /home/aurelien.stumpf/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages (from torch-geometric) (2024.6.0)
# Requirement already satisfied: scipy in /home/aurelien.stumpf/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages (from torch-geometric) (1.10.1)
# Requirement already satisfied: psutil>=5.8.0 in /home/aurelien.stumpf/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages (from torch-geometric) (6.0.0)
# Requirement already satisfied: aiohttp in /home/aurelien.stumpf/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages (from torch-geometric) (3.9.5)
# Requirement already satisfied: tqdm in /home/aurelien.stumpf/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages (from torch-geometric) (4.66.4)
# Requirement already satisfied: requests in /home/aurelien.stumpf/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages (from torch-geometric) (2.32.3)
# Requirement already satisfied: numpy in /home/aurelien.stumpf/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages (from torch-geometric) (1.24.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/aurelien.stumpf/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages (from jinja2->torch-geometric) (2.1.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/aurelien.stumpf/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages (from scikit-learn->torch-geometric) (3.5.0)
# Requirement already satisfied: joblib>=1.1.1 in /home/aurelien.stumpf/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages (from scikit-learn->torch-geometric) (1.4.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/aurelien.stumpf/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages (from aiohttp->torch-geometric) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0; python_version < "3.11" in /home/aurelien.stumpf/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages (from aiohttp->torch-geometric) (4.0.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/aurelien.stumpf/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages (from aiohttp->torch-geometric) (6.0.5)
# Requirement already satisfied: attrs>=17.3.0 in /home/aurelien.stumpf/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages (from aiohttp->torch-geometric) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/aurelien.stumpf/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages (from aiohttp->torch-geometric) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/aurelien.stumpf/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages (from aiohttp->torch-geometric) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/aurelien.stumpf/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages (from requests->torch-geometric) (3.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/aurelien.stumpf/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages (from requests->torch-geometric) (2024.6.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/aurelien.stumpf/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages (from requests->torch-geometric) (2.2.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/aurelien.stumpf/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages (from requests->torch-geometric) (3.7)
# Installing collected packages: torch-geometric
# Successfully installed torch-geometric-2.5.3
