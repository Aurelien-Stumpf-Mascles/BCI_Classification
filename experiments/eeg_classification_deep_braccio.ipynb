# %%
import mne
from mne.io import concatenate_raws, read_raw_edf
import matplotlib.pyplot as plt
import mne.viz
import os
import os.path as op
from mne.preprocessing import (ICA, create_eog_epochs, create_ecg_epochs,
                               corrmap)
from mne.time_frequency import tfr_multitaper
from mne.stats import permutation_cluster_1samp_test as pcluster_test
from mne.datasets import fetch_fsaverage

import torch
from torcheeg.models import EEGNet
from torcheeg.models import DGCNN
from torcheeg import transforms

import numpy as np
import matplotlib.pyplot as plt
import scipy.signal as signal
import scipy as sc
from matplotlib import cm
import matplotlib.colors as colors

from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.svm import SVC
from xgboost import XGBClassifier

import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)
# Out:
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages/xgboost/core.py:265: FutureWarning: Your system has an old version of glibc (< 2.28). We will stop supporting Linux distros with glibc older than 2.28 after **May 31, 2025**. Please upgrade to a recent Linux distro (with glibc 2.28+) to use future versions of XGBoost.
# Note: You have installed the 'manylinux2014' variant of XGBoost. Certain features such as GPU algorithms or federated learning are not available. To use these features, please upgrade to a recent Linux distro with glibc 2.28+, and install the 'manylinux_2_28' variant.
#   warnings.warn(

# %%
import sys 
sys.path.append("/home/aurelien.stumpf/Development/BCI_Classification/")
from eeg_project_package import dataset, models, training

# %%
import importlib
importlib.reload(dataset)
importlib.reload(training)
# Out:
# <module 'eeg_project_package.training' from '/home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/training.py'>

# %% [markdown]
# ## Check Loading of Physio Dataset Files

# %%
#Define the parameters
subject = 1  # use data from subject 1
runs = [6, 10, 14]  # use only hand and feet motor imagery runs

#Get data and locate in to given path
input_fname1 =  "/network/lustre/iss02/aramis/projects/cracknetworks/sub-01/ses-01/EEG/Test-[2022.03.28-17.46.29].edf"
#Read raw data files where each file contains a run
raws = read_raw_edf(input_fname1, preload=True)
#Combine all loaded runs
#raw_obj = concatenate_raws(raws)
raw_obj = raws

raw_data = raw_obj.get_data()
print("Number of channels: ", str(len(raw_data)))
print("Number of samples: ", str(len(raw_data)))

#Plot epochs & PSD
raw_obj.plot(duration=120, n_channels=15, scalings=dict(eeg=420e-6))
raw_obj.plot_psd(average=True)

# list of all channel names
list_all_ch_names = raw_obj.ch_names
# Out:
# Number of channels:  64
# Number of samples:  64
# <MNEBrowseFigure size 800x800 with 4 Axes>
# <MNELineFigure size 1000x350 with 1 Axes>

# %%
dict_channels = {'Fc5.' : 'FC5',
 'Fc3.' : 'FC3',
 'Fc1.' : 'FC1',
 'Fcz.' : 'FCz',
 'Fc2.' : 'FC2',
 'Fc4.' : 'FC4',
 'Fc6.' : 'FC6',
 'C5..' : 'C5',
 'C3..' : 'C3',
 'C1..' : 'C1',
 'Cz..' : 'Cz',
 'C2..' : 'C2',
 'C4..' : 'C4',
 'C6..' : 'C6',
 'Cp5.' : 'CP5',
 'Cp3.' : 'CP3',
 'Cp1.' : 'CP1',
 'Cpz.' : 'CPz',
 'Cp2.' : 'CP2',
 'Cp4.' : 'CP4',
 'Cp6.' : 'CP6',
 'Fp1.' : 'Fp1',
 'Fpz.' : 'Fpz',
 'Fp2.' : 'Fp2',
 'Af7.' : 'AF7',
 'Af3.' : 'AF3',
 'Afz.' : 'AFz',
 'Af4.' : 'AF4',
 'Af8.' : 'AF8',
 'F7..' : 'F7',
 'F5..' : 'F5',
 'F3..' : 'F3',
 'F1..' : 'F1',
 'Fz..' : 'Fz',
 'F2..' : 'F2',
 'F4..' : 'F4',
 'F6..' : 'F6',
 'F8..' : 'F8',
 'Ft7.' : 'FT7',
 'Ft8.' : 'FT8',
 'T7..' : 'T7',
 'T8..' : 'T8',
 'T9..' : 'T9',
 'T10.' : 'T10',
 'Tp7.' : 'TP7',
 'Tp8.' : 'TP8',
 'P7..' : 'P7',
 'P5..' : 'P5',
 'P3..' : 'P3',
 'P1..' : 'P1',
 'Pz..' : 'Pz',
 'P2..' : 'P2',
 'P4..' : 'P4',
 'P6..' : 'P6',
 'P8..' : 'P8',
 'Po7.' : 'PO7',
 'Po3.' : 'PO3',
 'Poz.' : 'POz',
 'Po4.' : 'PO4',
 'Po8.' : 'PO8',
 'O1..' : 'O1',
 'Oz..' : 'Oz',
 'O2..' : 'O2',
 'Iz..' : 'Iz'}

# Make ordered dict of channels
dict_channels_ordered = dict(sorted(dict_channels.items()))

# %% [markdown]
# ## Time Analysis

# %%
list_name_channels = ["Cp1.","Cp3.","Cp5.","C1..","C3..","C5..","C2..","Cp2.","Cz..","Fcz.","C4..","Cp4."]
ch_names = raw_obj.info['ch_names']
#list_idx_channels = [ch_names.index(name) for name in list_name_channels]
list_idx_channels = list(range(0, 64))

task_type = "imaginary_left/right"
folder_path = "/network/lustre/iss02/aramis/projects/cracknetworks/"

if task_type == "imaginary_feet/hand":
    num_sessions = [1,2,3]
    num_train_subjects = list(range(1, 8))
    num_test_subjects = list(range(8,14))
elif task_type == "imaginary_left/right":
    num_sessions = [1,2,3]
    num_train_subjects = [1,2,3,5,6,7]   
    num_test_subjects = [8,10,11,13,14]
list_labels = ['OVTK_GDF_Left','OVTK_GDF_Right']

torch_trainset = dataset.Braccio_Dataset_Multi_Subject(folder_path, num_train_subjects, num_sessions, list_idx_channels, list_labels, feature_type="time")
torch_testset = dataset.Braccio_Dataset_Multi_Subject(folder_path, num_test_subjects, num_sessions, list_idx_channels, list_labels, feature_type="time")
trainloader = torch.utils.data.DataLoader(torch_trainset, batch_size=16, shuffle=True, num_workers=2)
testloader = torch.utils.data.DataLoader(torch_testset, batch_size=16, shuffle=True, num_workers=2)
# Out:
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 19
#      16     num_test_subjects = [8,10,11,13,14]
#      17 list_labels = ['OVTK_GDF_Left','OVTK_GDF_Right']
# ---> 19 torch_trainset = dataset.Braccio_Dataset_Multi_Subject(folder_path, num_train_subjects, num_sessions, list_idx_channels, list_labels, feature_type="time")
#      20 torch_testset = dataset.Braccio_Dataset_Multi_Subject(folder_path, num_test_subjects, num_sessions, list_idx_channels, list_labels, feature_type="time")
#      21 trainloader = torch.utils.data.DataLoader(torch_trainset, batch_size=16, shuffle=True, num_workers=2)
#
# File ~/Development/BCI_Classification/eeg_project_package/dataset.py:249, in Braccio_Dataset_Multi_Subject.__init__(self, parent_folder_path, num_subjects, num_sessions, list_idx_channels, list_labels, feature_type)
#     247 # Choose the type of feature to extract
#     248 if feature_type == "time":
# --> 249     self.features,self.labels = time_dataset_creator(self.file_list,list_idx_channels,list_labels)
#     250 if feature_type == "psd":
#     251     self.features,self.labels,self.freqs = psd_dataset_creator(self.file_list,list_idx_channels,list_labels)
#
# File ~/Development/BCI_Classification/eeg_project_package/dataset.py:37, in time_dataset_creator(files, list_idx_channels, list_labels, freq)
#      35 try :
#      36     for event_name in list_labels:
# ---> 37         raw_training, events_from_annot,event_id = load_file_eeg(filepath = file)
#      38         tmin = 0
#      39         tmax = 4
#
# File ~/Development/BCI_Classification/eeg_project_package/dataset.py:11, in load_file_eeg(filepath)
#      10 def load_file_eeg(filepath):
# ---> 11     raw_Training_EEG =  mne.io.read_raw_edf(filepath, preload=True, verbose=False)
#      12     events_from_annot,event_id = mne.events_from_annotations(raw_Training_EEG,event_id='auto')
#      13     return raw_Training_EEG, events_from_annot,event_id
#
# File ~/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages/mne/io/edf/edf.py:1675, in read_raw_edf(input_fname, eog, misc, stim_channel, exclude, infer_types, include, preload, units, encoding, verbose)
#    1673 if ext != "edf":
#    1674     raise NotImplementedError(f"Only EDF files are supported, got {ext}.")
# -> 1675 return RawEDF(
#    1676     input_fname=input_fname,
#    1677     eog=eog,
#    1678     misc=misc,
#    1679     stim_channel=stim_channel,
#    1680     exclude=exclude,
#    1681     infer_types=infer_types,
#    1682     preload=preload,
#    1683     include=include,
#    1684     units=units,
#    1685     encoding=encoding,
#    1686     verbose=verbose,
#    1687 )
#
# File <decorator-gen-179>:10, in __init__(self, input_fname, eog, misc, stim_channel, exclude, infer_types, preload, include, units, encoding, verbose)
#
# File ~/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages/mne/io/edf/edf.py:183, in RawEDF.__init__(self, input_fname, eog, misc, stim_channel, exclude, infer_types, preload, include, units, encoding, verbose)
#     181 # Raw attributes
#     182 last_samps = [edf_info["nsamples"] - 1]
# --> 183 super().__init__(
#     184     info,
#     185     preload,
#     186     filenames=[input_fname],
#     187     raw_extras=[edf_info],
#     188     last_samps=last_samps,
#     189     orig_format="int",
#     190     orig_units=orig_units,
#     191     verbose=verbose,
#     192 )
#     194 # Read annotations from file and set it
#     195 if len(edf_info["tal_idx"]) > 0:
#     196     # Read TAL data exploiting the header info (no regexp)
#
# File <decorator-gen-162>:10, in __init__(self, info, preload, first_samps, last_samps, filenames, raw_extras, orig_format, dtype, buffer_size_sec, orig_units, verbose)
#
# File ~/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages/mne/io/base.py:309, in BaseRaw.__init__(self, info, preload, first_samps, last_samps, filenames, raw_extras, orig_format, dtype, buffer_size_sec, orig_units, verbose)
#     307 # If we have True or a string, actually do the preloading
#     308 if load_from_disk:
# --> 309     self._preload_data(preload)
#     310 self._init_kwargs = _get_argvalues()
#
# File ~/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages/mne/io/base.py:604, in BaseRaw._preload_data(self, preload)
#     599     data_buffer = None
#     600 logger.info(
#     601     "Reading %d ... %d  =  %9.3f ... %9.3f secs..."
#     602     % (0, len(self.times) - 1, 0.0, self.times[-1])
#     603 )
# --> 604 self._data = self._read_segment(data_buffer=data_buffer)
#     605 assert len(self._data) == self.info["nchan"]
#     606 self.preload = True
#
# File <decorator-gen-164>:12, in _read_segment(self, start, stop, sel, data_buffer, verbose)
#
# File ~/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages/mne/io/base.py:480, in BaseRaw._read_segment(***failed resolving arguments***)
#     478     # reindex back to original file
#     479     orig_idx = _convert_slice(self._read_picks[fi][need_idx])
# --> 480     _ReadSegmentFileProtector(self)._read_segment_file(
#     481         data[:, this_sl],
#     482         orig_idx,
#     483         fi,
#     484         int(start_file),
#     485         int(stop_file),
#     486         cals,
#     487         mult,
#     488     )
#     489     offset += n_read
#     490 return data
#
# File ~/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages/mne/io/base.py:2514, in _ReadSegmentFileProtector._read_segment_file(self, data, idx, fi, start, stop, cals, mult)
#    2513 def _read_segment_file(self, data, idx, fi, start, stop, cals, mult):
# -> 2514     return self.__raw.__class__._read_segment_file(
#    2515         self, data, idx, fi, start, stop, cals, mult
#    2516     )
#
# File ~/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages/mne/io/edf/edf.py:216, in RawEDF._read_segment_file(self, data, idx, fi, start, stop, cals, mult)
#     214 def _read_segment_file(self, data, idx, fi, start, stop, cals, mult):
#     215     """Read a chunk of raw data."""
# --> 216     return _read_segment_file(
#     217         data,
#     218         idx,
#     219         fi,
#     220         start,
#     221         stop,
#     222         self._raw_extras[fi],
#     223         self._filenames[fi],
#     224         cals,
#     225         mult,
#     226     )
#
# File ~/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages/mne/io/edf/edf.py:431, in _read_segment_file(data, idx, fi, start, stop, raw_extras, filenames, cals, mult)
#     429         # note how many samples have been read
#     430         smp_read = n_smp_read[orig_idx]
# --> 431         ones[orig_idx, smp_read : smp_read + len(one_i)] = one_i
#     432         n_smp_read[orig_idx] += len(one_i)
#     434 # skip if no data was requested, ie. only annotations were read
#
# KeyboardInterrupt:

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
criterion = torch.nn.CrossEntropyLoss()
model = EEGNet(chunk_size=2001,
               num_electrodes=64,
               dropout=0,
               kernel_1=64,
               kernel_2=16,
               F1=8,
               F2=16,
               D=2,
               num_classes=2)
model.to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
#scheduler = torch.optim.lr_scheduler.MultiStepLR(optimizer, milestones=[20, 50], gamma=0.1)
scheduler = torch.optim.lr_scheduler.MultiplicativeLR(optimizer, lr_lambda=lambda epoch: 0.95)
training.train_model(model, trainloader, testloader, device, criterion, 200, optimizer, scheduler)
# Out:
# Epoch 0:   0%|          | 0/178 [00:00<?, ?batch/s]
# Epoch 0: 100%|██████████| 178/178 [00:24<00:00,  7.14batch/s, accuracy=0.522, loss=0.0678]
# Epoch 0
# lr:  0.0095
# -------------------------
# Train set: Avg. loss: 0.0489, Balanced Accuracy: 0.5639045238494873 (56%)
# Test set: Avg. loss: 0.0521, Balanced Accuracy: 0.5182453989982605 (52%)
# -------------------------
# Epoch 1: 100%|██████████| 178/178 [00:25<00:00,  7.09batch/s, accuracy=0.557, loss=0.0439]
# Epoch 2: 100%|██████████| 178/178 [00:25<00:00,  7.10batch/s, accuracy=0.554, loss=0.0425]
# Epoch 3: 100%|██████████| 178/178 [00:25<00:00,  7.09batch/s, accuracy=0.559, loss=0.0427]
# Epoch 4: 100%|██████████| 178/178 [00:24<00:00,  7.15batch/s, accuracy=0.548, loss=0.0423]
# Epoch 5: 100%|██████████| 178/178 [00:24<00:00,  7.13batch/s, accuracy=0.569, loss=0.0425]
# Epoch 6: 100%|██████████| 178/178 [00:24<00:00,  7.15batch/s, accuracy=0.561, loss=0.0425]
# Epoch 7: 100%|██████████| 178/178 [00:24<00:00,  7.15batch/s, accuracy=0.573, loss=0.0422]
# Epoch 8: 100%|██████████| 178/178 [00:24<00:00,  7.14batch/s, accuracy=0.589, loss=0.0413]
# Epoch 9: 100%|██████████| 178/178 [00:24<00:00,  7.13batch/s, accuracy=0.606, loss=0.0409]
# Epoch 10: 100%|██████████| 178/178 [00:24<00:00,  7.14batch/s, accuracy=0.615, loss=0.0409]
# Epoch 10
# lr:  0.005688000922764597
# -------------------------
# Train set: Avg. loss: 0.0394, Balanced Accuracy: 0.6411516666412354 (64%)
# Test set: Avg. loss: 0.0436, Balanced Accuracy: 0.561904788017273 (56%)
# -------------------------
# Epoch 11: 100%|██████████| 178/178 [00:24<00:00,  7.13batch/s, accuracy=0.639, loss=0.0397]
# Epoch 12: 100%|██████████| 178/178 [00:24<00:00,  7.13batch/s, accuracy=0.65, loss=0.0395]
# Epoch 13: 100%|██████████| 178/178 [00:24<00:00,  7.14batch/s, accuracy=0.669, loss=0.0381]
# Epoch 14: 100%|██████████| 178/178 [00:24<00:00,  7.13batch/s, accuracy=0.679, loss=0.0378]
# Epoch 15: 100%|██████████| 178/178 [00:24<00:00,  7.13batch/s, accuracy=0.679, loss=0.0374]
# Epoch 16: 100%|██████████| 178/178 [00:24<00:00,  7.14batch/s, accuracy=0.695, loss=0.0365]
# Epoch 17: 100%|██████████| 178/178 [00:25<00:00,  7.12batch/s, accuracy=0.703, loss=0.036]
# Epoch 18: 100%|██████████| 178/178 [00:25<00:00,  7.12batch/s, accuracy=0.716, loss=0.0351]
# Epoch 19: 100%|██████████| 178/178 [00:24<00:00,  7.14batch/s, accuracy=0.71, loss=0.0351]
# Epoch 20: 100%|██████████| 178/178 [00:24<00:00,  7.14batch/s, accuracy=0.705, loss=0.0358]
# Epoch 20
# lr:  0.0034056162628811476
# -------------------------
# Train set: Avg. loss: 0.0342, Balanced Accuracy: 0.726123571395874 (73%)
# Test set: Avg. loss: 0.0464, Balanced Accuracy: 0.580703854560852 (58%)
# -------------------------
# Epoch 21: 100%|██████████| 178/178 [00:24<00:00,  7.14batch/s, accuracy=0.724, loss=0.0341]
# Epoch 22: 100%|██████████| 178/178 [00:24<00:00,  7.15batch/s, accuracy=0.732, loss=0.034]
# Epoch 23: 100%|██████████| 178/178 [00:24<00:00,  7.13batch/s, accuracy=0.73, loss=0.034]
# Epoch 24: 100%|██████████| 178/178 [00:24<00:00,  7.14batch/s, accuracy=0.747, loss=0.0323]
# Epoch 25: 100%|██████████| 178/178 [00:24<00:00,  7.14batch/s, accuracy=0.751, loss=0.0319]
# Epoch 26: 100%|██████████| 178/178 [00:24<00:00,  7.14batch/s, accuracy=0.748, loss=0.0317]
# Epoch 27: 100%|██████████| 178/178 [00:24<00:00,  7.14batch/s, accuracy=0.762, loss=0.0307]
# Epoch 28: 100%|██████████| 178/178 [00:24<00:00,  7.15batch/s, accuracy=0.766, loss=0.0304]
# Epoch 29: 100%|██████████| 178/178 [00:24<00:00,  7.12batch/s, accuracy=0.774, loss=0.0296]
# Epoch 30: 100%|██████████| 178/178 [00:24<00:00,  7.15batch/s, accuracy=0.784, loss=0.0287]
# Epoch 30
# lr:  0.0020390682574579037
# -------------------------
# Train set: Avg. loss: 0.0268, Balanced Accuracy: 0.7977527976036072 (80%)
# Test set: Avg. loss: 0.0539, Balanced Accuracy: 0.5895372629165649 (59%)
# -------------------------
# Epoch 31: 100%|██████████| 178/178 [00:24<00:00,  7.13batch/s, accuracy=0.781, loss=0.0282]
# Epoch 32: 100%|██████████| 178/178 [00:24<00:00,  7.14batch/s, accuracy=0.794, loss=0.0273]
# Epoch 33: 100%|██████████| 178/178 [00:24<00:00,  7.14batch/s, accuracy=0.79, loss=0.027]
# Epoch 34: 100%|██████████| 178/178 [00:24<00:00,  7.13batch/s, accuracy=0.8, loss=0.0266]
# Epoch 35: 100%|██████████| 178/178 [00:24<00:00,  7.14batch/s, accuracy=0.799, loss=0.0261]
# Epoch 36: 100%|██████████| 178/178 [00:24<00:00,  7.14batch/s, accuracy=0.809, loss=0.026]
# Epoch 37: 100%|██████████| 178/178 [00:24<00:00,  7.19batch/s, accuracy=0.821, loss=0.0245]
# Epoch 38: 100%|██████████| 178/178 [00:25<00:00,  7.09batch/s, accuracy=0.813, loss=0.0247]
# Epoch 39: 100%|██████████| 178/178 [00:24<00:00,  7.14batch/s, accuracy=0.824, loss=0.024]
# Epoch 40: 100%|██████████| 178/178 [00:24<00:00,  7.14batch/s, accuracy=0.83, loss=0.0236]
# Epoch 40
# lr:  0.0012208654873684791
# -------------------------
# Train set: Avg. loss: 0.0217, Balanced Accuracy: 0.8444522619247437 (84%)
# Test set: Avg. loss: 0.0589, Balanced Accuracy: 0.5961682796478271 (60%)
# -------------------------
# Epoch 41: 100%|██████████| 178/178 [00:24<00:00,  7.14batch/s, accuracy=0.834, loss=0.0227]
# Epoch 42: 100%|██████████| 178/178 [00:24<00:00,  7.12batch/s, accuracy=0.837, loss=0.0224]
# Epoch 43: 100%|██████████| 178/178 [00:24<00:00,  7.16batch/s, accuracy=0.837, loss=0.0222]
# Epoch 44: 100%|██████████| 178/178 [00:24<00:00,  7.14batch/s, accuracy=0.847, loss=0.0217]
# Epoch 45: 100%|██████████| 178/178 [00:24<00:00,  7.15batch/s, accuracy=0.854, loss=0.0211]
# Epoch 46: 100%|██████████| 178/178 [00:24<00:00,  7.15batch/s, accuracy=0.849, loss=0.0212]
# Epoch 47: 100%|██████████| 178/178 [00:24<00:00,  7.14batch/s, accuracy=0.856, loss=0.0202]
# Epoch 48: 100%|██████████| 178/178 [00:24<00:00,  7.14batch/s, accuracy=0.86, loss=0.0203]
# Epoch 49: 100%|██████████| 178/178 [00:24<00:00,  7.14batch/s, accuracy=0.864, loss=0.0196]
# Epoch 50: 100%|██████████| 178/178 [00:24<00:00,  7.14batch/s, accuracy=0.864, loss=0.0194]
# Epoch 50
# lr:  0.0007309772651287747
# -------------------------
# Train set: Avg. loss: 0.0180, Balanced Accuracy: 0.879564642906189 (88%)
# Test set: Avg. loss: 0.0694, Balanced Accuracy: 0.6007791757583618 (60%)
# -------------------------
# Epoch 51: 100%|██████████| 178/178 [00:24<00:00,  7.14batch/s, accuracy=0.86, loss=0.0206]
# Epoch 52: 100%|██████████| 178/178 [00:24<00:00,  7.14batch/s, accuracy=0.875, loss=0.0189]
# Epoch 53: 100%|██████████| 178/178 [00:24<00:00,  7.14batch/s, accuracy=0.876, loss=0.0185]
# Epoch 54: 100%|██████████| 178/178 [00:24<00:00,  7.13batch/s, accuracy=0.875, loss=0.0183]
# Epoch 55: 100%|██████████| 178/178 [00:24<00:00,  7.15batch/s, accuracy=0.882, loss=0.0177]
# Epoch 56: 100%|██████████| 178/178 [00:24<00:00,  7.15batch/s, accuracy=0.881, loss=0.0176]
# Epoch 57: 100%|██████████| 178/178 [00:24<00:00,  7.13batch/s, accuracy=0.879, loss=0.0183]
# Epoch 58: 100%|██████████| 178/178 [00:24<00:00,  7.13batch/s, accuracy=0.883, loss=0.0171]
# Epoch 59: 100%|██████████| 178/178 [00:24<00:00,  7.14batch/s, accuracy=0.888, loss=0.0167]
# Epoch 60: 100%|██████████| 178/178 [00:24<00:00,  7.13batch/s, accuracy=0.89, loss=0.0164]
# Epoch 60
# lr:  0.0004376630903760434
# -------------------------
# Train set: Avg. loss: 0.0158, Balanced Accuracy: 0.8985252976417542 (90%)
# Test set: Avg. loss: 0.0810, Balanced Accuracy: 0.5953852534294128 (60%)
# -------------------------
# Epoch 61: 100%|██████████| 178/178 [00:24<00:00,  7.13batch/s, accuracy=0.89, loss=0.0165]
# Epoch 62:  43%|████▎     | 77/178 [00:11<00:14,  6.90batch/s, accuracy=0.881, loss=0.00734]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[117], line 16
#      14 #scheduler = torch.optim.lr_scheduler.MultiStepLR(optimizer, milestones=[20, 50], gamma=0.1)
#      15 scheduler = torch.optim.lr_scheduler.MultiplicativeLR(optimizer, lr_lambda=lambda epoch: 0.95)
# ---> 16 training.train_model(model, trainloader, testloader, device, criterion, 200, optimizer, scheduler)
#
# File ~/Development/BCI_Classification/eeg_project_package/training.py:32, in train_model(model, trainloader, testloader, device, criterion, epochs, optimizer, scheduler, print_epoch)
#      29 loss.backward()
#      30 optimizer.step()
# ---> 32 total_loss += loss.item()/len(trainloader.dataset)
#      33 _, predicted = torch.max(outputs, 1)
#      35 # compute accuracy
#
# KeyboardInterrupt:

# %%
def get_positions_from_channel_list(channel_list, montage):
    dict_positions = montage.get_positions()["ch_pos"]
    positions = []
    for channel in channel_list:
        positions.append(dict_positions[dict_channels[channel]])
    return positions

# %%
montage = mne.channels.make_standard_montage('standard_1020')

def get_positions_from_channel_list(channel_list, montage):
    dict_positions = montage.get_positions()["ch_pos"]
    positions = []
    for channel in channel_list:
        positions.append(dict_positions[channel])
    return positions

ch_positions = np.array(get_positions_from_channel_list(list_all_ch_names, montage))

# %%
# display head topomap of all spatial filters 
fig, ax = plt.subplots(4, 4, figsize=(10, 10))

for i in range(4):
    for j in range(4):
        mne.viz.plot_topomap(
            model.block1[2].weight.data[i + 4 * j].cpu().numpy().flatten(),
            ch_positions[:, :2],
            show=False,
            axes=ax[i, j]
        )

plt.show()

# %% [markdown]
# ## PSD Dataset

# %%
list_name_channels = ["CP1","CP3","CP5","C1","C3","C5","C2","CP2","Cz","FCz","C4","CP4"]
ch_names = raw_obj.info['ch_names']
list_idx_channels = [ch_names.index(name) for name in list_name_channels]

trainset = dataset.Braccio_Dataset_Multi_Subject(folder_path, num_train_subjects, num_sessions, list_idx_channels, list_labels, feature_type="psd")
testset = dataset.Braccio_Dataset_Multi_Subject(folder_path, num_test_subjects, num_sessions, list_idx_channels, list_labels, feature_type="psd")
trainloader = torch.utils.data.DataLoader(trainset, batch_size=16, shuffle=True, num_workers=2)
testloader = torch.utils.data.DataLoader(testset, batch_size=16, shuffle=True, num_workers=2)
# Out:
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# Error in file:  /network/lustre/iss02/aramis/projects/cracknetworks/sub-03/ses-01/EEG/Test-[2022.03.15-16.39.19].edf
# could not convert string to float: './.).(-*'
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# Error in file:  /network/lustre/iss02/aramis/projects/cracknetworks/sub-01/ses-02/EEG/Train-[2022.04.04-16.15.17].edf
# 'Event name "OVTK_GDF_Left" could not be found. The following events are present in the data: OVTK_StimulationId_ExperimentStart, OVTK_StimulationId_BaselineStart/OVTK_StimulationId_Beep'
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# Error in file:  /network/lustre/iss02/aramis/projects/cracknetworks/sub-01/ses-02/EEG/Train-[2022.04.04-16.14.01].edf
# 'Event name "OVTK_GDF_Left" could not be found. The following events are present in the data: OVTK_StimulationId_ExperimentStart, OVTK_StimulationId_BaselineStart/OVTK_StimulationId_Beep'
# Error in file:  /network/lustre/iss02/aramis/projects/cracknetworks/sub-01/ses-02/EEG/Test-[2022.04.04-16.52.15].edf
# 'Event name "OVTK_GDF_Left" could not be found. The following events are present in the data: OVTK_GDF_Feedback_Continuous, OVTK_GDF_Right, OVTK_StimulationId_ExperimentStart, OVTK_StimulationId_BaselineStart/OVTK_StimulationId_Beep, OVTK_StimulationId_BaselineStop/OVTK_StimulationId_Beep, OVTK_GDF_Cross_On_Screen/OVTK_GDF_Start_Of_Trial/OVTK_StimulationId_Beep, OVTK_GDF_End_Of_Trial/OVTK_StimulationId_VisualStimulationStar'
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (4, 64, 2001)
# (4, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (9, 64, 2001)
# (8, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (1, 64, 2001)
# (2, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# Error in file:  /network/lustre/iss02/aramis/projects/cracknetworks/sub-06/ses-02/EEG/Test-[2022.05.10-16.09.32].edf
# 'Event name "OVTK_GDF_Left" could not be found. The following events are present in the data: OVTK_StimulationId_ExperimentStart, OVTK_StimulationId_BaselineStart/OVTK_StimulationId_Beep'
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# Error in file:  /network/lustre/iss02/aramis/projects/cracknetworks/sub-13/ses-01/EEG/Test-[2022.06.23-15.46.51].edf
# 'Event name "OVTK_GDF_Left" could not be found. The following events are present in the data: OVTK_StimulationId_ExperimentStart, OVTK_StimulationId_BaselineStart/OVTK_StimulationId_Beep'
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# Error in file:  /network/lustre/iss02/aramis/projects/cracknetworks/sub-08/ses-02/EEG/Test-[2022.05.18-15.56.08].edf
# 'Event name "OVTK_GDF_Left" could not be found. The following events are present in the data: OVTK_StimulationId_ExperimentStart, OVTK_StimulationId_BaselineStart/OVTK_StimulationId_Beep'
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# Error in file:  /network/lustre/iss02/aramis/projects/cracknetworks/sub-10/ses-02/EEG/Test-[2022.07.19-16.20.04].edf
# 'Event name "OVTK_GDF_Left" could not be found. The following events are present in the data: OVTK_StimulationId_ExperimentStart, OVTK_StimulationId_BaselineStart/OVTK_StimulationId_Beep'
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# Error in file:  /network/lustre/iss02/aramis/projects/cracknetworks/sub-11/ses-02/EEG/Train-[2022.06.27-15.00.42].edf
# 'Event name "OVTK_GDF_Left" could not be found. The following events are present in the data: OVTK_StimulationId_ExperimentStart, OVTK_StimulationId_BaselineStart/OVTK_StimulationId_Beep'
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# Error in file:  /network/lustre/iss02/aramis/projects/cracknetworks/sub-14/ses-02/EEG/Test-[2022.04.28-16.18.42].edf
# [Errno 5] Input/output error: '/network/lustre/iss02/aramis/projects/cracknetworks/sub-14/ses-02/EEG/Test-[2022.04.28-16.18.42].edf'
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (1, 64, 2001)
# (1, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# Error in file:  /network/lustre/iss02/aramis/projects/cracknetworks/sub-11/ses-03/EEG/Test-[2022.07.04-16.11.03].edf
# 'Event name "OVTK_GDF_Left" could not be found. The following events are present in the data: OVTK_StimulationId_ExperimentStart'
# (10, 64, 2001)
# (10, 64, 2001)
# (6, 64, 2001)
# (4, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)
# (10, 64, 2001)

# %%
X_train = trainset.features.reshape(trainset.features.shape[0], -1)
y_train = trainset.labels
X_test = testset.features.reshape(testset.features.shape[0], -1)
y_test = testset.labels

# Train LDA classifier
clf = LinearDiscriminantAnalysis()
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
acc = np.mean(y_pred == y_test)
print("LDA Accuracy: ", acc)

# Train SVM classifier
clf = SVC(kernel='linear')
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
acc = np.mean(y_pred == y_test)
print("SVM Accuracy: ", acc)

# Train XGBoost classifier
bst = XGBClassifier(n_estimators=100, max_depth=5, learning_rate=0.0005, objective='binary:logistic')
bst.fit(X_train, y_train)
preds = bst.predict(X_test)
acc = np.mean(preds == y_test)
print("XGBoost Accuracy: ", acc)
# Out:
# LDA Accuracy:  0.544732441471572
# SVM Accuracy:  0.584866220735786
# XGBoost Accuracy:  0.483695652173913

# %%
plt.bar(range(len(bst.feature_importances_)), bst.feature_importances_)
plt.show()

# %% [markdown]
# ## DGCNN

# %%
list_name_channels = ["CP1","CP3","CP5","C1","C3","C5","C2","CP2","Cz","FCz","C4","CP4"]
ch_names = raw_obj.info['ch_names']
list_idx_channels = [ch_names.index(name) for name in list_name_channels]
#list_idx_channels = list(range(0, 64))

task_type = "imaginary_left/right"
folder_path = "/network/lustre/iss02/aramis/projects/cracknetworks/"

if task_type == "imaginary_feet/hand":
    num_sessions = [1,2,3]
    num_train_subjects = list(range(1, 8))
    num_test_subjects = list(range(8,14))
elif task_type == "imaginary_left/right":
    num_sessions = [1,2,3]
    num_train_subjects = [1,2,3,5,6,7]   
    num_test_subjects = [8,10,11,13,14]
list_labels = ['OVTK_GDF_Left','OVTK_GDF_Right']

torch_trainset = dataset.Braccio_Dataset_Multi_Subject(folder_path, num_train_subjects, num_sessions, list_idx_channels, list_labels, feature_type="band")
torch_trainset.transform_dataset_numpy_to_torch()
torch_testset = dataset.Braccio_Dataset_Multi_Subject(folder_path, num_test_subjects, num_sessions, list_idx_channels, list_labels, feature_type="band")
torch_testset.transform_dataset_numpy_to_torch()
trainloader = torch.utils.data.DataLoader(torch_trainset, batch_size=16, shuffle=True, num_workers=2)
testloader = torch.utils.data.DataLoader(torch_testset, batch_size=16, shuffle=True, num_workers=2)
# Out:
# /network/lustre/iss02/aramis/projects/cracknetworks/sub-01/ses-01/EEG/Train-[2022.03.28-17.08.38].edf
# (10, 12, 5)
# (10, 12, 5)
# /network/lustre/iss02/aramis/projects/cracknetworks/sub-01/ses-01/EEG/Train-[2022.03.28-16.58.43].edf
# (10, 12, 5)
# (10, 12, 5)
# /network/lustre/iss02/aramis/projects/cracknetworks/sub-01/ses-01/EEG/Test-[2022.03.28-18.23.31].edf
# (10, 12, 5)
# (10, 12, 5)
# /network/lustre/iss02/aramis/projects/cracknetworks/sub-01/ses-01/EEG/Test-[2022.03.28-17.36.22].edf
# (10, 12, 5)
# (10, 12, 5)
# /network/lustre/iss02/aramis/projects/cracknetworks/sub-01/ses-01/EEG/Test-[2022.03.28-18.14.13].edf
# (10, 12, 5)
# (10, 12, 5)
# /network/lustre/iss02/aramis/projects/cracknetworks/sub-01/ses-01/EEG/Test-[2022.03.28-17.56.08].edf
# (10, 12, 5)
# (10, 12, 5)
# /network/lustre/iss02/aramis/projects/cracknetworks/sub-01/ses-01/EEG/Test-[2022.03.28-17.46.29].edf
# (10, 12, 5)
# (10, 12, 5)
# /network/lustre/iss02/aramis/projects/cracknetworks/sub-01/ses-01/EEG/Train-[2022.03.28-16.49.02].edf
# (10, 12, 5)
# (10, 12, 5)
# /network/lustre/iss02/aramis/projects/cracknetworks/sub-02/ses-01/EEG/Test-[2022.04.05-15.39.02].edf
# (10, 12, 5)
# (10, 12, 5)
# /network/lustre/iss02/aramis/projects/cracknetworks/sub-02/ses-01/EEG/Train-[2022.04.05-15.00.27].edf
# (10, 12, 5)
# (10, 12, 5)
# /network/lustre/iss02/aramis/projects/cracknetworks/sub-02/ses-01/EEG/Test-[2022.04.05-16.05.59].edf
# (10, 12, 5)
# (10, 12, 5)
# /network/lustre/iss02/aramis/projects/cracknetworks/sub-02/ses-01/EEG/Test-[2022.04.05-15.29.12].edf
# (10, 12, 5)
# (10, 12, 5)
# /network/lustre/iss02/aramis/projects/cracknetworks/sub-02/ses-01/EEG/Train-[2022.04.05-15.08.51].edf
# (10, 12, 5)
# (10, 12, 5)
# /network/lustre/iss02/aramis/projects/cracknetworks/sub-02/ses


# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
criterion = torch.nn.CrossEntropyLoss()
model = DGCNN(in_channels=5, num_electrodes=12, hid_channels=128, num_layers=3, num_classes=2)
model.to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
scheduler = torch.optim.lr_scheduler.MultiplicativeLR(optimizer, lr_lambda=lambda epoch: 0.95)
training.train_model(model, trainloader, testloader, device, criterion, 100, optimizer, scheduler)
# Out:
# Epoch 0:   0%|          | 0/178 [00:00<?, ?batch/s]
# Epoch 0: 100%|██████████| 178/178 [00:01<00:00, 93.39batch/s, accuracy=0.577, loss=0.044]
# Epoch 0
# lr:  0.0095
# -------------------------
# Train set: Avg. loss: 0.0422, Balanced Accuracy: 0.5990169048309326 (60%)
# Test set: Avg. loss: 0.0429, Balanced Accuracy: 0.5536938309669495 (55%)
# -------------------------
# Epoch 1: 100%|██████████| 178/178 [00:02<00:00, 84.96batch/s, accuracy=0.573, loss=0.0421]
# Epoch 2: 100%|██████████| 178/178 [00:02<00:00, 81.79batch/s, accuracy=0.601, loss=0.0411]
# Epoch 3: 100%|██████████| 178/178 [00:02<00:00, 81.97batch/s, accuracy=0.644, loss=0.0393]
# Epoch 4: 100%|██████████| 178/178 [00:02<00:00, 80.86batch/s, accuracy=0.653, loss=0.0385]
# Epoch 5: 100%|██████████| 178/178 [00:02<00:00, 79.08batch/s, accuracy=0.68, loss=0.0371]
# Epoch 6: 100%|██████████| 178/178 [00:02<00:00, 80.77batch/s, accuracy=0.693, loss=0.0361]
# Epoch 7: 100%|██████████| 178/178 [00:02<00:00, 78.90batch/s, accuracy=0.711, loss=0.0352]
# Epoch 8: 100%|██████████| 178/178 [00:02<00:00, 79.00batch/s, accuracy=0.726, loss=0.0349]
# Epoch 9: 100%|██████████| 178/178 [00:02<00:00, 80.27batch/s, accuracy=0.724, loss=0.0342]
# Epoch 10: 100%|██████████| 178/178 [00:02<00:00, 80.30batch/s, accuracy=0.734, loss=0.0337]
# Epoch 10
# lr:  0.005688000922764597
# -------------------------
# Train set: Avg. loss: 0.0323, Balanced Accuracy: 0.740168571472168 (74%)
# Test set: Avg. loss: 0.0480, Balanced Accuracy: 0.5694431066513062 (57%)
# -------------------------
# Epoch 11: 100%|██████████| 178/178 [00:02<00:00, 81.21batch/s, accuracy=0.738, loss=0.0327]
# Epoch 12: 100%|██████████| 178/178 [00:02<00:00, 79.97batch/s, accuracy=0.749, loss=0.0319]
# Epoch 13: 100%|██████████| 178/178 [00:02<00:00, 76.70batch/s, accuracy=0.746, loss=0.0323]
# Epoch 14: 100%|██████████| 178/178 [00:02<00:00, 78.16batch/s, accuracy=0.754, loss=0.0316]
# Epoch 15: 100%|██████████| 178/178 [00:02<00:00, 77.12batch/s, accuracy=0.751, loss=0.0313]
# Epoch 16: 100%|██████████| 178/178 [00:02<00:00, 77.48batch/s, accuracy=0.761, loss=0.0308]
# Epoch 17: 100%|██████████| 178/178 [00:02<00:00, 80.32batch/s, accuracy=0.77, loss=0.0303]
# Epoch 18: 100%|██████████| 178/178 [00:02<00:00, 79.66batch/s, accuracy=0.765, loss=0.0301]
# Epoch 19: 100%|██████████| 178/178 [00:02<00:00, 80.10batch/s, accuracy=0.774, loss=0.0295]
# Epoch 20: 100%|██████████| 178/178 [00:02<00:00, 80.44batch/s, accuracy=0.779, loss=0.0293]
# Epoch 20
# lr:  0.0034056162628811476
# -------------------------
# Train set: Avg. loss: 0.0286, Balanced Accuracy: 0.7851123809814453 (79%)
# Test set: Avg. loss: 0.0559, Balanced Accuracy: 0.5820709466934204 (58%)
# -------------------------
# Epoch 21: 100%|██████████| 178/178 [00:01<00:00, 90.51batch/s, accuracy=0.786, loss=0.029]
# Epoch 22: 100%|██████████| 178/178 [00:02<00:00, 77.53batch/s, accuracy=0.779, loss=0.0287]
# Epoch 23: 100%|██████████| 178/178 [00:02<00:00, 78.21batch/s, accuracy=0.792, loss=0.0282]
# Epoch 24: 100%|██████████| 178/178 [00:02<00:00, 79.38batch/s, accuracy=0.797, loss=0.0275]
# Epoch 25: 100%|██████████| 178/178 [00:02<00:00, 81.67batch/s, accuracy=0.785, loss=0.029]
# Epoch 26: 100%|██████████| 178/178 [00:02<00:00, 78.43batch/s, accuracy=0.797, loss=0.0272]
# Epoch 27: 100%|██████████| 178/178 [00:02<00:00, 78.76batch/s, accuracy=0.803, loss=0.0267]
# Epoch 28: 100%|██████████| 178/178 [00:02<00:00, 79.36batch/s, accuracy=0.805, loss=0.0266]
# Epoch 29: 100%|██████████| 178/178 [00:02<00:00, 78.32batch/s, accuracy=0.808, loss=0.0261]
# Epoch 30: 100%|██████████| 178/178 [00:02<00:00, 80.52batch/s, accuracy=0.807, loss=0.0261]
# Epoch 30
# lr:  0.0020390682574579037
# -------------------------
# Train set: Avg. loss: 0.0255, Balanced Accuracy: 0.8212780952453613 (82%)
# Test set: Avg. loss: 0.0500, Balanced Accuracy: 0.5994554162025452 (60%)
# -------------------------
# Epoch 31: 100%|██████████| 178/178 [00:02<00:00, 81.18batch/s, accuracy=0.821, loss=0.0256]
# Epoch 32: 100%|██████████| 178/178 [00:02<00:00, 82.10batch/s, accuracy=0.812, loss=0.026]
# Epoch 33: 100%|██████████| 178/178 [00:02<00:00, 88.91batch/s, accuracy=0.82, loss=0.0251]
# Epoch 34: 100%|██████████| 178/178 [00:02<00:00, 84.00batch/s, accuracy=0.826, loss=0.0252]
# Epoch 35: 100%|██████████| 178/178 [00:02<00:00, 83.07batch/s, accuracy=0.823, loss=0.0247]
# Epoch 36: 100%|██████████| 178/178 [00:02<00:00, 81.29batch/s, accuracy=0.824, loss=0.0244]
# Epoch 37: 100%|██████████| 178/178 [00:02<00:00, 81.46batch/s, accuracy=0.827, loss=0.024]
# Epoch 38: 100%|██████████| 178/178 [00:02<00:00, 81.89batch/s, accuracy=0.833, loss=0.0236]
# Epoch 39: 100%|██████████| 178/178 [00:02<00:00, 72.18batch/s, accuracy=0.831, loss=0.0235]
# Epoch 40: 100%|██████████| 178/178 [00:02<00:00, 80.64batch/s, accuracy=0.837, loss=0.0232]
# Epoch 40
# lr:  0.0012208654873684791
# -------------------------
# Train set: Avg. loss: 0.0236, Balanced Accuracy: 0.8254915475845337 (83%)
# Test set: Avg. loss: 0.0610, Balanced Accuracy: 0.5966936349868774 (60%)
# -------------------------
# Epoch 41: 100%|██████████| 178/178 [00:02<00:00, 84.96batch/s, accuracy=0.838, loss=0.0232]
# Epoch 42: 100%|██████████| 178/178 [00:02<00:00, 79.57batch/s, accuracy=0.838, loss=0.023]
# Epoch 43: 100%|██████████| 178/178 [00:02<00:00, 78.03batch/s, accuracy=0.841, loss=0.0227]
# Epoch 44: 100%|██████████| 178/178 [00:02<00:00, 79.44batch/s, accuracy=0.84, loss=0.0225]
# Epoch 45: 100%|██████████| 178/178 [00:02<00:00, 79.29batch/s, accuracy=0.84, loss=0.0225]
# Epoch 46: 100%|██████████| 178/178 [00:02<00:00, 78.35batch/s, accuracy=0.851, loss=0.0222]
# Epoch 47: 100%|██████████| 178/178 [00:02<00:00, 82.59batch/s, accuracy=0.844, loss=0.0222]
# Epoch 48: 100%|██████████| 178/178 [00:02<00:00, 85.28batch/s, accuracy=0.847, loss=0.0218]
# Epoch 49: 100%|██████████| 178/178 [00:02<00:00, 78.70batch/s, accuracy=0.843, loss=0.0216]
# Epoch 50: 100%|██████████| 178/178 [00:02<00:00, 78.42batch/s, accuracy=0.851, loss=0.0215]
# Epoch 50
# lr:  0.0007309772651287747
# -------------------------
# Train set: Avg. loss: 0.0211, Balanced Accuracy: 0.8542836904525757 (85%)
# Test set: Avg. loss: 0.0673, Balanced Accuracy: 0.597022533416748 (60%)
# -------------------------
# Epoch 51: 100%|██████████| 178/178 [00:02<00:00, 80.55batch/s, accuracy=0.848, loss=0.0217]
# Epoch 52: 100%|██████████| 178/178 [00:02<00:00, 78.16batch/s, accuracy=0.853, loss=0.0213]
# Epoch 53: 100%|██████████| 178/178 [00:02<00:00, 77.96batch/s, accuracy=0.854, loss=0.0211]
# Epoch 54: 100%|██████████| 178/178 [00:02<00:00, 78.75batch/s, accuracy=0.857, loss=0.021]
# Epoch 55: 100%|██████████| 178/178 [00:02<00:00, 78.28batch/s, accuracy=0.855, loss=0.0208]
# Epoch 56: 100%|██████████| 178/178 [00:02<00:00, 77.40batch/s, accuracy=0.858, loss=0.0207]
# Epoch 57: 100%|██████████| 178/178 [00:02<00:00, 78.88batch/s, accuracy=0.856, loss=0.0207]
# Epoch 58: 100%|██████████| 178/178 [00:02<00:00, 80.00batch/s, accuracy=0.861, loss=0.0205]
# Epoch 59: 100%|██████████| 178/178 [00:02<00:00, 78.19batch/s, accuracy=0.861, loss=0.0205]
# Epoch 60: 100%|██████████| 178/178 [00:02<00:00, 78.87batch/s, accuracy=0.857, loss=0.0204]
# Epoch 60
# lr:  0.0004376630903760434
# -------------------------
# Train set: Avg. loss: 0.0199, Balanced Accuracy: 0.8658707737922668 (87%)
# Test set: Avg. loss: 0.0729, Balanced Accuracy: 0.6007945537567139 (60%)
# -------------------------
# Epoch 61: 100%|██████████| 178/178 [00:02<00:00, 78.25batch/s, accuracy=0.858, loss=0.0203]
# Epoch 62: 100%|██████████| 178/178 [00:02<00:00, 79.28batch/s, accuracy=0.864, loss=0.0202]
# Epoch 63:  32%|███▏      | 57/178 [00:00<00:02, 59.52batch/s, accuracy=0.874, loss=0.00602]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[147], line 7
#       5 optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
#       6 scheduler = torch.optim.lr_scheduler.MultiplicativeLR(optimizer, lr_lambda=lambda epoch: 0.95)
# ----> 7 training.train_model(model, trainloader, testloader, device, criterion, 100, optimizer, scheduler)
#
# File ~/Development/BCI_Classification/eeg_project_package/training.py:29, in train_model(model, trainloader, testloader, device, criterion, epochs, optimizer, scheduler, print_epoch)
#      26 loss = criterion(outputs,y)
#      28 optimizer.zero_grad()
# ---> 29 loss.backward()
#      30 optimizer.step()
#      32 total_loss += loss.item()/len(trainloader.dataset)
#
# File ~/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages/torch/_tensor.py:525, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     515 if has_torch_function_unary(self):
#     516     return handle_torch_function(
#     517         Tensor.backward,
#     518         (self,),
#    (...)
#     523         inputs=inputs,
#     524     )
# --> 525 torch.autograd.backward(
#     526     self, gradient, retain_graph, create_graph, inputs=inputs
#     527 )
#
# File ~/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages/torch/autograd/__init__.py:267, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     262     retain_graph = create_graph
#     264 # The reason we repeat the same comment below is that
#     265 # some Python versions print out the first line of a multi-line function
#     266 # calls in the traceback and some print out the last line
# --> 267 _engine_run_backward(
#     268     tensors,
#     269     grad_tensors_,
#     270     retain_graph,
#     271     create_graph,
#     272     inputs,
#     273     allow_unreachable=True,
#     274     accumulate_grad=True,
#     275 )
#
# File ~/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages/torch/autograd/graph.py:744, in _engine_run_backward(t_outputs, *args, **kwargs)
#     742     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     743 try:
# --> 744     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     745         t_outputs, *args, **kwargs
#     746     )  # Calls into the C++ engine to run the backward pass
#     747 finally:
#     748     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %% [markdown]
# # Coherence features

# %%
list_name_channels = ["CP1","CP3","CP5","C1","C3","C5","C2","CP2","Cz","FCz","C4","CP4"]
ch_names = raw_obj.info['ch_names']
list_idx_channels = [ch_names.index(name) for name in list_name_channels]

trainset = dataset.Braccio_Dataset_Multi_Subject(folder_path, num_train_subjects, num_sessions, list_idx_channels, list_labels, feature_type="coh")
testset = dataset.Braccio_Dataset_Multi_Subject(folder_path, num_test_subjects, num_sessions, list_idx_channels, list_labels, feature_type="coh")
trainloader = torch.utils.data.DataLoader(trainset, batch_size=16, shuffle=True, num_workers=2)
testloader = torch.utils.data.DataLoader(testset, batch_size=16, shuffle=True, num_workers=2)
# Out:
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# Error in file:  /network/lustre/iss02/aramis/projects/cracknetworks/sub-03/ses-01/EEG/Test-[2022.03.15-16.39.19].edf
# could not convert string to float: './.).(-*'
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# Error in file:  /network/lustre/iss02/aramis/projects/cracknetworks/sub-01/ses-02/EEG/Train-[2022.04.04-16.15.17].edf
# 'Event name "OVTK_GDF_Left" could not be found. The following events are present in the data: OVTK_StimulationId_ExperimentStart, OVTK_StimulationId_BaselineStart/OVTK_StimulationId_Beep'
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# Error in file:  /network/lustre/iss02/aramis/projects/cracknetworks/sub-01/ses-02/EEG/Train-[2022.04.04-16.14.01].edf
# 'Event name "OVTK_GDF_Left" could not be found. The following events are present in the data: OVTK_StimulationId_ExperimentStart, OVTK_StimulationId_BaselineStart/OVTK_StimulationId_Beep'
# Error in file:  /network/lustre/iss02/aramis/projects/cracknetworks/sub-01/ses-02/EEG/Test-[2022.04.04-16.52.15].edf
# 'Event name "OVTK_GDF_Left" could not be found. The following events are present in the data: OVTK_GDF_Feedback_Continuous, OVTK_GDF_Right, OVTK_StimulationId_ExperimentStart, OVTK_StimulationId_BaselineStart/OVTK_StimulationId_Beep, OVTK_StimulationId_BaselineStop/OVTK_StimulationId_Beep, OVTK_GDF_Cross_On_Screen/OVTK_GDF_Start_Of_Trial/OVTK_StimulationId_Beep, OVTK_GDF_End_Of_Trial/OVTK_StimulationId_VisualStimulationStar'
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# Error in file:  /network/lustre/iss02/aramis/projects/cracknetworks/sub-06/ses-02/EEG/Test-[2022.05.10-16.09.32].edf
# 'Event name "OVTK_GDF_Left" could not be found. The following events are present in the data: OVTK_StimulationId_ExperimentStart, OVTK_StimulationId_BaselineStart/OVTK_StimulationId_Beep'
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# ...
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# Error in file:  /network/lustre/iss02/aramis/projects/cracknetworks/sub-11/ses-03/EEG/Test-[2022.07.04-16.11.03].edf
# 'Event name "OVTK_GDF_Left" could not be found. The following events are present in the data: OVTK_StimulationId_ExperimentStart'
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/dataset.py:197: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = event_var.get_data()

# %%
X_train = trainset.features.reshape(trainset.features.shape[0], -1)
y_train = trainset.labels
X_test = testset.features.reshape(testset.features.shape[0], -1)
y_test = testset.labels

# Train LDA classifier
clf = LinearDiscriminantAnalysis()
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
acc = np.mean(y_pred == y_test)
print("LDA Accuracy: ", acc)

# Train SVM classifier
clf = SVC(kernel='linear')
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
acc = np.mean(y_pred == y_test)
print("SVM Accuracy: ", acc)

# Train XGBoost classifier
bst = XGBClassifier(n_estimators=100, max_depth=5, learning_rate=0.0005, objective='binary:logistic')
bst.fit(X_train, y_train)
preds = bst.predict(X_test)
acc = np.mean(preds == y_test)
print("XGBoost Accuracy: ", acc)
# Out:
# LDA Accuracy:  0.5004180602006689
# SVM Accuracy:  0.504180602006689
# XGBoost Accuracy:  0.5004180602006689
