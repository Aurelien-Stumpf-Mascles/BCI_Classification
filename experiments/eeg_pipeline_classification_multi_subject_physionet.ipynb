# %%
import mne
from mne.io import concatenate_raws, read_raw_edf
import matplotlib.pyplot as plt
import mne.viz
import os
import os.path as op
from mne.preprocessing import (ICA, create_eog_epochs, create_ecg_epochs,
                               corrmap)
from mne.time_frequency import tfr_multitaper
from mne.stats import permutation_cluster_1samp_test as pcluster_test
from mne.datasets import fetch_fsaverage
from mne import Epochs, EvokedArray, create_info, io, pick_types, read_events
from mne.datasets import sample
from mne.decoding import Vectorizer
from mne.decoding import CSP

import torch
from torcheeg.models import EEGNet
from torcheeg.models import DGCNN
from torcheeg import transforms

import numpy as np
import matplotlib.pyplot as plt
import scipy.signal as signal
import scipy as sc
from matplotlib import cm
import matplotlib.colors as colors

from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import StratifiedKFold
from sklearn.multiclass import OneVsRestClassifier
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import MinMaxScaler
from xgboost import XGBClassifier
import torchaudio

import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)
# Out:
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages/xgboost/core.py:265: FutureWarning: Your system has an old version of glibc (< 2.28). We will stop supporting Linux distros with glibc older than 2.28 after **May 31, 2025**. Please upgrade to a recent Linux distro (with glibc 2.28+) to use future versions of XGBoost.
# Note: You have installed the 'manylinux2014' variant of XGBoost. Certain features such as GPU algorithms or federated learning are not available. To use these features, please upgrade to a recent Linux distro with glibc 2.28+, and install the 'manylinux_2_28' variant.
#   warnings.warn(

# %%
import sys 
sys.path.append("/home/aurelien.stumpf/Development/BCI_Classification/")
from eeg_project_package import dataset, models, spectral_analysis, training

# %%
import importlib
importlib.reload(dataset)
importlib.reload(training)
importlib.reload(models)
importlib.reload(spectral_analysis)
# Out:
# <module 'eeg_project_package.spectral_analysis' from '/home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/spectral_analysis.py'>

# %% [markdown]
# ## Check Loading of Braccio Dataset Files

# %%
#Define the parameters
subject = 1  # use data from subject 1
runs = [6, 10, 14]  # use only hand and feet motor imagery runs

#Get data and locate in to given path
input_fname1 =  "/home/aurelien.stumpf/Development/Datasets/physionet.org/files/eegmmidb/1.0.0/S001/S001R01.edf"
#Read raw data files where each file contains a run
raws = read_raw_edf(input_fname1, preload=True)
#Combine all loaded runs
#raw_obj = concatenate_raws(raws)
raw_obj = raws

raw_data = raw_obj.get_data()
print("Number of channels: ", str(len(raw_data)))
print("Number of samples: ", str(len(raw_data)))

#Plot epochs & PSD
raw_obj.plot(duration=120, n_channels=15, scalings=dict(eeg=420e-6))
raw_obj.plot_psd(average=True)

# list of all channel names
list_all_ch_names = raw_obj.ch_names
# Out:
# Number of channels:  64
# Number of samples:  64
# <MNEBrowseFigure size 800x800 with 4 Axes>
# <MNELineFigure size 1000x350 with 1 Axes>

# %%
dict_channels = {'Fc5.' : 'FC5',
 'Fc3.' : 'FC3',
 'Fc1.' : 'FC1',
 'Fcz.' : 'FCz',
 'Fc2.' : 'FC2',
 'Fc4.' : 'FC4',
 'Fc6.' : 'FC6',
 'C5..' : 'C5',
 'C3..' : 'C3',
 'C1..' : 'C1',
 'Cz..' : 'Cz',
 'C2..' : 'C2',
 'C4..' : 'C4',
 'C6..' : 'C6',
 'Cp5.' : 'CP5',
 'Cp3.' : 'CP3',
 'Cp1.' : 'CP1',
 'Cpz.' : 'CPz',
 'Cp2.' : 'CP2',
 'Cp4.' : 'CP4',
 'Cp6.' : 'CP6',
 'Fp1.' : 'Fp1',
 'Fpz.' : 'Fpz',
 'Fp2.' : 'Fp2',
 'Af7.' : 'AF7',
 'Af3.' : 'AF3',
 'Afz.' : 'AFz',
 'Af4.' : 'AF4',
 'Af8.' : 'AF8',
 'F7..' : 'F7',
 'F5..' : 'F5',
 'F3..' : 'F3',
 'F1..' : 'F1',
 'Fz..' : 'Fz',
 'F2..' : 'F2',
 'F4..' : 'F4',
 'F6..' : 'F6',
 'F8..' : 'F8',
 'Ft7.' : 'FT7',
 'Ft8.' : 'FT8',
 'T7..' : 'T7',
 'T8..' : 'T8',
 'T9..' : 'T9',
 'T10.' : 'T10',
 'Tp7.' : 'TP7',
 'Tp8.' : 'TP8',
 'P7..' : 'P7',
 'P5..' : 'P5',
 'P3..' : 'P3',
 'P1..' : 'P1',
 'Pz..' : 'Pz',
 'P2..' : 'P2',
 'P4..' : 'P4',
 'P6..' : 'P6',
 'P8..' : 'P8',
 'Po7.' : 'PO7',
 'Po3.' : 'PO3',
 'Poz.' : 'POz',
 'Po4.' : 'PO4',
 'Po8.' : 'PO8',
 'O1..' : 'O1',
 'Oz..' : 'Oz',
 'O2..' : 'O2',
 'Iz..' : 'Iz'}

dict_channels_inv = dict_channels.copy()

# Reverse dict
dict_channels = {v: k for k, v in dict_channels.items()}

# %% [markdown]
# ## Multi-Subject Classif

# %%
# Define the channels
list_name_channels = ["CP1","CP3","CP5","C1","C3","C5","C2","CP2","Cz","FCz","C4","CP4"]
list_idx_channels = [list_all_ch_names.index(dict_channels[ch]) for ch in list_name_channels]

# Define the labels
labels = ['T0', 'T2']

#
parent_folder_path = "/home/aurelien.stumpf/Development/Datasets/physionet.org/files/eegmmidb/1.0.0/"

task_type = "imaginary_right_hand/rest"
if task_type == "imaginary_feet/hand":
    num_runs = [5, 6, 9, 10, 13, 14]
    num_train_subjects = list(range(1, 40))
    num_test_subjects = list(range(64, 85))
elif task_type == "imaginary_left/right":
    num_runs = [4, 8, 12]
    num_train_subjects = list(range(1, 40))
    num_test_subjects = list(range(64, 85))
elif task_type == "imaginary_right_hand/rest":
    num_runs = [4, 8, 12]
    num_train_subjects = list(range(30,109))
    num_test_subjects = list(range(0,30))
num_sessions = []
list_labels = ["T0","T2"]

# Define the parameters of the dataset
feature_type = ["band_psd"]
dict_preprocessing = {"polynomial_degree":None,"tmin":0,"tmax":4,"scale":"standard","seq_length":641}
dict_features = {"type_psd":"welch","fs":500,"nfft":300,"noverlap":150,"nperseg":300,"filter_order":19,"fmin":4,"fmax":30}

torch_trainset = dataset.Physio_Dataset_Multi_Subject(parent_folder_path, num_train_subjects, num_runs, list_idx_channels, list_labels, feature_type, dict_preprocessing, dict_features)
torch_testset = dataset.Physio_Dataset_Multi_Subject(parent_folder_path, num_test_subjects, num_runs, list_idx_channels, list_labels, feature_type, dict_preprocessing, dict_features)
trainloader = torch.utils.data.DataLoader(torch_trainset, batch_size=16, shuffle=True, num_workers=2)
testloader = torch.utils.data.DataLoader(torch_testset, batch_size=16, shuffle=True, num_workers=2)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 32
#      29 dict_preprocessing = {"polynomial_degree":None,"tmin":0,"tmax":4,"scale":"standard","seq_length":641}
#      30 dict_features = {"type_psd":"welch","fs":500,"nfft":300,"noverlap":150,"nperseg":300,"filter_order":19,"fmin":4,"fmax":30}
# ---> 32 torch_trainset = dataset.Physio_Dataset_Multi_Subject(parent_folder_path, num_train_subjects, num_runs, list_idx_channels, list_labels, feature_type, dict_preprocessing, dict_features)
#      33 torch_testset = dataset.Physio_Dataset_Multi_Subject(parent_folder_path, num_test_subjects, num_runs, list_idx_channels, list_labels, feature_type, dict_preprocessing, dict_features)
#      34 trainloader = torch.utils.data.DataLoader(torch_trainset, batch_size=16, shuffle=True, num_workers=2)
#
# File ~/Development/BCI_Classification/eeg_project_package/dataset.py:283, in Physio_Dataset_Multi_Subject.__init__(self, parent_folder_path, num_subjects, num_runs, list_idx_channels, list_labels, feature_type, dict_preprocessing, dict_features)
#     280 self.file_list = file_list
#     282 # Extract the EEG data
# --> 283 self.eeg_data,self.labels = extract_EEG_data(self.file_list, list_labels, tmin=dict_preprocessing["tmin"], tmax=dict_preprocessing["tmax"], seq_length=dict_preprocessing["seq_length"])
#     285 # Preprocess the EEG data
#     286 self.eeg_data = preprocess_data(self.eeg_data, list_idx_channels, polynomial_degree=dict_preprocessing["polynomial_degree"], scale=dict_preprocessing["scale"])
#
# File ~/Development/BCI_Classification/eeg_project_package/dataset.py:30, in extract_EEG_data(files, list_labels, tmin, tmax, seq_length)
#      28 raw_training, events_from_annot,event_id = load_file_eeg(filepath = file)
#      29 event_var = select_Event(event_name,raw_training,events_from_annot,event_id,tmin,tmax,64)
# ---> 30 event_var.filter(l_freq=1.0, h_freq=50.0)
#      31 data = event_var.get_data()
#      32 if data.shape[2] != seq_length:
#
# File <decorator-gen-84>:12, in filter(self, l_freq, h_freq, picks, filter_length, l_trans_bandwidth, h_trans_bandwidth, n_jobs, method, iir_params, phase, fir_window, fir_design, skip_by_annotation, pad, verbose)
#
# File ~/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages/mne/filter.py:2610, in FilterMixin.filter(self, l_freq, h_freq, picks, filter_length, l_trans_bandwidth, h_trans_bandwidth, n_jobs, method, iir_params, phase, fir_window, fir_design, skip_by_annotation, pad, verbose)
#    2606 for si, (start, stop) in enumerate(zip(onsets, ends)):
#    2607     # Only output filter params once (for info level), and only warn
#    2608     # once about the length criterion (longest segment is too short)
#    2609     use_verbose = verbose if si == max_idx else "error"
# -> 2610     filter_data(
#    2611         self._data[:, start:stop],
#    2612         self.info["sfreq"],
#    2613         l_freq,
#    2614         h_freq,
#    2615         picks,
#    2616         filter_length,
#    2617         l_trans_bandwidth,
#    2618         h_trans_bandwidth,
#    2619         n_jobs,
#    2620         method,
#    2621         iir_params,
#    2622         copy=False,
#    2623         phase=phase,
#    2624         fir_window=fir_window,
#    2625         fir_design=fir_design,
#    2626         pad=pad,
#    2627         verbose=use_verbose,
#    2628     )
#    2629 # update info if filter is applied to all data channels,
#    2630 # and it's not a band-stop filter
#    2631 _filt_update_info(self.info, update_info, l_freq, h_freq)
#
# File <decorator-gen-79>:12, in filter_data(data, sfreq, l_freq, h_freq, picks, filter_length, l_trans_bandwidth, h_trans_bandwidth, n_jobs, method, iir_params, copy, phase, fir_window, fir_design, pad, verbose)
#
# File ~/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages/mne/filter.py:1112, in filter_data(data, sfreq, l_freq, h_freq, picks, filter_length, l_trans_bandwidth, h_trans_bandwidth, n_jobs, method, iir_params, copy, phase, fir_window, fir_design, pad, verbose)
#    1097 filt = create_filter(
#    1098     data,
#    1099     sfreq,
#    (...)
#    1109     fir_design,
#    1110 )
#    1111 if method in ("fir", "fft"):
# -> 1112     data = _overlap_add_filter(data, filt, None, phase, picks, n_jobs, copy, pad)
#    1113 else:
#    1114     data = _iir_filter(data, filt, picks, n_jobs, copy, phase)
#
# File ~/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages/mne/filter.py:398, in _overlap_add_filter(x, h, n_fft, phase, picks, n_jobs, copy, pad)
#     394         x[p] = _1d_overlap_filter(
#     395             x[p], len(h), n_edge, phase, cuda_dict, pad, n_fft
#     396         )
#     397 else:
# --> 398     data_new = parallel(
#     399         p_fun(x[p], len(h), n_edge, phase, cuda_dict, pad, n_fft) for p in picks
#     400     )
#     401     for pp, p in enumerate(picks):
#     402         x[p] = data_new[pp]
#
# File ~/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages/joblib/parallel.py:1918, in Parallel.__call__(self, iterable)
#    1916     output = self._get_sequential_output(iterable)
#    1917     next(output)
# -> 1918     return output if self.return_generator else list(output)
#    1920 # Let's create an ID that uniquely identifies the current call. If the
#    1921 # call is interrupted early and that the same instance is immediately
#    1922 # re-used, this id will be used to prevent workers that were
#    1923 # concurrently finalizing a task from the previous call to run the
#    1924 # callback.
#    1925 with self._lock:
#
# File ~/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages/joblib/parallel.py:1847, in Parallel._get_sequential_output(self, iterable)
#    1845 self.n_dispatched_batches += 1
#    1846 self.n_dispatched_tasks += 1
# -> 1847 res = func(*args, **kwargs)
#    1848 self.n_completed_tasks += 1
#    1849 self.print_progress()
#
# File ~/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages/mne/parallel.py:128, in parallel_func.<locals>.run_verbose(verbose, *args, **kwargs)
#     126 def run_verbose(*args, verbose=logger.level, **kwargs):
#     127     with use_log_level(verbose=verbose):
# --> 128         return func(*args, **kwargs)
#
# File ~/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages/mne/filter.py:427, in _1d_overlap_filter(x, n_h, n_edge, phase, cuda_dict, pad, n_fft)
#     424 seg = x_ext[start:stop]
#     425 seg = np.concatenate([seg, np.zeros(n_fft - len(seg))])
# --> 427 prod = _fft_multiply_repeated(seg, cuda_dict)
#     429 start_filt = max(0, start - shift)
#     430 stop_filt = min(start - shift + n_fft, n_x)
#
# File ~/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages/mne/cuda.py:219, in _fft_multiply_repeated(x, cuda_dict)
#     217 x_fft = cuda_dict["rfft"](x, cuda_dict["n_fft"])
#     218 x_fft *= cuda_dict["h_fft"]
# --> 219 x = cuda_dict["irfft"](x_fft, cuda_dict["n_fft"])
#     220 return x
#
# File ~/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages/scipy/fft/_backend.py:25, in _ScipyBackend.__ua_function__(method, args, kwargs)
#      23 if fn is None:
#      24     return NotImplemented
# ---> 25 return fn(*args, **kwargs)
#
# File ~/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages/scipy/fft/_pocketfft/basic.py:97, in c2r(forward, x, n, axis, norm, overwrite_x, workers, plan)
#      94     tmp, _ = _fix_shape_1d(tmp, (n//2) + 1, axis)
#      96 # Note: overwrite_x is not utilized
# ---> 97 return pfft.c2r(tmp, (axis,), n, forward, norm, None, workers)
#
# KeyboardInterrupt:

# %%
X = trainset.features["band_psd"]
labels = trainset.labels

# Create classification pipeline
lda = LinearDiscriminantAnalysis()
csp = CSP(n_components=10, reg=None, log=True, norm_trace=False)
clf = make_pipeline(csp, lda)

# Cross validator
cv = StratifiedKFold(n_splits=8, shuffle=True, random_state=42)

# Do cross-validation
preds = np.empty(len(labels))
for train, test in cv.split(X, labels):
    clf.fit(X[train], labels[train])
    preds[test] = clf.predict(X[test])

# Classification report
print(classification_report(labels, preds))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.60      0.57      0.58        70
#          1.0       0.59      0.61      0.60        70
#
#     accuracy                           0.59       140
#    macro avg       0.59      0.59      0.59       140
# weighted avg       0.59      0.59      0.59       140

# %% [markdown]
# # EEGNet

# %%
torch_trainset.transform_dataset_numpy_to_torch()
torch_trainset.features["time"] = torch_trainset.features["time"].unsqueeze(1)
torch_testset.transform_dataset_numpy_to_torch()
torch_testset.features["time"] = torch_testset.features["time"].unsqueeze(1)
trainloader = torch.utils.data.DataLoader(torch_trainset, batch_size=16, shuffle=True, num_workers=2)
testloader = torch.utils.data.DataLoader(torch_testset, batch_size=16, shuffle=True, num_workers=2)

# %%
torch_trainset.features["time"].shape
# Out:
# torch.Size([5102, 1, 12, 641])

# %%
feature_type = "time"
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
criterion = torch.nn.CrossEntropyLoss()
model = EEGNet(chunk_size=641,
               num_electrodes=12,
               dropout=0.25,
               kernel_1=50,
               kernel_2=25,
               F1=10,
               F2=16,
               D=2,
               num_classes=2)
model.to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
#scheduler = torch.optim.lr_scheduler.MultiStepLR(optimizer, milestones=[20, 50], gamma=0.1)
scheduler = torch.optim.lr_scheduler.MultiplicativeLR(optimizer, lr_lambda=lambda epoch: 0.97)
scheduler_dict = {"MultiplicativeLR" : scheduler}
logs = training.train_model(model, trainloader, testloader, device, criterion, feature_type, 31, optimizer, scheduler_dict, print_epoch = 5)
# Out:
# Epoch 0:   0%|          | 0/319 [00:00<?, ?batch/s]
# Epoch 0
# lr:  0.01
# -------------------------
# Train set: Avg. loss: 0.0433, Balanced Accuracy: 0.4774579703807831 (48%)
# Test set: Avg. loss: 0.0434, Balanced Accuracy: 0.465032696723938 (47%)
# -------------------------
# Epoch 0: 100%|██████████| 319/319 [00:04<00:00, 65.68batch/s, accuracy=0.699, loss=0.0376]
# Epoch 1: 100%|██████████| 319/319 [00:03<00:00, 98.90batch/s, accuracy=0.73, loss=0.0339]
# Epoch 2: 100%|██████████| 319/319 [00:03<00:00, 100.27batch/s, accuracy=0.743, loss=0.0331]
# Epoch 3: 100%|██████████| 319/319 [00:03<00:00, 99.28batch/s, accuracy=0.75, loss=0.0324]
# Epoch 4: 100%|██████████| 319/319 [00:03<00:00, 102.74batch/s, accuracy=0.749, loss=0.0324]
# Epoch 5:   0%|          | 0/319 [00:00<?, ?batch/s]
# Epoch 5
# lr:  0.008587340256999998
# -------------------------
# Train set: Avg. loss: 0.0313, Balanced Accuracy: 0.6851121187210083 (69%)
# Test set: Avg. loss: 0.0317, Balanced Accuracy: 0.7137942910194397 (71%)
# -------------------------
# Epoch 5: 100%|██████████| 319/319 [00:04<00:00, 64.03batch/s, accuracy=0.754, loss=0.0322]
# Epoch 6: 100%|██████████| 319/319 [00:03<00:00, 101.05batch/s, accuracy=0.758, loss=0.032]
# Epoch 7: 100%|██████████| 319/319 [00:03<00:00, 100.41batch/s, accuracy=0.761, loss=0.0312]
# Epoch 8: 100%|██████████| 319/319 [00:03<00:00, 98.90batch/s, accuracy=0.763, loss=0.0309]
# Epoch 9: 100%|██████████| 319/319 [00:03<00:00, 103.34batch/s, accuracy=0.768, loss=0.0308]
# Epoch 10:   0%|          | 0/319 [00:00<?, ?batch/s]
# Epoch 10
# lr:  0.0073742412689492805
# -------------------------
# Train set: Avg. loss: 0.0336, Balanced Accuracy: 0.6004692316055298 (60%)
# Test set: Avg. loss: 0.0350, Balanced Accuracy: 0.6103827953338623 (61%)
# -------------------------
# Epoch 10: 100%|██████████| 319/319 [00:04<00:00, 64.01batch/s, accuracy=0.766, loss=0.0307]
# Epoch 11: 100%|██████████| 319/319 [00:03<00:00, 99.77batch/s, accuracy=0.774, loss=0.0303]
# Epoch 12: 100%|██████████| 319/319 [00:03<00:00, 96.26batch/s, accuracy=0.777, loss=0.0298]
# Epoch 13: 100%|██████████| 319/319 [00:03<00:00, 102.04batch/s, accuracy=0.775, loss=0.0303]
# Epoch 14: 100%|██████████| 319/319 [00:03<00:00, 100.47batch/s, accuracy=0.777, loss=0.0296]
# Epoch 15:   0%|          | 0/319 [00:00<?, ?batch/s]
# Epoch 15
# lr:  0.006332511891367892
# -------------------------
# Train set: Avg. loss: 0.0267, Balanced Accuracy: 0.7426204681396484 (74%)
# Test set: Avg. loss: 0.0288, Balanced Accuracy: 0.7376415729522705 (74%)
# -------------------------
# Epoch 15: 100%|██████████| 319/319 [00:04<00:00, 65.97batch/s, accuracy=0.782, loss=0.0295]
# Epoch 16: 100%|██████████| 319/319 [00:03<00:00, 100.07batch/s, accuracy=0.783, loss=0.0293]
# Epoch 17: 100%|██████████| 319/319 [00:03<00:00, 99.48batch/s, accuracy=0.785, loss=0.0288]
# Epoch 18: 100%|██████████| 319/319 [00:03<00:00, 101.12batch/s, accuracy=0.787, loss=0.0286]
# Epoch 19: 100%|██████████| 319/319 [00:03<00:00, 103.16batch/s, accuracy=0.787, loss=0.0284]
# Epoch 20:   0%|          | 0/319 [00:00<?, ?batch/s]
# Epoch 20
# lr:  0.005437943429267469
# -------------------------
# Train set: Avg. loss: 0.0268, Balanced Accuracy: 0.735637903213501 (74%)
# Test set: Avg. loss: 0.0288, Balanced Accuracy: 0.7369292974472046 (74%)
# -------------------------
# Epoch 20: 100%|██████████| 319/319 [00:05<00:00, 62.28batch/s, accuracy=0.788, loss=0.0284]
# Epoch 21: 100%|██████████| 319/319 [00:03<00:00, 100.16batch/s, accuracy=0.798, loss=0.0282]
# Epoch 22: 100%|██████████| 319/319 [00:03<00:00, 98.98batch/s, accuracy=0.795, loss=0.0283]
# Epoch 23: 100%|██████████| 319/319 [00:03<00:00, 100.98batch/s, accuracy=0.795, loss=0.0281]
# Epoch 24: 100%|██████████| 319/319 [00:03<00:00, 100.17batch/s, accuracy=0.796, loss=0.0278]
# Epoch 25:   0%|          | 0/319 [00:00<?, ?batch/s]
# Epoch 25
# lr:  0.004669747052543716
# -------------------------
# Train set: Avg. loss: 0.0254, Balanced Accuracy: 0.7870384454727173 (79%)
# Test set: Avg. loss: 0.0283, Balanced Accuracy: 0.7715224027633667 (77%)
# -------------------------
# Epoch 25: 100%|██████████| 319/319 [00:04<00:00, 63.80batch/s, accuracy=0.797, loss=0.0279]
# Epoch 26: 100%|██████████| 319/319 [00:03<00:00, 99.03batch/s, accuracy=0.799, loss=0.0274]
# Epoch 27: 100%|██████████| 319/319 [00:03<00:00, 101.01batch/s, accuracy=0.802, loss=0.0275]
# Epoch 28: 100%|██████████| 319/319 [00:03<00:00, 105.00batch/s, accuracy=0.802, loss=0.027]
# Epoch 29: 100%|██████████| 319/319 [00:03<00:00, 100.44batch/s, accuracy=0.804, loss=0.027]
# Epoch 30:   0%|          | 0/319 [00:00<?, ?batch/s]
# Epoch 30
# lr:  0.004010070685431574
# -------------------------
# Train set: Avg. loss: 0.0251, Balanced Accuracy: 0.7508774995803833 (75%)
# Test set: Avg. loss: 0.0295, Balanced Accuracy: 0.7276259660720825 (73%)
# -------------------------
# Epoch 30: 100%|██████████| 319/319 [00:05<00:00, 58.09batch/s, accuracy=0.806, loss=0.0271]

# %%
for param in model.parameters():
    print(param.data.shape)
    time_filters = param.data.cpu().numpy()
    break
# Out:
# torch.Size([10, 1, 1, 50])

# %%
time_filters = time_filters.reshape(10, 50)
for i in range(10):
    plt.plot(time_filters[i])
    plt.show()

# %%
torch.save(model.state_dict(), "/home/aurelien.stumpf/Development/BCI_Classification/models/physionet/EEGNet.pth")

# %%
plt.plot(logs["train_losses"], label="train", color="blue", alpha=0.5)
plt.plot(logs["test_losses"], label="test", color="red", alpha=0.5)
plt.legend()
plt.show()

# %%
dict_channels_inv.values()
# Out:
# dict_values(['FC5', 'FC3', 'FC1', 'FCz', 'FC2', 'FC4', 'FC6', 'C5', 'C3', 'C1', 'Cz', 'C2', 'C4', 'C6', 'CP5', 'CP3', 'CP1', 'CPz', 'CP2', 'CP4', 'CP6', 'Fp1', 'Fpz', 'Fp2', 'AF7', 'AF3', 'AFz', 'AF4', 'AF8', 'F7', 'F5', 'F3', 'F1', 'Fz', 'F2', 'F4', 'F6', 'F8', 'FT7', 'FT8', 'T7', 'T8', 'T9', 'T10', 'TP7', 'TP8', 'P7', 'P5', 'P3', 'P1', 'Pz', 'P2', 'P4', 'P6', 'P8', 'PO7', 'PO3', 'POz', 'PO4', 'PO8', 'O1', 'Oz', 'O2', 'Iz'])

# %%
montage = mne.channels.make_standard_montage('standard_1020')
list_channels_std = list(dict_channels_inv.values())

def get_positions_from_channel_list(channel_list, montage):
    dict_positions = montage.get_positions()["ch_pos"]
    positions = []
    for channel in channel_list:
        positions.append(dict_positions[channel])
    return positions

ch_positions = np.array(get_positions_from_channel_list(list_channels_std, montage))

# %%
fig, ax = plt.subplots(4, 4, figsize=(10, 10))

for i in range(4):
    for j in range(4):
        spatial_map_12 = model.block1[2].weight.data[i + 4 * j].cpu().numpy().flatten()
        spatial_map_64 = np.zeros(64)
        spatial_map_64[list_idx_channels] = spatial_map_12
        mne.viz.plot_topomap(
            spatial_map_64,
            ch_positions[:, :2],
            show=False,
            axes=ax[i, j]
        )

plt.show()

# %% [markdown]
# # Corr

# %%
importlib.reload(dataset)
importlib.reload(training)
importlib.reload(models)
# Out:
# <module 'eeg_project_package.models' from '/home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/models.py'>

# %%
torch_trainset.transform_dataset_numpy_to_torch()
torch_trainset.features["time"] = torch_trainset.features["time"].squeeze(1)
torch_testset.transform_dataset_numpy_to_torch()
torch_testset.features["time"] = torch_testset.features["time"].squeeze(1)

# %%
torch_trainset.features["time"].shape
# Out:
# torch.Size([2623, 1, 12, 641])

# %%
plt.plot(torch_trainset.features["time"][0,0,:].cpu().numpy())
plt.show()

# %%
feature_type = "time"
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
criterion = torch.nn.CrossEntropyLoss()
model = models.Corr_MLP(n_channels = 12, n_filters = 100, nperseg = 100, noverlap = 50, seq_length = 641, layer_size_list = [100,2], F1 = 16, F2 = 32, pool_size = 7, non_linearity="relu", initialization="xavier")
model.to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.1)
scheduler1 = torch.optim.lr_scheduler.MultiplicativeLR(optimizer, lr_lambda=lambda epoch: 0.95)
scheduler2 = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=3, factor=0.5)
scheduler_dict = {"ReduceLROnPlateau":scheduler2, "MultiplicativeLR":scheduler1, "ReduceLROnPlateau":scheduler2}
logs = training.train_model(model, trainloader, testloader, device, criterion, feature_type, 101, optimizer, scheduler_dict, print_epoch = 10)
# Out:
# Epoch 0:   0%|          | 0/164 [00:00<?, ?batch/s]
# Epoch 0
# lr:  0.1
# -------------------------
# Epoch 0:   0%|          | 0/164 [00:00<?, ?batch/s]
# torch.Size([16, 32, 641])
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[40], line 10
#       8 scheduler2 = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=3, factor=0.5)
#       9 scheduler_dict = {"ReduceLROnPlateau":scheduler2, "MultiplicativeLR":scheduler1, "ReduceLROnPlateau":scheduler2}
# ---> 10 logs = training.train_model(model, trainloader, testloader, device, criterion, feature_type, 101, optimizer, scheduler_dict, print_epoch = 10)
#
# File ~/Development/BCI_Classification/eeg_project_package/training.py:28, in train_model(model, trainloader, testloader, device, criterion, feature_type, epochs, optimizer, schedulers_dict, print_epoch)
#      26 print("lr: ", optimizer.param_groups[0]['lr'])
#      27 print("-------------------------")
# ---> 28 train_balanced_accuracy, train_loss = evaluate_classification_model(model,trainloader,device,criterion,feature_type,dataset="Train")
#      29 logs["train_balanced_accs"].append(train_balanced_accuracy)
#      30 logs["train_losses"].append(train_loss)
#
# File ~/Development/BCI_Classification/eeg_project_package/training.py:85, in evaluate_classification_model(model, dataloader, device, criterion, feature_type, dataset)
#      83 X = X.to(device)
#      84 y = label.to(device)
# ---> 85 outputs = model(X)
#      86 loss = criterion(outputs,y)
#      87 total_loss += loss.item()
#
# File ~/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/Development/BCI_Classification/eeg_project_package/models.py:176, in Corr_MLP.forward(self, inputs)
#     173 x = x.squeeze(2)
#     174 print(x.shape)
# --> 176 xA =torch.einsum('ijk,lk->iljk', x, self.q1)
#     177 xA = xA.reshape(batch_size, self.n_channels*self.n_filters, self.nperseg)
#     178 xAx = torch.bmm(xA, x.permute(0,2,1)).reshape(batch_size, self.n_filters, self.n_channels, self.n_channels)
#
# File ~/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages/torch/functional.py:385, in einsum(*args)
#     380     return einsum(equation, *_operands)
#     382 if len(operands) <= 2 or not opt_einsum.enabled:
#     383     # the path for contracting 0 or 1 time(s) is already optimized
#     384     # or the user has disabled using opt_einsum
# --> 385     return _VF.einsum(equation, operands)  # type: ignore[attr-defined]
#     387 path = None
#     388 if opt_einsum.is_available():
#
# RuntimeError: einsum(): subscript k has size 32 for operand 1 which does not broadcast with previously seen size 641

# %%
for param in model.parameters():
    print(param.data.shape)
    time_filters = param.data.cpu().numpy()
    break

plt.imshow(time_filters, aspect='auto')
plt.colorbar()
plt.show()
# Out:
# torch.Size([100, 100])

# %% [markdown]
# # Quadra

# %%
importlib.reload(dataset)
importlib.reload(training)
importlib.reload(models)
# Out:
# <module 'eeg_project_package.models' from '/home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/models.py'>

# %%
feature_type = "time"
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
criterion = torch.nn.CrossEntropyLoss()
model = models.Quadra_MLP(n_channels = 12, n_filters = 20, nperseg = 300, noverlap = 150, seq_length = 641, layer_size_list = [100,2], non_linearity="relu", initialization="xavier")
model.to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
scheduler1 = torch.optim.lr_scheduler.MultiplicativeLR(optimizer, lr_lambda=lambda epoch: 0.95)
scheduler2 = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=3, factor=0.5)
scheduler_dict = {"ReduceLROnPlateau":scheduler2, "MultiplicativeLR":scheduler1, "ReduceLROnPlateau":scheduler2}
logs = training.train_model(model, trainloader, testloader, device, criterion, feature_type, 101, optimizer, scheduler_dict, print_epoch = 10)
# Out:
# Epoch 0:   0%|          | 0/164 [00:00<?, ?batch/s]
# Epoch 0
# lr:  0.01
# -------------------------
# Train set: Avg. loss: 0.0465, Balanced Accuracy: 0.5137448310852051 (51%)
# Test set: Avg. loss: 0.0485, Balanced Accuracy: 0.4969741404056549 (50%)
# -------------------------
# Epoch 0: 100%|██████████| 164/164 [00:03<00:00, 43.36batch/s, accuracy=0.616, loss=0.227]
# Epoch 1: 100%|██████████| 164/164 [00:02<00:00, 62.21batch/s, accuracy=0.668, loss=0.041]
# Epoch 2: 100%|██████████| 164/164 [00:02<00:00, 63.43batch/s, accuracy=0.669, loss=0.0402]
# Epoch 3: 100%|██████████| 164/164 [00:02<00:00, 62.37batch/s, accuracy=0.668, loss=0.0397]
# Epoch 4: 100%|██████████| 164/164 [00:02<00:00, 62.72batch/s, accuracy=0.669, loss=0.04]
# Epoch 5: 100%|██████████| 164/164 [00:02<00:00, 62.94batch/s, accuracy=0.672, loss=0.0395]
# Epoch 6: 100%|██████████| 164/164 [00:02<00:00, 62.91batch/s, accuracy=0.672, loss=0.0393]
# Epoch 7: 100%|██████████| 164/164 [00:02<00:00, 61.92batch/s, accuracy=0.672, loss=0.0391]
# Epoch 8: 100%|██████████| 164/164 [00:02<00:00, 61.72batch/s, accuracy=0.671, loss=0.04]
# Epoch 9: 100%|██████████| 164/164 [00:02<00:00, 63.91batch/s, accuracy=0.672, loss=0.0394]
# Epoch 10:   0%|          | 0/164 [00:00<?, ?batch/s]
# Epoch 10
# lr:  0.005987369392383786
# -------------------------
# Train set: Avg. loss: 0.0393, Balanced Accuracy: 0.5051843523979187 (51%)
# Test set: Avg. loss: 0.0418, Balanced Accuracy: 0.5005438327789307 (50%)
# -------------------------
# Epoch 10: 100%|██████████| 164/164 [00:04<00:00, 39.86batch/s, accuracy=0.673, loss=0.0394]
# Epoch 11: 100%|██████████| 164/164 [00:02<00:00, 63.68batch/s, accuracy=0.671, loss=0.0397]
# Epoch 12: 100%|██████████| 164/164 [00:02<00:00, 64.73batch/s, accuracy=0.67, loss=0.0396]
# Epoch 13: 100%|██████████| 164/164 [00:02<00:00, 60.67batch/s, accuracy=0.669, loss=0.0418]
# Epoch 14: 100%|██████████| 164/164 [00:02<00:00, 64.15batch/s, accuracy=0.671, loss=0.0412]
# Epoch 15: 100%|██████████| 164/164 [00:02<00:00, 66.11batch/s, accuracy=0.671, loss=0.0397]
# Epoch 16: 100%|██████████| 164/164 [00:02<00:00, 67.82batch/s, accuracy=0.671, loss=0.0396]
# Epoch 17: 100%|██████████| 164/164 [00:02<00:00, 58.23batch/s, accuracy=0.671, loss=0.0396]
# Epoch 18: 100%|██████████| 164/164 [00:02<00:00, 67.55batch/s, accuracy=0.671, loss=0.0395]
# Epoch 19: 100%|██████████| 164/164 [00:02<00:00, 74.90batch/s, accuracy=0.671, loss=0.0398]
# Epoch 20:   0%|          | 0/164 [00:00<?, ?batch/s]
# Epoch 20
# lr:  0.0035848592240854188
# -------------------------
# Train set: Avg. loss: 0.0395, Balanced Accuracy: 0.5028801560401917 (50%)
# Test set: Avg. loss: 0.0401, Balanced Accuracy: 0.49947088956832886 (50%)
# -------------------------
# Epoch 20: 100%|██████████| 164/164 [00:03<00:00, 43.03batch/s, accuracy=0.671, loss=0.0395]
# Epoch 21: 100%|██████████| 164/164 [00:02<00:00, 59.99batch/s, accuracy=0.671, loss=0.0395]
# Epoch 22: 100%|██████████| 164/164 [00:02<00:00, 65.78batch/s, accuracy=0.671, loss=0.0395]
# Epoch 23: 100%|██████████| 164/164 [00:02<00:00, 63.20batch/s, accuracy=0.671, loss=0.0395]
# Epoch 24: 100%|██████████| 164/164 [00:02<00:00, 61.48batch/s, accuracy=0.671, loss=0.0396]
# Epoch 25: 100%|██████████| 164/164 [00:02<00:00, 60.43batch/s, accuracy=0.671, loss=0.0395]
# Epoch 26: 100%|██████████| 164/164 [00:02<00:00, 60.77batch/s, accuracy=0.671, loss=0.0395]
# Epoch 27: 100%|██████████| 164/164 [00:02<00:00, 62.30batch/s, accuracy=0.671, loss=0.0395]
# Epoch 28:  28%|██▊       | 46/164 [00:00<00:02, 57.60batch/s, accuracy=0.673, loss=0.0111]
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7f344001c790>
# Traceback (most recent call last):
#   File "/home/aurelien.stumpf/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#     self._shutdown_workers()
#   File "/home/aurelien.stumpf/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1443, in _shutdown_workers
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 149, in join
#     res = self._popen.wait(timeout)
#   File "/usr/lib/python3.8/multiprocessing/popen_fork.py", line 44, in wait
#     if not wait([self.sentinel], timeout):
#   File "/usr/lib/python3.8/multiprocessing/connection.py", line 931, in wait
#     ready = selector.select(timeout)
#   File "/usr/lib/python3.8/selectors.py", line 415, in select
#     fd_event_list = self._selector.poll(timeout)
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[223], line 10
#       8 scheduler2 = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=3, factor=0.5)
#       9 scheduler_dict = {"ReduceLROnPlateau":scheduler2, "MultiplicativeLR":scheduler1, "ReduceLROnPlateau":scheduler2}
# ---> 10 logs = training.train_model(model, trainloader, testloader, device, criterion, feature_type, 101, optimizer, scheduler_dict, print_epoch = 10)
#
# File ~/Development/BCI_Classification/eeg_project_package/training.py:42, in train_model(model, trainloader, testloader, device, criterion, feature_type, epochs, optimizer, schedulers_dict, print_epoch)
#      38             schedulers_dict[key].step(test_loss)
#      40 model.train()
# ---> 42 for features,label in tepoch:
#      43     tepoch.set_description(f"Epoch {epoch}")
#      44     X = features[feature_type]
#
# File ~/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages/tqdm/std.py:1181, in tqdm.__iter__(self)
#    1178 time = self._time
#    1180 try:
# -> 1181     for obj in iterable:
#    1182         yield obj
#    1183         # Update and possibly print the progressbar.
#    1184         # Note: does not call self.update(1) for speed optimisation.
#
# File ~/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages/torch/utils/data/dataloader.py:631, in _BaseDataLoaderIter.__next__(self)
#     628 if self._sampler_iter is None:
#     629     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     630     self._reset()  # type: ignore[call-arg]
# --> 631 data = self._next_data()
#     632 self._num_yielded += 1
#     633 if self._dataset_kind == _DatasetKind.Iterable and \
#     634         self._IterableDataset_len_called is not None and \
#     635         self._num_yielded > self._IterableDataset_len_called:
#
# File ~/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages/torch/utils/data/dataloader.py:1329, in _MultiProcessingDataLoaderIter._next_data(self)
#    1326     return self._process_data(data)
#    1328 assert not self._shutdown and self._tasks_outstanding > 0
# -> 1329 idx, data = self._get_data()
#    1330 self._tasks_outstanding -= 1
#    1331 if self._dataset_kind == _DatasetKind.Iterable:
#    1332     # Check for _IterableDatasetStopIteration
#
# File ~/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages/torch/utils/data/dataloader.py:1295, in _MultiProcessingDataLoaderIter._get_data(self)
#    1291     # In this case, `self._data_queue` is a `queue.Queue`,. But we don't
#    1292     # need to call `.task_done()` because we don't use `.join()`.
#    1293 else:
#    1294     while True:
# -> 1295         success, data = self._try_get_data()
#    1296         if success:
#    1297             return data
#
# File ~/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages/torch/utils/data/dataloader.py:1133, in _MultiProcessingDataLoaderIter._try_get_data(self, timeout)
#    1120 def _try_get_data(self, timeout=_utils.MP_STATUS_CHECK_INTERVAL):
#    1121     # Tries to fetch data from `self._data_queue` once for a given timeout.
#    1122     # This can also be used as inner loop of fetching without timeout, with
#    (...)
#    1130     # Returns a 2-tuple:
#    1131     #   (bool: whether successfully get data, any: data if successful else None)
#    1132     try:
# -> 1133         data = self._data_queue.get(timeout=timeout)
#    1134         return (True, data)
#    1135     except Exception as e:
#    1136         # At timeout and error, we manually check whether any worker has
#    1137         # failed. Note that this is the only mechanism for Windows to detect
#    1138         # worker failures.
#
# File /usr/lib/python3.8/multiprocessing/queues.py:116, in Queue.get(self, block, timeout)
#     114         self._rlock.release()
#     115 # unserialize the data after having released the lock
# --> 116 return _ForkingPickler.loads(res)
#
# File ~/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages/torch/multiprocessing/reductions.py:500, in rebuild_storage_fd(cls, df, size)
#     498 if storage is not None:
#     499     return storage
# --> 500 storage = cls._new_shared_fd_cpu(fd, size)
#     501 shared_cache[fd_id(fd)] = StorageWeakRef(storage)
#     502 return storage
#
# KeyboardInterrupt:

# %% [markdown]
# # Transformer

# %%
import importlib
importlib.reload(dataset)
importlib.reload(training)
importlib.reload(models)
# Out:
# <module 'eeg_project_package.models' from '/home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/models.py'>

# %%
torch_trainset.transform_dataset_numpy_to_torch()
torch_trainset.features["time"] = torch_trainset.features["time"].transpose(1,2)
torch_testset.transform_dataset_numpy_to_torch()
torch_testset.features["time"] = torch_testset.features["time"].transpose(1,2)
trainloader = torch.utils.data.DataLoader(torch_trainset, batch_size=16, shuffle=True, num_workers=2)
testloader = torch.utils.data.DataLoader(torch_testset, batch_size=16, shuffle=True, num_workers=2)

# %%
feature_type = "time"
src_vocab_size = 12
layer_size_list = [10,2]
d_model = 20
num_heads = 10
num_layers = 2
d_ff = 20
nperseg = 200
noverlap = 100
dropout = 0
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
criterion = torch.nn.CrossEntropyLoss()
model = models.Transformer(src_vocab_size, layer_size_list, d_model, num_heads, num_layers, d_ff, nperseg, noverlap, dropout)
model.to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
scheduler1 = torch.optim.lr_scheduler.MultiplicativeLR(optimizer, lr_lambda=lambda epoch: 0.95)
scheduler2 = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=3, factor=0.5)
scheduler_dict = {"ReduceLROnPlateau":scheduler2, "MultiplicativeLR":scheduler1}
logs = training.train_model(model, trainloader, testloader, device, criterion, feature_type, 101, optimizer, scheduler_dict, print_epoch = 10)
# Out:
# Epoch 0:   0%|          | 0/164 [00:00<?, ?batch/s]
# Epoch 0
# lr:  0.001
# -------------------------
# Epoch 0:   0%|          | 0/164 [00:00<?, ?batch/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 19
#      17 scheduler2 = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=3, factor=0.5)
#      18 scheduler_dict = {"ReduceLROnPlateau":scheduler2, "MultiplicativeLR":scheduler1}
# ---> 19 logs = training.train_model(model, trainloader, testloader, device, criterion, feature_type, 101, optimizer, scheduler_dict, print_epoch = 10)
#
# File ~/Development/BCI_Classification/eeg_project_package/training.py:28, in train_model(model, trainloader, testloader, device, criterion, feature_type, epochs, optimizer, schedulers_dict, print_epoch)
#      26 print("lr: ", optimizer.param_groups[0]['lr'])
#      27 print("-------------------------")
# ---> 28 train_balanced_accuracy, train_loss = evaluate_classification_model(model,trainloader,device,criterion,feature_type,dataset="Train")
#      29 logs["train_balanced_accs"].append(train_balanced_accuracy)
#      30 logs["train_losses"].append(train_loss)
#
# File ~/Development/BCI_Classification/eeg_project_package/training.py:85, in evaluate_classification_model(model, dataloader, device, criterion, feature_type, dataset)
#      83 X = X.to(device)
#      84 y = label.to(device)
# ---> 85 outputs = model(X)
#      86 loss = criterion(outputs,y)
#      87 total_loss += loss.item()
#
# File ~/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/Development/BCI_Classification/eeg_project_package/models.py:420, in Transformer.forward(self, src)
#     419 def forward(self, src):
# --> 420     batch_size, seq_length, n_channels = src.size()
#     421     ind = 0
#     422     probs = []
#
# ValueError: too many values to unpack (expected 3)

# %% [markdown]
# # ATCNet

# %%
import importlib
importlib.reload(dataset)
importlib.reload(training)
importlib.reload(models)
# Out:
# <module 'eeg_project_package.models' from '/home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/models.py'>

# %%
from torcheeg.models import ATCNet

# %%
torch_trainset.transform_dataset_numpy_to_torch()
torch_trainset.features["time"] = torch_trainset.features["time"].squeeze(1)
torch_testset.transform_dataset_numpy_to_torch()
torch_testset.features["time"] = torch_testset.features["time"].squeeze(1)
trainloader = torch.utils.data.DataLoader(torch_trainset, batch_size=16, shuffle=True, num_workers=2)
testloader = torch.utils.data.DataLoader(torch_testset, batch_size=16, shuffle=True, num_workers=2)

# %%
torch_trainset.features["time"].shape
# Out:
# torch.Size([5042, 1, 1, 12, 641])

# %%
feature_type = "time"
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
criterion = torch.nn.CrossEntropyLoss()
model = models.ATCNet(in_channels=1,
               num_classes=2,
               num_windows=5,
               num_electrodes=12,
               chunk_size=641,
               filter_size=50,)
model.to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
scheduler1 = torch.optim.lr_scheduler.MultiplicativeLR(optimizer, lr_lambda=lambda epoch: 0.95)
scheduler2 = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=3, factor=0.5)
scheduler_dict = {"MultiplicativeLR":scheduler1} #, "ReduceLROnPlateau":scheduler2}
logs = training.train_model(model, trainloader, testloader, device, criterion, feature_type, 101, optimizer, scheduler_dict, print_epoch = 1)
# Out:
# Epoch 0:   0%|          | 0/319 [00:00<?, ?batch/s]
# Epoch 0
# lr:  0.001
# -------------------------
# Train set: Avg. loss: 0.0436, Balanced Accuracy: 0.49626627564430237 (50%)
# Test set: Avg. loss: 0.0436, Balanced Accuracy: 0.5093935132026672 (51%)
# -------------------------
# Epoch 0: 100%|██████████| 319/319 [00:19<00:00, 16.03batch/s, accuracy=0.711, loss=0.0366]
# Epoch 1:   0%|          | 0/319 [00:00<?, ?batch/s]
# Epoch 1
# lr:  0.00095
# -------------------------
# Train set: Avg. loss: 0.0342, Balanced Accuracy: 0.7064461708068848 (71%)
# Test set: Avg. loss: 0.0338, Balanced Accuracy: 0.726064920425415 (73%)
# -------------------------
# Epoch 1: 100%|██████████| 319/319 [00:19<00:00, 16.00batch/s, accuracy=0.76, loss=0.0339]
# Epoch 2:   0%|          | 0/319 [00:00<?, ?batch/s]
# Epoch 2
# lr:  0.0009025
# -------------------------
# Train set: Avg. loss: 0.0329, Balanced Accuracy: 0.7368427515029907 (74%)
# Test set: Avg. loss: 0.0324, Balanced Accuracy: 0.7608637809753418 (76%)
# -------------------------
# Epoch 2: 100%|██████████| 319/319 [00:19<00:00, 16.36batch/s, accuracy=0.77, loss=0.0332]
# Epoch 3:   0%|          | 0/319 [00:00<?, ?batch/s]
# Epoch 3
# lr:  0.000857375
# -------------------------
# Train set: Avg. loss: 0.0321, Balanced Accuracy: 0.7277892827987671 (73%)
# Test set: Avg. loss: 0.0323, Balanced Accuracy: 0.7331286668777466 (73%)
# -------------------------
# Epoch 3: 100%|██████████| 319/319 [00:19<00:00, 16.13batch/s, accuracy=0.778, loss=0.0327]
# Epoch 4:   0%|          | 0/319 [00:00<?, ?batch/s]
# Epoch 4
# lr:  0.0008145062499999999
# -------------------------
# Train set: Avg. loss: 0.0326, Balanced Accuracy: 0.7426129579544067 (74%)
# Test set: Avg. loss: 0.0324, Balanced Accuracy: 0.7628257274627686 (76%)
# -------------------------
# Epoch 4: 100%|██████████| 319/319 [00:18<00:00, 16.90batch/s, accuracy=0.784, loss=0.0324]
# Epoch 5:   0%|          | 0/319 [00:00<?, ?batch/s]
# Epoch 5
# lr:  0.0007737809374999998
# -------------------------
# Train set: Avg. loss: 0.0313, Balanced Accuracy: 0.7573095560073853 (76%)
# Test set: Avg. loss: 0.0316, Balanced Accuracy: 0.7626484036445618 (76%)
# -------------------------
# Epoch 5: 100%|██████████| 319/319 [00:19<00:00, 16.38batch/s, accuracy=0.792, loss=0.032]
# Epoch 6:   0%|          | 0/319 [00:00<?, ?batch/s]
# Epoch 6
# lr:  0.0007350918906249997
# -------------------------
# Train set: Avg. loss: 0.0309, Balanced Accuracy: 0.7778528928756714 (78%)
# Test set: Avg. loss: 0.0317, Balanced Accuracy: 0.7708486318588257 (77%)
# -------------------------
# Epoch 6: 100%|██████████| 319/319 [00:20<00:00, 15.82batch/s, accuracy=0.794, loss=0.0318]
# Epoch 7:   0%|          | 0/319 [00:00<?, ?batch/s]
# Epoch 7
# lr:  0.0006983372960937497
# -------------------------
# Train set: Avg. loss: 0.0308, Balanced Accuracy: 0.7851728796958923 (79%)
# Test set: Avg. loss: 0.0317, Balanced Accuracy: 0.772895336151123 (77%)
# -------------------------
# Epoch 7: 100%|██████████| 319/319 [00:19<00:00, 15.99batch/s, accuracy=0.802, loss=0.0315]
# Epoch 8:   0%|          | 0/319 [00:00<?, ?batch/s]
# Epoch 8
# lr:  0.0006634204312890621
# -------------------------
# Train set: Avg. loss: 0.0305, Balanced Accuracy: 0.7875221371650696 (79%)
# Test set: Avg. loss: 0.0321, Balanced Accuracy: 0.7663202881813049 (77%)
# -------------------------
# Epoch 8: 100%|██████████| 319/319 [00:19<00:00, 16.77batch/s, accuracy=0.803, loss=0.0313]
# Epoch 9:   0%|          | 0/319 [00:00<?, ?batch/s]
# Epoch 9
# lr:  0.000630249409724609
# -------------------------
# Train set: Avg. loss: 0.0301, Balanced Accuracy: 0.7874048352241516 (79%)
# Test set: Avg. loss: 0.0316, Balanced Accuracy: 0.7619823217391968 (76%)
# -------------------------
# Epoch 9: 100%|██████████| 319/319 [00:19<00:00, 16.08batch/s, accuracy=0.81, loss=0.0311]
# Epoch 10:   0%|          | 0/319 [00:00<?, ?batch/s]
# Epoch 10
# lr:  0.0005987369392383785
# -------------------------
# Train set: Avg. loss: 0.0300, Balanced Accuracy: 0.7843227982521057 (78%)
# Test set: Avg. loss: 0.0317, Balanced Accuracy: 0.7553841471672058 (76%)
# -------------------------
# Epoch 10: 100%|██████████| 319/319 [00:20<00:00, 15.80batch/s, accuracy=0.818, loss=0.0307]
# Epoch 11:   0%|          | 0/319 [00:00<?, ?batch/s]
# Epoch 11
# lr:  0.0005688000922764595
# -------------------------
# Train set: Avg. loss: 0.0300, Balanced Accuracy: 0.792043924331665 (79%)
# Test set: Avg. loss: 0.0313, Balanced Accuracy: 0.7767037153244019 (78%)
# -------------------------
# Epoch 11: 100%|██████████| 319/319 [00:18<00:00, 17.17batch/s, accuracy=0.816, loss=0.0307]
# Epoch 12:   0%|          | 0/319 [00:00<?, ?batch/s]
# Epoch 12
# lr:  0.0005403600876626365
# -------------------------
# Train set: Avg. loss: 0.0294, Balanced Accuracy: 0.798531174659729 (80%)
# Test set: Avg. loss: 0.0313, Balanced Accuracy: 0.763828694820404 (76%)
# -------------------------
# Epoch 12: 100%|██████████| 319/319 [00:18<00:00, 16.81batch/s, accuracy=0.822, loss=0.0303]
# Epoch 13:   0%|          | 0/319 [00:00<?, ?batch/s]
# Epoch 13
# lr:  0.0005133420832795047
# -------------------------
# Train set: Avg. loss: 0.0292, Balanced Accuracy: 0.8071169853210449 (81%)
# Test set: Avg. loss: 0.0311, Balanced Accuracy: 0.7774545550346375 (78%)
# -------------------------
# Epoch 13: 100%|██████████| 319/319 [00:20<00:00, 15.52batch/s, accuracy=0.823, loss=0.0302]
# Epoch 14:   0%|          | 0/319 [00:00<?, ?batch/s]
# Epoch 14
# lr:  0.00048767497911552944
# -------------------------
# Train set: Avg. loss: 0.0289, Balanced Accuracy: 0.8180462121963501 (82%)
# Test set: Avg. loss: 0.0313, Balanced Accuracy: 0.7813553810119629 (78%)
# -------------------------
# Epoch 14: 100%|██████████| 319/319 [00:19<00:00, 16.64batch/s, accuracy=0.825, loss=0.0299]
# Epoch 15:   0%|          | 0/319 [00:00<?, ?batch/s]
# Epoch 15
# lr:  0.00046329123015975297
# -------------------------
# Train set: Avg. loss: 0.0288, Balanced Accuracy: 0.8136128187179565 (81%)
# Test set: Avg. loss: 0.0313, Balanced Accuracy: 0.7704500555992126 (77%)
# -------------------------
# Epoch 15: 100%|██████████| 319/319 [00:20<00:00, 15.68batch/s, accuracy=0.827, loss=0.0299]
# Epoch 16:   0%|          | 0/319 [00:00<?, ?batch/s]
# Epoch 16
# lr:  0.0004401266686517653
# -------------------------
# Train set: Avg. loss: 0.0288, Balanced Accuracy: 0.8169223070144653 (82%)
# Test set: Avg. loss: 0.0312, Balanced Accuracy: 0.7692466378211975 (77%)
# -------------------------
# Epoch 16: 100%|██████████| 319/319 [00:21<00:00, 15.08batch/s, accuracy=0.829, loss=0.0299]
# Epoch 17:   0%|          | 0/319 [00:00<?, ?batch/s]
# Epoch 17
# lr:  0.00041812033521917703
# -------------------------
# Train set: Avg. loss: 0.0286, Balanced Accuracy: 0.828774094581604 (83%)
# Test set: Avg. loss: 0.0318, Balanced Accuracy: 0.7710182666778564 (77%)
# -------------------------
# Epoch 17: 100%|██████████| 319/319 [00:18<00:00, 16.90batch/s, accuracy=0.839, loss=0.0295]
# Epoch 18:   0%|          | 0/319 [00:00<?, ?batch/s]
# Epoch 18
# lr:  0.00039721431845821814
# -------------------------
# Train set: Avg. loss: 0.0281, Balanced Accuracy: 0.8210429549217224 (82%)
# Test set: Avg. loss: 0.0307, Balanced Accuracy: 0.7746028900146484 (77%)
# -------------------------
# Epoch 18: 100%|██████████| 319/319 [00:18<00:00, 17.15batch/s, accuracy=0.833, loss=0.0296]
# Epoch 19:   0%|          | 0/319 [00:00<?, ?batch/s]
# Epoch 19
# lr:  0.0003773536025353072
# -------------------------
# Train set: Avg. loss: 0.0281, Balanced Accuracy: 0.8287336826324463 (83%)
# Test set: Avg. loss: 0.0314, Balanced Accuracy: 0.7657983303070068 (77%)
# -------------------------
# Epoch 19: 100%|██████████| 319/319 [00:19<00:00, 16.08batch/s, accuracy=0.843, loss=0.0292]
# Epoch 20:   0%|          | 0/319 [00:00<?, ?batch/s]
# Epoch 20
# lr:  0.0003584859224085418
# -------------------------
# Train set: Avg. loss: 0.0280, Balanced Accuracy: 0.83054119348526 (83%)
# Test set: Avg. loss: 0.0310, Balanced Accuracy: 0.7778068780899048 (78%)
# -------------------------
# Epoch 20: 100%|██████████| 319/319 [00:20<00:00, 15.58batch/s, accuracy=0.844, loss=0.0291]
# Epoch 21:   0%|          | 0/319 [00:00<?, ?batch/s]
# Epoch 21
# lr:  0.0003405616262881147
# -------------------------
# Train set: Avg. loss: 0.0284, Balanced Accuracy: 0.8338303565979004 (83%)
# Test set: Avg. loss: 0.0317, Balanced Accuracy: 0.7779764533042908 (78%)
# -------------------------
# Epoch 21: 100%|██████████| 319/319 [00:19<00:00, 16.25batch/s, accuracy=0.848, loss=0.0289]
# Epoch 22:   0%|          | 0/319 [00:00<?, ?batch/s]
# Epoch 22
# lr:  0.00032353354497370894
# -------------------------
# Train set: Avg. loss: 0.0279, Balanced Accuracy: 0.8387388586997986 (84%)
# Test set: Avg. loss: 0.0312, Balanced Accuracy: 0.7824816703796387 (78%)
# -------------------------
# Epoch 22: 100%|██████████| 319/319 [00:20<00:00, 15.52batch/s, accuracy=0.852, loss=0.0288]
# Epoch 23:   0%|          | 0/319 [00:00<?, ?batch/s]
# Epoch 23
# lr:  0.00030735686772502346
# -------------------------
# Train set: Avg. loss: 0.0279, Balanced Accuracy: 0.8417644500732422 (84%)
# Test set: Avg. loss: 0.0314, Balanced Accuracy: 0.7798459529876709 (78%)
# -------------------------
# Epoch 23: 100%|██████████| 319/319 [00:19<00:00, 16.09batch/s, accuracy=0.851, loss=0.0287]
# Epoch 24:   0%|          | 0/319 [00:00<?, ?batch/s]
# Epoch 24
# lr:  0.00029198902433877225
# -------------------------
# Train set: Avg. loss: 0.0275, Balanced Accuracy: 0.8450421094894409 (85%)
# Test set: Avg. loss: 0.0310, Balanced Accuracy: 0.7793702483177185 (78%)
# -------------------------
# Epoch 24:  47%|████▋     | 151/319 [00:11<00:13, 12.85batch/s, accuracy=0.858, loss=0.0134]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 15
#      13 scheduler2 = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=3, factor=0.5)
#      14 scheduler_dict = {"MultiplicativeLR":scheduler1} #, "ReduceLROnPlateau":scheduler2}
# ---> 15 logs = training.train_model(model, trainloader, testloader, device, criterion, feature_type, 101, optimizer, scheduler_dict, print_epoch = 1)
#
# File ~/Development/BCI_Classification/eeg_project_package/training.py:47, in train_model(model, trainloader, testloader, device, criterion, feature_type, epochs, optimizer, schedulers_dict, print_epoch)
#      45 X = X.to(device)
#      46 y = label.to(device)
# ---> 47 outputs = model(X)
#      49 if criterion.__class__.__name__ == "BCEWithLogitsLoss":
#      50     loss = criterion(outputs.flatten(),y.float())
#
# File ~/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/Development/BCI_Classification/eeg_project_package/models.py:607, in ATCNet.forward(self, x)
#     603 x2 = torch.add(x2,x2_)
#     606 for j in range(self.tcn_depth):
# --> 607    out = self.get_submodule("tcn"+str( (i+1)*j ))(x2)
#     608    if x2.shape[1] != out.shape[1]:
#     609         x2 = self.get_submodule("re"+str(i))(x2)
#
# File ~/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages/torch/nn/modules/container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# KeyboardInterrupt:

# %%
li_eegnet = np.array([0.75, 0.75, 0.77])
li_atcnet = np.array([0.77, 0.76, 0.78])
print(np.mean(li_eegnet), np.mean(li_atcnet))
print(np.std(li_eegnet), np.std(li_atcnet))
# Out:
# 0.7566666666666667 0.77
# 0.009428090415820642 0.008164965809277268

# %%
model
# Out:
# ATCNet(
#   (conv_block): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(1, 321), stride=(1, 1), padding=same, bias=False)
#     (1): BatchNorm2d(16, eps=False, momentum=0.1, affine=True, track_running_stats=True)
#     (2): Conv2d(16, 32, kernel_size=(12, 1), stride=(1, 1), groups=16)
#     (3): BatchNorm2d(32, eps=False, momentum=0.1, affine=True, track_running_stats=True)
#     (4): ELU(alpha=1.0)
#     (5): AvgPool2d(kernel_size=(1, 8), stride=(1, 8), padding=0)
#     (6): Dropout2d(p=0.1, inplace=False)
#     (7): Conv2d(32, 32, kernel_size=(1, 16), stride=(1, 1), padding=same, bias=False)
#     (8): BatchNorm2d(32, eps=False, momentum=0.1, affine=True, track_running_stats=True)
#     (9): ELU(alpha=1.0)
#     (10): AvgPool2d(kernel_size=(1, 7), stride=(1, 7), padding=0)
#     (11): Dropout2d(p=0.1, inplace=False)
#   )
#   (msa0): MultiheadAttention(
#     (out_proj): NonDynamicallyQuantizableLinear(in_features=32, out_features=32, bias=True)
#   )
#   (msa_drop0): Dropout(p=0.3, inplace=False)
#   (tcn0): Sequential(
#     (0): Conv1d(9, 32, kernel_size=(4,), stride=(1,), padding=same)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ELU(alpha=1.0)
#     (3): Dropout(p=0.3, inplace=False)
#     (4): Conv1d(32, 32, kernel_size=(4,), stride=(1,), padding=same)
#     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ELU(alpha=1.0)
#     (7): Dropout(p=0.3, inplace=False)
#   )
#   (re0): Conv1d(9, 32, kernel_size=(4,), stride=(1,), padding=same)
#   (tcn1): Sequential(
#     (0): Conv1d(32, 32, kernel_size=(4,), stride=(1,), padding=same)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ELU(alpha=1.0)
#     (3): Dropout(p=0.3, inplace=False)
#     (4): Conv1d(32, 32, kernel_size=(4,), stride=(1,), padding=same)
#     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ELU(alpha=1.0)
#     (7): Dropout(p=0.3, inplace=False)
#   )
#   (dense0): Linear(in_features=32, out_features=2, bias=True)
#   (msa1): MultiheadAttention(
#     (out_proj): NonDynamicallyQuantizableLinear(in_features=32, out_features=32, bias=True)
#   )
#   (msa_drop1): Dropout(p=0.3, inplace=False)
#   (re1): Conv1d(9, 32, kernel_size=(4,), stride=(1,), padding=same)
#   (tcn2): Sequential(
#     (0): Conv1d(32, 32, kernel_size=(4,), stride=(1,), padding=same)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ELU(alpha=1.0)
#     (3): Dropout(p=0.3, inplace=False)
#     (4): Conv1d(32, 32, kernel_size=(4,), stride=(1,), padding=same)
#     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ELU(alpha=1.0)
#     (7): Dropout(p=0.3, inplace=False)
#   )
#   (dense1): Linear(in_features=32, out_features=2, bias=True)
#   (msa2): MultiheadAttention(
#     (out_proj): NonDynamicallyQuantizableLinear(in_features=32, out_features=32, bias=True)
#   )
#   (msa_drop2): Dropout(p=0.3, inplace=False)
#   (re2): Conv1d(9, 32, kernel_size=(4,), stride=(1,), padding=same)
#   (tcn3): Sequential(
#     (0): Conv1d(32, 32, kernel_size=(4,), stride=(1,), padding=same)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ELU(alpha=1.0)
#     (3): Dropout(p=0.3, inplace=False)
#     (4): Conv1d(32, 32, kernel_size=(4,), stride=(1,), padding=same)
#     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ELU(alpha=1.0)
#     (7): Dropout(p=0.3, inplace=False)
#   )
#   (dense2): Linear(in_features=32, out_features=2, bias=True)
# )

# %%
for param in model.parameters():
    print(param.data.shape)
    time_filters = param.data.cpu().numpy()
    break

for i in range(16):
    plt.plot(time_filters[i,0,0,:])
    plt.show()
# Out:
# torch.Size([16, 1, 1, 50])

# %%
model
# Out:
# ATCNet(
#   (conv_block): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(1, 50), stride=(1, 1), padding=same, bias=False)
#     (1): BatchNorm2d(16, eps=False, momentum=0.1, affine=True, track_running_stats=True)
#     (2): Conv2d(16, 32, kernel_size=(12, 1), stride=(1, 1), groups=16)
#     (3): BatchNorm2d(32, eps=False, momentum=0.1, affine=True, track_running_stats=True)
#     (4): ELU(alpha=1.0)
#     (5): AvgPool2d(kernel_size=(1, 8), stride=(1, 8), padding=0)
#     (6): Dropout2d(p=0.1, inplace=False)
#     (7): Conv2d(32, 32, kernel_size=(1, 16), stride=(1, 1), padding=same, bias=False)
#     (8): BatchNorm2d(32, eps=False, momentum=0.1, affine=True, track_running_stats=True)
#     (9): ELU(alpha=1.0)
#     (10): AvgPool2d(kernel_size=(1, 7), stride=(1, 7), padding=0)
#     (11): Dropout2d(p=0.1, inplace=False)
#   )
#   (msa0): MultiheadAttention(
#     (out_proj): NonDynamicallyQuantizableLinear(in_features=32, out_features=32, bias=True)
#   )
#   (msa_drop0): Dropout(p=0.3, inplace=False)
#   (tcn0): Sequential(
#     (0): Conv1d(7, 32, kernel_size=(4,), stride=(1,), padding=same)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ELU(alpha=1.0)
#     (3): Dropout(p=0.3, inplace=False)
#     (4): Conv1d(32, 32, kernel_size=(4,), stride=(1,), padding=same)
#     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ELU(alpha=1.0)
#     (7): Dropout(p=0.3, inplace=False)
#   )
#   (re0): Conv1d(7, 32, kernel_size=(4,), stride=(1,), padding=same)
#   (tcn1): Sequential(
#     (0): Conv1d(32, 32, kernel_size=(4,), stride=(1,), padding=same)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ELU(alpha=1.0)
#     (3): Dropout(p=0.3, inplace=False)
#     (4): Conv1d(32, 32, kernel_size=(4,), stride=(1,), padding=same)
#     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ELU(alpha=1.0)
#     (7): Dropout(p=0.3, inplace=False)
#   )
#   (dense0): Linear(in_features=32, out_features=2, bias=True)
#   (msa1): MultiheadAttention(
#     (out_proj): NonDynamicallyQuantizableLinear(in_features=32, out_features=32, bias=True)
#   )
#   (msa_drop1): Dropout(p=0.3, inplace=False)
#   (re1): Conv1d(7, 32, kernel_size=(4,), stride=(1,), padding=same)
#   (tcn2): Sequential(
#     (0): Conv1d(32, 32, kernel_size=(4,), stride=(1,), padding=same)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ELU(alpha=1.0)
#     (3): Dropout(p=0.3, inplace=False)
#     (4): Conv1d(32, 32, kernel_size=(4,), stride=(1,), padding=same)
#     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ELU(alpha=1.0)
#     (7): Dropout(p=0.3, inplace=False)
#   )
#   (dense1): Linear(in_features=32, out_features=2, bias=True)
#   (msa2): MultiheadAttention(
#     (out_proj): NonDynamicallyQuantizableLinear(in_features=32, out_features=32, bias=True)
#   )
#   (msa_drop2): Dropout(p=0.3, inplace=False)
#   (re2): Conv1d(7, 32, kernel_size=(4,), stride=(1,), padding=same)
#   (tcn3): Sequential(
#     (0): Conv1d(32, 32, kernel_size=(4,), stride=(1,), padding=same)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ELU(alpha=1.0)
#     (3): Dropout(p=0.3, inplace=False)
#     (4): Conv1d(32, 32, kernel_size=(4,), stride=(1,), padding=same)
#     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ELU(alpha=1.0)
#     (7): Dropout(p=0.3, inplace=False)
#   )
#   (dense2): Linear(in_features=32, out_features=2, bias=True)
#   (msa3): MultiheadAttention(
#     (out_proj): NonDynamicallyQuantizableLinear(in_features=32, out_features=32, bias=True)
#   )
#   (msa_drop3): Dropout(p=0.3, inplace=False)
#   (re3): Conv1d(7, 32, kernel_size=(4,), stride=(1,), padding=same)
#   (tcn4): Sequential(
#     (0): Conv1d(32, 32, kernel_size=(4,), stride=(1,), padding=same)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ELU(alpha=1.0)
#     (3): Dropout(p=0.3, inplace=False)
#     (4): Conv1d(32, 32, kernel_size=(4,), stride=(1,), padding=same)
#     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ELU(alpha=1.0)
#     (7): Dropout(p=0.3, inplace=False)
#   )
#   (dense3): Linear(in_features=32, out_features=2, bias=True)
#   (msa4): MultiheadAttention(
#     (out_proj): NonDynamicallyQuantizableLinear(in_features=32, out_features=32, bias=True)
#   )
#   (msa_drop4): Dropout(p=0.3, inplace=False)
#   (re4): Conv1d(7, 32, kernel_size=(4,), stride=(1,), padding=same)
#   (tcn5): Sequential(
#     (0): Conv1d(32, 32, kernel_size=(4,), stride=(1,), padding=same)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ELU(alpha=1.0)
#     (3): Dropout(p=0.3, inplace=False)
#     (4): Conv1d(32, 32, kernel_size=(4,), stride=(1,), padding=same)
#     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ELU(alpha=1.0)
#     (7): Dropout(p=0.3, inplace=False)
#   )
#   (dense4): Linear(in_features=32, out_features=2, bias=True)
# )

# %%
fig, ax = plt.subplots(4, 4, figsize=(10, 10))

for i in range(4):
    for j in range(4):
        spatial_map_12 = model.conv_block[2].weight.data[i + 4 * j].cpu().numpy().flatten()
        spatial_map_64 = np.zeros(64)
        spatial_map_64[list_idx_channels] = spatial_map_12
        mne.viz.plot_topomap(
            spatial_map_64,
            ch_positions[:, :2],
            show=False,
            axes=ax[i, j]
        )

plt.show()

# %% [markdown]
# # LDA / SVM

# %%
X_train = torch_trainset.features["band_psd"].reshape(torch_trainset.features["band_psd"].shape[0], -1)
y_train = torch_trainset.labels
X_test = torch_testset.features["band_psd"].reshape(torch_testset.features["band_psd"].shape[0], -1)
y_test = torch_testset.labels

# Train LDA classifier
lda_clf = LinearDiscriminantAnalysis()
lda_clf.fit(X_train, y_train)
y_pred = lda_clf.predict(X_test)
acc = np.mean(y_pred == y_test)
print("LDA accuracy: ", acc)

# Train SVM classifier
svm_clf = SVC(kernel='linear')
svm_clf.fit(X_train, y_train)
y_pred = svm_clf.predict(X_test)
acc = np.mean(y_pred == y_test)
print("SVM accuracy: ", acc)

# Train SVM classifier
svm_clf = SVC(kernel='rbf')
svm_clf.fit(X_train, y_train)
y_pred = svm_clf.predict(X_test)
acc = np.mean(y_pred == y_test)
print("rbf SVM accuracy: ", acc)
# Out:
# LDA accuracy:  0.66376217324449
# SVM accuracy:  0.6688877498718606
# rbf SVM accuracy:  0.6688877498718606

# %% [markdown]
# # Deep Fourier Transform

# %%
torch_trainset.features["time"].shape
# Out:
# torch.Size([2623, 641])

# %%
import importlib
importlib.reload(dataset)
importlib.reload(training)
importlib.reload(models)
# Out:
# <module 'eeg_project_package.models' from '/home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/models.py'>

# %%
torch_trainset.transform_dataset_numpy_to_torch()
torch_trainset.features["time"] = torch_trainset.features["time"][:,0,:].squeeze(1)
torch_testset.transform_dataset_numpy_to_torch()
torch_testset.features["time"] = torch_testset.features["time"][:,0,:].squeeze(1)

# %%
feature_type = "time"
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
criterion = torch.nn.BCEWithLogitsLoss() #CrossEntropyLoss()
model = models.DeepWelchTransform(nperseg = 400, noverlap = 100, seq_length = 641)
model.to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
scheduler1 = torch.optim.lr_scheduler.MultiplicativeLR(optimizer, lr_lambda=lambda epoch: 0.95)
scheduler2 = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=3, factor=0.5)
scheduler_dict = {"MultiplicativeLR":scheduler1} #, "ReduceLROnPlateau":scheduler2}
logs = training.train_model(model, trainloader, testloader, device, criterion, feature_type, 101, optimizer, scheduler_dict, print_epoch = 10)
# Out:
# Epoch 0:   0%|          | 0/164 [00:00<?, ?batch/s]
# Epoch 0
# lr:  0.001
# -------------------------
# Train set: Avg. loss: 15.7218, Balanced Accuracy: 0.5009794235229492 (50%)
# Test set: Avg. loss: 30.8711, Balanced Accuracy: 0.493813157081604 (49%)
# -------------------------
# Epoch 0: 100%|██████████| 164/164 [00:02<00:00, 69.26batch/s, accuracy=0.662, loss=14.8]
# Epoch 1: 100%|██████████| 164/164 [00:01<00:00, 118.11batch/s, accuracy=0.66, loss=12.9]
# Epoch 2: 100%|██████████| 164/164 [00:01<00:00, 119.11batch/s, accuracy=0.657, loss=11.1]
# Epoch 3: 100%|██████████| 164/164 [00:01<00:00, 120.89batch/s, accuracy=0.654, loss=9.41]
# Epoch 4: 100%|██████████| 164/164 [00:01<00:00, 110.56batch/s, accuracy=0.651, loss=7.78]
# Epoch 5: 100%|██████████| 164/164 [00:01<00:00, 120.72batch/s, accuracy=0.648, loss=6.24]
# Epoch 6: 100%|██████████| 164/164 [00:01<00:00, 122.47batch/s, accuracy=0.643, loss=4.78]
# Epoch 7: 100%|██████████| 164/164 [00:01<00:00, 104.92batch/s, accuracy=0.639, loss=3.4]
# Epoch 8: 100%|██████████| 164/164 [00:01<00:00, 114.68batch/s, accuracy=0.628, loss=2.09]
# Epoch 9: 100%|██████████| 164/164 [00:01<00:00, 119.43batch/s, accuracy=0.6, loss=0.876]
# Epoch 10:   0%|          | 0/164 [00:00<?, ?batch/s]
# Epoch 10
# lr:  0.0005987369392383785
# -------------------------
# Train set: Avg. loss: 0.3076, Balanced Accuracy: 0.5089123249053955 (51%)
# Test set: Avg. loss: 0.6126, Balanced Accuracy: 0.48246246576309204 (48%)
# -------------------------
# Epoch 10: 100%|██████████| 164/164 [00:02<00:00, 68.18batch/s, accuracy=0.442, loss=0.101]
# Epoch 11: 100%|██████████| 164/164 [00:01<00:00, 116.24batch/s, accuracy=0.41, loss=0.0737]
# Epoch 12: 100%|██████████| 164/164 [00:01<00:00, 111.37batch/s, accuracy=0.414, loss=0.0708]
# Epoch 13: 100%|██████████| 164/164 [00:01<00:00, 120.12batch/s, accuracy=0.411, loss=0.0682]
# Epoch 14: 100%|██████████| 164/164 [00:01<00:00, 124.34batch/s, accuracy=0.419, loss=0.0671]
# Epoch 15: 100%|██████████| 164/164 [00:01<00:00, 122.71batch/s, accuracy=0.418, loss=0.0642]
# Epoch 16: 100%|██████████| 164/164 [00:01<00:00, 111.98batch/s, accuracy=0.424, loss=0.0647]
# Epoch 17: 100%|██████████| 164/164 [00:01<00:00, 112.41batch/s, accuracy=0.417, loss=0.0625]
# Epoch 18: 100%|██████████| 164/164 [00:01<00:00, 122.31batch/s, accuracy=0.424, loss=0.0611]
# Epoch 19: 100%|██████████| 164/164 [00:01<00:00, 101.35batch/s, accuracy=0.425, loss=0.0599]
# Epoch 20:   0%|          | 0/164 [00:00<?, ?batch/s]
# Epoch 20
# lr:  0.0003584859224085418
# -------------------------
# Train set: Avg. loss: 0.0584, Balanced Accuracy: 0.5147550702095032 (51%)
# Test set: Avg. loss: 0.0758, Balanced Accuracy: 0.49383360147476196 (49%)
# -------------------------
# Epoch 20: 100%|██████████| 164/164 [00:02<00:00, 58.52batch/s, accuracy=0.43, loss=0.0588]
# Epoch 21: 100%|██████████| 164/164 [00:01<00:00, 117.74batch/s, accuracy=0.422, loss=0.0578]
# Epoch 22: 100%|██████████| 164/164 [00:01<00:00, 118.03batch/s, accuracy=0.438, loss=0.0569]
# Epoch 23: 100%|██████████| 164/164 [00:01<00:00, 119.32batch/s, accuracy=0.44, loss=0.0563]
# Epoch 24: 100%|██████████| 164/164 [00:01<00:00, 113.35batch/s, accuracy=0.445, loss=0.0551]
# Epoch 25: 100%|██████████| 164/164 [00:01<00:00, 105.12batch/s, accuracy=0.444, loss=0.054]
# Epoch 26: 100%|██████████| 164/164 [00:01<00:00, 113.68batch/s, accuracy=0.456, loss=0.0533]
# Epoch 27: 100%|██████████| 164/164 [00:01<00:00, 120.65batch/s, accuracy=0.458, loss=0.0532]
# Epoch 28: 100%|██████████| 164/164 [00:01<00:00, 120.59batch/s, accuracy=0.457, loss=0.053]
# Epoch 29: 100%|██████████| 164/164 [00:01<00:00, 114.84batch/s, accuracy=0.468, loss=0.0519]
# Epoch 30:   0%|          | 0/164 [00:00<?, ?batch/s]
# Epoch 30
# lr:  0.00021463876394293716
# -------------------------
# Train set: Avg. loss: 0.0515, Balanced Accuracy: 0.509131908416748 (51%)
# Test set: Avg. loss: 0.0569, Balanced Accuracy: 0.49661195278167725 (50%)
# -------------------------
# Epoch 30: 100%|██████████| 164/164 [00:02<00:00, 64.17batch/s, accuracy=0.469, loss=0.0515]
# Epoch 31: 100%|██████████| 164/164 [00:01<00:00, 111.51batch/s, accuracy=0.475, loss=0.0512]
# Epoch 32: 100%|██████████| 164/164 [00:01<00:00, 110.73batch/s, accuracy=0.478, loss=0.0505]
# Epoch 33: 100%|██████████| 164/164 [00:01<00:00, 111.49batch/s, accuracy=0.488, loss=0.0502]
# Epoch 34: 100%|██████████| 164/164 [00:01<00:00, 116.68batch/s, accuracy=0.508, loss=0.0499]
# Epoch 35: 100%|██████████| 164/164 [00:01<00:00, 113.88batch/s, accuracy=0.516, loss=0.0494]
# Epoch 36: 100%|██████████| 164/164 [00:01<00:00, 119.03batch/s, accuracy=0.514, loss=0.0487]
# Epoch 37: 100%|██████████| 164/164 [00:01<00:00, 118.48batch/s, accuracy=0.552, loss=0.0491]
# Epoch 38: 100%|██████████| 164/164 [00:01<00:00, 123.62batch/s, accuracy=0.572, loss=0.0486]
# Epoch 39: 100%|██████████| 164/164 [00:01<00:00, 110.92batch/s, accuracy=0.608, loss=0.0484]
# Epoch 40:   0%|          | 0/164 [00:00<?, ?batch/s]
# Epoch 40
# lr:  0.00012851215656510304
# -------------------------
# Train set: Avg. loss: 0.0477, Balanced Accuracy: 0.5033354759216309 (50%)
# Test set: Avg. loss: 0.0538, Balanced Accuracy: 0.4906998574733734 (49%)
# -------------------------
# Epoch 40: 100%|██████████| 164/164 [00:02<00:00, 68.89batch/s, accuracy=0.662, loss=0.0482]
# Epoch 41: 100%|██████████| 164/164 [00:01<00:00, 103.83batch/s, accuracy=0.669, loss=0.0478]
# Epoch 42: 100%|██████████| 164/164 [00:01<00:00, 108.03batch/s, accuracy=0.669, loss=0.0475]
# Epoch 43: 100%|██████████| 164/164 [00:01<00:00, 114.62batch/s, accuracy=0.669, loss=0.0474]
# Epoch 44: 100%|██████████| 164/164 [00:01<00:00, 119.76batch/s, accuracy=0.669, loss=0.0472]
# Epoch 45: 100%|██████████| 164/164 [00:01<00:00, 119.36batch/s, accuracy=0.669, loss=0.0471]
# Epoch 46: 100%|██████████| 164/164 [00:01<00:00, 121.80batch/s, accuracy=0.669, loss=0.0467]
# Epoch 47: 100%|██████████| 164/164 [00:01<00:00, 110.86batch/s, accuracy=0.669, loss=0.0466]
# Epoch 48: 100%|██████████| 164/164 [00:01<00:00, 108.69batch/s, accuracy=0.669, loss=0.0464]
# Epoch 49: 100%|██████████| 164/164 [00:01<00:00, 107.93batch/s, accuracy=0.669, loss=0.0462]
# Epoch 50:   0%|          | 0/164 [00:00<?, ?batch/s]
# Epoch 50
# lr:  7.69449752767131e-05
# -------------------------
# Train set: Avg. loss: 0.0461, Balanced Accuracy: 0.5 (50%)
# Test set: Avg. loss: 0.0545, Balanced Accuracy: 0.5 (50%)
# -------------------------
# Epoch 50: 100%|██████████| 164/164 [00:02<00:00, 63.31batch/s, accuracy=0.669, loss=0.0462]
# Epoch 51: 100%|██████████| 164/164 [00:01<00:00, 114.96batch/s, accuracy=0.669, loss=0.046]
# Epoch 52: 100%|██████████| 164/164 [00:01<00:00, 115.90batch/s, accuracy=0.669, loss=0.0458]
# Epoch 53: 100%|██████████| 164/164 [00:01<00:00, 104.54batch/s, accuracy=0.669, loss=0.0458]
# Epoch 54: 100%|██████████| 164/164 [00:01<00:00, 116.80batch/s, accuracy=0.669, loss=0.0457]
# Epoch 55: 100%|██████████| 164/164 [00:01<00:00, 98.11batch/s, accuracy=0.669, loss=0.0455]
# Epoch 56: 100%|██████████| 164/164 [00:01<00:00, 111.65batch/s, accuracy=0.669, loss=0.0456]
# Epoch 57: 100%|██████████| 164/164 [00:01<00:00, 119.93batch/s, accuracy=0.669, loss=0.0453]
# Epoch 58: 100%|██████████| 164/164 [00:01<00:00, 117.22batch/s, accuracy=0.669, loss=0.0454]
# Epoch 59: 100%|██████████| 164/164 [00:01<00:00, 110.81batch/s, accuracy=0.669, loss=0.0452]
# Epoch 60:   0%|          | 0/164 [00:00<?, ?batch/s]
# Epoch 60
# lr:  4.606979898695191e-05
# -------------------------
# Train set: Avg. loss: 0.0450, Balanced Accuracy: 0.5 (50%)
# Test set: Avg. loss: 0.0503, Balanced Accuracy: 0.5 (50%)
# -------------------------
# Epoch 60: 100%|██████████| 164/164 [00:02<00:00, 68.91batch/s, accuracy=0.669, loss=0.0453]
# Epoch 61: 100%|██████████| 164/164 [00:01<00:00, 101.78batch/s, accuracy=0.669, loss=0.045]
# Epoch 62: 100%|██████████| 164/164 [00:01<00:00, 115.43batch/s, accuracy=0.669, loss=0.045]
# Epoch 63: 100%|██████████| 164/164 [00:01<00:00, 119.82batch/s, accuracy=0.669, loss=0.0449]
# Epoch 64: 100%|██████████| 164/164 [00:01<00:00, 124.90batch/s, accuracy=0.669, loss=0.0449]
# Epoch 65: 100%|██████████| 164/164 [00:01<00:00, 104.84batch/s, accuracy=0.669, loss=0.0449]
# Epoch 66: 100%|██████████| 164/164 [00:01<00:00, 109.40batch/s, accuracy=0.669, loss=0.0448]
# Epoch 67: 100%|██████████| 164/164 [00:01<00:00, 109.49batch/s, accuracy=0.669, loss=0.0447]
# Epoch 68: 100%|██████████| 164/164 [00:01<00:00, 111.84batch/s, accuracy=0.669, loss=0.0448]
# Epoch 69: 100%|██████████| 164/164 [00:01<00:00, 114.76batch/s, accuracy=0.669, loss=0.0445]
# Epoch 70:   0%|          | 0/164 [00:00<?, ?batch/s]
# Epoch 70
# lr:  2.758369043677494e-05
# -------------------------
# Train set: Avg. loss: 0.0447, Balanced Accuracy: 0.5 (50%)
# Test set: Avg. loss: 0.0479, Balanced Accuracy: 0.5 (50%)
# -------------------------
# Epoch 70: 100%|██████████| 164/164 [00:02<00:00, 57.36batch/s, accuracy=0.669, loss=0.0444]
# Epoch 71: 100%|██████████| 164/164 [00:01<00:00, 114.05batch/s, accuracy=0.669, loss=0.0446]
# Epoch 72: 100%|██████████| 164/164 [00:01<00:00, 118.62batch/s, accuracy=0.669, loss=0.0444]
# Epoch 73: 100%|██████████| 164/164 [00:01<00:00, 119.99batch/s, accuracy=0.669, loss=0.0445]
# Epoch 74:   5%|▌         | 9/164 [00:00<00:03, 42.11batch/s, accuracy=0.613, loss=0.00276]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[88], line 10
#       8 scheduler2 = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=3, factor=0.5)
#       9 scheduler_dict = {"MultiplicativeLR":scheduler1} #, "ReduceLROnPlateau":scheduler2}
# ---> 10 logs = training.train_model(model, trainloader, testloader, device, criterion, feature_type, 101, optimizer, scheduler_dict, print_epoch = 10)
#
# File ~/Development/BCI_Classification/eeg_project_package/training.py:67, in train_model(model, trainloader, testloader, device, criterion, feature_type, epochs, optimizer, schedulers_dict, print_epoch)
#      64         size += len(y)
#      65         accuracy = correct/size
# ---> 67         tepoch.set_postfix(loss=total_loss, accuracy=accuracy)
#      69 for key in schedulers_dict:
#      70     if key == "MultiplicativeLR":
#
# File ~/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages/tqdm/std.py:1431, in tqdm.set_postfix(self, ordered_dict, refresh, **kwargs)
#    1428 self.postfix = ', '.join(key + '=' + postfix[key].strip()
#    1429                          for key in postfix.keys())
#    1430 if refresh:
# -> 1431     self.refresh()
#
# File ~/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages/tqdm/std.py:1347, in tqdm.refresh(self, nolock, lock_args)
#    1345     else:
#    1346         self._lock.acquire()
# -> 1347 self.display()
#    1348 if not nolock:
#    1349     self._lock.release()
#
# File ~/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages/tqdm/std.py:1495, in tqdm.display(self, msg, pos)
#    1493 if pos:
#    1494     self.moveto(pos)
# -> 1495 self.sp(self.__str__() if msg is None else msg)
#    1496 if pos:
#    1497     self.moveto(-pos)
#
# File ~/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages/tqdm/std.py:459, in tqdm.status_printer.<locals>.print_status(s)
#     457 def print_status(s):
#     458     len_s = disp_len(s)
# --> 459     fp_write('\r' + s + (' ' * max(last_len[0] - len_s, 0)))
#     460     last_len[0] = len_s
#
# File ~/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages/tqdm/std.py:453, in tqdm.status_printer.<locals>.fp_write(s)
#     451 def fp_write(s):
#     452     fp.write(str(s))
# --> 453     fp_flush()
#
# File ~/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages/tqdm/utils.py:196, in DisableOnWriteError.disable_on_exception.<locals>.inner(*args, **kwargs)
#     194 def inner(*args, **kwargs):
#     195     try:
# --> 196         return func(*args, **kwargs)
#     197     except OSError as e:
#     198         if e.errno != 5:
#
# File ~/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages/ipykernel/iostream.py:609, in OutStream.flush(self)
#     607     self.pub_thread.schedule(evt.set)
#     608     # and give a timeout to avoid
# --> 609     if not evt.wait(self.flush_timeout):
#     610         # write directly to __stderr__ instead of warning because
#     611         # if this is happening sys.stderr may be the problem.
#     612         print("IOStream.flush timed out", file=sys.__stderr__)
#     613 else:
#
# File /usr/lib/python3.8/threading.py:558, in Event.wait(self, timeout)
#     556 signaled = self._flag
#     557 if not signaled:
# --> 558     signaled = self._cond.wait(timeout)
#     559 return signaled
#
# File /usr/lib/python3.8/threading.py:306, in Condition.wait(self, timeout)
#     304 else:
#     305     if timeout > 0:
# --> 306         gotit = waiter.acquire(True, timeout)
#     307     else:
#     308         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
criterion.__class__.__name__
# Out:
# 'BCEWithLogitsLoss'
