# %%
import mne
from mne.io import concatenate_raws, read_raw_edf
import matplotlib.pyplot as plt
import mne.viz
import os
import os.path as op
from mne.preprocessing import (ICA, create_eog_epochs, create_ecg_epochs,
                               corrmap)
from mne.time_frequency import tfr_multitaper
from mne.stats import permutation_cluster_1samp_test as pcluster_test
from mne.datasets import fetch_fsaverage
from mne import Epochs, EvokedArray, create_info, io, pick_types, read_events
from mne.datasets import sample
from mne.decoding import Vectorizer
from mne.decoding import CSP

import torch
from torcheeg.models import EEGNet
from torcheeg.models import DGCNN
from torcheeg import transforms

import numpy as np
import matplotlib.pyplot as plt
import scipy.signal as signal
import scipy as sc
from matplotlib import cm
import matplotlib.colors as colors

from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import StratifiedKFold
from sklearn.multiclass import OneVsRestClassifier
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import MinMaxScaler
from xgboost import XGBClassifier
import torchaudio

import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning) 

import pickle
# Out:
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages/xgboost/core.py:265: FutureWarning: Your system has an old version of glibc (< 2.28). We will stop supporting Linux distros with glibc older than 2.28 after **May 31, 2025**. Please upgrade to a recent Linux distro (with glibc 2.28+) to use future versions of XGBoost.
# Note: You have installed the 'manylinux2014' variant of XGBoost. Certain features such as GPU algorithms or federated learning are not available. To use these features, please upgrade to a recent Linux distro with glibc 2.28+, and install the 'manylinux_2_28' variant.
#   warnings.warn(

# %%
import sys 
sys.path.append("/home/aurelien.stumpf/Development/BCI_Classification/")
from eeg_project_package import dataset, models, spectral_analysis, training

# %%
import importlib
importlib.reload(dataset)
importlib.reload(training)
importlib.reload(models)
importlib.reload(spectral_analysis)
# Out:
# <module 'eeg_project_package.spectral_analysis' from '/home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/spectral_analysis.py'>

# %% [markdown]
# ## Check Loading of Braccio Dataset Files

# %%
#Define the parameters
subject = 1  # use data from subject 1
runs = [6, 10, 14]  # use only hand and feet motor imagery runs

#Get data and locate in to given path
input_fname1 =  "/network/lustre/iss02/aramis/projects/cracknetworks/sub-01/ses-01/EEG/Test-[2022.03.28-17.46.29].edf"
#Read raw data files where each file contains a run
raws = read_raw_edf(input_fname1, preload=True)
#Combine all loaded runs
#raw_obj = concatenate_raws(raws)
raw_obj = raws

raw_data = raw_obj.get_data()
print("Number of channels: ", str(len(raw_data)))
print("Number of samples: ", str(len(raw_data)))

#Plot epochs & PSD
raw_obj.plot(duration=120, n_channels=15, scalings=dict(eeg=420e-6))
raw_obj.plot_psd(average=True)

# list of all channel names
list_all_ch_names = raw_obj.ch_names
# Out:
# Number of channels:  64
# Number of samples:  64
# <MNEBrowseFigure size 800x800 with 4 Axes>
# <MNELineFigure size 1000x350 with 1 Axes>

# %% [markdown]
# ## Intra-Subject Classification

# %%
# Define the subject and the session
task_type = "imaginary_left/right"
folder_path = "/network/lustre/iss02/aramis/projects/cracknetworks/"

num_sessions = [1,2,3]
num_subjects = [1,2,3,5,6,7,8,10,11,13,14]   
list_labels = ['OVTK_GDF_Left','OVTK_GDF_Right']

# Define the channels
list_name_channels = ["CP1","CP3","CP5","C1","C3","C5","C2","CP2","Cz","FCz","C4","CP4"]
list_idx_channels = [list_all_ch_names.index(ch) for ch in list_name_channels]

# Define the labels
labels = ['OVTK_GDF_Left', 'OVTK_GDF_Right']

# Define the parameters of the dataset
feature_type = ["time"]
dict_preprocessing = {"polynomial_degree":None,"tmin":0,"tmax":4,"seq_length":2001}
dict_features = {"type_psd":"welch","fs":500,"nfft":300,"noverlap":150,"nperseg":300,"filter_order":19,"fmin":4,"fmax":30}

num_subject = num_subjects[4]
num_val_subjects = [num_subject]
num_test_subjects = [num_subject]
num_train_subjects = [num_subject]
num_train_sessions = [1]
num_val_sessions = [2]
num_test_sessions = [3]

print("Train subjects: ", num_train_subjects)
print("Val subjects: ", num_val_subjects)
print("Test subjects: ", num_test_subjects)

# Create the dataset
trainset = dataset.Braccio_Dataset_Multi_Subject(folder_path, num_train_subjects, num_train_sessions, list_idx_channels = list_idx_channels, list_labels = labels, feature_type = feature_type, dict_preprocessing = dict_preprocessing, dict_features = dict_features)
testset = dataset.Braccio_Dataset_Multi_Subject(folder_path, num_test_subjects, num_test_sessions, list_idx_channels = list_idx_channels, list_labels = labels, feature_type = feature_type, dict_preprocessing = dict_preprocessing, dict_features = dict_features)
valset = dataset.Braccio_Dataset_Multi_Subject(folder_path, num_val_subjects, num_val_sessions, list_idx_channels = list_idx_channels, list_labels = labels, feature_type = feature_type, dict_preprocessing = dict_preprocessing, dict_features = dict_features)

# Create the dataloader
trainset.transform_dataset_numpy_to_torch()
trainset.features["time"] = trainset.features["time"].unsqueeze(1)
testset.transform_dataset_numpy_to_torch()
testset.features["time"] = testset.features["time"].unsqueeze(1)
valset.transform_dataset_numpy_to_torch()
valset.features["time"] = valset.features["time"].unsqueeze(1)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=16, shuffle=True, num_workers=2)
testloader = torch.utils.data.DataLoader(testset, batch_size=32, shuffle=True, num_workers=2)
valloader = torch.utils.data.DataLoader(valset, batch_size=32, shuffle=True, num_workers=2)

feature_type = "time"
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
criterion = torch.nn.CrossEntropyLoss()
model = EEGNet(chunk_size=2001,
            num_electrodes=12,
            dropout=0,
            kernel_1=500,
            kernel_2=250,
            F1=4,
            F2=16,
            D=2,
            num_classes=2)
model.to(device)
model.load_state_dict(torch.load("../models/EEGNet/EEGNet_Subject_{}.pt".format(num_subject)))
for param in model.named_parameters():
    if "lin" in param[0]:
        continue
    else:
        param[1].requires_grad = False
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
#scheduler = torch.optim.lr_scheduler.MultiStepLR(optimizer, milestones=[20, 50], gamma=0.1)
scheduler = torch.optim.lr_scheduler.MultiplicativeLR(optimizer, lr_lambda=lambda epoch: 0.95)
scheduler_dict = {"MultiplicativeLR" : scheduler}
logs = training.train_model(model, trainloader, valloader, device, criterion, feature_type, 51, optimizer, scheduler_dict, print_epoch = 5)
# change weights of the model to the best weights
model.load_state_dict(logs["best_model_weights"])
model.eval()
train_balanced_accuracy, train_loss = training.evaluate_classification_model(model,trainloader,device,criterion,feature_type,dataset="Train")
val_balanced_accuracy, val_loss = training.evaluate_classification_model(model,valloader,device,criterion,feature_type,dataset="Val")
test_balanced_accuracy, test_loss = training.evaluate_classification_model(model,testloader,device,criterion,feature_type,dataset="Test")
# Out:
# Train subjects:  [6]
# Val subjects:  [6]
# Test subjects:  [6]
# Error in file:  /network/lustre/iss02/aramis/projects/cracknetworks/sub-06/ses-02/EEG/Test-[2022.05.10-16.09.32].edf
# 'Event name "OVTK_GDF_Left" could not be found. The following events are present in the data: OVTK_StimulationId_ExperimentStart, OVTK_StimulationId_BaselineStart/OVTK_StimulationId_Beep'
# Epoch 0:   0%|          | 0/10 [00:00<?, ?batch/s]
# Epoch 0
# lr:  0.01
# -------------------------
# Train set: Avg. loss: 0.0394, Balanced Accuracy: 0.6687500476837158 (67%)
# Test set: Avg. loss: 0.0172, Balanced Accuracy: 0.7687499523162842 (77%)
# Saving best model weights with balanced accuracy:  0.7687499523162842
# -------------------------
# Epoch 0: 100%|██████████| 10/10 [00:02<00:00,  4.05batch/s, accuracy=0.688, loss=0.04]
# Epoch 1: 100%|██████████| 10/10 [00:00<00:00, 11.90batch/s, accuracy=0.831, loss=0.0212]
# Epoch 2: 100%|██████████| 10/10 [00:00<00:00, 13.34batch/s, accuracy=0.938, loss=0.0132]
# Epoch 3: 100%|██████████| 10/10 [00:00<00:00, 13.21batch/s, accuracy=0.938, loss=0.00988]
# Epoch 4: 100%|██████████| 10/10 [00:00<00:00, 13.90batch/s, accuracy=0.988, loss=0.00787]
# Epoch 5:   0%|          | 0/10 [00:00<?, ?batch/s]
# Epoch 5
# lr:  0.007737809374999999
# -------------------------
# Train set: Avg. loss: 0.0127, Balanced Accuracy: 0.9312499761581421 (93%)
# Test set: Avg. loss: 0.0204, Balanced Accuracy: 0.75 (75%)
# -------------------------
# Epoch 5: 100%|██████████| 10/10 [00:02<00:00,  4.55batch/s, accuracy=1, loss=0.0061]
# Epoch 6: 100%|██████████| 10/10 [00:00<00:00, 12.32batch/s, accuracy=1, loss=0.00527]
# Epoch 7: 100%|██████████| 10/10 [00:00<00:00, 13.04batch/s, accuracy=1, loss=0.00487]
# Epoch 8: 100%|██████████| 10/10 [00:00<00:00, 13.21batch/s, accuracy=1, loss=0.00442]
# Epoch 9: 100%|██████████| 10/10 [00:00<00:00, 11.76batch/s, accuracy=1, loss=0.00382]
# Epoch 10:   0%|          | 0/10 [00:00<?, ?batch/s]
# Epoch 10
# lr:  0.005987369392383786
# -------------------------
# Train set: Avg. loss: 0.0071, Balanced Accuracy: 0.9937499761581421 (99%)
# Test set: Avg. loss: 0.0236, Balanced Accuracy: 0.7749999761581421 (77%)
# Saving best model weights with balanced accuracy:  0.7749999761581421
# -------------------------
# Epoch 10: 100%|██████████| 10/10 [00:02<00:00,  4.82batch/s, accuracy=1, loss=0.00314]
# Epoch 11: 100%|██████████| 10/10 [00:00<00:00, 12.74batch/s, accuracy=1, loss=0.0031]
# Epoch 12: 100%|██████████| 10/10 [00:00<00:00, 12.86batch/s, accuracy=1, loss=0.00324]
# Epoch 13: 100%|██████████| 10/10 [00:00<00:00, 13.56batch/s, accuracy=1, loss=0.00278]
# Epoch 14: 100%|██████████| 10/10 [00:00<00:00, 11.89batch/s, accuracy=1, loss=0.00284]
# Epoch 15:   0%|          | 0/10 [00:00<?, ?batch/s]
# Epoch 15
# lr:  0.00463291230159753
# -------------------------
# Train set: Avg. loss: 0.0041, Balanced Accuracy: 1.0 (100%)
# Test set: Avg. loss: 0.0267, Balanced Accuracy: 0.7749999761581421 (77%)
# -------------------------
# Epoch 15: 100%|██████████| 10/10 [00:02<00:00,  4.57batch/s, accuracy=1, loss=0.00255]
# Epoch 16: 100%|██████████| 10/10 [00:00<00:00, 12.80batch/s, accuracy=1, loss=0.00267]
# Epoch 17: 100%|██████████| 10/10 [00:00<00:00, 12.56batch/s, accuracy=1, loss=0.00228]
# Epoch 18: 100%|██████████| 10/10 [00:00<00:00, 13.06batch/s, accuracy=1, loss=0.00204]
# Epoch 19: 100%|██████████| 10/10 [00:00<00:00, 13.86batch/s, accuracy=1, loss=0.0027]
# Epoch 20:   0%|          | 0/10 [00:00<?, ?batch/s]
# Epoch 20
# lr:  0.0035848592240854188
# -------------------------
# Train set: Avg. loss: 0.0026, Balanced Accuracy: 1.0 (100%)
# Test set: Avg. loss: 0.0297, Balanced Accuracy: 0.7562500238418579 (76%)
# -------------------------
# Epoch 20: 100%|██████████| 10/10 [00:02<00:00,  4.73batch/s, accuracy=1, loss=0.00249]
# Epoch 21: 100%|██████████| 10/10 [00:00<00:00, 13.51batch/s, accuracy=1, loss=0.0021]
# Epoch 22: 100%|██████████| 10/10 [00:00<00:00, 12.65batch/s, accuracy=1, loss=0.00208]
# Epoch 23: 100%|██████████| 10/10 [00:00<00:00, 11.80batch/s, accuracy=1, loss=0.00175]
# Epoch 24: 100%|██████████| 10/10 [00:00<00:00, 14.02batch/s, accuracy=0.994, loss=0.00283]
# Epoch 25:   0%|          | 0/10 [00:00<?, ?batch/s]
# Epoch 25
# lr:  0.0027738957312183374
# -------------------------
# Train set: Avg. loss: 0.0019, Balanced Accuracy: 1.0 (100%)
# Test set: Avg. loss: 0.0316, Balanced Accuracy: 0.7562500238418579 (76%)
# -------------------------
# Epoch 25: 100%|██████████| 10/10 [00:02<00:00,  4.53batch/s, accuracy=1, loss=0.00197]
# Epoch 26: 100%|██████████| 10/10 [00:00<00:00, 12.54batch/s, accuracy=1, loss=0.00188]
# Epoch 27: 100%|██████████| 10/10 [00:00<00:00, 16.09batch/s, accuracy=1, loss=0.00188]
# Epoch 28: 100%|██████████| 10/10 [00:00<00:00, 11.74batch/s, accuracy=1, loss=0.00197]
# Epoch 29: 100%|██████████| 10/10 [00:00<00:00, 12.71batch/s, accuracy=1, loss=0.00164]
# Epoch 30:   0%|          | 0/10 [00:00<?, ?batch/s]
# Epoch 30
# lr:  0.0021463876394293723
# -------------------------
# Train set: Avg. loss: 0.0015, Balanced Accuracy: 1.0 (100%)
# Test set: Avg. loss: 0.0341, Balanced Accuracy: 0.7437499761581421 (74%)
# -------------------------
# Epoch 30: 100%|██████████| 10/10 [00:02<00:00,  4.67batch/s, accuracy=1, loss=0.00184]
# Epoch 31: 100%|██████████| 10/10 [00:00<00:00, 12.80batch/s, accuracy=1, loss=0.0017]
# Epoch 32: 100%|██████████| 10/10 [00:00<00:00, 13.53batch/s, accuracy=1, loss=0.00131]
# Epoch 33: 100%|██████████| 10/10 [00:00<00:00, 14.90batch/s, accuracy=1, loss=0.0014]
# Epoch 34: 100%|██████████| 10/10 [00:00<00:00, 11.08batch/s, accuracy=1, loss=0.00169]
# Epoch 35:   0%|          | 0/10 [00:00<?, ?batch/s]
# Epoch 35
# lr:  0.0016608338398760713
# -------------------------
# Train set: Avg. loss: 0.0013, Balanced Accuracy: 1.0 (100%)
# Test set: Avg. loss: 0.0350, Balanced Accuracy: 0.75 (75%)
# -------------------------
# Epoch 35: 100%|██████████| 10/10 [00:02<00:00,  4.57batch/s, accuracy=1, loss=0.00153]
# Epoch 36: 100%|██████████| 10/10 [00:00<00:00, 13.14batch/s, accuracy=1, loss=0.00144]
# Epoch 37: 100%|██████████| 10/10 [00:00<00:00, 13.22batch/s, accuracy=1, loss=0.00137]
# Epoch 38: 100%|██████████| 10/10 [00:00<00:00, 12.47batch/s, accuracy=1, loss=0.00131]
# Epoch 39: 100%|██████████| 10/10 [00:00<00:00, 13.43batch/s, accuracy=1, loss=0.0013]
# Epoch 40:   0%|          | 0/10 [00:00<?, ?batch/s]
# Epoch 40
# lr:  0.0012851215656510308
# -------------------------
# Train set: Avg. loss: 0.0012, Balanced Accuracy: 1.0 (100%)
# Test set: Avg. loss: 0.0359, Balanced Accuracy: 0.7374999523162842 (74%)
# -------------------------
# Epoch 40: 100%|██████████| 10/10 [00:02<00:00,  4.63batch/s, accuracy=1, loss=0.00128]
# Epoch 41: 100%|██████████| 10/10 [00:00<00:00, 12.15batch/s, accuracy=1, loss=0.00122]
# Epoch 42: 100%|██████████| 10/10 [00:00<00:00, 13.44batch/s, accuracy=1, loss=0.00124]
# Epoch 43: 100%|██████████| 10/10 [00:00<00:00, 12.82batch/s, accuracy=1, loss=0.0012]
# Epoch 44: 100%|██████████| 10/10 [00:00<00:00, 12.03batch/s, accuracy=1, loss=0.00147]
# Epoch 45:   0%|          | 0/10 [00:00<?, ?batch/s]
# Epoch 45
# lr:  0.000994402569870922
# -------------------------
# Train set: Avg. loss: 0.0011, Balanced Accuracy: 1.0 (100%)
# Test set: Avg. loss: 0.0368, Balanced Accuracy: 0.7437499761581421 (74%)
# -------------------------
# Epoch 45: 100%|██████████| 10/10 [00:02<00:00,  4.57batch/s, accuracy=1, loss=0.00143]
# Epoch 46: 100%|██████████| 10/10 [00:00<00:00, 12.12batch/s, accuracy=1, loss=0.00155]
# Epoch 47: 100%|██████████| 10/10 [00:00<00:00, 12.33batch/s, accuracy=1, loss=0.00112]
# Epoch 48: 100%|██████████| 10/10 [00:00<00:00, 14.39batch/s, accuracy=1, loss=0.00122]
# Epoch 49: 100%|██████████| 10/10 [00:00<00:00, 12.80batch/s, accuracy=1, loss=0.00127]
# Epoch 50:   0%|          | 0/10 [00:00<?, ?batch/s]
# Epoch 50
# lr:  0.0007694497527671312
# -------------------------
# Train set: Avg. loss: 0.0010, Balanced Accuracy: 1.0 (100%)
# Test set: Avg. loss: 0.0371, Balanced Accuracy: 0.7437499761581421 (74%)
# -------------------------
# Epoch 50: 100%|██████████| 10/10 [00:01<00:00,  6.05batch/s, accuracy=1, loss=0.00127]
# Train set: Avg. loss: 0.0071, Balanced Accuracy: 0.9937499761581421 (99%)
# Val set: Avg. loss: 0.0236, Balanced Accuracy: 0.7749999761581421 (77%)
# Test set: Avg. loss: 0.0226, Balanced Accuracy: 0.7062499523162842 (71%)

# %%
feature_type = "time"
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
criterion = torch.nn.CrossEntropyLoss()
model = EEGNet(chunk_size=2001,
            num_electrodes=12,
            dropout=0,
            kernel_1=500,
            kernel_2=250,
            F1=4,
            F2=16,
            D=2,
            num_classes=2)
model.to(device)
model.load_state_dict(torch.load("../models/EEGNet/EEGNet_Subject_{}.pt".format(num_subject)))
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
#scheduler = torch.optim.lr_scheduler.MultiStepLR(optimizer, milestones=[20, 50], gamma=0.1)
scheduler = torch.optim.lr_scheduler.MultiplicativeLR(optimizer, lr_lambda=lambda epoch: 0.95)
scheduler_dict = {"MultiplicativeLR" : scheduler}
logs = training.train_model(model, trainloader, valloader, device, criterion, feature_type, 51, optimizer, scheduler_dict, print_epoch = 5)
# change weights of the model to the best weights
model.load_state_dict(logs["best_model_weights"])
model.eval()
train_balanced_accuracy, train_loss = training.evaluate_classification_model(model,trainloader,device,criterion,feature_type,dataset="Train")
val_balanced_accuracy, val_loss = training.evaluate_classification_model(model,valloader,device,criterion,feature_type,dataset="Val")
test_balanced_accuracy, test_loss = training.evaluate_classification_model(model,testloader,device,criterion,feature_type,dataset="Test")
# Out:
# Epoch 0:   0%|          | 0/10 [00:00<?, ?batch/s]
# Epoch 0
# lr:  0.01
# -------------------------
# Train set: Avg. loss: 0.0394, Balanced Accuracy: 0.6687500476837158 (67%)
# Test set: Avg. loss: 0.0172, Balanced Accuracy: 0.7687499523162842 (77%)
# Saving best model weights with balanced accuracy:  0.7687499523162842
# -------------------------
# Epoch 0: 100%|██████████| 10/10 [00:02<00:00,  4.15batch/s, accuracy=0.619, loss=0.0484]
# Epoch 1: 100%|██████████| 10/10 [00:01<00:00,  8.52batch/s, accuracy=0.85, loss=0.0212]
# Epoch 2: 100%|██████████| 10/10 [00:01<00:00,  8.67batch/s, accuracy=0.881, loss=0.0167]
# Epoch 3: 100%|██████████| 10/10 [00:01<00:00,  8.71batch/s, accuracy=0.975, loss=0.00901]
# Epoch 4: 100%|██████████| 10/10 [00:01<00:00,  8.20batch/s, accuracy=0.981, loss=0.00596]
# Epoch 5:   0%|          | 0/10 [00:00<?, ?batch/s]
# Epoch 5
# lr:  0.007737809374999999
# -------------------------
# Train set: Avg. loss: 0.0070, Balanced Accuracy: 0.9437500238418579 (94%)
# Test set: Avg. loss: 0.0195, Balanced Accuracy: 0.8312499523162842 (83%)
# Saving best model weights with balanced accuracy:  0.8312499523162842
# -------------------------
# Epoch 5: 100%|██████████| 10/10 [00:02<00:00,  3.97batch/s, accuracy=0.994, loss=0.00392]
# Epoch 6: 100%|██████████| 10/10 [00:01<00:00,  9.50batch/s, accuracy=0.981, loss=0.00379]
# Epoch 7: 100%|██████████| 10/10 [00:01<00:00,  8.79batch/s, accuracy=0.994, loss=0.00316]
# Epoch 8: 100%|██████████| 10/10 [00:01<00:00,  8.29batch/s, accuracy=0.975, loss=0.00388]
# Epoch 9: 100%|██████████| 10/10 [00:01<00:00,  8.10batch/s, accuracy=1, loss=0.00225]
# Epoch 10:   0%|          | 0/10 [00:00<?, ?batch/s]
# Epoch 10
# lr:  0.005987369392383786
# -------------------------
# Train set: Avg. loss: 0.0068, Balanced Accuracy: 0.9437500238418579 (94%)
# Test set: Avg. loss: 0.0275, Balanced Accuracy: 0.7875000238418579 (79%)
# -------------------------
# Epoch 10: 100%|██████████| 10/10 [00:02<00:00,  4.07batch/s, accuracy=0.994, loss=0.00248]
# Epoch 11: 100%|██████████| 10/10 [00:01<00:00,  9.07batch/s, accuracy=0.994, loss=0.00186]
# Epoch 12: 100%|██████████| 10/10 [00:01<00:00,  9.13batch/s, accuracy=1, loss=0.0008]
# Epoch 13: 100%|██████████| 10/10 [00:01<00:00,  8.46batch/s, accuracy=1, loss=0.000885]
# Epoch 14: 100%|██████████| 10/10 [00:01<00:00,  8.49batch/s, accuracy=1, loss=0.000558]
# Epoch 15:   0%|          | 0/10 [00:00<?, ?batch/s]
# Epoch 15
# lr:  0.00463291230159753
# -------------------------
# Train set: Avg. loss: 0.0007, Balanced Accuracy: 1.0 (100%)
# Test set: Avg. loss: 0.0284, Balanced Accuracy: 0.7937500476837158 (79%)
# -------------------------
# Epoch 15: 100%|██████████| 10/10 [00:02<00:00,  3.97batch/s, accuracy=1, loss=0.000463]
# Epoch 16: 100%|██████████| 10/10 [00:01<00:00,  9.09batch/s, accuracy=0.994, loss=0.000784]
# Epoch 17: 100%|██████████| 10/10 [00:01<00:00,  9.26batch/s, accuracy=1, loss=0.000536]
# Epoch 18: 100%|██████████| 10/10 [00:01<00:00,  8.47batch/s, accuracy=1, loss=0.000548]
# Epoch 19: 100%|██████████| 10/10 [00:01<00:00,  8.51batch/s, accuracy=0.994, loss=0.000979]
# Epoch 20:   0%|          | 0/10 [00:00<?, ?batch/s]
# Epoch 20
# lr:  0.0035848592240854188
# -------------------------
# Train set: Avg. loss: 0.0010, Balanced Accuracy: 1.0 (100%)
# Test set: Avg. loss: 0.0273, Balanced Accuracy: 0.8125 (81%)
# -------------------------
# Epoch 20: 100%|██████████| 10/10 [00:02<00:00,  4.23batch/s, accuracy=1, loss=0.000415]
# Epoch 21: 100%|██████████| 10/10 [00:01<00:00,  9.02batch/s, accuracy=1, loss=0.000397]
# Epoch 22: 100%|██████████| 10/10 [00:01<00:00,  8.67batch/s, accuracy=1, loss=0.000254]
# Epoch 23: 100%|██████████| 10/10 [00:01<00:00,  9.81batch/s, accuracy=1, loss=0.000265]
# Epoch 24: 100%|██████████| 10/10 [00:00<00:00, 10.18batch/s, accuracy=1, loss=0.000218]
# Epoch 25:   0%|          | 0/10 [00:00<?, ?batch/s]
# Epoch 25
# lr:  0.0027738957312183374
# -------------------------
# Train set: Avg. loss: 0.0002, Balanced Accuracy: 1.0 (100%)
# Test set: Avg. loss: 0.0319, Balanced Accuracy: 0.800000011920929 (80%)
# -------------------------
# Epoch 25: 100%|██████████| 10/10 [00:01<00:00,  5.05batch/s, accuracy=1, loss=0.000251]
# Epoch 26: 100%|██████████| 10/10 [00:00<00:00, 11.11batch/s, accuracy=1, loss=0.000273]
# Epoch 27: 100%|██████████| 10/10 [00:00<00:00, 11.49batch/s, accuracy=1, loss=0.000262]
# Epoch 28: 100%|██████████| 10/10 [00:00<00:00, 11.51batch/s, accuracy=1, loss=0.000294]
# Epoch 29: 100%|██████████| 10/10 [00:00<00:00, 11.18batch/s, accuracy=1, loss=0.000182]
# Epoch 30:   0%|          | 0/10 [00:00<?, ?batch/s]
# Epoch 30
# lr:  0.0021463876394293723
# -------------------------
# Train set: Avg. loss: 0.0001, Balanced Accuracy: 1.0 (100%)
# Test set: Avg. loss: 0.0331, Balanced Accuracy: 0.8125 (81%)
# -------------------------
# Epoch 30: 100%|██████████| 10/10 [00:01<00:00,  5.13batch/s, accuracy=1, loss=0.000199]
# Epoch 31: 100%|██████████| 10/10 [00:00<00:00, 10.82batch/s, accuracy=1, loss=0.000143]
# Epoch 32: 100%|██████████| 10/10 [00:00<00:00, 10.78batch/s, accuracy=1, loss=0.000137]
# Epoch 33: 100%|██████████| 10/10 [00:01<00:00,  8.78batch/s, accuracy=1, loss=0.000133]
# Epoch 34: 100%|██████████| 10/10 [00:00<00:00, 10.27batch/s, accuracy=1, loss=0.000188]
# Epoch 35:   0%|          | 0/10 [00:00<?, ?batch/s]
# Epoch 35
# lr:  0.0016608338398760713
# -------------------------
# Train set: Avg. loss: 0.0001, Balanced Accuracy: 1.0 (100%)
# Test set: Avg. loss: 0.0337, Balanced Accuracy: 0.8125 (81%)
# -------------------------
# Epoch 35: 100%|██████████| 10/10 [00:01<00:00,  5.25batch/s, accuracy=1, loss=0.000134]
# Epoch 36: 100%|██████████| 10/10 [00:00<00:00, 12.30batch/s, accuracy=1, loss=0.000105]
# Epoch 37: 100%|██████████| 10/10 [00:00<00:00, 12.39batch/s, accuracy=1, loss=0.000174]
# Epoch 38: 100%|██████████| 10/10 [00:00<00:00, 11.01batch/s, accuracy=1, loss=0.000104]
# Epoch 39: 100%|██████████| 10/10 [00:00<00:00, 11.58batch/s, accuracy=1, loss=0.000146]
# Epoch 40:   0%|          | 0/10 [00:00<?, ?batch/s]
# Epoch 40
# lr:  0.0012851215656510308
# -------------------------
# Train set: Avg. loss: 0.0001, Balanced Accuracy: 1.0 (100%)
# Test set: Avg. loss: 0.0347, Balanced Accuracy: 0.8062499761581421 (81%)
# -------------------------
# Epoch 40: 100%|██████████| 10/10 [00:01<00:00,  5.53batch/s, accuracy=1, loss=0.00016]
# Epoch 41: 100%|██████████| 10/10 [00:00<00:00, 11.88batch/s, accuracy=1, loss=0.000121]
# Epoch 42: 100%|██████████| 10/10 [00:00<00:00, 13.10batch/s, accuracy=1, loss=0.000124]
# Epoch 43: 100%|██████████| 10/10 [00:00<00:00, 12.40batch/s, accuracy=1, loss=9.32e-5]
# Epoch 44: 100%|██████████| 10/10 [00:00<00:00, 12.45batch/s, accuracy=1, loss=0.000108]
# Epoch 45:   0%|          | 0/10 [00:00<?, ?batch/s]
# Epoch 45
# lr:  0.000994402569870922
# -------------------------
# Train set: Avg. loss: 0.0001, Balanced Accuracy: 1.0 (100%)
# Test set: Avg. loss: 0.0349, Balanced Accuracy: 0.8062499761581421 (81%)
# -------------------------
# Epoch 45: 100%|██████████| 10/10 [00:01<00:00,  5.24batch/s, accuracy=1, loss=0.000124]
# Epoch 46: 100%|██████████| 10/10 [00:00<00:00, 12.02batch/s, accuracy=1, loss=0.000112]
# Epoch 47: 100%|██████████| 10/10 [00:00<00:00, 11.05batch/s, accuracy=1, loss=0.000119]
# Epoch 48: 100%|██████████| 10/10 [00:00<00:00, 11.07batch/s, accuracy=1, loss=0.000137]
# Epoch 49: 100%|██████████| 10/10 [00:00<00:00, 11.02batch/s, accuracy=1, loss=0.000207]
# Epoch 50:   0%|          | 0/10 [00:00<?, ?batch/s]
# Epoch 50
# lr:  0.0007694497527671312
# -------------------------
# Train set: Avg. loss: 0.0001, Balanced Accuracy: 1.0 (100%)
# Test set: Avg. loss: 0.0354, Balanced Accuracy: 0.8187500238418579 (82%)
# -------------------------
# Epoch 50: 100%|██████████| 10/10 [00:01<00:00,  5.29batch/s, accuracy=1, loss=0.000125]
# Train set: Avg. loss: 0.0070, Balanced Accuracy: 0.9437500238418579 (94%)
# Val set: Avg. loss: 0.0195, Balanced Accuracy: 0.8312499523162842 (83%)
# Test set: Avg. loss: 0.0184, Balanced Accuracy: 0.8125 (81%)

# %%
for param in model.parameters():
    print(param.data.shape)
    time_filters = param.data.cpu().numpy()
    break

# plot all the filters
fig, axs = plt.subplots(2,2,figsize=(10,10))
for i in range(4):
    ax = axs[i//2,i%2]
    ax.plot(time_filters[i,0,0,:])
    ax.set_title("Filter "+str(i))
plt.savefig("../plots/intra_subject_classification_transfer/time_filters_eegnet_sessions.png")
plt.show()
# Out:
# torch.Size([4, 1, 1, 500])

# %%
montage = mne.channels.make_standard_montage('standard_1020')
list_channels_std = list_all_ch_names

def get_positions_from_channel_list(channel_list, montage):
    dict_positions = montage.get_positions()["ch_pos"]
    positions = []
    for channel in channel_list:
        positions.append(dict_positions[channel])
    return np.array(positions)

ch_positions = get_positions_from_channel_list(list_channels_std, montage)

fig, ax = plt.subplots(2, 4, figsize=(10, 5))

for i in range(2):
    for j in range(4):
        spatial_map_12 = model.block1[2].weight.data[i + 2 * j].cpu().numpy().flatten()
        spatial_map_64 = np.zeros(64)
        spatial_map_64[list_idx_channels] = spatial_map_12
        mne.viz.plot_topomap(
            spatial_map_64,
            ch_positions[:, :2],
            show=False,
            axes=ax[i, j]
        )
plt.savefig("../plots/intra_subject_classification_transfer/spatial_filters_eegnet_sessions.png")
plt.show()

# %% [markdown]
# ## ATCNet

# %%
import importlib
importlib.reload(dataset)
importlib.reload(training)
importlib.reload(models)
# Out:
# <module 'eeg_project_package.models' from '/home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/models.py'>

# %%
# Define the subject and the session
task_type = "imaginary_left/right"
folder_path = "/network/lustre/iss02/aramis/projects/cracknetworks/"

num_sessions = [1,2,3]
num_subjects = [1,2,3,5,6,7,8,10,11,13,14]   
list_labels = ['OVTK_GDF_Left','OVTK_GDF_Right']

# Define the channels
list_name_channels = ["CP1","CP3","CP5","C1","C3","C5","C2","CP2","Cz","FCz","C4","CP4"]
list_idx_channels = [list_all_ch_names.index(ch) for ch in list_name_channels]

# Define the labels
labels = ['OVTK_GDF_Left', 'OVTK_GDF_Right']

# Define the parameters of the dataset
feature_type = ["time"]
dict_preprocessing = {"polynomial_degree":None,"tmin":0,"tmax":4,"seq_length":2001}
dict_features = {"type_psd":"welch","fs":500,"nfft":300,"noverlap":150,"nperseg":300,"filter_order":19,"fmin":4,"fmax":30}

num_subject = num_subjects[4]
num_val_subjects = [num_subject]
num_test_subjects = [num_subject]
num_train_subjects = [num_subject]
num_train_sessions = [1]
num_val_sessions = [2]
num_test_sessions = [3]

print("Train subjects: ", num_train_subjects)
print("Val subjects: ", num_val_subjects)
print("Test subjects: ", num_test_subjects)

# Create the dataset
trainset = dataset.Braccio_Dataset_Multi_Subject(folder_path, num_train_subjects, num_train_sessions, list_idx_channels = list_idx_channels, list_labels = labels, feature_type = feature_type, dict_preprocessing = dict_preprocessing, dict_features = dict_features)
testset = dataset.Braccio_Dataset_Multi_Subject(folder_path, num_test_subjects, num_test_sessions, list_idx_channels = list_idx_channels, list_labels = labels, feature_type = feature_type, dict_preprocessing = dict_preprocessing, dict_features = dict_features)
valset = dataset.Braccio_Dataset_Multi_Subject(folder_path, num_val_subjects, num_val_sessions, list_idx_channels = list_idx_channels, list_labels = labels, feature_type = feature_type, dict_preprocessing = dict_preprocessing, dict_features = dict_features)

# Create the dataloader
trainset.transform_dataset_numpy_to_torch()
trainset.features["time"] = trainset.features["time"].unsqueeze(1)
testset.transform_dataset_numpy_to_torch()
testset.features["time"] = testset.features["time"].unsqueeze(1)
valset.transform_dataset_numpy_to_torch()
valset.features["time"] = valset.features["time"].unsqueeze(1)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=16, shuffle=True, num_workers=2)
testloader = torch.utils.data.DataLoader(testset, batch_size=32, shuffle=True, num_workers=2)
valloader = torch.utils.data.DataLoader(valset, batch_size=32, shuffle=True, num_workers=2)

feature_type = "time"
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
criterion = torch.nn.CrossEntropyLoss()
model = models.ATCNet(in_channels=1,
            num_classes=2,
            num_windows=5,
            num_electrodes=12,
            chunk_size=2001,
            filter_size=250,)
model.to(device)
model.load_state_dict(torch.load("../models/ATCNet/ATCNet_Subject_{}.pt".format(num_subjects[i])))
for param in model.named_parameters():
    if "dense4" in param[0]:
        continue
    else:
        param[1].requires_grad = False
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
scheduler1 = torch.optim.lr_scheduler.MultiplicativeLR(optimizer, lr_lambda=lambda epoch: 0.95)
scheduler2 = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=3, factor=0.5)
scheduler_dict = {"MultiplicativeLR":scheduler1} #, "ReduceLROnPlateau":scheduler2}
logs = training.train_model(model, trainloader, valloader, device, criterion, feature_type, 51, optimizer, scheduler_dict, print_epoch = 5)
# change weights of the model to the best weights
model.load_state_dict(logs["best_model_weights"])
model.eval()
train_balanced_accuracy, train_loss = training.evaluate_classification_model(model,trainloader,device,criterion,feature_type,dataset="Train")
val_balanced_accuracy, val_loss = training.evaluate_classification_model(model,valloader,device,criterion,feature_type,dataset="Val")
test_balanced_accuracy, test_loss = training.evaluate_classification_model(model,testloader,device,criterion,feature_type,dataset="Test")
# Out:
# Train subjects:  [6]
# Val subjects:  [6]
# Test subjects:  [6]
# Error in file:  /network/lustre/iss02/aramis/projects/cracknetworks/sub-06/ses-02/EEG/Test-[2022.05.10-16.09.32].edf
# 'Event name "OVTK_GDF_Left" could not be found. The following events are present in the data: OVTK_StimulationId_ExperimentStart, OVTK_StimulationId_BaselineStart/OVTK_StimulationId_Beep'
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages/torch/nn/modules/conv.py:456: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at ../aten/src/ATen/native/Convolution.cpp:1031.)
#   return F.conv2d(input, weight, bias, self.stride,
# Epoch 0:   0%|          | 0/10 [00:00<?, ?batch/s]
# Epoch 0
# lr:  0.001
# -------------------------
# Train set: Avg. loss: 0.0297, Balanced Accuracy: 0.84375 (84%)
# Test set: Avg. loss: 0.0126, Balanced Accuracy: 0.9125000238418579 (91%)
# Saving best model weights with balanced accuracy:  0.9125000238418579
# -------------------------
# Epoch 0: 100%|██████████| 10/10 [00:01<00:00,  5.54batch/s, accuracy=0.825, loss=0.03]
# Epoch 1: 100%|██████████| 10/10 [00:00<00:00, 16.00batch/s, accuracy=0.844, loss=0.0296]
# Epoch 2: 100%|██████████| 10/10 [00:00<00:00, 12.60batch/s, accuracy=0.838, loss=0.0299]
# Epoch 3: 100%|██████████| 10/10 [00:00<00:00, 13.37batch/s, accuracy=0.762, loss=0.0328]
# Epoch 4: 100%|██████████| 10/10 [00:00<00:00, 12.73batch/s, accuracy=0.8, loss=0.0318]
# Epoch 5:   0%|          | 0/10 [00:00<?, ?batch/s]
# Epoch 5
# lr:  0.0007737809374999998
# -------------------------
# Train set: Avg. loss: 0.0287, Balanced Accuracy: 0.8374999761581421 (84%)
# Test set: Avg. loss: 0.0125, Balanced Accuracy: 0.9125000238418579 (91%)
# -------------------------
# Epoch 5: 100%|██████████| 10/10 [00:01<00:00,  5.62batch/s, accuracy=0.806, loss=0.0308]
# Epoch 6: 100%|██████████| 10/10 [00:00<00:00, 14.26batch/s, accuracy=0.8, loss=0.0308]
# Epoch 7: 100%|██████████| 10/10 [00:00<00:00, 12.37batch/s, accuracy=0.75, loss=0.034]
# Epoch 8: 100%|██████████| 10/10 [00:00<00:00, 15.86batch/s, accuracy=0.844, loss=0.0301]
# Epoch 9: 100%|██████████| 10/10 [00:00<00:00, 13.56batch/s, accuracy=0.819, loss=0.0307]
# Epoch 10:   0%|          | 0/10 [00:00<?, ?batch/s]
# Epoch 10
# lr:  0.0005987369392383785
# -------------------------
# Train set: Avg. loss: 0.0288, Balanced Accuracy: 0.8374999761581421 (84%)
# Test set: Avg. loss: 0.0126, Balanced Accuracy: 0.9125000238418579 (91%)
# -------------------------
# Epoch 10: 100%|██████████| 10/10 [00:01<00:00,  5.36batch/s, accuracy=0.838, loss=0.0293]
# Epoch 11: 100%|██████████| 10/10 [00:00<00:00, 14.20batch/s, accuracy=0.744, loss=0.033]
# Epoch 12: 100%|██████████| 10/10 [00:00<00:00, 12.36batch/s, accuracy=0.831, loss=0.0301]
# Epoch 13: 100%|██████████| 10/10 [00:00<00:00, 13.04batch/s, accuracy=0.787, loss=0.0315]
# Epoch 14: 100%|██████████| 10/10 [00:00<00:00, 13.06batch/s, accuracy=0.787, loss=0.0317]
# Epoch 15:   0%|          | 0/10 [00:00<?, ?batch/s]
# Epoch 15
# lr:  0.00046329123015975297
# -------------------------
# Train set: Avg. loss: 0.0286, Balanced Accuracy: 0.8374999761581421 (84%)
# Test set: Avg. loss: 0.0124, Balanced Accuracy: 0.9125000238418579 (91%)
# -------------------------
# Epoch 15: 100%|██████████| 10/10 [00:01<00:00,  5.60batch/s, accuracy=0.781, loss=0.0316]
# Epoch 16: 100%|██████████| 10/10 [00:00<00:00, 12.02batch/s, accuracy=0.806, loss=0.0307]
# Epoch 17: 100%|██████████| 10/10 [00:00<00:00, 14.35batch/s, accuracy=0.844, loss=0.0297]
# Epoch 18: 100%|██████████| 10/10 [00:00<00:00, 13.50batch/s, accuracy=0.756, loss=0.0336]
# Epoch 19: 100%|██████████| 10/10 [00:00<00:00, 12.05batch/s, accuracy=0.756, loss=0.0319]
# Epoch 20:   0%|          | 0/10 [00:00<?, ?batch/s]
# Epoch 20
# lr:  0.0003584859224085418
# -------------------------
# Train set: Avg. loss: 0.0286, Balanced Accuracy: 0.84375 (84%)
# Test set: Avg. loss: 0.0125, Balanced Accuracy: 0.9125000238418579 (91%)
# -------------------------
# Epoch 20: 100%|██████████| 10/10 [00:01<00:00,  5.54batch/s, accuracy=0.781, loss=0.0316]
# Epoch 21: 100%|██████████| 10/10 [00:00<00:00, 13.98batch/s, accuracy=0.8, loss=0.0311]
# Epoch 22: 100%|██████████| 10/10 [00:00<00:00, 13.27batch/s, accuracy=0.825, loss=0.0306]
# Epoch 23: 100%|██████████| 10/10 [00:00<00:00, 12.38batch/s, accuracy=0.775, loss=0.032]
# Epoch 24: 100%|██████████| 10/10 [00:00<00:00, 15.36batch/s, accuracy=0.819, loss=0.0297]
# Epoch 25:   0%|          | 0/10 [00:00<?, ?batch/s]
# Epoch 25
# lr:  0.00027738957312183364
# -------------------------
# Train set: Avg. loss: 0.0285, Balanced Accuracy: 0.84375 (84%)
# Test set: Avg. loss: 0.0124, Balanced Accuracy: 0.918749988079071 (92%)
# Saving best model weights with balanced accuracy:  0.918749988079071
# -------------------------
# Epoch 25: 100%|██████████| 10/10 [00:01<00:00,  5.46batch/s, accuracy=0.819, loss=0.0304]
# Epoch 26: 100%|██████████| 10/10 [00:00<00:00, 12.82batch/s, accuracy=0.806, loss=0.0303]
# Epoch 27: 100%|██████████| 10/10 [00:00<00:00, 14.04batch/s, accuracy=0.8, loss=0.0308]
# Epoch 28: 100%|██████████| 10/10 [00:00<00:00, 14.06batch/s, accuracy=0.831, loss=0.0299]
# Epoch 29: 100%|██████████| 10/10 [00:00<00:00, 12.84batch/s, accuracy=0.825, loss=0.0305]
# Epoch 30:   0%|          | 0/10 [00:00<?, ?batch/s]
# Epoch 30
# lr:  0.00021463876394293716
# -------------------------
# Train set: Avg. loss: 0.0284, Balanced Accuracy: 0.84375 (84%)
# Test set: Avg. loss: 0.0124, Balanced Accuracy: 0.918749988079071 (92%)
# -------------------------
# Epoch 30: 100%|██████████| 10/10 [00:01<00:00,  5.40batch/s, accuracy=0.819, loss=0.0302]
# Epoch 31: 100%|██████████| 10/10 [00:00<00:00, 13.60batch/s, accuracy=0.819, loss=0.0303]
# Epoch 32: 100%|██████████| 10/10 [00:00<00:00, 12.98batch/s, accuracy=0.806, loss=0.0307]
# Epoch 33: 100%|██████████| 10/10 [00:00<00:00, 19.33batch/s, accuracy=0.806, loss=0.0302]
# Epoch 34: 100%|██████████| 10/10 [00:00<00:00, 18.92batch/s, accuracy=0.819, loss=0.0304]
# Epoch 35:   0%|          | 0/10 [00:00<?, ?batch/s]
# Epoch 35
# lr:  0.00016608338398760707
# -------------------------
# Train set: Avg. loss: 0.0284, Balanced Accuracy: 0.84375 (84%)
# Test set: Avg. loss: 0.0124, Balanced Accuracy: 0.918749988079071 (92%)
# -------------------------
# Epoch 35: 100%|██████████| 10/10 [00:01<00:00,  6.66batch/s, accuracy=0.775, loss=0.0325]
# Epoch 36: 100%|██████████| 10/10 [00:00<00:00, 17.29batch/s, accuracy=0.794, loss=0.0316]
# Epoch 37: 100%|██████████| 10/10 [00:00<00:00, 20.32batch/s, accuracy=0.8, loss=0.0313]
# Epoch 38: 100%|██████████| 10/10 [00:00<00:00, 16.22batch/s, accuracy=0.85, loss=0.0298]
# Epoch 39: 100%|██████████| 10/10 [00:00<00:00, 18.33batch/s, accuracy=0.831, loss=0.0293]
# Epoch 40:   0%|          | 0/10 [00:00<?, ?batch/s]
# Epoch 40
# lr:  0.00012851215656510304
# -------------------------
# Train set: Avg. loss: 0.0284, Balanced Accuracy: 0.84375 (84%)
# Test set: Avg. loss: 0.0123, Balanced Accuracy: 0.918749988079071 (92%)
# -------------------------
# Epoch 40: 100%|██████████| 10/10 [00:01<00:00,  6.45batch/s, accuracy=0.819, loss=0.0296]
# Epoch 41: 100%|██████████| 10/10 [00:00<00:00, 15.88batch/s, accuracy=0.85, loss=0.0295]
# Epoch 42: 100%|██████████| 10/10 [00:00<00:00, 19.08batch/s, accuracy=0.831, loss=0.0301]
# Epoch 43: 100%|██████████| 10/10 [00:00<00:00, 17.20batch/s, accuracy=0.819, loss=0.0304]
# Epoch 44: 100%|██████████| 10/10 [00:00<00:00, 16.28batch/s, accuracy=0.794, loss=0.0312]
# Epoch 45:   0%|          | 0/10 [00:00<?, ?batch/s]
# Epoch 45
# lr:  9.944025698709218e-05
# -------------------------
# Train set: Avg. loss: 0.0284, Balanced Accuracy: 0.84375 (84%)
# Test set: Avg. loss: 0.0123, Balanced Accuracy: 0.918749988079071 (92%)
# -------------------------
# Epoch 45: 100%|██████████| 10/10 [00:01<00:00,  7.19batch/s, accuracy=0.819, loss=0.0319]
# Epoch 46: 100%|██████████| 10/10 [00:00<00:00, 18.76batch/s, accuracy=0.812, loss=0.0308]
# Epoch 47: 100%|██████████| 10/10 [00:00<00:00, 15.72batch/s, accuracy=0.85, loss=0.0294]
# Epoch 48: 100%|██████████| 10/10 [00:00<00:00, 17.43batch/s, accuracy=0.775, loss=0.0321]
# Epoch 49: 100%|██████████| 10/10 [00:00<00:00, 19.31batch/s, accuracy=0.806, loss=0.0309]
# Epoch 50:   0%|          | 0/10 [00:00<?, ?batch/s]
# Epoch 50
# lr:  7.69449752767131e-05
# -------------------------
# Train set: Avg. loss: 0.0284, Balanced Accuracy: 0.84375 (84%)
# Test set: Avg. loss: 0.0123, Balanced Accuracy: 0.918749988079071 (92%)
# -------------------------
# Epoch 50: 100%|██████████| 10/10 [00:01<00:00,  6.71batch/s, accuracy=0.831, loss=0.0297]
# Train set: Avg. loss: 0.0285, Balanced Accuracy: 0.84375 (84%)
# Val set: Avg. loss: 0.0124, Balanced Accuracy: 0.918749988079071 (92%)
# Test set: Avg. loss: 0.0135, Balanced Accuracy: 0.8562500476837158 (86%)

# %%
feature_type = "time"
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
criterion = torch.nn.CrossEntropyLoss()
model = models.ATCNet(in_channels=1,
            num_classes=2,
            num_windows=5,
            num_electrodes=12,
            chunk_size=2001,
            filter_size=250,)
model.to(device)
model.load_state_dict(torch.load("../models/ATCNet/ATCNet_Subject_{}.pt".format(num_subjects[i])))
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
scheduler1 = torch.optim.lr_scheduler.MultiplicativeLR(optimizer, lr_lambda=lambda epoch: 0.95)
scheduler2 = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=3, factor=0.5)
scheduler_dict = {"MultiplicativeLR":scheduler1} #, "ReduceLROnPlateau":scheduler2}
logs = training.train_model(model, trainloader, valloader, device, criterion, feature_type, 51, optimizer, scheduler_dict, print_epoch = 5)
# change weights of the model to the best weights
model.load_state_dict(logs["best_model_weights"])
model.eval()
train_balanced_accuracy, train_loss = training.evaluate_classification_model(model,trainloader,device,criterion,feature_type,dataset="Train")
val_balanced_accuracy, val_loss = training.evaluate_classification_model(model,valloader,device,criterion,feature_type,dataset="Val")
test_balanced_accuracy, test_loss = training.evaluate_classification_model(model,testloader,device,criterion,feature_type,dataset="Test")
# Out:
# Epoch 0:   0%|          | 0/10 [00:00<?, ?batch/s]
# Epoch 0
# lr:  0.001
# -------------------------
# Train set: Avg. loss: 0.0297, Balanced Accuracy: 0.84375 (84%)
# Test set: Avg. loss: 0.0126, Balanced Accuracy: 0.9125000238418579 (91%)
# Saving best model weights with balanced accuracy:  0.9125000238418579
# -------------------------
# Epoch 0: 100%|██████████| 10/10 [00:02<00:00,  4.77batch/s, accuracy=0.781, loss=0.0322]
# Epoch 1: 100%|██████████| 10/10 [00:01<00:00,  7.92batch/s, accuracy=0.844, loss=0.0288]
# Epoch 2: 100%|██████████| 10/10 [00:01<00:00,  8.03batch/s, accuracy=0.887, loss=0.0267]
# Epoch 3: 100%|██████████| 10/10 [00:01<00:00,  8.04batch/s, accuracy=0.919, loss=0.0256]
# Epoch 4: 100%|██████████| 10/10 [00:01<00:00,  7.52batch/s, accuracy=0.912, loss=0.0251]
# Epoch 5:   0%|          | 0/10 [00:00<?, ?batch/s]
# Epoch 5
# lr:  0.0007737809374999998
# -------------------------
# Train set: Avg. loss: 0.0224, Balanced Accuracy: 0.9562499523162842 (96%)
# Test set: Avg. loss: 0.0131, Balanced Accuracy: 0.8999999761581421 (90%)
# -------------------------
# Epoch 5: 100%|██████████| 10/10 [00:02<00:00,  4.87batch/s, accuracy=0.938, loss=0.0236]
# Epoch 6: 100%|██████████| 10/10 [00:01<00:00,  7.78batch/s, accuracy=0.95, loss=0.0228]
# Epoch 7: 100%|██████████| 10/10 [00:01<00:00,  7.92batch/s, accuracy=0.969, loss=0.0224]
# Epoch 8: 100%|██████████| 10/10 [00:01<00:00,  7.75batch/s, accuracy=0.975, loss=0.0219]
# Epoch 9: 100%|██████████| 10/10 [00:01<00:00,  7.81batch/s, accuracy=0.988, loss=0.0213]
# Epoch 10:   0%|          | 0/10 [00:00<?, ?batch/s]
# Epoch 10
# lr:  0.0005987369392383785
# -------------------------
# Train set: Avg. loss: 0.0205, Balanced Accuracy: 0.9937499761581421 (99%)
# Test set: Avg. loss: 0.0135, Balanced Accuracy: 0.887499988079071 (89%)
# -------------------------
# Epoch 10: 100%|██████████| 10/10 [00:02<00:00,  4.55batch/s, accuracy=0.969, loss=0.0217]
# Epoch 11: 100%|██████████| 10/10 [00:01<00:00,  7.41batch/s, accuracy=0.988, loss=0.021]
# Epoch 12: 100%|██████████| 10/10 [00:01<00:00,  6.25batch/s, accuracy=0.988, loss=0.0211]
# Epoch 13: 100%|██████████| 10/10 [00:01<00:00,  5.06batch/s, accuracy=0.994, loss=0.0207]
# Epoch 14: 100%|██████████| 10/10 [00:01<00:00,  5.30batch/s, accuracy=0.988, loss=0.0209]
# Epoch 15:   0%|          | 0/10 [00:00<?, ?batch/s]
# Epoch 15
# lr:  0.00046329123015975297
# -------------------------
# Train set: Avg. loss: 0.0201, Balanced Accuracy: 0.9937499761581421 (99%)
# Test set: Avg. loss: 0.0139, Balanced Accuracy: 0.8624999523162842 (86%)
# -------------------------
# Epoch 15: 100%|██████████| 10/10 [00:02<00:00,  3.48batch/s, accuracy=0.994, loss=0.0205]
# Epoch 16: 100%|██████████| 10/10 [00:01<00:00,  5.19batch/s, accuracy=0.994, loss=0.0205]
# Epoch 17: 100%|██████████| 10/10 [00:02<00:00,  4.64batch/s, accuracy=0.994, loss=0.0204]
# Epoch 18: 100%|██████████| 10/10 [00:02<00:00,  4.86batch/s, accuracy=0.988, loss=0.0205]
# Epoch 19: 100%|██████████| 10/10 [00:01<00:00,  5.09batch/s, accuracy=0.994, loss=0.0205]
# Epoch 20:   0%|          | 0/10 [00:00<?, ?batch/s]
# Epoch 20
# lr:  0.0003584859224085418
# -------------------------
# Train set: Avg. loss: 0.0199, Balanced Accuracy: 0.9937499761581421 (99%)
# Test set: Avg. loss: 0.0137, Balanced Accuracy: 0.8812500238418579 (88%)
# -------------------------
# Epoch 20: 100%|██████████| 10/10 [00:03<00:00,  3.08batch/s, accuracy=0.994, loss=0.0203]
# Epoch 21: 100%|██████████| 10/10 [00:01<00:00,  5.33batch/s, accuracy=0.988, loss=0.0207]
# Epoch 22: 100%|██████████| 10/10 [00:01<00:00,  5.73batch/s, accuracy=1, loss=0.0205]
# Epoch 23: 100%|██████████| 10/10 [00:01<00:00,  5.29batch/s, accuracy=0.994, loss=0.0202]
# Epoch 24: 100%|██████████| 10/10 [00:01<00:00,  5.08batch/s, accuracy=0.994, loss=0.0205]
# Epoch 25:   0%|          | 0/10 [00:00<?, ?batch/s]
# Epoch 25
# lr:  0.00027738957312183364
# -------------------------
# Train set: Avg. loss: 0.0197, Balanced Accuracy: 1.0 (100%)
# Test set: Avg. loss: 0.0138, Balanced Accuracy: 0.856249988079071 (86%)
# -------------------------
# Epoch 25: 100%|██████████| 10/10 [00:02<00:00,  3.34batch/s, accuracy=0.994, loss=0.0204]
# Epoch 26: 100%|██████████| 10/10 [00:01<00:00,  5.25batch/s, accuracy=1, loss=0.0199]
# Epoch 27: 100%|██████████| 10/10 [00:01<00:00,  5.85batch/s, accuracy=0.994, loss=0.0203]
# Epoch 28: 100%|██████████| 10/10 [00:01<00:00,  5.09batch/s, accuracy=1, loss=0.0202]
# Epoch 29: 100%|██████████| 10/10 [00:01<00:00,  5.43batch/s, accuracy=1, loss=0.0199]
# Epoch 30:   0%|          | 0/10 [00:00<?, ?batch/s]
# Epoch 30
# lr:  0.00021463876394293716
# -------------------------
# Train set: Avg. loss: 0.0196, Balanced Accuracy: 1.0 (100%)
# Test set: Avg. loss: 0.0137, Balanced Accuracy: 0.856249988079071 (86%)
# -------------------------
# Epoch 30: 100%|██████████| 10/10 [00:03<00:00,  3.32batch/s, accuracy=0.994, loss=0.0203]
# Epoch 31: 100%|██████████| 10/10 [00:01<00:00,  5.43batch/s, accuracy=1, loss=0.0201]
# Epoch 32: 100%|██████████| 10/10 [00:01<00:00,  5.67batch/s, accuracy=1, loss=0.0199]
# Epoch 33: 100%|██████████| 10/10 [00:01<00:00,  5.39batch/s, accuracy=0.994, loss=0.0201]
# Epoch 34: 100%|██████████| 10/10 [00:01<00:00,  5.37batch/s, accuracy=1, loss=0.0199]
# Epoch 35:   0%|          | 0/10 [00:00<?, ?batch/s]
# Epoch 35
# lr:  0.00016608338398760707
# -------------------------
# Train set: Avg. loss: 0.0196, Balanced Accuracy: 1.0 (100%)
# Test set: Avg. loss: 0.0136, Balanced Accuracy: 0.875 (88%)
# -------------------------
# Epoch 35: 100%|██████████| 10/10 [00:02<00:00,  3.35batch/s, accuracy=1, loss=0.0202]
# Epoch 36: 100%|██████████| 10/10 [00:01<00:00,  5.25batch/s, accuracy=1, loss=0.0198]
# Epoch 37: 100%|██████████| 10/10 [00:01<00:00,  5.44batch/s, accuracy=0.988, loss=0.0203]
# Epoch 38: 100%|██████████| 10/10 [00:01<00:00,  5.30batch/s, accuracy=1, loss=0.02]
# Epoch 39: 100%|██████████| 10/10 [00:01<00:00,  5.45batch/s, accuracy=1, loss=0.0199]
# Epoch 40:   0%|          | 0/10 [00:00<?, ?batch/s]
# Epoch 40
# lr:  0.00012851215656510304
# -------------------------
# Train set: Avg. loss: 0.0196, Balanced Accuracy: 1.0 (100%)
# Test set: Avg. loss: 0.0136, Balanced Accuracy: 0.875 (88%)
# -------------------------
# Epoch 40: 100%|██████████| 10/10 [00:02<00:00,  3.45batch/s, accuracy=1, loss=0.0199]
# Epoch 41: 100%|██████████| 10/10 [00:01<00:00,  5.45batch/s, accuracy=1, loss=0.02]
# Epoch 42: 100%|██████████| 10/10 [00:01<00:00,  5.24batch/s, accuracy=1, loss=0.0198]
# Epoch 43: 100%|██████████| 10/10 [00:01<00:00,  5.59batch/s, accuracy=1, loss=0.0198]
# Epoch 44: 100%|██████████| 10/10 [00:01<00:00,  5.19batch/s, accuracy=1, loss=0.0199]
# Epoch 45:   0%|          | 0/10 [00:00<?, ?batch/s]
# Epoch 45
# lr:  9.944025698709218e-05
# -------------------------
# Train set: Avg. loss: 0.0196, Balanced Accuracy: 1.0 (100%)
# Test set: Avg. loss: 0.0137, Balanced Accuracy: 0.862500011920929 (86%)
# -------------------------
# Epoch 45: 100%|██████████| 10/10 [00:03<00:00,  3.24batch/s, accuracy=1, loss=0.0198]
# Epoch 46: 100%|██████████| 10/10 [00:01<00:00,  5.66batch/s, accuracy=1, loss=0.0198]
# Epoch 47: 100%|██████████| 10/10 [00:01<00:00,  5.37batch/s, accuracy=1, loss=0.0198]
# Epoch 48: 100%|██████████| 10/10 [00:01<00:00,  5.06batch/s, accuracy=1, loss=0.0198]
# Epoch 49: 100%|██████████| 10/10 [00:01<00:00,  5.25batch/s, accuracy=1, loss=0.0199]
# Epoch 50:   0%|          | 0/10 [00:00<?, ?batch/s]
# Epoch 50
# lr:  7.69449752767131e-05
# -------------------------
# Train set: Avg. loss: 0.0196, Balanced Accuracy: 1.0 (100%)
# Test set: Avg. loss: 0.0137, Balanced Accuracy: 0.8500000238418579 (85%)
# -------------------------
# Epoch 50: 100%|██████████| 10/10 [00:02<00:00,  3.45batch/s, accuracy=1, loss=0.02]
# Train set: Avg. loss: 0.0297, Balanced Accuracy: 0.84375 (84%)
# Val set: Avg. loss: 0.0126, Balanced Accuracy: 0.9125000238418579 (91%)
# Test set: Avg. loss: 0.0135, Balanced Accuracy: 0.8812500238418579 (88%)

# %%
for param in model.parameters():
    print(param.data.shape)
    time_filters = param.data.cpu().numpy()
    break

# plot all the filters
fig, axs = plt.subplots(4,4,figsize=(20,20))
for i in range(4):
    for j in range(4):
        axs[i,j].plot(time_filters[i + 4*j,0,0,:])
        axs[i,j].set_title("Filter " + str(i + 4*j))
plt.savefig("../plots/intra_subject_classification_transfer/time_filters_atcnet_sessions.png")
plt.show()
# Out:
# torch.Size([16, 1, 1, 250])

# %%
montage = mne.channels.make_standard_montage('standard_1020')
list_channels_std = list_all_ch_names

def get_positions_from_channel_list(channel_list, montage):
    dict_positions = montage.get_positions()["ch_pos"]
    positions = []
    for channel in channel_list:
        positions.append(dict_positions[channel])
    return np.array(positions)

ch_positions = get_positions_from_channel_list(list_channels_std, montage)

fig, ax = plt.subplots(4, 4, figsize=(20, 20))

for i in range(4):
    for j in range(4):
        spatial_map_12 = model.conv_block[2].weight.data[i + 4 * j].cpu().numpy().flatten()
        spatial_map_64 = np.zeros(64)
        spatial_map_64[list_idx_channels] = spatial_map_12
        mne.viz.plot_topomap(
            spatial_map_64,
            ch_positions[:, :2],
            show=False,
            axes=ax[j, i]
        )
plt.savefig("../plots/intra_subject_classification_transfer/spatial_filters_atcnet_sessions.png")
plt.show()
