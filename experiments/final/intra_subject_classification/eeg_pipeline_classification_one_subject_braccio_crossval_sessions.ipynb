# %%
import mne
from mne.io import concatenate_raws, read_raw_edf
import matplotlib.pyplot as plt
import mne.viz
import os
import os.path as op
from mne.preprocessing import (ICA, create_eog_epochs, create_ecg_epochs,
                               corrmap)
from mne.time_frequency import tfr_multitaper
from mne.stats import permutation_cluster_1samp_test as pcluster_test
from mne.datasets import fetch_fsaverage
from mne import Epochs, EvokedArray, create_info, io, pick_types, read_events
from mne.datasets import sample
from mne.decoding import Vectorizer
from mne.decoding import CSP

import torch
from torcheeg.models import EEGNet
from torcheeg.models import DGCNN
from torcheeg import transforms

import numpy as np
import matplotlib.pyplot as plt
import scipy.signal as signal
import scipy as sc
from matplotlib import cm
import matplotlib.colors as colors

from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import StratifiedKFold
from sklearn.multiclass import OneVsRestClassifier
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import MinMaxScaler
from xgboost import XGBClassifier
import torchaudio

import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning) 

import pickle

# %%
import sys 
sys.path.append("/home/aurelien.stumpf/Development/BCI_Classification/")
from eeg_project_package import dataset, models, spectral_analysis, training

# %%
import importlib
importlib.reload(dataset)
importlib.reload(training)
importlib.reload(models)
importlib.reload(spectral_analysis)
# Out:
# <module 'eeg_project_package.spectral_analysis' from '/home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/spectral_analysis.py'>

# %% [markdown]
# ## Check Loading of Braccio Dataset Files

# %%
#Define the parameters
subject = 1  # use data from subject 1
runs = [6, 10, 14]  # use only hand and feet motor imagery runs

#Get data and locate in to given path
input_fname1 =  "/network/lustre/iss02/aramis/projects/cracknetworks/sub-01/ses-01/EEG/Test-[2022.03.28-17.46.29].edf"
#Read raw data files where each file contains a run
raws = read_raw_edf(input_fname1, preload=True)
#Combine all loaded runs
#raw_obj = concatenate_raws(raws)
raw_obj = raws

raw_data = raw_obj.get_data()
print("Number of channels: ", str(len(raw_data)))
print("Number of samples: ", str(len(raw_data)))

#Plot epochs & PSD
raw_obj.plot(duration=120, n_channels=15, scalings=dict(eeg=420e-6))
raw_obj.plot_psd(average=True)

# list of all channel names
list_all_ch_names = raw_obj.ch_names
# Out:
# Number of channels:  64
# Number of samples:  64
# <MNEBrowseFigure size 800x800 with 4 Axes>

# %% [markdown]
# ## Intra-Subject Classification

# %%
# Define the subject and the session
task_type = "imaginary_left/right"
folder_path = "/network/lustre/iss02/aramis/projects/cracknetworks/"

num_sessions = [1,2,3]
num_subjects = [1,2,3,5,6,7,8,10,11,13,14]   
list_labels = ['OVTK_GDF_Left','OVTK_GDF_Right']

# Define the channels
list_name_channels = ["CP1","CP3","CP5","C1","C3","C5","C2","CP2","Cz","FCz","C4","CP4"]
list_idx_channels = [list_all_ch_names.index(ch) for ch in list_name_channels]

# Define the labels
labels = ['OVTK_GDF_Left', 'OVTK_GDF_Right']

dict_crossval = {"test_balanced_accuracy":np.zeros((11,3)), "test_loss":np.zeros((11,3)), "val_balanced_accuracy":np.zeros((11,3)), "val_loss":np.zeros((11,3)), "train_balanced_accuracy":np.zeros((11,3)), "train_loss":np.zeros((11,3))}

# Define the parameters of the dataset
feature_type = ["time"]
dict_preprocessing = {"polynomial_degree":None,"tmin":0,"tmax":4,"seq_length":2001}
dict_features = {"type_psd":"welch","fs":500,"nfft":300,"noverlap":150,"nperseg":300,"filter_order":19,"fmin":4,"fmax":30}

for i in range(len(num_subjects)):
    for session in num_sessions : 
        # cross-validation
        num_val_subjects = [num_subjects[i]]
        num_test_subjects = [num_subjects[i]]
        num_train_subjects = [num_subjects[i]]
        if session == 1:
            num_train_sessions = [1]
            num_val_sessions = [2]
            num_test_sessions = [3]
        elif session == 2:
            num_train_sessions = [2]
            num_val_sessions = [3]
            num_test_sessions = [1]
        elif session == 3:
            num_train_sessions = [3]
            num_val_sessions = [1]
            num_test_sessions = [2]

        print("Train subjects: ", num_train_subjects)
        print("Val subjects: ", num_val_subjects)
        print("Test subjects: ", num_test_subjects)

        # Create the dataset
        trainset = dataset.Braccio_Dataset_Multi_Subject(folder_path, num_train_subjects, num_train_sessions, list_idx_channels = list_idx_channels, list_labels = labels, feature_type = feature_type, dict_preprocessing = dict_preprocessing, dict_features = dict_features)
        testset = dataset.Braccio_Dataset_Multi_Subject(folder_path, num_test_subjects, num_test_sessions, list_idx_channels = list_idx_channels, list_labels = labels, feature_type = feature_type, dict_preprocessing = dict_preprocessing, dict_features = dict_features)
        valset = dataset.Braccio_Dataset_Multi_Subject(folder_path, num_val_subjects, num_val_sessions, list_idx_channels = list_idx_channels, list_labels = labels, feature_type = feature_type, dict_preprocessing = dict_preprocessing, dict_features = dict_features)

        # Create the dataloader
        trainset.transform_dataset_numpy_to_torch()
        trainset.features["time"] = trainset.features["time"].unsqueeze(1)
        testset.transform_dataset_numpy_to_torch()
        testset.features["time"] = testset.features["time"].unsqueeze(1)
        valset.transform_dataset_numpy_to_torch()
        valset.features["time"] = valset.features["time"].unsqueeze(1)
        trainloader = torch.utils.data.DataLoader(trainset, batch_size=100, shuffle=True, num_workers=2)
        testloader = torch.utils.data.DataLoader(testset, batch_size=100, shuffle=True, num_workers=2)
        valloader = torch.utils.data.DataLoader(valset, batch_size=100, shuffle=True, num_workers=2)

        feature_type = "time"
        device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        criterion = torch.nn.CrossEntropyLoss()
        model = EEGNet(chunk_size=2001,
                    num_electrodes=12,
                    dropout=0.25,
                    kernel_1=500,
                    kernel_2=250,
                    F1=4,
                    F2=16,
                    D=2,
                    num_classes=2)
        model.to(device)
        optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
        #scheduler = torch.optim.lr_scheduler.MultiStepLR(optimizer, milestones=[20, 50], gamma=0.1)
        scheduler = torch.optim.lr_scheduler.MultiplicativeLR(optimizer, lr_lambda=lambda epoch: 0.95)
        scheduler_dict = {"MultiplicativeLR" : scheduler}
        logs = training.train_model(model, trainloader, valloader, device, criterion, feature_type, 51, optimizer, scheduler_dict, print_epoch = 5)

        # change weights of the model to the best weights
        model.load_state_dict(logs["best_model_weights"])
        model.eval()
        train_balanced_accuracy, train_loss = training.evaluate_classification_model(model,trainloader,device,criterion,feature_type,dataset="Train")
        val_balanced_accuracy, val_loss = training.evaluate_classification_model(model,valloader,device,criterion,feature_type,dataset="Val")
        test_balanced_accuracy, test_loss = training.evaluate_classification_model(model,testloader,device,criterion,feature_type,dataset="Test")
        dict_crossval["test_balanced_accuracy"][i,session-1] = test_balanced_accuracy
        dict_crossval["test_loss"][i,session-1] = test_loss
        dict_crossval["val_balanced_accuracy"][i,session-1] = val_balanced_accuracy
        dict_crossval["val_loss"][i,session-1] = val_loss
        dict_crossval["train_balanced_accuracy"][i,session-1] = train_balanced_accuracy
        dict_crossval["train_loss"][i,session-1] = train_loss

        # Save the model
        model_name = "EEGNet"
        model_path = "../models/EEGNet_session/"
        model_filename = model_path + "EEGNet_Subject_" + str(num_subjects[i]) + "Session_" + str(session) + ".pt"
        torch.save(model.state_dict(), model_filename)
# Out:
# Train subjects:  [1]
# Val subjects:  [1]
# Test subjects:  [1]
# Error in file:  /network/lustre/iss02/aramis/projects/cracknetworks/sub-01/ses-02/EEG/Train-[2022.04.04-16.15.17].edf
# 'Event name "OVTK_GDF_Left" could not be found. The following events are present in the data: OVTK_StimulationId_ExperimentStart, OVTK_StimulationId_BaselineStart/OVTK_StimulationId_Beep'
# Error in file:  /network/lustre/iss02/aramis/projects/cracknetworks/sub-01/ses-02/EEG/Train-[2022.04.04-16.14.01].edf
# 'Event name "OVTK_GDF_Left" could not be found. The following events are present in the data: OVTK_StimulationId_ExperimentStart, OVTK_StimulationId_BaselineStart/OVTK_StimulationId_Beep'
# Error in file:  /network/lustre/iss02/aramis/projects/cracknetworks/sub-01/ses-02/EEG/Test-[2022.04.04-16.52.15].edf
# 'Event name "OVTK_GDF_Left" could not be found. The following events are present in the data: OVTK_GDF_Feedback_Continuous, OVTK_GDF_Right, OVTK_StimulationId_ExperimentStart, OVTK_StimulationId_BaselineStart/OVTK_StimulationId_Beep, OVTK_StimulationId_BaselineStop/OVTK_StimulationId_Beep, OVTK_GDF_Cross_On_Screen/OVTK_GDF_Start_Of_Trial/OVTK_StimulationId_Beep, OVTK_GDF_End_Of_Trial/OVTK_StimulationId_VisualStimulationStar'
# Epoch 0:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 0
# lr:  0.01
# -------------------------
# Train set: Avg. loss: 0.0099, Balanced Accuracy: 0.4750000238418579 (48%)
# Test set: Avg. loss: 0.0152, Balanced Accuracy: 0.27142858505249023 (27%)
# Saving best model weights with balanced accuracy:  0.27142858505249023
# -------------------------
# Epoch 0: 100%|██████████| 2/2 [00:03<00:00,  1.76s/batch, accuracy=0.525, loss=0.0108]
# Epoch 1: 100%|██████████| 2/2 [00:01<00:00,  1.21batch/s, accuracy=0.7, loss=0.00656]
# Epoch 2: 100%|██████████| 2/2 [00:01<00:00,  1.38batch/s, accuracy=0.756, loss=0.00721]
# Epoch 3: 100%|██████████| 2/2 [00:01<00:00,  1.53batch/s, accuracy=0.863, loss=0.00422]
# Epoch 4: 100%|██████████| 2/2 [00:01<00:00,  1.38batch/s, accuracy=0.85, loss=0.00483]
# Epoch 5:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 5
# lr:  0.007737809374999999
# -------------------------
# Train set: Avg. loss: 0.0157, Balanced Accuracy: 0.75 (75%)
# Test set: Avg. loss: 0.3943, Balanced Accuracy: 0.41428571939468384 (41%)
# Saving best model weights with balanced accuracy:  0.41428571939468384
# -------------------------
# Epoch 5: 100%|██████████| 2/2 [00:02<00:00,  1.43s/batch, accuracy=0.819, loss=0.00463]
# Epoch 6: 100%|██████████| 2/2 [00:01<00:00,  2.00batch/s, accuracy=0.869, loss=0.00344]
# Epoch 7: 100%|██████████| 2/2 [00:01<00:00,  1.70batch/s, accuracy=0.9, loss=0.00276]
# Epoch 8: 100%|██████████| 2/2 [00:01<00:00,  1.61batch/s, accuracy=0.906, loss=0.00316]
# Epoch 9: 100%|██████████| 2/2 [00:01<00:00,  1.62batch/s, accuracy=0.931, loss=0.00287]
# Epoch 10:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 10
# lr:  0.005987369392383786
# -------------------------
# Train set: Avg. loss: 0.0038, Balanced Accuracy: 0.8999999761581421 (90%)
# Test set: Avg. loss: 0.3596, Balanced Accuracy: 0.40714287757873535 (41%)
# -------------------------
# Epoch 10: 100%|██████████| 2/2 [00:02<00:00,  1.38s/batch, accuracy=0.931, loss=0.00219]
# Epoch 11: 100%|██████████| 2/2 [00:01<00:00,  1.67batch/s, accuracy=0.95, loss=0.00177]
# Epoch 12: 100%|██████████| 2/2 [00:01<00:00,  1.68batch/s, accuracy=0.944, loss=0.00192]
# Epoch 13: 100%|██████████| 2/2 [00:01<00:00,  1.82batch/s, accuracy=0.963, loss=0.00137]
# Epoch 14: 100%|██████████| 2/2 [00:01<00:00,  1.81batch/s, accuracy=0.944, loss=0.00165]
# Epoch 15:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 15
# lr:  0.00463291230159753
# -------------------------
# Train set: Avg. loss: 0.0049, Balanced Accuracy: 0.875 (88%)
# Test set: Avg. loss: 0.3384, Balanced Accuracy: 0.4285714328289032 (43%)
# Saving best model weights with balanced accuracy:  0.4285714328289032
# -------------------------
# Epoch 15: 100%|██████████| 2/2 [00:02<00:00,  1.34s/batch, accuracy=0.95, loss=0.00171]
# Epoch 16: 100%|██████████| 2/2 [00:01<00:00,  1.80batch/s, accuracy=0.95, loss=0.00168]
# Epoch 17: 100%|██████████| 2/2 [00:01<00:00,  1.64batch/s, accuracy=0.981, loss=0.000978]
# Epoch 18: 100%|██████████| 2/2 [00:01<00:00,  1.89batch/s, accuracy=0.956, loss=0.00155]
# Epoch 19: 100%|██████████| 2/2 [00:01<00:00,  1.61batch/s, accuracy=0.988, loss=0.00114]
# Epoch 20:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 20
# lr:  0.0035848592240854188
# -------------------------
# Train set: Avg. loss: 0.0020, Balanced Accuracy: 0.918749988079071 (92%)
# Test set: Avg. loss: 0.2789, Balanced Accuracy: 0.4214285910129547 (42%)
# -------------------------
# Epoch 20: 100%|██████████| 2/2 [00:02<00:00,  1.26s/batch, accuracy=0.963, loss=0.00144]
# Epoch 21: 100%|██████████| 2/2 [00:01<00:00,  1.82batch/s, accuracy=0.975, loss=0.00121]
# Epoch 22: 100%|██████████| 2/2 [00:01<00:00,  1.59batch/s, accuracy=0.975, loss=0.001]
# Epoch 23: 100%|██████████| 2/2 [00:01<00:00,  1.82batch/s, accuracy=0.988, loss=0.000831]
# Epoch 24: 100%|██████████| 2/2 [00:01<00:00,  1.70batch/s, accuracy=0.988, loss=0.000949]
# Epoch 25:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 25
# lr:  0.0027738957312183374
# -------------------------
# Train set: Avg. loss: 0.0009, Balanced Accuracy: 0.981249988079071 (98%)
# Test set: Avg. loss: 0.2379, Balanced Accuracy: 0.4214285612106323 (42%)
# -------------------------
# Epoch 25: 100%|██████████| 2/2 [00:02<00:00,  1.33s/batch, accuracy=1, loss=0.000644]
# Epoch 26: 100%|██████████| 2/2 [00:01<00:00,  1.71batch/s, accuracy=0.994, loss=0.00077]
# Epoch 27: 100%|██████████| 2/2 [00:01<00:00,  1.75batch/s, accuracy=0.981, loss=0.00057]
# Epoch 28: 100%|██████████| 2/2 [00:01<00:00,  1.66batch/s, accuracy=0.994, loss=0.000619]
# Epoch 29: 100%|██████████| 2/2 [00:01<00:00,  1.64batch/s, accuracy=1, loss=0.000624]
# Epoch 30:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 30
# lr:  0.0021463876394293723
# -------------------------
# Train set: Avg. loss: 0.0007, Balanced Accuracy: 0.987500011920929 (99%)
# Test set: Avg. loss: 0.2345, Balanced Accuracy: 0.4214285612106323 (42%)
# -------------------------
# Epoch 30: 100%|██████████| 2/2 [00:02<00:00,  1.25s/batch, accuracy=0.994, loss=0.000616]
# Epoch 31: 100%|██████████| 2/2 [00:01<00:00,  1.69batch/s, accuracy=0.988, loss=0.00068]
# Epoch 32: 100%|██████████| 2/2 [00:01<00:00,  1.62batch/s, accuracy=0.988, loss=0.000584]
# Epoch 33: 100%|██████████| 2/2 [00:01<00:00,  1.78batch/s, accuracy=1, loss=0.000473]
# Epoch 34: 100%|██████████| 2/2 [00:01<00:00,  1.98batch/s, accuracy=1, loss=0.000563]
# Epoch 35:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 35
# lr:  0.0016608338398760713
# -------------------------
# Train set: Avg. loss: 0.0006, Balanced Accuracy: 1.0 (100%)
# Test set: Avg. loss: 0.2221, Balanced Accuracy: 0.4285714328289032 (43%)
# -------------------------
# Epoch 35: 100%|██████████| 2/2 [00:02<00:00,  1.21s/batch, accuracy=0.994, loss=0.00051]
# Epoch 36: 100%|██████████| 2/2 [00:01<00:00,  1.72batch/s, accuracy=0.994, loss=0.000496]
# Epoch 37: 100%|██████████| 2/2 [00:01<00:00,  1.67batch/s, accuracy=0.994, loss=0.000512]
# Epoch 38: 100%|██████████| 2/2 [00:01<00:00,  1.89batch/s, accuracy=0.988, loss=0.000686]
# Epoch 39: 100%|██████████| 2/2 [00:00<00:00,  2.86batch/s, accuracy=0.988, loss=0.000569]
# Epoch 40:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 40
# lr:  0.0012851215656510308
# -------------------------
# Train set: Avg. loss: 0.0004, Balanced Accuracy: 1.0 (100%)
# Test set: Avg. loss: 0.1976, Balanced Accuracy: 0.4214285910129547 (42%)
# -------------------------
# Epoch 40: 100%|██████████| 2/2 [00:01<00:00,  1.15batch/s, accuracy=0.994, loss=0.000441]
# Epoch 41: 100%|██████████| 2/2 [00:00<00:00,  2.43batch/s, accuracy=0.988, loss=0.00058]
# Epoch 42: 100%|██████████| 2/2 [00:00<00:00,  2.29batch/s, accuracy=0.988, loss=0.000558]
# Epoch 43: 100%|██████████| 2/2 [00:00<00:00,  2.75batch/s, accuracy=1, loss=0.000357]
# Epoch 44: 100%|██████████| 2/2 [00:00<00:00,  2.67batch/s, accuracy=1, loss=0.000365]
# Epoch 45:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 45
# lr:  0.000994402569870922
# -------------------------
# Train set: Avg. loss: 0.0004, Balanced Accuracy: 1.0 (100%)
# Test set: Avg. loss: 0.2074, Balanced Accuracy: 0.4214285910129547 (42%)
# -------------------------
# Epoch 45: 100%|██████████| 2/2 [00:01<00:00,  1.06batch/s, accuracy=0.988, loss=0.000624]
# Epoch 46: 100%|██████████| 2/2 [00:00<00:00,  2.47batch/s, accuracy=1, loss=0.000426]
# Epoch 47: 100%|██████████| 2/2 [00:00<00:00,  2.81batch/s, accuracy=0.994, loss=0.000388]
# Epoch 48: 100%|██████████| 2/2 [00:00<00:00,  2.42batch/s, accuracy=0.994, loss=0.000572]
# Epoch 49: 100%|██████████| 2/2 [00:00<00:00,  2.48batch/s, accuracy=1, loss=0.000567]
# Epoch 50:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 50
# lr:  0.0007694497527671312
# -------------------------
# Train set: Avg. loss: 0.0003, Balanced Accuracy: 1.0 (100%)
# Test set: Avg. loss: 0.2043, Balanced Accuracy: 0.4214285910129547 (42%)
# -------------------------
# Epoch 50: 100%|██████████| 2/2 [00:01<00:00,  1.12batch/s, accuracy=1, loss=0.000403]
# Train set: Avg. loss: 0.0048, Balanced Accuracy: 0.875 (88%)
# Val set: Avg. loss: 0.3292, Balanced Accuracy: 0.4285714328289032 (43%)
# Test set: Avg. loss: 0.3311, Balanced Accuracy: 0.45000001788139343 (45%)
# Train subjects:  [1]
# Val subjects:  [1]
# Test subjects:  [1]
# Error in file:  /network/lustre/iss02/aramis/projects/cracknetworks/sub-01/ses-02/EEG/Train-[2022.04.04-16.15.17].edf
# 'Event name "OVTK_GDF_Left" could not be found. The following events are present in the data: OVTK_StimulationId_ExperimentStart, OVTK_StimulationId_BaselineStart/OVTK_StimulationId_Beep'
# Error in file:  /network/lustre/iss02/aramis/projects/cracknetworks/sub-01/ses-02/EEG/Train-[2022.04.04-16.14.01].edf
# 'Event name "OVTK_GDF_Left" could not be found. The following events are present in the data: OVTK_StimulationId_ExperimentStart, OVTK_StimulationId_BaselineStart/OVTK_StimulationId_Beep'
# Error in file:  /network/lustre/iss02/aramis/projects/cracknetworks/sub-01/ses-02/EEG/Test-[2022.04.04-16.52.15].edf
# 'Event name "OVTK_GDF_Left" could not be found. The following events are present in the data: OVTK_GDF_Feedback_Continuous, OVTK_GDF_Right, OVTK_StimulationId_ExperimentStart, OVTK_StimulationId_BaselineStart/OVTK_StimulationId_Beep, OVTK_StimulationId_BaselineStop/OVTK_StimulationId_Beep, OVTK_GDF_Cross_On_Screen/OVTK_GDF_Start_Of_Trial/OVTK_StimulationId_Beep, OVTK_GDF_End_Of_Trial/OVTK_StimulationId_VisualStimulationStar'
# Epoch 0:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 0
# lr:  0.01
# -------------------------
# Train set: Avg. loss: 0.0131, Balanced Accuracy: 0.33571431040763855 (34%)
# Test set: Avg. loss: 0.0119, Balanced Accuracy: 0.4571428596973419 (46%)
# Saving best model weights with balanced accuracy:  0.4571428596973419
# -------------------------
# Epoch 0: 100%|██████████| 2/2 [00:02<00:00,  1.04s/batch, accuracy=0.314, loss=0.0173]
# Epoch 1: 100%|██████████| 2/2 [00:00<00:00,  2.12batch/s, accuracy=0.707, loss=0.00838]
# Epoch 2: 100%|██████████| 2/2 [00:01<00:00,  1.75batch/s, accuracy=0.85, loss=0.00689]
# Epoch 3: 100%|██████████| 2/2 [00:01<00:00,  1.98batch/s, accuracy=0.9, loss=0.00304]
# Epoch 4: 100%|██████████| 2/2 [00:01<00:00,  1.73batch/s, accuracy=0.914, loss=0.0027]
# Epoch 5:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 5
# lr:  0.007737809374999999
# -------------------------
# Train set: Avg. loss: 0.1117, Balanced Accuracy: 0.6142857074737549 (61%)
# Test set: Avg. loss: 0.1860, Balanced Accuracy: 0.5714285373687744 (57%)
# Saving best model weights with balanced accuracy:  0.5714285373687744
# -------------------------
# Epoch 5: 100%|██████████| 2/2 [00:02<00:00,  1.05s/batch, accuracy=0.95, loss=0.00213]
# Epoch 6: 100%|██████████| 2/2 [00:00<00:00,  2.87batch/s, accuracy=0.957, loss=0.00216]
# Epoch 7: 100%|██████████| 2/2 [00:00<00:00,  2.18batch/s, accuracy=0.943, loss=0.00331]
# Epoch 8: 100%|██████████| 2/2 [00:01<00:00,  1.87batch/s, accuracy=0.943, loss=0.00179]
# Epoch 9: 100%|██████████| 2/2 [00:00<00:00,  2.24batch/s, accuracy=0.957, loss=0.0018]
# Epoch 10:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 10
# lr:  0.005987369392383786
# -------------------------
# Train set: Avg. loss: 0.0963, Balanced Accuracy: 0.6571428775787354 (66%)
# Test set: Avg. loss: 0.1646, Balanced Accuracy: 0.5857142806053162 (59%)
# Saving best model weights with balanced accuracy:  0.5857142806053162
# -------------------------
# Epoch 10: 100%|██████████| 2/2 [00:02<00:00,  1.16s/batch, accuracy=0.979, loss=0.000794]
# Epoch 11: 100%|██████████| 2/2 [00:00<00:00,  2.11batch/s, accuracy=0.979, loss=0.000955]
# Epoch 12: 100%|██████████| 2/2 [00:01<00:00,  1.99batch/s, accuracy=0.979, loss=0.00068]
# Epoch 13: 100%|██████████| 2/2 [00:00<00:00,  2.15batch/s, accuracy=0.986, loss=0.000792]
# Epoch 14: 100%|██████████| 2/2 [00:01<00:00,  1.87batch/s, accuracy=0.971, loss=0.000995]
# Epoch 15:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 15
# lr:  0.00463291230159753
# -------------------------
# Train set: Avg. loss: 0.0523, Balanced Accuracy: 0.6714285612106323 (67%)
# Test set: Avg. loss: 0.1206, Balanced Accuracy: 0.6071428656578064 (61%)
# Saving best model weights with balanced accuracy:  0.6071428656578064
# -------------------------
# Epoch 15: 100%|██████████| 2/2 [00:02<00:00,  1.17s/batch, accuracy=0.986, loss=0.000558]
# Epoch 16: 100%|██████████| 2/2 [00:01<00:00,  1.80batch/s, accuracy=0.986, loss=0.000806]
# Epoch 17: 100%|██████████| 2/2 [00:00<00:00,  2.26batch/s, accuracy=0.957, loss=0.00163]
# Epoch 18: 100%|██████████| 2/2 [00:00<00:00,  2.08batch/s, accuracy=0.986, loss=0.000524]
# Epoch 19: 100%|██████████| 2/2 [00:01<00:00,  1.82batch/s, accuracy=0.979, loss=0.000489]
# Epoch 20:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 20
# lr:  0.0035848592240854188
# -------------------------
# Train set: Avg. loss: 0.0355, Balanced Accuracy: 0.735714316368103 (74%)
# Test set: Avg. loss: 0.0883, Balanced Accuracy: 0.6142857074737549 (61%)
# Saving best model weights with balanced accuracy:  0.6142857074737549
# -------------------------
# Epoch 20: 100%|██████████| 2/2 [00:02<00:00,  1.10s/batch, accuracy=0.986, loss=0.000505]
# Epoch 21: 100%|██████████| 2/2 [00:00<00:00,  2.02batch/s, accuracy=0.979, loss=0.000713]
# Epoch 22: 100%|██████████| 2/2 [00:00<00:00,  2.07batch/s, accuracy=0.993, loss=0.000726]
# Epoch 23: 100%|██████████| 2/2 [00:00<00:00,  2.05batch/s, accuracy=1, loss=0.000244]
# Epoch 24: 100%|██████████| 2/2 [00:01<00:00,  1.81batch/s, accuracy=0.993, loss=0.000328]
# Epoch 25:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 25
# lr:  0.0027738957312183374
# -------------------------
# Train set: Avg. loss: 0.0210, Balanced Accuracy: 0.7857142686843872 (79%)
# Test set: Avg. loss: 0.0705, Balanced Accuracy: 0.6285714507102966 (63%)
# Saving best model weights with balanced accuracy:  0.6285714507102966
# -------------------------
# Epoch 25: 100%|██████████| 2/2 [00:02<00:00,  1.09s/batch, accuracy=0.986, loss=0.000573]
# Epoch 26: 100%|██████████| 2/2 [00:00<00:00,  2.23batch/s, accuracy=0.993, loss=0.000366]
# Epoch 27: 100%|██████████| 2/2 [00:00<00:00,  2.03batch/s, accuracy=1, loss=0.000276]
# Epoch 28: 100%|██████████| 2/2 [00:00<00:00,  2.23batch/s, accuracy=1, loss=0.000177]
# Epoch 29: 100%|██████████| 2/2 [00:01<00:00,  1.93batch/s, accuracy=0.986, loss=0.000426]
# Epoch 30:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 30
# lr:  0.0021463876394293723
# -------------------------
# Train set: Avg. loss: 0.0162, Balanced Accuracy: 0.8214285373687744 (82%)
# Test set: Avg. loss: 0.0412, Balanced Accuracy: 0.6785714626312256 (68%)
# Saving best model weights with balanced accuracy:  0.6785714626312256
# -------------------------
# Epoch 30: 100%|██████████| 2/2 [00:02<00:00,  1.11s/batch, accuracy=1, loss=0.000267]
# Epoch 31: 100%|██████████| 2/2 [00:00<00:00,  2.15batch/s, accuracy=0.993, loss=0.000282]
# Epoch 32: 100%|██████████| 2/2 [00:01<00:00,  1.81batch/s, accuracy=1, loss=0.000172]
# Epoch 33: 100%|██████████| 2/2 [00:00<00:00,  2.18batch/s, accuracy=1, loss=0.000106]
# Epoch 34: 100%|██████████| 2/2 [00:00<00:00,  2.05batch/s, accuracy=1, loss=0.000143]
# Epoch 35:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 35
# lr:  0.0016608338398760713
# -------------------------
# Train set: Avg. loss: 0.0073, Balanced Accuracy: 0.8857142925262451 (89%)
# Test set: Avg. loss: 0.0321, Balanced Accuracy: 0.699999988079071 (70%)
# Saving best model weights with balanced accuracy:  0.699999988079071
# -------------------------
# Epoch 35: 100%|██████████| 2/2 [00:01<00:00,  1.02batch/s, accuracy=1, loss=0.000195]
# Epoch 36: 100%|██████████| 2/2 [00:00<00:00,  2.34batch/s, accuracy=1, loss=0.000145]
# Epoch 37: 100%|██████████| 2/2 [00:00<00:00,  2.03batch/s, accuracy=1, loss=0.000124]
# Epoch 38: 100%|██████████| 2/2 [00:01<00:00,  1.99batch/s, accuracy=0.993, loss=0.000176]
# Epoch 39: 100%|██████████| 2/2 [00:00<00:00,  2.03batch/s, accuracy=1, loss=9.78e-5]
# Epoch 40:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 40
# lr:  0.0012851215656510308
# -------------------------
# Train set: Avg. loss: 0.0060, Balanced Accuracy: 0.9214285612106323 (92%)
# Test set: Avg. loss: 0.0283, Balanced Accuracy: 0.7214285731315613 (72%)
# Saving best model weights with balanced accuracy:  0.7214285731315613
# -------------------------
# Epoch 40: 100%|██████████| 2/2 [00:02<00:00,  1.19s/batch, accuracy=1, loss=0.000158]
# Epoch 41: 100%|██████████| 2/2 [00:01<00:00,  1.96batch/s, accuracy=1, loss=8.43e-5]
# Epoch 42: 100%|██████████| 2/2 [00:01<00:00,  1.94batch/s, accuracy=1, loss=0.000202]
# Epoch 43: 100%|██████████| 2/2 [00:00<00:00,  2.26batch/s, accuracy=1, loss=6.6e-5]
# Epoch 44: 100%|██████████| 2/2 [00:00<00:00,  2.32batch/s, accuracy=0.979, loss=0.000878]
# Epoch 45:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 45
# lr:  0.000994402569870922
# -------------------------
# Train set: Avg. loss: 0.0021, Balanced Accuracy: 0.9357142448425293 (94%)
# Test set: Avg. loss: 0.0247, Balanced Accuracy: 0.7428570985794067 (74%)
# Saving best model weights with balanced accuracy:  0.7428570985794067
# -------------------------
# Epoch 45: 100%|██████████| 2/2 [00:02<00:00,  1.07s/batch, accuracy=1, loss=0.00019]
# Epoch 46: 100%|██████████| 2/2 [00:01<00:00,  1.90batch/s, accuracy=1, loss=0.000158]
# Epoch 47: 100%|██████████| 2/2 [00:01<00:00,  1.95batch/s, accuracy=1, loss=0.000122]
# Epoch 48: 100%|██████████| 2/2 [00:00<00:00,  2.02batch/s, accuracy=0.993, loss=0.000234]
# Epoch 49: 100%|██████████| 2/2 [00:01<00:00,  1.75batch/s, accuracy=1, loss=0.000142]
# Epoch 50:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 50
# lr:  0.0007694497527671312
# -------------------------
# Train set: Avg. loss: 0.0020, Balanced Accuracy: 0.949999988079071 (95%)
# Test set: Avg. loss: 0.0213, Balanced Accuracy: 0.75 (75%)
# Saving best model weights with balanced accuracy:  0.75
# -------------------------
# Epoch 50: 100%|██████████| 2/2 [00:02<00:00,  1.09s/batch, accuracy=1, loss=0.000197]
# Train set: Avg. loss: 0.0022, Balanced Accuracy: 0.949999988079071 (95%)
# Val set: Avg. loss: 0.0241, Balanced Accuracy: 0.75 (75%)
# Test set: Avg. loss: 0.0573, Balanced Accuracy: 0.45625001192092896 (46%)
# Train subjects:  [1]
# Val subjects:  [1]
# Test subjects:  [1]
# Error in file:  /network/lustre/iss02/aramis/projects/cracknetworks/sub-01/ses-02/EEG/Train-[2022.04.04-16.15.17].edf
# 'Event name "OVTK_GDF_Left" could not be found. The following events are present in the data: OVTK_StimulationId_ExperimentStart, OVTK_StimulationId_BaselineStart/OVTK_StimulationId_Beep'
# Error in file:  /network/lustre/iss02/aramis/projects/cracknetworks/sub-01/ses-02/EEG/Train-[2022.04.04-16.14.01].edf
# 'Event name "OVTK_GDF_Left" could not be found. The following events are present in the data: OVTK_StimulationId_ExperimentStart, OVTK_StimulationId_BaselineStart/OVTK_StimulationId_Beep'
# Error in file:  /network/lustre/iss02/aramis/projects/cracknetworks/sub-01/ses-02/EEG/Test-[2022.04.04-16.52.15].edf
# 'Event name "OVTK_GDF_Left" could not be found. The following events are present in the data: OVTK_GDF_Feedback_Continuous, OVTK_GDF_Right, OVTK_StimulationId_ExperimentStart, OVTK_StimulationId_BaselineStart/OVTK_StimulationId_Beep, OVTK_StimulationId_BaselineStop/OVTK_StimulationId_Beep, OVTK_GDF_Cross_On_Screen/OVTK_GDF_Start_Of_Trial/OVTK_StimulationId_Beep, OVTK_GDF_End_Of_Trial/OVTK_StimulationId_VisualStimulationStar'
# Epoch 0:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 0
# lr:  0.01
# -------------------------
# Train set: Avg. loss: 0.0131, Balanced Accuracy: 0.44999998807907104 (45%)
# Test set: Avg. loss: 0.0088, Balanced Accuracy: 0.4937499761581421 (49%)
# Saving best model weights with balanced accuracy:  0.4937499761581421
# -------------------------
# Epoch 0: 100%|██████████| 2/2 [00:01<00:00,  1.28batch/s, accuracy=0.529, loss=0.0106]
# Epoch 1: 100%|██████████| 2/2 [00:00<00:00,  3.25batch/s, accuracy=0.671, loss=0.0176]
# Epoch 2: 100%|██████████| 2/2 [00:00<00:00,  3.42batch/s, accuracy=0.793, loss=0.00794]
# Epoch 3: 100%|██████████| 2/2 [00:00<00:00,  3.23batch/s, accuracy=0.771, loss=0.00797]
# Epoch 4: 100%|██████████| 2/2 [00:00<00:00,  3.25batch/s, accuracy=0.829, loss=0.00493]
# Epoch 5:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 5
# lr:  0.007737809374999999
# -------------------------
# Train set: Avg. loss: 0.0492, Balanced Accuracy: 0.5785714387893677 (58%)
# Test set: Avg. loss: 0.0425, Balanced Accuracy: 0.42500001192092896 (43%)
# -------------------------
# Epoch 5: 100%|██████████| 2/2 [00:01<00:00,  1.18batch/s, accuracy=0.829, loss=0.00494]
# Epoch 6: 100%|██████████| 2/2 [00:00<00:00,  3.20batch/s, accuracy=0.85, loss=0.00546]
# Epoch 7: 100%|██████████| 2/2 [00:00<00:00,  2.78batch/s, accuracy=0.907, loss=0.0034]
# Epoch 8: 100%|██████████| 2/2 [00:00<00:00,  2.77batch/s, accuracy=0.936, loss=0.00252]
# Epoch 9: 100%|██████████| 2/2 [00:00<00:00,  3.06batch/s, accuracy=0.893, loss=0.0042]
# Epoch 10:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 10
# lr:  0.005987369392383786
# -------------------------
# Train set: Avg. loss: 0.0617, Balanced Accuracy: 0.5571428537368774 (56%)
# Test set: Avg. loss: 0.0603, Balanced Accuracy: 0.4437499940395355 (44%)
# -------------------------
# Epoch 10: 100%|██████████| 2/2 [00:01<00:00,  1.34batch/s, accuracy=0.9, loss=0.00409]
# Epoch 11: 100%|██████████| 2/2 [00:00<00:00,  3.41batch/s, accuracy=0.929, loss=0.00254]
# Epoch 12: 100%|██████████| 2/2 [00:00<00:00,  3.15batch/s, accuracy=0.957, loss=0.00308]
# Epoch 13: 100%|██████████| 2/2 [00:00<00:00,  3.10batch/s, accuracy=0.929, loss=0.00271]
# Epoch 14: 100%|██████████| 2/2 [00:00<00:00,  2.93batch/s, accuracy=0.943, loss=0.00274]
# Epoch 15:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 15
# lr:  0.00463291230159753
# -------------------------
# Train set: Avg. loss: 0.0415, Balanced Accuracy: 0.5928571224212646 (59%)
# Test set: Avg. loss: 0.0464, Balanced Accuracy: 0.4625000059604645 (46%)
# -------------------------
# Epoch 15: 100%|██████████| 2/2 [00:01<00:00,  1.27batch/s, accuracy=0.957, loss=0.00221]
# Epoch 16: 100%|██████████| 2/2 [00:00<00:00,  2.19batch/s, accuracy=0.929, loss=0.00234]
# Epoch 17: 100%|██████████| 2/2 [00:00<00:00,  2.04batch/s, accuracy=0.914, loss=0.00335]
# Epoch 18: 100%|██████████| 2/2 [00:01<00:00,  1.85batch/s, accuracy=0.929, loss=0.00285]
# Epoch 19: 100%|██████████| 2/2 [00:00<00:00,  2.15batch/s, accuracy=0.921, loss=0.00329]
# Epoch 20:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 20
# lr:  0.0035848592240854188
# -------------------------
# Train set: Avg. loss: 0.0224, Balanced Accuracy: 0.6785714626312256 (68%)
# Test set: Avg. loss: 0.0365, Balanced Accuracy: 0.4624999761581421 (46%)
# -------------------------
# Epoch 20: 100%|██████████| 2/2 [00:02<00:00,  1.19s/batch, accuracy=0.943, loss=0.00213]
# Epoch 21: 100%|██████████| 2/2 [00:01<00:00,  1.81batch/s, accuracy=0.957, loss=0.00156]
# Epoch 22: 100%|██████████| 2/2 [00:00<00:00,  2.06batch/s, accuracy=0.964, loss=0.00234]
# Epoch 23: 100%|██████████| 2/2 [00:01<00:00,  1.99batch/s, accuracy=0.957, loss=0.00223]
# Epoch 24: 100%|██████████| 2/2 [00:00<00:00,  2.20batch/s, accuracy=0.95, loss=0.0023]
# Epoch 25:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 25
# lr:  0.0027738957312183374
# -------------------------
# Train set: Avg. loss: 0.0178, Balanced Accuracy: 0.735714316368103 (74%)
# Test set: Avg. loss: 0.0324, Balanced Accuracy: 0.4312499761581421 (43%)
# -------------------------
# Epoch 25: 100%|██████████| 2/2 [00:02<00:00,  1.28s/batch, accuracy=0.979, loss=0.0017]
# Epoch 26: 100%|██████████| 2/2 [00:00<00:00,  2.06batch/s, accuracy=0.986, loss=0.00112]
# Epoch 27: 100%|██████████| 2/2 [00:01<00:00,  1.74batch/s, accuracy=0.971, loss=0.00128]
# Epoch 28: 100%|██████████| 2/2 [00:00<00:00,  2.19batch/s, accuracy=0.95, loss=0.00168]
# Epoch 29: 100%|██████████| 2/2 [00:01<00:00,  1.91batch/s, accuracy=0.957, loss=0.00136]
# Epoch 30:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 30
# lr:  0.0021463876394293723
# -------------------------
# Train set: Avg. loss: 0.0159, Balanced Accuracy: 0.735714316368103 (74%)
# Test set: Avg. loss: 0.0308, Balanced Accuracy: 0.4312499761581421 (43%)
# -------------------------
# Epoch 30: 100%|██████████| 2/2 [00:02<00:00,  1.22s/batch, accuracy=0.957, loss=0.00145]
# Epoch 31: 100%|██████████| 2/2 [00:01<00:00,  1.82batch/s, accuracy=0.979, loss=0.00116]
# Epoch 32: 100%|██████████| 2/2 [00:00<00:00,  2.54batch/s, accuracy=0.979, loss=0.00112]
# Epoch 33: 100%|██████████| 2/2 [00:00<00:00,  2.04batch/s, accuracy=0.971, loss=0.0016]
# Epoch 34: 100%|██████████| 2/2 [00:01<00:00,  1.79batch/s, accuracy=0.979, loss=0.000974]
# Epoch 35:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 35
# lr:  0.0016608338398760713
# -------------------------
# Train set: Avg. loss: 0.0159, Balanced Accuracy: 0.7785714268684387 (78%)
# Test set: Avg. loss: 0.0278, Balanced Accuracy: 0.4000000059604645 (40%)
# -------------------------
# Epoch 35: 100%|██████████| 2/2 [00:02<00:00,  1.19s/batch, accuracy=0.957, loss=0.00158]
# Epoch 36: 100%|██████████| 2/2 [00:01<00:00,  1.96batch/s, accuracy=0.964, loss=0.0011]
# Epoch 37: 100%|██████████| 2/2 [00:01<00:00,  1.93batch/s, accuracy=0.95, loss=0.00203]
# Epoch 38: 100%|██████████| 2/2 [00:00<00:00,  2.02batch/s, accuracy=0.986, loss=0.00076]
# Epoch 39: 100%|██████████| 2/2 [00:00<00:00,  3.07batch/s, accuracy=0.979, loss=0.00135]
# Epoch 40:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 40
# lr:  0.0012851215656510308
# -------------------------
# Train set: Avg. loss: 0.0081, Balanced Accuracy: 0.800000011920929 (80%)
# Test set: Avg. loss: 0.0275, Balanced Accuracy: 0.375 (38%)
# -------------------------
# Epoch 40: 100%|██████████| 2/2 [00:01<00:00,  1.05batch/s, accuracy=0.964, loss=0.0013]
# Epoch 41: 100%|██████████| 2/2 [00:00<00:00,  2.56batch/s, accuracy=0.993, loss=0.000684]
# Epoch 42: 100%|██████████| 2/2 [00:00<00:00,  3.12batch/s, accuracy=0.964, loss=0.00146]
# Epoch 43: 100%|██████████| 2/2 [00:00<00:00,  2.55batch/s, accuracy=0.979, loss=0.00125]
# Epoch 44: 100%|██████████| 2/2 [00:00<00:00,  2.52batch/s, accuracy=0.986, loss=0.00127]
# Epoch 45:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 45
# lr:  0.000994402569870922
# -------------------------
# Train set: Avg. loss: 0.0074, Balanced Accuracy: 0.8357142806053162 (84%)
# Test set: Avg. loss: 0.0289, Balanced Accuracy: 0.38749998807907104 (39%)
# -------------------------
# Epoch 45: 100%|██████████| 2/2 [00:01<00:00,  1.22batch/s, accuracy=0.993, loss=0.000864]
# Epoch 46: 100%|██████████| 2/2 [00:00<00:00,  2.55batch/s, accuracy=0.986, loss=0.0011]
# Epoch 47: 100%|██████████| 2/2 [00:00<00:00,  2.46batch/s, accuracy=0.979, loss=0.00102]
# Epoch 48: 100%|██████████| 2/2 [00:00<00:00,  2.62batch/s, accuracy=0.964, loss=0.000909]
# Epoch 49: 100%|██████████| 2/2 [00:00<00:00,  2.59batch/s, accuracy=0.964, loss=0.00108]
# Epoch 50:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 50
# lr:  0.0007694497527671312
# -------------------------
# Train set: Avg. loss: 0.0065, Balanced Accuracy: 0.8357142806053162 (84%)
# Test set: Avg. loss: 0.0295, Balanced Accuracy: 0.38749998807907104 (39%)
# -------------------------
# Epoch 50: 100%|██████████| 2/2 [00:01<00:00,  1.34batch/s, accuracy=0.971, loss=0.00119]
# Train set: Avg. loss: 0.0125, Balanced Accuracy: 0.44999998807907104 (45%)
# Val set: Avg. loss: 0.0088, Balanced Accuracy: 0.4937499761581421 (49%)
# Test set: Avg. loss: 0.0134, Balanced Accuracy: 0.392857164144516 (39%)
# Train subjects:  [2]
# Val subjects:  [2]
# Test subjects:  [2]
# Epoch 0:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 0
# lr:  0.01
# -------------------------
# Train set: Avg. loss: 0.0092, Balanced Accuracy: 0.4624999761581421 (46%)
# Test set: Avg. loss: 0.0087, Balanced Accuracy: 0.4345238208770752 (43%)
# Saving best model weights with balanced accuracy:  0.4345238208770752
# -------------------------
# Epoch 0: 100%|██████████| 2/2 [00:03<00:00,  1.71s/batch, accuracy=0.431, loss=0.0104]
# Epoch 1: 100%|██████████| 2/2 [00:01<00:00,  1.45batch/s, accuracy=0.512, loss=0.0114]
# Epoch 2: 100%|██████████| 2/2 [00:01<00:00,  1.34batch/s, accuracy=0.713, loss=0.00732]
# Epoch 3: 100%|██████████| 2/2 [00:01<00:00,  1.56batch/s, accuracy=0.756, loss=0.00639]
# Epoch 4: 100%|██████████| 2/2 [00:01<00:00,  1.33batch/s, accuracy=0.744, loss=0.00657]
# Epoch 5:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 5
# lr:  0.007737809374999999
# -------------------------
# Train set: Avg. loss: 0.0092, Balanced Accuracy: 0.7124999761581421 (71%)
# Test set: Avg. loss: 0.0260, Balanced Accuracy: 0.5416666865348816 (54%)
# Saving best model weights with balanced accuracy:  0.5416666865348816
# -------------------------
# Epoch 5: 100%|██████████| 2/2 [00:03<00:00,  1.61s/batch, accuracy=0.812, loss=0.00534]
# Epoch 6: 100%|██████████| 2/2 [00:01<00:00,  1.47batch/s, accuracy=0.856, loss=0.00487]
# Epoch 7: 100%|██████████| 2/2 [00:01<00:00,  1.37batch/s, accuracy=0.869, loss=0.004]
# Epoch 8: 100%|██████████| 2/2 [00:01<00:00,  1.37batch/s, accuracy=0.869, loss=0.0036]
# Epoch 9: 100%|██████████| 2/2 [00:01<00:00,  1.47batch/s, accuracy=0.887, loss=0.00306]
# Epoch 10:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 10
# lr:  0.005987369392383786
# -------------------------
# Train set: Avg. loss: 0.0090, Balanced Accuracy: 0.706250011920929 (71%)
# Test set: Avg. loss: 0.0362, Balanced Accuracy: 0.5178571343421936 (52%)
# -------------------------
# Epoch 10: 100%|██████████| 2/2 [00:03<00:00,  1.70s/batch, accuracy=0.887, loss=0.00355]
# Epoch 11: 100%|██████████| 2/2 [00:01<00:00,  1.36batch/s, accuracy=0.887, loss=0.00289]
# Epoch 12: 100%|██████████| 2/2 [00:01<00:00,  1.38batch/s, accuracy=0.919, loss=0.00224]
# Epoch 13: 100%|██████████| 2/2 [00:01<00:00,  1.45batch/s, accuracy=0.938, loss=0.0022]
# Epoch 14: 100%|██████████| 2/2 [00:01<00:00,  1.33batch/s, accuracy=0.944, loss=0.00212]
# Epoch 15:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 15
# lr:  0.00463291230159753
# -------------------------
# Train set: Avg. loss: 0.0025, Balanced Accuracy: 0.90625 (91%)
# Test set: Avg. loss: 0.0323, Balanced Accuracy: 0.5357142686843872 (54%)
# -------------------------
# Epoch 15: 100%|██████████| 2/2 [00:03<00:00,  1.70s/batch, accuracy=0.95, loss=0.00176]
# Epoch 16: 100%|██████████| 2/2 [00:01<00:00,  1.46batch/s, accuracy=0.944, loss=0.00184]
# Epoch 17: 100%|██████████| 2/2 [00:01<00:00,  1.28batch/s, accuracy=0.969, loss=0.00135]
# Epoch 18: 100%|██████████| 2/2 [00:01<00:00,  1.46batch/s, accuracy=0.981, loss=0.00139]
# Epoch 19: 100%|██████████| 2/2 [00:01<00:00,  1.36batch/s, accuracy=0.963, loss=0.00138]
# Epoch 20:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 20
# lr:  0.0035848592240854188
# -------------------------
# Train set: Avg. loss: 0.0014, Balanced Accuracy: 0.9624999761581421 (96%)
# Test set: Avg. loss: 0.0252, Balanced Accuracy: 0.5416666269302368 (54%)
# -------------------------
# Epoch 20: 100%|██████████| 2/2 [00:03<00:00,  1.78s/batch, accuracy=0.994, loss=0.000977]
# Epoch 21: 100%|██████████| 2/2 [00:01<00:00,  1.48batch/s, accuracy=0.956, loss=0.00155]
# Epoch 22: 100%|██████████| 2/2 [00:01<00:00,  1.32batch/s, accuracy=0.981, loss=0.00122]
# Epoch 23: 100%|██████████| 2/2 [00:01<00:00,  1.46batch/s, accuracy=0.975, loss=0.00125]
# Epoch 24: 100%|██████████| 2/2 [00:01<00:00,  1.30batch/s, accuracy=0.981, loss=0.000964]
# Epoch 25:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 25
# lr:  0.0027738957312183374
# -------------------------
# Train set: Avg. loss: 0.0019, Balanced Accuracy: 0.9375 (94%)
# Test set: Avg. loss: 0.0244, Balanced Accuracy: 0.5357142686843872 (54%)
# -------------------------
# Epoch 25: 100%|██████████| 2/2 [00:03<00:00,  1.74s/batch, accuracy=0.981, loss=0.000949]
# Epoch 26: 100%|██████████| 2/2 [00:01<00:00,  1.35batch/s, accuracy=0.994, loss=0.000856]
# Epoch 27: 100%|██████████| 2/2 [00:01<00:00,  1.36batch/s, accuracy=0.988, loss=0.00098]
# Epoch 28: 100%|██████████| 2/2 [00:01<00:00,  1.40batch/s, accuracy=0.994, loss=0.000697]
# Epoch 29: 100%|██████████| 2/2 [00:01<00:00,  1.34batch/s, accuracy=0.981, loss=0.000766]
# Epoch 30:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 30
# lr:  0.0021463876394293723
# -------------------------
# Train set: Avg. loss: 0.0022, Balanced Accuracy: 0.925000011920929 (93%)
# Test set: Avg. loss: 0.0262, Balanced Accuracy: 0.5357142686843872 (54%)
# -------------------------
# Epoch 30: 100%|██████████| 2/2 [00:03<00:00,  1.76s/batch, accuracy=0.981, loss=0.00109]
# Epoch 31: 100%|██████████| 2/2 [00:01<00:00,  1.60batch/s, accuracy=0.994, loss=0.000533]
# Epoch 32: 100%|██████████| 2/2 [00:01<00:00,  1.29batch/s, accuracy=0.963, loss=0.0012]
# Epoch 33: 100%|██████████| 2/2 [00:01<00:00,  1.35batch/s, accuracy=0.975, loss=0.00104]
# Epoch 34: 100%|██████████| 2/2 [00:01<00:00,  1.17batch/s, accuracy=0.994, loss=0.000444]
# Epoch 35:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 35
# lr:  0.0016608338398760713
# -------------------------
# Train set: Avg. loss: 0.0035, Balanced Accuracy: 0.887499988079071 (89%)
# Test set: Avg. loss: 0.0270, Balanced Accuracy: 0.523809552192688 (52%)
# -------------------------
# Epoch 35: 100%|██████████| 2/2 [00:05<00:00,  2.74s/batch, accuracy=0.994, loss=0.00056]
# Epoch 36: 100%|██████████| 2/2 [00:02<00:00,  1.15s/batch, accuracy=0.981, loss=0.000725]
# Epoch 37: 100%|██████████| 2/2 [00:01<00:00,  1.00batch/s, accuracy=1, loss=0.000451]
# Epoch 38: 100%|██████████| 2/2 [00:01<00:00,  1.00batch/s, accuracy=1, loss=0.000524]
# Epoch 39: 100%|██████████| 2/2 [00:01<00:00,  1.00batch/s, accuracy=0.988, loss=0.000607]
# Epoch 40:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 40
# lr:  0.0012851215656510308
# -------------------------
# Train set: Avg. loss: 0.0032, Balanced Accuracy: 0.856249988079071 (86%)
# Test set: Avg. loss: 0.0263, Balanced Accuracy: 0.5297619104385376 (53%)
# -------------------------
# Epoch 40: 100%|██████████| 2/2 [00:04<00:00,  2.33s/batch, accuracy=0.981, loss=0.000636]
# Epoch 41: 100%|██████████| 2/2 [00:02<00:00,  1.01s/batch, accuracy=0.994, loss=0.000468]
# Epoch 42: 100%|██████████| 2/2 [00:01<00:00,  1.09batch/s, accuracy=0.981, loss=0.000749]
# Epoch 43: 100%|██████████| 2/2 [00:01<00:00,  1.12batch/s, accuracy=1, loss=0.000462]
# Epoch 44: 100%|██████████| 2/2 [00:02<00:00,  1.08s/batch, accuracy=0.994, loss=0.000456]
# Epoch 45:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 45
# lr:  0.000994402569870922
# -------------------------
# Train set: Avg. loss: 0.0038, Balanced Accuracy: 0.856249988079071 (86%)
# Test set: Avg. loss: 0.0240, Balanced Accuracy: 0.5297619104385376 (53%)
# -------------------------
# Epoch 45: 100%|██████████| 2/2 [00:05<00:00,  2.65s/batch, accuracy=1, loss=0.000336]
# Epoch 46: 100%|██████████| 2/2 [00:02<00:00,  1.18s/batch, accuracy=0.988, loss=0.000449]
# Epoch 47: 100%|██████████| 2/2 [00:02<00:00,  1.21s/batch, accuracy=0.994, loss=0.00069]
# Epoch 48: 100%|██████████| 2/2 [00:02<00:00,  1.20s/batch, accuracy=0.994, loss=0.000502]
# Epoch 49: 100%|██████████| 2/2 [00:02<00:00,  1.20s/batch, accuracy=1, loss=0.000511]
# Epoch 50:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 50
# lr:  0.0007694497527671312
# -------------------------
# Train set: Avg. loss: 0.0035, Balanced Accuracy: 0.862500011920929 (86%)
# Test set: Avg. loss: 0.0251, Balanced Accuracy: 0.511904776096344 (51%)
# -------------------------
# Epoch 50: 100%|██████████| 2/2 [00:05<00:00,  2.76s/batch, accuracy=0.994, loss=0.000504]
# Train set: Avg. loss: 0.0089, Balanced Accuracy: 0.7124999761581421 (71%)
# Val set: Avg. loss: 0.0256, Balanced Accuracy: 0.5416666865348816 (54%)
# Test set: Avg. loss: 0.0331, Balanced Accuracy: 0.5812499523162842 (58%)
# Train subjects:  [2]
# Val subjects:  [2]
# Test subjects:  [2]
# Epoch 0:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 0
# lr:  0.01
# -------------------------
# Train set: Avg. loss: 0.0086, Balanced Accuracy: 0.4464285671710968 (45%)
# Test set: Avg. loss: 0.0092, Balanced Accuracy: 0.5 (50%)
# Saving best model weights with balanced accuracy:  0.5
# -------------------------
# Epoch 0: 100%|██████████| 2/2 [00:05<00:00,  2.82s/batch, accuracy=0.458, loss=0.0102]
# Epoch 1: 100%|██████████| 2/2 [00:02<00:00,  1.23s/batch, accuracy=0.69, loss=0.00833]
# Epoch 2: 100%|██████████| 2/2 [00:02<00:00,  1.22s/batch, accuracy=0.69, loss=0.00809]
# Epoch 3: 100%|██████████| 2/2 [00:02<00:00,  1.24s/batch, accuracy=0.792, loss=0.00571]
# Epoch 4: 100%|██████████| 2/2 [00:02<00:00,  1.26s/batch, accuracy=0.81, loss=0.00471]
# Epoch 5:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 5
# lr:  0.007737809374999999
# -------------------------
# Train set: Avg. loss: 0.0100, Balanced Accuracy: 0.8214285373687744 (82%)
# Test set: Avg. loss: 0.0557, Balanced Accuracy: 0.5062500238418579 (51%)
# Saving best model weights with balanced accuracy:  0.5062500238418579
# -------------------------
# Epoch 5: 100%|██████████| 2/2 [00:05<00:00,  2.75s/batch, accuracy=0.875, loss=0.00386]
# Epoch 6: 100%|██████████| 2/2 [00:02<00:00,  1.12s/batch, accuracy=0.851, loss=0.0036]
# Epoch 7: 100%|██████████| 2/2 [00:02<00:00,  1.30s/batch, accuracy=0.893, loss=0.0028]
# Epoch 8: 100%|██████████| 2/2 [00:02<00:00,  1.34s/batch, accuracy=0.917, loss=0.0023]
# Epoch 9: 100%|██████████| 2/2 [00:02<00:00,  1.33s/batch, accuracy=0.94, loss=0.00271]
# Epoch 10:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 10
# lr:  0.005987369392383786
# -------------------------
# Train set: Avg. loss: 0.0042, Balanced Accuracy: 0.8869047164916992 (89%)
# Test set: Avg. loss: 0.0500, Balanced Accuracy: 0.53125 (53%)
# Saving best model weights with balanced accuracy:  0.53125
# -------------------------
# Epoch 10: 100%|██████████| 2/2 [00:05<00:00,  2.91s/batch, accuracy=0.917, loss=0.00215]
# Epoch 11: 100%|██████████| 2/2 [00:02<00:00,  1.28s/batch, accuracy=0.935, loss=0.00194]
# Epoch 12: 100%|██████████| 2/2 [00:02<00:00,  1.22s/batch, accuracy=0.911, loss=0.00236]
# Epoch 13: 100%|██████████| 2/2 [00:02<00:00,  1.19s/batch, accuracy=0.923, loss=0.00183]
# Epoch 14: 100%|██████████| 2/2 [00:02<00:00,  1.25s/batch, accuracy=0.94, loss=0.00154]
# Epoch 15:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 15
# lr:  0.00463291230159753
# -------------------------
# Train set: Avg. loss: 0.0028, Balanced Accuracy: 0.8869047164916992 (89%)
# Test set: Avg. loss: 0.0518, Balanced Accuracy: 0.53125 (53%)
# -------------------------
# Epoch 15: 100%|██████████| 2/2 [00:05<00:00,  2.85s/batch, accuracy=0.958, loss=0.00145]
# Epoch 16: 100%|██████████| 2/2 [00:02<00:00,  1.29s/batch, accuracy=0.958, loss=0.00118]
# Epoch 17: 100%|██████████| 2/2 [00:02<00:00,  1.22s/batch, accuracy=0.952, loss=0.00129]
# Epoch 18: 100%|██████████| 2/2 [00:02<00:00,  1.26s/batch, accuracy=0.946, loss=0.00158]
# Epoch 19: 100%|██████████| 2/2 [00:02<00:00,  1.23s/batch, accuracy=0.958, loss=0.00125]
# Epoch 20:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 20
# lr:  0.0035848592240854188
# -------------------------
# Train set: Avg. loss: 0.0019, Balanced Accuracy: 0.9285714626312256 (93%)
# Test set: Avg. loss: 0.0512, Balanced Accuracy: 0.518750011920929 (52%)
# -------------------------
# Epoch 20: 100%|██████████| 2/2 [00:05<00:00,  2.86s/batch, accuracy=0.97, loss=0.00119]
# Epoch 21: 100%|██████████| 2/2 [00:02<00:00,  1.23s/batch, accuracy=0.952, loss=0.00135]
# Epoch 22: 100%|██████████| 2/2 [00:02<00:00,  1.28s/batch, accuracy=0.994, loss=0.000881]
# Epoch 23: 100%|██████████| 2/2 [00:02<00:00,  1.26s/batch, accuracy=0.976, loss=0.00101]
# Epoch 24: 100%|██████████| 2/2 [00:02<00:00,  1.26s/batch, accuracy=0.97, loss=0.000987]
# Epoch 25:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 25
# lr:  0.0027738957312183374
# -------------------------
# Train set: Avg. loss: 0.0020, Balanced Accuracy: 0.9226190447807312 (92%)
# Test set: Avg. loss: 0.0468, Balanced Accuracy: 0.5375000238418579 (54%)
# Saving best model weights with balanced accuracy:  0.5375000238418579
# -------------------------
# Epoch 25: 100%|██████████| 2/2 [00:05<00:00,  2.84s/batch, accuracy=0.982, loss=0.00079]
# Epoch 26: 100%|██████████| 2/2 [00:02<00:00,  1.19s/batch, accuracy=0.982, loss=0.000744]
# Epoch 27: 100%|██████████| 2/2 [00:02<00:00,  1.23s/batch, accuracy=0.958, loss=0.00113]
# Epoch 28: 100%|██████████| 2/2 [00:02<00:00,  1.20s/batch, accuracy=0.976, loss=0.000864]
# Epoch 29: 100%|██████████| 2/2 [00:02<00:00,  1.26s/batch, accuracy=0.994, loss=0.000594]
# Epoch 30:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 30
# lr:  0.0021463876394293723
# -------------------------
# Train set: Avg. loss: 0.0018, Balanced Accuracy: 0.9107142686843872 (91%)
# Test set: Avg. loss: 0.0503, Balanced Accuracy: 0.53125 (53%)
# -------------------------
# Epoch 30: 100%|██████████| 2/2 [00:05<00:00,  2.80s/batch, accuracy=0.982, loss=0.000708]
# Epoch 31: 100%|██████████| 2/2 [00:02<00:00,  1.19s/batch, accuracy=0.988, loss=0.000482]
# Epoch 32: 100%|██████████| 2/2 [00:02<00:00,  1.23s/batch, accuracy=0.988, loss=0.000684]
# Epoch 33: 100%|██████████| 2/2 [00:02<00:00,  1.29s/batch, accuracy=0.982, loss=0.000879]
# Epoch 34: 100%|██████████| 2/2 [00:02<00:00,  1.23s/batch, accuracy=1, loss=0.00039]
# Epoch 35:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 35
# lr:  0.0016608338398760713
# -------------------------
# Train set: Avg. loss: 0.0017, Balanced Accuracy: 0.9345238208770752 (93%)
# Test set: Avg. loss: 0.0441, Balanced Accuracy: 0.518750011920929 (52%)
# -------------------------
# Epoch 35: 100%|██████████| 2/2 [00:05<00:00,  2.81s/batch, accuracy=1, loss=0.00051]
# Epoch 36: 100%|██████████| 2/2 [00:02<00:00,  1.20s/batch, accuracy=0.988, loss=0.000662]
# Epoch 37: 100%|██████████| 2/2 [00:02<00:00,  1.24s/batch, accuracy=0.982, loss=0.000667]
# Epoch 38: 100%|██████████| 2/2 [00:02<00:00,  1.21s/batch, accuracy=0.982, loss=0.000548]
# Epoch 39: 100%|██████████| 2/2 [00:02<00:00,  1.24s/batch, accuracy=0.988, loss=0.000724]
# Epoch 40:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 40
# lr:  0.0012851215656510308
# -------------------------
# Train set: Avg. loss: 0.0013, Balanced Accuracy: 0.9464285373687744 (95%)
# Test set: Avg. loss: 0.0400, Balanced Accuracy: 0.5249999761581421 (52%)
# -------------------------
# Epoch 40: 100%|██████████| 2/2 [00:05<00:00,  2.88s/batch, accuracy=0.976, loss=0.000811]
# Epoch 41: 100%|██████████| 2/2 [00:02<00:00,  1.27s/batch, accuracy=0.994, loss=0.000551]
# Epoch 42: 100%|██████████| 2/2 [00:02<00:00,  1.24s/batch, accuracy=1, loss=0.000463]
# Epoch 43: 100%|██████████| 2/2 [00:02<00:00,  1.22s/batch, accuracy=0.994, loss=0.000526]
# Epoch 44: 100%|██████████| 2/2 [00:02<00:00,  1.22s/batch, accuracy=0.994, loss=0.000447]
# Epoch 45:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 45
# lr:  0.000994402569870922
# -------------------------
# Train set: Avg. loss: 0.0012, Balanced Accuracy: 0.9523809552192688 (95%)
# Test set: Avg. loss: 0.0422, Balanced Accuracy: 0.53125 (53%)
# -------------------------
# Epoch 45: 100%|██████████| 2/2 [00:05<00:00,  2.83s/batch, accuracy=0.988, loss=0.000869]
# Epoch 46: 100%|██████████| 2/2 [00:02<00:00,  1.30s/batch, accuracy=0.988, loss=0.000563]
# Epoch 47: 100%|██████████| 2/2 [00:02<00:00,  1.19s/batch, accuracy=0.994, loss=0.000378]
# Epoch 48: 100%|██████████| 2/2 [00:02<00:00,  1.26s/batch, accuracy=0.994, loss=0.000422]
# Epoch 49: 100%|██████████| 2/2 [00:02<00:00,  1.23s/batch, accuracy=0.994, loss=0.000541]
# Epoch 50:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 50
# lr:  0.0007694497527671312
# -------------------------
# Train set: Avg. loss: 0.0014, Balanced Accuracy: 0.9464285373687744 (95%)
# Test set: Avg. loss: 0.0392, Balanced Accuracy: 0.5249999761581421 (52%)
# -------------------------
# Epoch 50: 100%|██████████| 2/2 [00:05<00:00,  2.83s/batch, accuracy=0.988, loss=0.000556]
# Train set: Avg. loss: 0.0020, Balanced Accuracy: 0.9226190447807312 (92%)
# Val set: Avg. loss: 0.0488, Balanced Accuracy: 0.5375000238418579 (54%)
# Test set: Avg. loss: 0.0345, Balanced Accuracy: 0.5 (50%)
# Train subjects:  [2]
# Val subjects:  [2]
# Test subjects:  [2]
# Epoch 0:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 0
# lr:  0.01
# -------------------------
# Train set: Avg. loss: 0.0089, Balanced Accuracy: 0.48124998807907104 (48%)
# Test set: Avg. loss: 0.0091, Balanced Accuracy: 0.4375 (44%)
# Saving best model weights with balanced accuracy:  0.4375
# -------------------------
# Epoch 0: 100%|██████████| 2/2 [00:04<00:00,  2.32s/batch, accuracy=0.525, loss=0.01]
# Epoch 1: 100%|██████████| 2/2 [00:02<00:00,  1.08s/batch, accuracy=0.606, loss=0.0102]
# Epoch 2: 100%|██████████| 2/2 [00:02<00:00,  1.18s/batch, accuracy=0.675, loss=0.0078]
# Epoch 3: 100%|██████████| 2/2 [00:02<00:00,  1.23s/batch, accuracy=0.756, loss=0.00604]
# Epoch 4: 100%|██████████| 2/2 [00:02<00:00,  1.18s/batch, accuracy=0.812, loss=0.00515]
# Epoch 5:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 5
# lr:  0.007737809374999999
# -------------------------
# Train set: Avg. loss: 0.0071, Balanced Accuracy: 0.7625000476837158 (76%)
# Test set: Avg. loss: 0.0204, Balanced Accuracy: 0.512499988079071 (51%)
# Saving best model weights with balanced accuracy:  0.512499988079071
# -------------------------
# Epoch 5: 100%|██████████| 2/2 [00:05<00:00,  2.72s/batch, accuracy=0.844, loss=0.00457]
# Epoch 6: 100%|██████████| 2/2 [00:02<00:00,  1.11s/batch, accuracy=0.825, loss=0.00425]
# Epoch 7: 100%|██████████| 2/2 [00:02<00:00,  1.17s/batch, accuracy=0.812, loss=0.00405]
# Epoch 8: 100%|██████████| 2/2 [00:02<00:00,  1.18s/batch, accuracy=0.869, loss=0.00336]
# Epoch 9: 100%|██████████| 2/2 [00:02<00:00,  1.18s/batch, accuracy=0.887, loss=0.00318]
# Epoch 10:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 10
# lr:  0.005987369392383786
# -------------------------
# Train set: Avg. loss: 0.0054, Balanced Accuracy: 0.793749988079071 (79%)
# Test set: Avg. loss: 0.0243, Balanced Accuracy: 0.5249999761581421 (52%)
# Saving best model weights with balanced accuracy:  0.5249999761581421
# -------------------------
# Epoch 10: 100%|██████████| 2/2 [00:05<00:00,  2.89s/batch, accuracy=0.95, loss=0.00228]
# Epoch 11: 100%|██████████| 2/2 [00:02<00:00,  1.32s/batch, accuracy=0.938, loss=0.00218]
# Epoch 12: 100%|██████████| 2/2 [00:02<00:00,  1.27s/batch, accuracy=0.906, loss=0.0021]
# Epoch 13: 100%|██████████| 2/2 [00:02<00:00,  1.18s/batch, accuracy=0.944, loss=0.00195]
# Epoch 14: 100%|██████████| 2/2 [00:02<00:00,  1.23s/batch, accuracy=0.931, loss=0.0018]
# Epoch 15:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 15
# lr:  0.00463291230159753
# -------------------------
# Train set: Avg. loss: 0.0034, Balanced Accuracy: 0.8687499761581421 (87%)
# Test set: Avg. loss: 0.0264, Balanced Accuracy: 0.53125 (53%)
# Saving best model weights with balanced accuracy:  0.53125
# -------------------------
# Epoch 15: 100%|██████████| 2/2 [00:05<00:00,  2.73s/batch, accuracy=0.975, loss=0.00138]
# Epoch 16: 100%|██████████| 2/2 [00:02<00:00,  1.21s/batch, accuracy=0.956, loss=0.00151]
# Epoch 17: 100%|██████████| 2/2 [00:02<00:00,  1.24s/batch, accuracy=0.956, loss=0.00169]
# Epoch 18: 100%|██████████| 2/2 [00:02<00:00,  1.14s/batch, accuracy=0.975, loss=0.00115]
# Epoch 19: 100%|██████████| 2/2 [00:02<00:00,  1.23s/batch, accuracy=0.981, loss=0.00115]
# Epoch 20:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 20
# lr:  0.0035848592240854188
# -------------------------
# Train set: Avg. loss: 0.0025, Balanced Accuracy: 0.90625 (91%)
# Test set: Avg. loss: 0.0253, Balanced Accuracy: 0.5125000476837158 (51%)
# -------------------------
# Epoch 20: 100%|██████████| 2/2 [00:05<00:00,  2.79s/batch, accuracy=0.988, loss=0.00106]
# Epoch 21: 100%|██████████| 2/2 [00:02<00:00,  1.23s/batch, accuracy=0.956, loss=0.00137]
# Epoch 22: 100%|██████████| 2/2 [00:02<00:00,  1.17s/batch, accuracy=0.981, loss=0.00121]
# ...
# Epoch 1: 100%|██████████| 2/2 [00:01<00:00,  1.65batch/s, accuracy=0.644, loss=0.0089]
# Epoch 2: 100%|██████████| 2/2 [00:01<00:00,  1.62batch/s, accuracy=0.7, loss=0.00938]
# Epoch 3: 100%|██████████| 2/2 [00:01<00:00,  1.68batch/s, accuracy=0.762, loss=0.00677]
# Epoch 4: 100%|██████████| 2/2 [00:01<00:00,  1.62batch/s, accuracy=0.769, loss=0.00719]
# Epoch 5:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 5
# lr:  0.007737809374999999
# -------------------------
# Train set: Avg. loss: 0.0239, Balanced Accuracy: 0.637499988079071 (64%)
# Test set: Avg. loss: 0.0176, Balanced Accuracy: 0.6499999761581421 (65%)
# Saving best model weights with balanced accuracy:  0.6499999761581421
# -------------------------
# Epoch 5: 100%|██████████| 2/2 [00:02<00:00,  1.34s/batch, accuracy=0.787, loss=0.00598]
# Epoch 6: 100%|██████████| 2/2 [00:01<00:00,  1.60batch/s, accuracy=0.787, loss=0.00519]
# Epoch 7: 100%|██████████| 2/2 [00:01<00:00,  1.67batch/s, accuracy=0.831, loss=0.00464]
# Epoch 8: 100%|██████████| 2/2 [00:01<00:00,  1.64batch/s, accuracy=0.838, loss=0.00453]
# Epoch 9: 100%|██████████| 2/2 [00:01<00:00,  1.68batch/s, accuracy=0.881, loss=0.00377]
# Epoch 10:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 10
# lr:  0.005987369392383786
# -------------------------
# Train set: Avg. loss: 0.0107, Balanced Accuracy: 0.731249988079071 (73%)
# Test set: Avg. loss: 0.0137, Balanced Accuracy: 0.6312500238418579 (63%)
# -------------------------
# Epoch 10: 100%|██████████| 2/2 [00:02<00:00,  1.30s/batch, accuracy=0.9, loss=0.00348]
# Epoch 11: 100%|██████████| 2/2 [00:00<00:00,  2.14batch/s, accuracy=0.856, loss=0.00392]
# Epoch 12: 100%|██████████| 2/2 [00:00<00:00,  2.16batch/s, accuracy=0.906, loss=0.00297]
# Epoch 13: 100%|██████████| 2/2 [00:00<00:00,  2.15batch/s, accuracy=0.919, loss=0.00277]
# Epoch 14: 100%|██████████| 2/2 [00:00<00:00,  2.75batch/s, accuracy=0.956, loss=0.00232]
# Epoch 15:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 15
# lr:  0.00463291230159753
# -------------------------
# Train set: Avg. loss: 0.0084, Balanced Accuracy: 0.75 (75%)
# Test set: Avg. loss: 0.0142, Balanced Accuracy: 0.6124999523162842 (61%)
# -------------------------
# Epoch 15: 100%|██████████| 2/2 [00:01<00:00,  1.06batch/s, accuracy=0.919, loss=0.0025]
# Epoch 16: 100%|██████████| 2/2 [00:00<00:00,  2.49batch/s, accuracy=0.938, loss=0.00195]
# Epoch 17: 100%|██████████| 2/2 [00:00<00:00,  2.41batch/s, accuracy=0.944, loss=0.002]
# Epoch 18: 100%|██████████| 2/2 [00:00<00:00,  2.35batch/s, accuracy=0.938, loss=0.00212]
# Epoch 19: 100%|██████████| 2/2 [00:00<00:00,  2.36batch/s, accuracy=0.956, loss=0.00156]
# Epoch 20:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 20
# lr:  0.0035848592240854188
# -------------------------
# Train set: Avg. loss: 0.0052, Balanced Accuracy: 0.824999988079071 (82%)
# Test set: Avg. loss: 0.0147, Balanced Accuracy: 0.6000000238418579 (60%)
# -------------------------
# Epoch 20: 100%|██████████| 2/2 [00:01<00:00,  1.01batch/s, accuracy=0.944, loss=0.00171]
# Epoch 21: 100%|██████████| 2/2 [00:00<00:00,  2.34batch/s, accuracy=0.963, loss=0.00152]
# Epoch 22: 100%|██████████| 2/2 [00:00<00:00,  2.42batch/s, accuracy=0.969, loss=0.00147]
# Epoch 23: 100%|██████████| 2/2 [00:00<00:00,  2.32batch/s, accuracy=0.975, loss=0.00117]
# Epoch 24: 100%|██████████| 2/2 [00:00<00:00,  2.30batch/s, accuracy=0.956, loss=0.00178]
# Epoch 25:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 25
# lr:  0.0027738957312183374
# -------------------------
# Train set: Avg. loss: 0.0036, Balanced Accuracy: 0.875 (88%)
# Test set: Avg. loss: 0.0167, Balanced Accuracy: 0.6000000238418579 (60%)
# -------------------------
# Epoch 25: 100%|██████████| 2/2 [00:01<00:00,  1.01batch/s, accuracy=0.956, loss=0.0013]
# Epoch 26: 100%|██████████| 2/2 [00:01<00:00,  1.84batch/s, accuracy=0.975, loss=0.00112]
# Epoch 27: 100%|██████████| 2/2 [00:01<00:00,  1.68batch/s, accuracy=0.994, loss=0.000781]
# Epoch 28: 100%|██████████| 2/2 [00:01<00:00,  1.66batch/s, accuracy=0.988, loss=0.000905]
# Epoch 29: 100%|██████████| 2/2 [00:01<00:00,  1.67batch/s, accuracy=0.988, loss=0.00122]
# Epoch 30:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 30
# lr:  0.0021463876394293723
# -------------------------
# Train set: Avg. loss: 0.0028, Balanced Accuracy: 0.8999999761581421 (90%)
# Test set: Avg. loss: 0.0175, Balanced Accuracy: 0.5874999761581421 (59%)
# -------------------------
# Epoch 30: 100%|██████████| 2/2 [00:02<00:00,  1.28s/batch, accuracy=0.956, loss=0.00126]
# Epoch 31: 100%|██████████| 2/2 [00:01<00:00,  1.67batch/s, accuracy=0.969, loss=0.00109]
# Epoch 32: 100%|██████████| 2/2 [00:01<00:00,  1.63batch/s, accuracy=0.969, loss=0.00116]
# Epoch 33: 100%|██████████| 2/2 [00:01<00:00,  1.61batch/s, accuracy=0.994, loss=0.000632]
# Epoch 34: 100%|██████████| 2/2 [00:01<00:00,  1.86batch/s, accuracy=0.988, loss=0.000935]
# Epoch 35:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 35
# lr:  0.0016608338398760713
# -------------------------
# Train set: Avg. loss: 0.0025, Balanced Accuracy: 0.9312499761581421 (93%)
# Test set: Avg. loss: 0.0185, Balanced Accuracy: 0.606249988079071 (61%)
# -------------------------
# Epoch 35: 100%|██████████| 2/2 [00:02<00:00,  1.42s/batch, accuracy=1, loss=0.000664]
# Epoch 36: 100%|██████████| 2/2 [00:01<00:00,  1.63batch/s, accuracy=0.981, loss=0.000802]
# Epoch 37: 100%|██████████| 2/2 [00:01<00:00,  1.66batch/s, accuracy=0.988, loss=0.000807]
# Epoch 38: 100%|██████████| 2/2 [00:01<00:00,  1.75batch/s, accuracy=0.994, loss=0.000861]
# Epoch 39: 100%|██████████| 2/2 [00:01<00:00,  1.72batch/s, accuracy=1, loss=0.000687]
# Epoch 40:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 40
# lr:  0.0012851215656510308
# -------------------------
# Train set: Avg. loss: 0.0013, Balanced Accuracy: 0.96875 (97%)
# Test set: Avg. loss: 0.0187, Balanced Accuracy: 0.5874999761581421 (59%)
# -------------------------
# Epoch 40: 100%|██████████| 2/2 [00:02<00:00,  1.44s/batch, accuracy=1, loss=0.000581]
# Epoch 41: 100%|██████████| 2/2 [00:01<00:00,  1.79batch/s, accuracy=0.994, loss=0.000667]
# Epoch 42: 100%|██████████| 2/2 [00:01<00:00,  1.61batch/s, accuracy=0.994, loss=0.000591]
# Epoch 43: 100%|██████████| 2/2 [00:01<00:00,  1.67batch/s, accuracy=0.981, loss=0.000787]
# Epoch 44: 100%|██████████| 2/2 [00:01<00:00,  1.70batch/s, accuracy=0.994, loss=0.000559]
# Epoch 45:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 45
# lr:  0.000994402569870922
# -------------------------
# Train set: Avg. loss: 0.0011, Balanced Accuracy: 0.987500011920929 (99%)
# Test set: Avg. loss: 0.0183, Balanced Accuracy: 0.5874999761581421 (59%)
# -------------------------
# Epoch 45: 100%|██████████| 2/2 [00:02<00:00,  1.35s/batch, accuracy=0.988, loss=0.000767]
# Epoch 46: 100%|██████████| 2/2 [00:01<00:00,  1.66batch/s, accuracy=0.988, loss=0.000677]
# Epoch 47: 100%|██████████| 2/2 [00:01<00:00,  1.63batch/s, accuracy=0.994, loss=0.000614]
# Epoch 48: 100%|██████████| 2/2 [00:01<00:00,  1.70batch/s, accuracy=0.981, loss=0.000935]
# Epoch 49: 100%|██████████| 2/2 [00:01<00:00,  1.75batch/s, accuracy=1, loss=0.000474]
# Epoch 50:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 50
# lr:  0.0007694497527671312
# -------------------------
# Train set: Avg. loss: 0.0010, Balanced Accuracy: 0.987500011920929 (99%)
# Test set: Avg. loss: 0.0195, Balanced Accuracy: 0.5874999761581421 (59%)
# -------------------------
# Epoch 50: 100%|██████████| 2/2 [00:02<00:00,  1.37s/batch, accuracy=1, loss=0.000505]
# Train set: Avg. loss: 0.0257, Balanced Accuracy: 0.637499988079071 (64%)
# Val set: Avg. loss: 0.0172, Balanced Accuracy: 0.6499999761581421 (65%)
# Test set: Avg. loss: 0.0484, Balanced Accuracy: 0.518750011920929 (52%)
# Train subjects:  [14]
# Val subjects:  [14]
# Test subjects:  [14]
# Epoch 0:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 0
# lr:  0.01
# -------------------------
# Train set: Avg. loss: 0.0099, Balanced Accuracy: 0.4375 (44%)
# Test set: Avg. loss: 0.0099, Balanced Accuracy: 0.45625001192092896 (46%)
# Saving best model weights with balanced accuracy:  0.45625001192092896
# -------------------------
# Epoch 0: 100%|██████████| 2/2 [00:04<00:00,  2.27s/batch, accuracy=0.494, loss=0.0098]
# Epoch 1: 100%|██████████| 2/2 [00:01<00:00,  1.10batch/s, accuracy=0.75, loss=0.00676]
# Epoch 2: 100%|██████████| 2/2 [00:01<00:00,  1.01batch/s, accuracy=0.787, loss=0.00544]
# Epoch 3: 100%|██████████| 2/2 [00:02<00:00,  1.04s/batch, accuracy=0.812, loss=0.00508]
# Epoch 4: 100%|██████████| 2/2 [00:02<00:00,  1.01s/batch, accuracy=0.825, loss=0.00476]
# Epoch 5:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 5
# lr:  0.007737809374999999
# -------------------------
# Train set: Avg. loss: 0.0576, Balanced Accuracy: 0.512499988079071 (51%)
# Test set: Avg. loss: 0.1211, Balanced Accuracy: 0.5 (50%)
# Saving best model weights with balanced accuracy:  0.5
# -------------------------
# Epoch 5: 100%|██████████| 2/2 [00:04<00:00,  2.38s/batch, accuracy=0.863, loss=0.00337]
# Epoch 6: 100%|██████████| 2/2 [00:02<00:00,  1.00s/batch, accuracy=0.875, loss=0.00285]
# Epoch 7: 100%|██████████| 2/2 [00:02<00:00,  1.01s/batch, accuracy=0.931, loss=0.0022]
# Epoch 8: 100%|██████████| 2/2 [00:02<00:00,  1.00s/batch, accuracy=0.938, loss=0.0021]
# Epoch 9: 100%|██████████| 2/2 [00:02<00:00,  1.00s/batch, accuracy=0.969, loss=0.00128]
# Epoch 10:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 10
# lr:  0.005987369392383786
# -------------------------
# Train set: Avg. loss: 0.0398, Balanced Accuracy: 0.5062500238418579 (51%)
# Test set: Avg. loss: 0.0960, Balanced Accuracy: 0.5 (50%)
# -------------------------
# Epoch 10: 100%|██████████| 2/2 [00:04<00:00,  2.30s/batch, accuracy=0.988, loss=0.000842]
# Epoch 11: 100%|██████████| 2/2 [00:02<00:00,  1.02s/batch, accuracy=0.969, loss=0.000934]
# Epoch 12: 100%|██████████| 2/2 [00:01<00:00,  1.04batch/s, accuracy=0.975, loss=0.000577]
# Epoch 13: 100%|██████████| 2/2 [00:02<00:00,  1.01s/batch, accuracy=0.969, loss=0.000774]
# Epoch 14: 100%|██████████| 2/2 [00:02<00:00,  1.02s/batch, accuracy=0.988, loss=0.000363]
# Epoch 15:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 15
# lr:  0.00463291230159753
# -------------------------
# Train set: Avg. loss: 0.0338, Balanced Accuracy: 0.550000011920929 (55%)
# Test set: Avg. loss: 0.1036, Balanced Accuracy: 0.5062500238418579 (51%)
# Saving best model weights with balanced accuracy:  0.5062500238418579
# -------------------------
# Epoch 15: 100%|██████████| 2/2 [00:04<00:00,  2.37s/batch, accuracy=0.994, loss=0.00025]
# Epoch 16: 100%|██████████| 2/2 [00:01<00:00,  1.02batch/s, accuracy=1, loss=0.000206]
# Epoch 17: 100%|██████████| 2/2 [00:02<00:00,  1.08s/batch, accuracy=0.994, loss=0.000208]
# Epoch 18: 100%|██████████| 2/2 [00:02<00:00,  1.00s/batch, accuracy=0.994, loss=0.000267]
# Epoch 19: 100%|██████████| 2/2 [00:01<00:00,  1.04batch/s, accuracy=0.994, loss=0.000234]
# Epoch 20:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 20
# lr:  0.0035848592240854188
# -------------------------
# Train set: Avg. loss: 0.0204, Balanced Accuracy: 0.637499988079071 (64%)
# Test set: Avg. loss: 0.1022, Balanced Accuracy: 0.518750011920929 (52%)
# Saving best model weights with balanced accuracy:  0.518750011920929
# -------------------------
# Epoch 20: 100%|██████████| 2/2 [00:04<00:00,  2.21s/batch, accuracy=0.994, loss=0.000143]
# Epoch 21: 100%|██████████| 2/2 [00:01<00:00,  1.02batch/s, accuracy=1, loss=0.000122]
# Epoch 22: 100%|██████████| 2/2 [00:01<00:00,  1.01batch/s, accuracy=0.988, loss=0.000263]
# Epoch 23: 100%|██████████| 2/2 [00:01<00:00,  1.01batch/s, accuracy=1, loss=0.000173]
# Epoch 24: 100%|██████████| 2/2 [00:02<00:00,  1.00s/batch, accuracy=0.994, loss=9.76e-5]
# Epoch 25:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 25
# lr:  0.0027738957312183374
# -------------------------
# Train set: Avg. loss: 0.0068, Balanced Accuracy: 0.7749999761581421 (77%)
# Test set: Avg. loss: 0.0741, Balanced Accuracy: 0.550000011920929 (55%)
# Saving best model weights with balanced accuracy:  0.550000011920929
# -------------------------
# Epoch 25: 100%|██████████| 2/2 [00:04<00:00,  2.34s/batch, accuracy=1, loss=6.79e-5]
# Epoch 26: 100%|██████████| 2/2 [00:01<00:00,  1.01batch/s, accuracy=1, loss=7.43e-5]
# Epoch 27: 100%|██████████| 2/2 [00:01<00:00,  1.02batch/s, accuracy=0.994, loss=0.000165]
# Epoch 28: 100%|██████████| 2/2 [00:02<00:00,  1.00s/batch, accuracy=0.994, loss=0.000253]
# Epoch 29: 100%|██████████| 2/2 [00:01<00:00,  1.05batch/s, accuracy=1, loss=7.85e-5]
# Epoch 30:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 30
# lr:  0.0021463876394293723
# -------------------------
# Train set: Avg. loss: 0.0032, Balanced Accuracy: 0.887499988079071 (89%)
# Test set: Avg. loss: 0.0611, Balanced Accuracy: 0.5874999761581421 (59%)
# Saving best model weights with balanced accuracy:  0.5874999761581421
# -------------------------
# Epoch 30: 100%|██████████| 2/2 [00:04<00:00,  2.25s/batch, accuracy=1, loss=5.43e-5]
# Epoch 31: 100%|██████████| 2/2 [00:01<00:00,  1.04batch/s, accuracy=1, loss=7.78e-5]
# Epoch 32: 100%|██████████| 2/2 [00:01<00:00,  1.01batch/s, accuracy=1, loss=0.000103]
# Epoch 33: 100%|██████████| 2/2 [00:02<00:00,  1.01s/batch, accuracy=1, loss=5.06e-5]
# Epoch 34: 100%|██████████| 2/2 [00:01<00:00,  1.05batch/s, accuracy=1, loss=8.74e-5]
# Epoch 35:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 35
# lr:  0.0016608338398760713
# -------------------------
# Train set: Avg. loss: 0.0013, Balanced Accuracy: 0.9624999761581421 (96%)
# Test set: Avg. loss: 0.0519, Balanced Accuracy: 0.6124999523162842 (61%)
# Saving best model weights with balanced accuracy:  0.6124999523162842
# -------------------------
# Epoch 35: 100%|██████████| 2/2 [00:04<00:00,  2.21s/batch, accuracy=1, loss=8.78e-5]
# Epoch 36: 100%|██████████| 2/2 [00:02<00:00,  1.02s/batch, accuracy=1, loss=0.000191]
# Epoch 37: 100%|██████████| 2/2 [00:01<00:00,  1.00batch/s, accuracy=1, loss=7.19e-5]
# Epoch 38: 100%|██████████| 2/2 [00:01<00:00,  1.01batch/s, accuracy=1, loss=3.63e-5]
# Epoch 39: 100%|██████████| 2/2 [00:02<00:00,  1.02s/batch, accuracy=1, loss=3.57e-5]
# Epoch 40:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 40
# lr:  0.0012851215656510308
# -------------------------
# Train set: Avg. loss: 0.0004, Balanced Accuracy: 0.9937499761581421 (99%)
# Test set: Avg. loss: 0.0458, Balanced Accuracy: 0.637499988079071 (64%)
# Saving best model weights with balanced accuracy:  0.637499988079071
# -------------------------
# Epoch 40: 100%|██████████| 2/2 [00:04<00:00,  2.30s/batch, accuracy=1, loss=4.05e-5]
# Epoch 41: 100%|██████████| 2/2 [00:02<00:00,  1.03s/batch, accuracy=1, loss=8.64e-5]
# Epoch 42: 100%|██████████| 2/2 [00:02<00:00,  1.01s/batch, accuracy=1, loss=3.62e-5]
# Epoch 43: 100%|██████████| 2/2 [00:01<00:00,  1.00batch/s, accuracy=1, loss=3.68e-5]
# Epoch 44: 100%|██████████| 2/2 [00:01<00:00,  1.01batch/s, accuracy=1, loss=5.64e-5]
# Epoch 45:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 45
# lr:  0.000994402569870922
# -------------------------
# Train set: Avg. loss: 0.0001, Balanced Accuracy: 1.0 (100%)
# Test set: Avg. loss: 0.0411, Balanced Accuracy: 0.6749999523162842 (67%)
# Saving best model weights with balanced accuracy:  0.6749999523162842
# -------------------------
# Epoch 45: 100%|██████████| 2/2 [00:04<00:00,  2.30s/batch, accuracy=1, loss=4.61e-5]
# Epoch 46: 100%|██████████| 2/2 [00:02<00:00,  1.04s/batch, accuracy=1, loss=3.63e-5]
# Epoch 47: 100%|██████████| 2/2 [00:01<00:00,  1.00batch/s, accuracy=1, loss=3.55e-5]
# Epoch 48: 100%|██████████| 2/2 [00:01<00:00,  1.06batch/s, accuracy=1, loss=6.06e-5]
# Epoch 49: 100%|██████████| 2/2 [00:01<00:00,  1.17batch/s, accuracy=1, loss=4.04e-5]
# Epoch 50:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 50
# lr:  0.0007694497527671312
# -------------------------
# Train set: Avg. loss: 0.0001, Balanced Accuracy: 1.0 (100%)
# Test set: Avg. loss: 0.0381, Balanced Accuracy: 0.675000011920929 (68%)
# Saving best model weights with balanced accuracy:  0.675000011920929
# -------------------------
# Epoch 50: 100%|██████████| 2/2 [00:03<00:00,  1.74s/batch, accuracy=1, loss=7.11e-5]
# Train set: Avg. loss: 0.0001, Balanced Accuracy: 1.0 (100%)
# Val set: Avg. loss: 0.0368, Balanced Accuracy: 0.675000011920929 (68%)
# Test set: Avg. loss: 0.0173, Balanced Accuracy: 0.7749999761581421 (77%)

# %%
with open('../dicts_results/intra_subject_classification/braccio_eegnet_sessions_F1_4_F2_16_D_2.pkl', 'wb') as f:
    pickle.dump(dict_crossval, f)

# %% [markdown]
# ## ATCNet

# %%
import importlib
importlib.reload(dataset)
importlib.reload(training)
importlib.reload(models)
# Out:
# <module 'eeg_project_package.models' from '/home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/models.py'>

# %%
# Define the subject and the session
task_type = "imaginary_left/right"
folder_path = "/network/lustre/iss02/aramis/projects/cracknetworks/"

num_sessions = [1,2,3]
num_subjects = [1,2,3,5,6,7,8,10,11,13,14]   
list_labels = ['OVTK_GDF_Left','OVTK_GDF_Right']

# Define the channels
list_name_channels = ["CP1","CP3","CP5","C1","C3","C5","C2","CP2","Cz","FCz","C4","CP4"]
list_idx_channels = [list_all_ch_names.index(ch) for ch in list_name_channels]

# Define the labels
labels = ['OVTK_GDF_Left', 'OVTK_GDF_Right']

dict_crossval = {"test_balanced_accuracy":np.zeros((11,3)), "test_loss":np.zeros((11,3)), "val_balanced_accuracy":np.zeros((11,3)), "val_loss":np.zeros((11,3)), "train_balanced_accuracy":np.zeros((11,3)), "train_loss":np.zeros((11,3))}

# Define the parameters of the dataset
feature_type = ["time"]
dict_preprocessing = {"polynomial_degree":None,"tmin":0,"tmax":4,"seq_length":2001}
dict_features = {"type_psd":"welch","fs":500,"nfft":300,"noverlap":150,"nperseg":300,"filter_order":19,"fmin":4,"fmax":30}

for i in range(len(num_subjects)):
    for session in num_sessions : 
        # cross-validation
        num_val_subjects = [num_subjects[i]]
        num_test_subjects = [num_subjects[i]]
        num_train_subjects = [num_subjects[i]]
        if session == 1:
            num_train_sessions = [1]
            num_val_sessions = [2]
            num_test_sessions = [3]
        elif session == 2:
            num_train_sessions = [2]
            num_val_sessions = [3]
            num_test_sessions = [1]
        elif session == 3:
            num_train_sessions = [3]
            num_val_sessions = [1]
            num_test_sessions = [2]

        print("Train subjects: ", num_train_subjects)
        print("Val subjects: ", num_val_subjects)
        print("Test subjects: ", num_test_subjects)

        # Create the dataset
        trainset = dataset.Braccio_Dataset_Multi_Subject(folder_path, num_train_subjects, num_train_sessions, list_idx_channels = list_idx_channels, list_labels = labels, feature_type = feature_type, dict_preprocessing = dict_preprocessing, dict_features = dict_features)
        testset = dataset.Braccio_Dataset_Multi_Subject(folder_path, num_test_subjects, num_test_sessions, list_idx_channels = list_idx_channels, list_labels = labels, feature_type = feature_type, dict_preprocessing = dict_preprocessing, dict_features = dict_features)
        valset = dataset.Braccio_Dataset_Multi_Subject(folder_path, num_val_subjects, num_val_sessions, list_idx_channels = list_idx_channels, list_labels = labels, feature_type = feature_type, dict_preprocessing = dict_preprocessing, dict_features = dict_features)

        # Create the dataloader
        trainset.transform_dataset_numpy_to_torch()
        trainset.features["time"] = trainset.features["time"].unsqueeze(1)
        testset.transform_dataset_numpy_to_torch()
        testset.features["time"] = testset.features["time"].unsqueeze(1)
        valset.transform_dataset_numpy_to_torch()
        valset.features["time"] = valset.features["time"].unsqueeze(1)
        trainloader = torch.utils.data.DataLoader(trainset, batch_size=100, shuffle=True, num_workers=2)
        testloader = torch.utils.data.DataLoader(testset, batch_size=100, shuffle=True, num_workers=2)
        valloader = torch.utils.data.DataLoader(valset, batch_size=100, shuffle=True, num_workers=2)

        feature_type = "time"
        device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        criterion = torch.nn.CrossEntropyLoss()
        model = models.ATCNet(in_channels=1,
                    num_classes=2,
                    num_windows=5,
                    num_electrodes=12,
                    chunk_size=2001,
                    filter_size=250,)
        model.to(device)
        optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
        scheduler1 = torch.optim.lr_scheduler.MultiplicativeLR(optimizer, lr_lambda=lambda epoch: 0.95)
        scheduler2 = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=3, factor=0.5)
        scheduler_dict = {"MultiplicativeLR":scheduler1} #, "ReduceLROnPlateau":scheduler2}
        logs = training.train_model(model, trainloader, valloader, device, criterion, feature_type, 51, optimizer, scheduler_dict, print_epoch = 5)

        # change weights of the model to the best weights
        model.load_state_dict(logs["best_model_weights"])
        model.eval()
        train_balanced_accuracy, train_loss = training.evaluate_classification_model(model,trainloader,device,criterion,feature_type,dataset="Train")
        val_balanced_accuracy, val_loss = training.evaluate_classification_model(model,valloader,device,criterion,feature_type,dataset="Val")
        test_balanced_accuracy, test_loss = training.evaluate_classification_model(model,testloader,device,criterion,feature_type,dataset="Test")
        dict_crossval["test_balanced_accuracy"][i,session-1] = test_balanced_accuracy
        dict_crossval["test_loss"][i,session-1] = test_loss
        dict_crossval["val_balanced_accuracy"][i,session-1] = val_balanced_accuracy
        dict_crossval["val_loss"][i,session-1] = val_loss
        dict_crossval["train_balanced_accuracy"][i,session-1] = train_balanced_accuracy
        dict_crossval["train_loss"][i,session-1] = train_loss

        # Save the model
        model_name = "ATCNet"
        model_path = "../models/ATCNet_session/"
        model_filename = model_path + "ATCNet_Subject_" + str(num_subjects[i]) + "Session_" + str(session) + ".pt"
        torch.save(model.state_dict(), model_filename)
# Out:
# Train subjects:  [1]
# Val subjects:  [1]
# Test subjects:  [1]
# Error in file:  /network/lustre/iss02/aramis/projects/cracknetworks/sub-01/ses-02/EEG/Train-[2022.04.04-16.15.17].edf
# 'Event name "OVTK_GDF_Left" could not be found. The following events are present in the data: OVTK_StimulationId_ExperimentStart, OVTK_StimulationId_BaselineStart/OVTK_StimulationId_Beep'
# Error in file:  /network/lustre/iss02/aramis/projects/cracknetworks/sub-01/ses-02/EEG/Train-[2022.04.04-16.14.01].edf
# 'Event name "OVTK_GDF_Left" could not be found. The following events are present in the data: OVTK_StimulationId_ExperimentStart, OVTK_StimulationId_BaselineStart/OVTK_StimulationId_Beep'
# Error in file:  /network/lustre/iss02/aramis/projects/cracknetworks/sub-01/ses-02/EEG/Test-[2022.04.04-16.52.15].edf
# 'Event name "OVTK_GDF_Left" could not be found. The following events are present in the data: OVTK_GDF_Feedback_Continuous, OVTK_GDF_Right, OVTK_StimulationId_ExperimentStart, OVTK_StimulationId_BaselineStart/OVTK_StimulationId_Beep, OVTK_StimulationId_BaselineStop/OVTK_StimulationId_Beep, OVTK_GDF_Cross_On_Screen/OVTK_GDF_Start_Of_Trial/OVTK_StimulationId_Beep, OVTK_GDF_End_Of_Trial/OVTK_StimulationId_VisualStimulationStar'
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages/torch/nn/modules/conv.py:456: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at ../aten/src/ATen/native/Convolution.cpp:1031.)
#   return F.conv2d(input, weight, bias, self.stride,
# Epoch 0:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 0
# lr:  0.001
# -------------------------
# Train set: Avg. loss: 0.0086, Balanced Accuracy: 0.53125 (53%)
# Test set: Avg. loss: 0.0106, Balanced Accuracy: 0.47857144474983215 (48%)
# Saving best model weights with balanced accuracy:  0.47857144474983215
# -------------------------
# Epoch 0: 100%|██████████| 2/2 [00:02<00:00,  1.19s/batch, accuracy=0.613, loss=0.0085]
# Epoch 1:  50%|█████     | 1/2 [00:00<00:00,  1.05batch/s, accuracy=0.7, loss=0.004]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 76
#      74 scheduler2 = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=3, factor=0.5)
#      75 scheduler_dict = {"MultiplicativeLR":scheduler1} #, "ReduceLROnPlateau":scheduler2}
# ---> 76 logs = training.train_model(model, trainloader, valloader, device, criterion, feature_type, 51, optimizer, scheduler_dict, print_epoch = 5)
#      78 # change weights of the model to the best weights
#      79 model.load_state_dict(logs["best_model_weights"])
#
# File ~/Development/BCI_Classification/eeg_project_package/training.py:60, in train_model(model, trainloader, testloader, device, criterion, feature_type, epochs, optimizer, schedulers_dict, print_epoch)
#      58 else:
#      59     loss = criterion(outputs,y)
# ---> 60     total_loss += loss.item()/len(trainloader.dataset)
#      61     _, predicted = torch.max(outputs, 1)
#      63 optimizer.zero_grad()
#
# KeyboardInterrupt:

# %%
with open('../dicts_results/intra_subject_classification/braccio_sessions_atcnet_numwin_5_filtersize_250.pkl', 'wb') as f:
    pickle.dump(dict_crossval, f)

# %%
with open('../dicts_results/inter_subject_classification/braccio_atcnet_numwin_5_filtersize_250.pkl', 'rb') as f:
    loaded_dict = pickle.load(f)

plt.plot(loaded_dict["test_balanced_accuracy"], label = "Test")
plt.plot(loaded_dict["val_balanced_accuracy"], label = "Val")
plt.plot(loaded_dict["train_balanced_accuracy"], label = "Train")
plt.legend()
plt.show()

# %% [markdown]
# # LDA / SVM

# %%
# Define the subject and the session
task_type = "imaginary_left/right"
folder_path = "/network/lustre/iss02/aramis/projects/cracknetworks/"

num_sessions = [1,2,3]
num_subjects = [1,2,3,5,6,7,8,10,11,13,14]   
list_labels = ['OVTK_GDF_Left','OVTK_GDF_Right']

# Define the channels
list_name_channels = ["CP1","CP3","CP5","C1","C3","C5","C2","CP2","Cz","FCz","C4","CP4"]
list_idx_channels = [list_all_ch_names.index(ch) for ch in list_name_channels]

# Define the labels
labels = ['OVTK_GDF_Left', 'OVTK_GDF_Right']

dict_crossval = {"lda_balanced_accuracy":np.zeros((11,3)), "svm_balanced_accuracy":np.zeros((11,3)), "svm_rbf_balanced_accuracy":np.zeros((11,3))}

# Define the parameters of the dataset
feature_type = ["band_psd"]
dict_preprocessing = {"polynomial_degree":None,"tmin":0,"tmax":4,"seq_length":2001}
dict_features = {"type_psd":"welch","fs":500,"nfft":300,"noverlap":150,"nperseg":300,"filter_order":19,"fmin":4,"fmax":30}

for i in range(len(num_subjects)):
    for session in num_sessions : 
        # cross-validation
        num_test_subjects = [num_subjects[i]]
        num_train_subjects = [num_subjects[i]]
        if session == 1:
            num_train_sessions = [1,2]
            num_test_sessions = [3]
        elif session == 2:
            num_train_sessions = [2,3]
            num_test_sessions = [1]
        elif session == 3:
            num_train_sessions = [1,3]
            num_test_sessions = [2]

        print("Train subjects: ", num_train_subjects)
        print("Test subjects: ", num_test_subjects)

        # Create the dataset
        trainset = dataset.Braccio_Dataset_Multi_Subject(folder_path, num_train_subjects, num_train_sessions, list_idx_channels = list_idx_channels, list_labels = labels, feature_type = feature_type, dict_preprocessing = dict_preprocessing, dict_features = dict_features)
        testset = dataset.Braccio_Dataset_Multi_Subject(folder_path, num_test_subjects, num_test_sessions, list_idx_channels = list_idx_channels, list_labels = labels, feature_type = feature_type, dict_preprocessing = dict_preprocessing, dict_features = dict_features)

        X_train = trainset.features["band_psd"].reshape(trainset.features["band_psd"].shape[0], -1)
        y_train = trainset.labels
        X_test = testset.features["band_psd"].reshape(testset.features["band_psd"].shape[0], -1)
        y_test = testset.labels

        # Train LDA classifier
        lda_clf = LinearDiscriminantAnalysis()
        lda_clf.fit(X_train, y_train)
        y_pred = lda_clf.predict(X_test)
        balanced_acc = 0.5*(np.mean(y_pred[y_test == 0] == 0) + np.mean(y_pred[y_test == 1] == 1))
        dict_crossval["lda_balanced_accuracy"][i,session-1] = balanced_acc
        print("LDA accuracy: ", balanced_acc)

        # Train SVM classifier
        svm_clf = SVC(kernel='linear')
        svm_clf.fit(X_train, y_train)
        y_pred = svm_clf.predict(X_test)
        balanced_acc = 0.5*(np.mean(y_pred[y_test == 0] == 0) + np.mean(y_pred[y_test == 1] == 1))
        dict_crossval["svm_balanced_accuracy"][i,session-1] = balanced_acc
        print("SVM accuracy: ", balanced_acc)

        # Train SVM classifier
        svm_clf = SVC(kernel='rbf')
        svm_clf.fit(X_train, y_train)
        y_pred = svm_clf.predict(X_test)
        balanced_acc = 0.5*(np.mean(y_pred[y_test == 0] == 0) + np.mean(y_pred[y_test == 1] == 1))
        dict_crossval["svm_rbf_balanced_accuracy"][i,session-1] = balanced_acc
        print("SVM rbf accuracy: ", balanced_acc)
# Out:
# Train subjects:  [1]
# Test subjects:  [1]
# Error in file:  /network/lustre/iss02/aramis/projects/cracknetworks/sub-01/ses-02/EEG/Train-[2022.04.04-16.15.17].edf
# 'Event name "OVTK_GDF_Left" could not be found. The following events are present in the data: OVTK_StimulationId_ExperimentStart, OVTK_StimulationId_BaselineStart/OVTK_StimulationId_Beep'
# Error in file:  /network/lustre/iss02/aramis/projects/cracknetworks/sub-01/ses-02/EEG/Train-[2022.04.04-16.14.01].edf
# 'Event name "OVTK_GDF_Left" could not be found. The following events are present in the data: OVTK_StimulationId_ExperimentStart, OVTK_StimulationId_BaselineStart/OVTK_StimulationId_Beep'
# Error in file:  /network/lustre/iss02/aramis/projects/cracknetworks/sub-01/ses-02/EEG/Test-[2022.04.04-16.52.15].edf
# 'Event name "OVTK_GDF_Left" could not be found. The following events are present in the data: OVTK_GDF_Feedback_Continuous, OVTK_GDF_Right, OVTK_StimulationId_ExperimentStart, OVTK_StimulationId_BaselineStart/OVTK_StimulationId_Beep, OVTK_StimulationId_BaselineStop/OVTK_StimulationId_Beep, OVTK_GDF_Cross_On_Screen/OVTK_GDF_Start_Of_Trial/OVTK_StimulationId_Beep, OVTK_GDF_End_Of_Trial/OVTK_StimulationId_VisualStimulationStar'
# LDA accuracy:  0.6499999999999999
# SVM accuracy:  0.7571428571428571
# SVM rbf accuracy:  0.6428571428571429
# Train subjects:  [1]
# Test subjects:  [1]
# Error in file:  /network/lustre/iss02/aramis/projects/cracknetworks/sub-01/ses-02/EEG/Train-[2022.04.04-16.15.17].edf
# 'Event name "OVTK_GDF_Left" could not be found. The following events are present in the data: OVTK_StimulationId_ExperimentStart, OVTK_StimulationId_BaselineStart/OVTK_StimulationId_Beep'
# Error in file:  /network/lustre/iss02/aramis/projects/cracknetworks/sub-01/ses-02/EEG/Train-[2022.04.04-16.14.01].edf
# 'Event name "OVTK_GDF_Left" could not be found. The following events are present in the data: OVTK_StimulationId_ExperimentStart, OVTK_StimulationId_BaselineStart/OVTK_StimulationId_Beep'
# Error in file:  /network/lustre/iss02/aramis/projects/cracknetworks/sub-01/ses-02/EEG/Test-[2022.04.04-16.52.15].edf
# 'Event name "OVTK_GDF_Left" could not be found. The following events are present in the data: OVTK_GDF_Feedback_Continuous, OVTK_GDF_Right, OVTK_StimulationId_ExperimentStart, OVTK_StimulationId_BaselineStart/OVTK_StimulationId_Beep, OVTK_StimulationId_BaselineStop/OVTK_StimulationId_Beep, OVTK_GDF_Cross_On_Screen/OVTK_GDF_Start_Of_Trial/OVTK_StimulationId_Beep, OVTK_GDF_End_Of_Trial/OVTK_StimulationId_VisualStimulationStar'
# LDA accuracy:  0.5125
# SVM accuracy:  0.51875
# SVM rbf accuracy:  0.475
# Train subjects:  [1]
# Test subjects:  [1]
# Error in file:  /network/lustre/iss02/aramis/projects/cracknetworks/sub-01/ses-02/EEG/Train-[2022.04.04-16.15.17].edf
# 'Event name "OVTK_GDF_Left" could not be found. The following events are present in the data: OVTK_StimulationId_ExperimentStart, OVTK_StimulationId_BaselineStart/OVTK_StimulationId_Beep'
# Error in file:  /network/lustre/iss02/aramis/projects/cracknetworks/sub-01/ses-02/EEG/Train-[2022.04.04-16.14.01].edf
# 'Event name "OVTK_GDF_Left" could not be found. The following events are present in the data: OVTK_StimulationId_ExperimentStart, OVTK_StimulationId_BaselineStart/OVTK_StimulationId_Beep'
# Error in file:  /network/lustre/iss02/aramis/projects/cracknetworks/sub-01/ses-02/EEG/Test-[2022.04.04-16.52.15].edf
# 'Event name "OVTK_GDF_Left" could not be found. The following events are present in the data: OVTK_GDF_Feedback_Continuous, OVTK_GDF_Right, OVTK_StimulationId_ExperimentStart, OVTK_StimulationId_BaselineStart/OVTK_StimulationId_Beep, OVTK_StimulationId_BaselineStop/OVTK_StimulationId_Beep, OVTK_GDF_Cross_On_Screen/OVTK_GDF_Start_Of_Trial/OVTK_StimulationId_Beep, OVTK_GDF_End_Of_Trial/OVTK_StimulationId_VisualStimulationStar'
# LDA accuracy:  0.7285714285714286
# SVM accuracy:  0.6928571428571428
# SVM rbf accuracy:  0.7142857142857142
# Train subjects:  [2]
# Test subjects:  [2]
# LDA accuracy:  0.6375
# SVM accuracy:  0.5875
# SVM rbf accuracy:  0.51875
# Train subjects:  [2]
# Test subjects:  [2]
# LDA accuracy:  0.7
# SVM accuracy:  0.6875
# SVM rbf accuracy:  0.4375
# Train subjects:  [2]
# Test subjects:  [2]
# LDA accuracy:  0.6904761904761905
# SVM accuracy:  0.7321428571428572
# SVM rbf accuracy:  0.44047619047619047
# Train subjects:  [3]
# Test subjects:  [3]
# Error in file:  /network/lustre/iss02/aramis/projects/cracknetworks/sub-03/ses-01/EEG/Test-[2022.03.15-16.39.19].edf
# could not convert string to float: './.).(-*'
# LDA accuracy:  0.71875
# SVM accuracy:  0.58125
# SVM rbf accuracy:  0.675
# Train subjects:  [3]
# Test subjects:  [3]
# Error in file:  /network/lustre/iss02/aramis/projects/cracknetworks/sub-03/ses-01/EEG/Test-[2022.03.15-16.39.19].edf
# could not convert string to float: './.).(-*'
# LDA accuracy:  0.61875
# SVM accuracy:  0.6125
# SVM rbf accuracy:  0.5
# Train subjects:  [3]
# Test subjects:  [3]
# Error in file:  /network/lustre/iss02/aramis/projects/cracknetworks/sub-03/ses-01/EEG/Test-[2022.03.15-16.39.19].edf
# could not convert string to float: './.).(-*'
# LDA accuracy:  0.7332099080694586
# SVM accuracy:  0.7956460674157304
# SVM rbf accuracy:  0.7573416751787538
# Train subjects:  [5]
# Test subjects:  [5]
# LDA accuracy:  0.7625
# SVM accuracy:  0.76875
# SVM rbf accuracy:  0.6625
# Train subjects:  [5]
# Test subjects:  [5]
# LDA accuracy:  0.7125
# SVM accuracy:  0.71875
# SVM rbf accuracy:  0.6937500000000001
# Train subjects:  [5]
# Test subjects:  [5]
# LDA accuracy:  0.8455594679186229
# SVM accuracy:  0.8384194053208138
# SVM rbf accuracy:  0.7627151799687011
# Train subjects:  [6]
# Test subjects:  [6]
# Error in file:  /network/lustre/iss02/aramis/projects/cracknetworks/sub-06/ses-02/EEG/Test-[2022.05.10-16.09.32].edf
# 'Event name "OVTK_GDF_Left" could not be found. The following events are present in the data: OVTK_StimulationId_ExperimentStart, OVTK_StimulationId_BaselineStart/OVTK_StimulationId_Beep'
# LDA accuracy:  0.81875
# SVM accuracy:  0.83125
# SVM rbf accuracy:  0.8
# Train subjects:  [6]
# Test subjects:  [6]
# Error in file:  /network/lustre/iss02/aramis/projects/cracknetworks/sub-06/ses-02/EEG/Test-[2022.05.10-16.09.32].edf
# 'Event name "OVTK_GDF_Left" could not be found. The following events are present in the data: OVTK_StimulationId_ExperimentStart, OVTK_StimulationId_BaselineStart/OVTK_StimulationId_Beep'
# LDA accuracy:  0.6499999999999999
# SVM accuracy:  0.7
# SVM rbf accuracy:  0.70625
# Train subjects:  [6]
# Test subjects:  [6]
# Error in file:  /network/lustre/iss02/aramis/projects/cracknetworks/sub-06/ses-02/EEG/Test-[2022.05.10-16.09.32].edf
# 'Event name "OVTK_GDF_Left" could not be found. The following events are present in the data: OVTK_StimulationId_ExperimentStart, OVTK_StimulationId_BaselineStart/OVTK_StimulationId_Beep'
# LDA accuracy:  0.59375
# SVM accuracy:  0.7875000000000001
# SVM rbf accuracy:  0.75625
# Train subjects:  [7]
# Test subjects:  [7]
# LDA accuracy:  0.625
# SVM accuracy:  0.6937500000000001
# SVM rbf accuracy:  0.5625
# Train subjects:  [7]
# Test subjects:  [7]
# LDA accuracy:  0.6
# SVM accuracy:  0.5437500000000001
# SVM rbf accuracy:  0.59375
# Train subjects:  [7]
# Test subjects:  [7]
# LDA accuracy:  0.56875
# SVM accuracy:  0.6
# SVM rbf accuracy:  0.625
# Train subjects:  [8]
# Test subjects:  [8]
# Error in file:  /network/lustre/iss02/aramis/projects/cracknetworks/sub-08/ses-02/EEG/Test-[2022.05.18-15.56.08].edf
# 'Event name "OVTK_GDF_Left" could not be found. The following events are present in the data: OVTK_StimulationId_ExperimentStart, OVTK_StimulationId_BaselineStart/OVTK_StimulationId_Beep'
# LDA accuracy:  0.7857142857142857
# SVM accuracy:  0.7785714285714285
# SVM rbf accuracy:  0.75
# Train subjects:  [8]
# Test subjects:  [8]
# Error in file:  /network/lustre/iss02/aramis/projects/cracknetworks/sub-08/ses-02/EEG/Test-[2022.05.18-15.56.08].edf
# 'Event name "OVTK_GDF_Left" could not be found. The following events are present in the data: OVTK_StimulationId_ExperimentStart, OVTK_StimulationId_BaselineStart/OVTK_StimulationId_Beep'
# LDA accuracy:  0.7437499999999999
# SVM accuracy:  0.80625
# SVM rbf accuracy:  0.7124999999999999
# Train subjects:  [8]
# Test subjects:  [8]
# Error in file:  /network/lustre/iss02/aramis/projects/cracknetworks/sub-08/ses-02/EEG/Test-[2022.05.18-15.56.08].edf
# 'Event name "OVTK_GDF_Left" could not be found. The following events are present in the data: OVTK_StimulationId_ExperimentStart, OVTK_StimulationId_BaselineStart/OVTK_StimulationId_Beep'
# LDA accuracy:  0.9142857142857143
# SVM accuracy:  0.9428571428571428
# SVM rbf accuracy:  0.8142857142857143
# Train subjects:  [10]
# Test subjects:  [10]
# Error in file:  /network/lustre/iss02/aramis/projects/cracknetworks/sub-10/ses-02/EEG/Test-[2022.07.19-16.20.04].edf
# 'Event name "OVTK_GDF_Left" could not be found. The following events are present in the data: OVTK_StimulationId_ExperimentStart, OVTK_StimulationId_BaselineStart/OVTK_StimulationId_Beep'
# LDA accuracy:  0.74375
# SVM accuracy:  0.70625
# SVM rbf accuracy:  0.49375
# Train subjects:  [10]
# Test subjects:  [10]
# Error in file:  /network/lustre/iss02/aramis/projects/cracknetworks/sub-10/ses-02/EEG/Test-[2022.07.19-16.20.04].edf
# 'Event name "OVTK_GDF_Left" could not be found. The following events are present in the data: OVTK_StimulationId_ExperimentStart, OVTK_StimulationId_BaselineStart/OVTK_StimulationId_Beep'
# LDA accuracy:  0.65625
# SVM accuracy:  0.65625
# SVM rbf accuracy:  0.425
# Train subjects:  [10]
# Test subjects:  [10]
# Error in file:  /network/lustre/iss02/aramis/projects/cracknetworks/sub-10/ses-02/EEG/Test-[2022.07.19-16.20.04].edf
# 'Event name "OVTK_GDF_Left" could not be found. The following events are present in the data: OVTK_StimulationId_ExperimentStart, OVTK_StimulationId_BaselineStart/OVTK_StimulationId_Beep'
# LDA accuracy:  0.6187499999999999
# SVM accuracy:  0.64375
# SVM rbf accuracy:  0.4875
# Train subjects:  [11]
# Test subjects:  [11]
# Error in file:  /network/lustre/iss02/aramis/projects/cracknetworks/sub-11/ses-02/EEG/Train-[2022.06.27-15.00.42].edf
# 'Event name "OVTK_GDF_Left" could not be found. The following events are present in the data: OVTK_StimulationId_ExperimentStart, OVTK_StimulationId_BaselineStart/OVTK_StimulationId_Beep'
# Error in file:  /network/lustre/iss02/aramis/projects/cracknetworks/sub-11/ses-03/EEG/Test-[2022.07.04-16.11.03].edf
# 'Event name "OVTK_GDF_Left" could not be found. The following events are present in the data: OVTK_StimulationId_ExperimentStart'
# LDA accuracy:  0.8395061728395061
# SVM accuracy:  0.8518518518518519
# SVM rbf accuracy:  0.5987654320987654
# Train subjects:  [11]
# Test subjects:  [11]
# Error in file:  /network/lustre/iss02/aramis/projects/cracknetworks/sub-11/ses-02/EEG/Train-[2022.06.27-15.00.42].edf
# 'Event name "OVTK_GDF_Left" could not be found. The following events are present in the data: OVTK_StimulationId_ExperimentStart, OVTK_StimulationId_BaselineStart/OVTK_StimulationId_Beep'
# Error in file:  /network/lustre/iss02/aramis/projects/cracknetworks/sub-11/ses-03/EEG/Test-[2022.07.04-16.11.03].edf
# 'Event name "OVTK_GDF_Left" could not be found. The following events are present in the data: OVTK_StimulationId_ExperimentStart'
# LDA accuracy:  0.78125
# SVM accuracy:  0.8125
# SVM rbf accuracy:  0.55
# Train subjects:  [11]
# Test subjects:  [11]
# Error in file:  /network/lustre/iss02/aramis/projects/cracknetworks/sub-11/ses-03/EEG/Test-[2022.07.04-16.11.03].edf
# 'Event name "OVTK_GDF_Left" could not be found. The following events are present in the data: OVTK_StimulationId_ExperimentStart'
# Error in file:  /network/lustre/iss02/aramis/projects/cracknetworks/sub-11/ses-02/EEG/Train-[2022.06.27-15.00.42].edf
# 'Event name "OVTK_GDF_Left" could not be found. The following events are present in the data: OVTK_StimulationId_ExperimentStart, OVTK_StimulationId_BaselineStart/OVTK_StimulationId_Beep'
# LDA accuracy:  0.63125
# SVM accuracy:  0.71875
# SVM rbf accuracy:  0.4875
# Train subjects:  [13]
# Test subjects:  [13]
# Error in file:  /network/lustre/iss02/aramis/projects/cracknetworks/sub-13/ses-01/EEG/Test-[2022.06.23-15.46.51].edf
# 'Event name "OVTK_GDF_Left" could not be found. The following events are present in the data: OVTK_StimulationId_ExperimentStart, OVTK_StimulationId_BaselineStart/OVTK_StimulationId_Beep'
# LDA accuracy:  0.7769933554817275
# SVM accuracy:  0.6788482834994463
# SVM rbf accuracy:  0.5538482834994463
# Train subjects:  [13]
# Test subjects:  [13]
# Error in file:  /network/lustre/iss02/aramis/projects/cracknetworks/sub-13/ses-01/EEG/Test-[2022.06.23-15.46.51].edf
# 'Event name "OVTK_GDF_Left" could not be found. The following events are present in the data: OVTK_StimulationId_ExperimentStart, OVTK_StimulationId_BaselineStart/OVTK_StimulationId_Beep'
# LDA accuracy:  0.6875
# SVM accuracy:  0.73125
# SVM rbf accuracy:  0.5375
# Train subjects:  [13]
# Test subjects:  [13]
# Error in file:  /network/lustre/iss02/aramis/projects/cracknetworks/sub-13/ses-01/EEG/Test-[2022.06.23-15.46.51].edf
# 'Event name "OVTK_GDF_Left" could not be found. The following events are present in the data: OVTK_StimulationId_ExperimentStart, OVTK_StimulationId_BaselineStart/OVTK_StimulationId_Beep'
# LDA accuracy:  0.685
# SVM accuracy:  0.745
# SVM rbf accuracy:  0.53
# Train subjects:  [14]
# Test subjects:  [14]
# LDA accuracy:  0.81875
# SVM accuracy:  0.8875
# SVM rbf accuracy:  0.63125
# Train subjects:  [14]
# Test subjects:  [14]
# LDA accuracy:  0.7125
# SVM accuracy:  0.8
# SVM rbf accuracy:  0.61875
# Train subjects:  [14]
# Test subjects:  [14]
# LDA accuracy:  0.79375
# SVM accuracy:  0.8187500000000001
# SVM rbf accuracy:  0.64375

# %%
with open('../dicts_results/intra_subject_classification/braccio_sessions_cassical.pkl', 'wb') as f:
    pickle.dump(dict_crossval, f)

# %%
import platform 
platform.processor()
# Out:
# 'x86_64'
