# %%
import mne
from mne.io import concatenate_raws, read_raw_edf
import matplotlib.pyplot as plt
import mne.viz
import os
import os.path as op
from mne.preprocessing import (ICA, create_eog_epochs, create_ecg_epochs,
                               corrmap)
from mne.time_frequency import tfr_multitaper
from mne.stats import permutation_cluster_1samp_test as pcluster_test
from mne.datasets import fetch_fsaverage
from mne import Epochs, EvokedArray, create_info, io, pick_types, read_events
from mne.datasets import sample
from mne.decoding import Vectorizer
from mne.decoding import CSP

import torch
from torcheeg.models import EEGNet
from torcheeg.models import DGCNN
from torcheeg import transforms

import numpy as np
import matplotlib.pyplot as plt
import scipy.signal as signal
import scipy as sc
from matplotlib import cm
import matplotlib.colors as colors

from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import StratifiedKFold
from sklearn.multiclass import OneVsRestClassifier
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import MinMaxScaler
from xgboost import XGBClassifier
import torchaudio

import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning) 

import pickle
# Out:
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages/xgboost/core.py:265: FutureWarning: Your system has an old version of glibc (< 2.28). We will stop supporting Linux distros with glibc older than 2.28 after **May 31, 2025**. Please upgrade to a recent Linux distro (with glibc 2.28+) to use future versions of XGBoost.
# Note: You have installed the 'manylinux2014' variant of XGBoost. Certain features such as GPU algorithms or federated learning are not available. To use these features, please upgrade to a recent Linux distro with glibc 2.28+, and install the 'manylinux_2_28' variant.
#   warnings.warn(

# %%
import sys 
sys.path.append("/home/aurelien.stumpf/Development/BCI_Classification/")
from eeg_project_package import dataset, models, spectral_analysis, training

# %%
import importlib
importlib.reload(dataset)
importlib.reload(training)
importlib.reload(models)
importlib.reload(spectral_analysis)
# Out:
# <module 'eeg_project_package.spectral_analysis' from '/home/aurelien.stumpf/Development/BCI_Classification/eeg_project_package/spectral_analysis.py'>

# %% [markdown]
# ## Check Loading of Braccio Dataset Files

# %%
#Define the parameters
subject = 1  # use data from subject 1
runs = [6, 10, 14]  # use only hand and feet motor imagery runs

#Get data and locate in to given path
input_fname1 =  "/network/lustre/iss02/aramis/projects/cracknetworks/sub-01/ses-01/EEG/Test-[2022.03.28-17.46.29].edf"
#Read raw data files where each file contains a run
raws = read_raw_edf(input_fname1, preload=True)
#Combine all loaded runs
#raw_obj = concatenate_raws(raws)
raw_obj = raws

raw_data = raw_obj.get_data()
print("Number of channels: ", str(len(raw_data)))
print("Number of samples: ", str(len(raw_data)))

#Plot epochs & PSD
raw_obj.plot(duration=120, n_channels=15, scalings=dict(eeg=420e-6))
raw_obj.plot_psd(average=True)

# list of all channel names
list_all_ch_names = raw_obj.ch_names
# Out:
# Number of channels:  64
# Number of samples:  64
# <MNEBrowseFigure size 800x800 with 4 Axes>
# <MNELineFigure size 1000x350 with 1 Axes>

# %% [markdown]
# ## Training on one subject

# %%
# Define the subject and the session
num_sessions = [1,2,3]
num_subjects = [1,2,3,5,6,7,8,10,11,13,14]  
dict_crossval = {"test_balanced_accuracy":np.zeros((11,3,3)), "test_loss":np.zeros((11,3,3)), "val_balanced_accuracy":np.zeros((11,3,3)), "val_loss":np.zeros((11,3,3)), "train_balanced_accuracy":np.zeros((11,3,3)), "train_loss":np.zeros((11,3,3))}

for i in range(len(num_subjects)):
    for num_session in num_sessions:
    
        num_subject = num_subjects[i]
        print("Subject: ", num_subject, " Session: ", num_session)

        # Define the path to the data and the train and test files
        if num_subject < 10:
            subject_number = "0" + str(num_subject)
        else:
            subject_number = str(num_subject)
        session_number = "0" + str(num_session)
        folder_path = "/network/lustre/iss02/aramis/projects/cracknetworks/sub-{}/ses-{}/EEG/".format(subject_number, session_number)
        files = [folder_path + f for f in os.listdir(folder_path) if f.endswith('.edf') and not(f.startswith("._"))]
        list_train_files = files[:-2]
        list_val_files = files[-2:-1]
        list_test_files = files[-1:]

        # Define the channels
        list_name_channels = ["CP1","CP3","CP5","C1","C3","C5","C2","CP2","Cz","FCz","C4","CP4"]
        list_idx_channels = [list_all_ch_names.index(ch) for ch in list_name_channels]

        # Define the labels
        labels = ['OVTK_GDF_Left', 'OVTK_GDF_Right']

        # Define the parameters of the dataset
        feature_type = ["time","band_psd","band_coh"]
        dict_preprocessing = {"polynomial_degree":10,"tmin":0,"tmax":4,"seq_length":2001}
        dict_features = {"type_psd":"welch","fs":500,"nfft":300,"noverlap":150,"nperseg":300,"filter_order":19,"fmin":4,"fmax":30}

        # Create the dataset
        try : 
            subject_trainset = dataset.EEG_Dataset(files_list = list_train_files, list_idx_channels = list_idx_channels, list_labels = labels, feature_type = feature_type, dict_preprocessing = dict_preprocessing, dict_features = dict_features)
            subject_valset = dataset.EEG_Dataset(files_list = list_val_files, list_idx_channels = list_idx_channels, list_labels = labels, feature_type = feature_type, dict_preprocessing = dict_preprocessing, dict_features = dict_features)
            subject_testset = dataset.EEG_Dataset(files_list = list_test_files, list_idx_channels = list_idx_channels, list_labels = labels, feature_type = feature_type, dict_preprocessing = dict_preprocessing, dict_features = dict_features)

            subject_trainset.transform_dataset_numpy_to_torch()
            subject_trainset.features["time"] = subject_trainset.features["time"].unsqueeze(1)
            subject_testset.transform_dataset_numpy_to_torch()
            subject_testset.features["time"] = subject_testset.features["time"].unsqueeze(1)
            subject_valset.transform_dataset_numpy_to_torch()
            subject_valset.features["time"] = subject_valset.features["time"].unsqueeze(1)
            trainloader = torch.utils.data.DataLoader(subject_trainset, batch_size=16, shuffle=True, num_workers=2)
            valloader = torch.utils.data.DataLoader(subject_valset, batch_size=32, shuffle=True, num_workers=2)
            testloader = torch.utils.data.DataLoader(subject_testset, batch_size=32, shuffle=True, num_workers=2)

            feature_type = "time"
            device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
            criterion = torch.nn.CrossEntropyLoss()

            for num_trial in range(3):
                model = EEGNet(chunk_size=2001,
                            num_electrodes=12,
                            dropout=0.25,
                            kernel_1=500,
                            kernel_2=250,
                            F1=4,
                            F2=16,
                            D=2,
                            num_classes=2)
                # get parameters of the model
                model.to(device)
                optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
                #scheduler = torch.optim.lr_scheduler.MultiStepLR(optimizer, milestones=[20, 50], gamma=0.1)
                scheduler = torch.optim.lr_scheduler.MultiplicativeLR(optimizer, lr_lambda=lambda epoch: 0.95)
                scheduler_dict = {"MultiplicativeLR" : scheduler}
                logs = training.train_model(model, trainloader, valloader, device, criterion, feature_type, 51, optimizer, scheduler_dict, print_epoch = 5)

                model.load_state_dict(logs["best_model_weights"])
                model.eval()
                train_balanced_accuracy, train_loss = training.evaluate_classification_model(model,trainloader,device,criterion,feature_type,dataset="Train")
                val_balanced_accuracy, val_loss = training.evaluate_classification_model(model,valloader,device,criterion,feature_type,dataset="Val")
                test_balanced_accuracy, test_loss = training.evaluate_classification_model(model,testloader,device,criterion,feature_type,dataset="Test")
                dict_crossval["test_balanced_accuracy"][i,num_session-1,num_trial] = test_balanced_accuracy
                dict_crossval["test_loss"][i,num_session-1,num_trial] = test_loss
                dict_crossval["val_balanced_accuracy"][i,num_session-1,num_trial] = val_balanced_accuracy
                dict_crossval["val_loss"][i,num_session-1,num_trial] = val_loss
                dict_crossval["train_balanced_accuracy"][i,num_session-1,num_trial] = train_balanced_accuracy
                dict_crossval["train_loss"][i,num_session-1,num_trial] = train_loss
        except:
            print("Error in subject ", num_subject, " session ", num_session)
            continue
# Out:
# Subject:  1  Session:  1
# Epoch 0:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 0
# lr:  0.01
# -------------------------
# Train set: Avg. loss: 0.0121, Balanced Accuracy: 0.5166666507720947 (52%)
# Test set: Avg. loss: 0.0363, Balanced Accuracy: 0.3499999940395355 (35%)
# Saving best model weights with balanced accuracy:  0.3499999940395355
# -------------------------
# Epoch 0: 100%|██████████| 2/2 [00:02<00:00,  1.35s/batch, accuracy=0.525, loss=0.0136]
# Epoch 1: 100%|██████████| 2/2 [00:01<00:00,  1.74batch/s, accuracy=0.775, loss=0.0071]
# Epoch 2: 100%|██████████| 2/2 [00:01<00:00,  1.79batch/s, accuracy=0.833, loss=0.00651]
# Epoch 3: 100%|██████████| 2/2 [00:01<00:00,  1.67batch/s, accuracy=0.833, loss=0.00574]
# Epoch 4: 100%|██████████| 2/2 [00:01<00:00,  1.63batch/s, accuracy=0.858, loss=0.00548]
# Epoch 5:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 5
# lr:  0.007737809374999999
# -------------------------
# Train set: Avg. loss: 0.0963, Balanced Accuracy: 0.5416666865348816 (54%)
# Test set: Avg. loss: 0.4978, Balanced Accuracy: 0.5 (50%)
# Saving best model weights with balanced accuracy:  0.5
# -------------------------
# Epoch 5: 100%|██████████| 2/2 [00:02<00:00,  1.04s/batch, accuracy=0.858, loss=0.00548]
# Epoch 6: 100%|██████████| 2/2 [00:01<00:00,  1.71batch/s, accuracy=0.842, loss=0.00668]
# Epoch 7: 100%|██████████| 2/2 [00:00<00:00,  2.03batch/s, accuracy=0.858, loss=0.00818]
# Epoch 8: 100%|██████████| 2/2 [00:00<00:00,  2.13batch/s, accuracy=0.883, loss=0.0048]
# Epoch 9: 100%|██████████| 2/2 [00:01<00:00,  1.78batch/s, accuracy=0.875, loss=0.00265]
# Epoch 10:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 10
# lr:  0.005987369392383786
# -------------------------
# Train set: Avg. loss: 0.0235, Balanced Accuracy: 0.7666666507720947 (77%)
# Test set: Avg. loss: 0.3318, Balanced Accuracy: 0.5 (50%)
# -------------------------
# Epoch 10: 100%|██████████| 2/2 [00:02<00:00,  1.07s/batch, accuracy=0.9, loss=0.00485]
# Epoch 11: 100%|██████████| 2/2 [00:01<00:00,  1.93batch/s, accuracy=0.925, loss=0.00288]
# Epoch 12: 100%|██████████| 2/2 [00:01<00:00,  1.74batch/s, accuracy=0.908, loss=0.00322]
# Epoch 13: 100%|██████████| 2/2 [00:01<00:00,  1.81batch/s, accuracy=0.925, loss=0.00261]
# Epoch 14: 100%|██████████| 2/2 [00:01<00:00,  1.72batch/s, accuracy=0.925, loss=0.00303]
# Epoch 15:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 15
# lr:  0.00463291230159753
# -------------------------
# Train set: Avg. loss: 0.0199, Balanced Accuracy: 0.8583333492279053 (86%)
# Test set: Avg. loss: 0.2317, Balanced Accuracy: 0.550000011920929 (55%)
# Saving best model weights with balanced accuracy:  0.550000011920929
# -------------------------
# Epoch 15: 100%|██████████| 2/2 [00:01<00:00,  1.01batch/s, accuracy=0.942, loss=0.00188]
# Epoch 16: 100%|██████████| 2/2 [00:01<00:00,  1.93batch/s, accuracy=0.933, loss=0.00181]
# Epoch 17: 100%|██████████| 2/2 [00:00<00:00,  2.12batch/s, accuracy=0.933, loss=0.00509]
# Epoch 18: 100%|██████████| 2/2 [00:00<00:00,  2.10batch/s, accuracy=0.933, loss=0.00176]
# Epoch 19: 100%|██████████| 2/2 [00:00<00:00,  2.46batch/s, accuracy=0.925, loss=0.00267]
# Epoch 20:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 20
# lr:  0.0035848592240854188
# -------------------------
# Train set: Avg. loss: 0.0073, Balanced Accuracy: 0.8833333253860474 (88%)
# Test set: Avg. loss: 0.2079, Balanced Accuracy: 0.6000000238418579 (60%)
# Saving best model weights with balanced accuracy:  0.6000000238418579
# -------------------------
# Epoch 20: 100%|██████████| 2/2 [00:01<00:00,  1.11batch/s, accuracy=0.942, loss=0.00204]
# Epoch 21: 100%|██████████| 2/2 [00:00<00:00,  2.18batch/s, accuracy=0.933, loss=0.00277]
# Epoch 22: 100%|██████████| 2/2 [00:00<00:00,  2.05batch/s, accuracy=0.958, loss=0.00142]
# Epoch 23: 100%|██████████| 2/2 [00:00<00:00,  2.34batch/s, accuracy=0.958, loss=0.00209]
# Epoch 24: 100%|██████████| 2/2 [00:00<00:00,  2.20batch/s, accuracy=0.95, loss=0.00139]
# Epoch 25:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 25
# lr:  0.0027738957312183374
# -------------------------
# Train set: Avg. loss: 0.0066, Balanced Accuracy: 0.9333333373069763 (93%)
# Test set: Avg. loss: 0.1837, Balanced Accuracy: 0.6499999761581421 (65%)
# Saving best model weights with balanced accuracy:  0.6499999761581421
# -------------------------
# Epoch 25: 100%|██████████| 2/2 [00:01<00:00,  1.23batch/s, accuracy=0.967, loss=0.00167]
# Epoch 26: 100%|██████████| 2/2 [00:00<00:00,  2.20batch/s, accuracy=0.967, loss=0.00126]
# Epoch 27: 100%|██████████| 2/2 [00:00<00:00,  2.40batch/s, accuracy=0.967, loss=0.00124]
# Epoch 28: 100%|██████████| 2/2 [00:00<00:00,  2.10batch/s, accuracy=0.983, loss=0.000924]
# Epoch 29: 100%|██████████| 2/2 [00:00<00:00,  2.21batch/s, accuracy=0.975, loss=0.0019]
# Epoch 30:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 30
# lr:  0.0021463876394293723
# -------------------------
# Train set: Avg. loss: 0.0046, Balanced Accuracy: 0.9166666269302368 (92%)
# Test set: Avg. loss: 0.1678, Balanced Accuracy: 0.6499999761581421 (65%)
# -------------------------
# Epoch 30: 100%|██████████| 2/2 [00:01<00:00,  1.32batch/s, accuracy=0.958, loss=0.00152]
# Epoch 31: 100%|██████████| 2/2 [00:00<00:00,  2.34batch/s, accuracy=0.942, loss=0.00135]
# Epoch 32: 100%|██████████| 2/2 [00:00<00:00,  2.14batch/s, accuracy=0.967, loss=0.00143]
# Epoch 33: 100%|██████████| 2/2 [00:00<00:00,  2.14batch/s, accuracy=0.983, loss=0.000875]
# Epoch 34: 100%|██████████| 2/2 [00:00<00:00,  2.18batch/s, accuracy=0.967, loss=0.00278]
# Epoch 35:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 35
# lr:  0.0016608338398760713
# -------------------------
# Train set: Avg. loss: 0.0038, Balanced Accuracy: 0.9166666269302368 (92%)
# Test set: Avg. loss: 0.1450, Balanced Accuracy: 0.6000000238418579 (60%)
# -------------------------
# Epoch 35: 100%|██████████| 2/2 [00:01<00:00,  1.25batch/s, accuracy=0.983, loss=0.00101]
# Epoch 36: 100%|██████████| 2/2 [00:00<00:00,  2.07batch/s, accuracy=1, loss=0.000766]
# Epoch 37: 100%|██████████| 2/2 [00:00<00:00,  2.68batch/s, accuracy=0.975, loss=0.000795]
# Epoch 38: 100%|██████████| 2/2 [00:00<00:00,  2.81batch/s, accuracy=0.983, loss=0.00124]
# Epoch 39: 100%|██████████| 2/2 [00:00<00:00,  2.88batch/s, accuracy=0.983, loss=0.0013]
# Epoch 40:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 40
# lr:  0.0012851215656510308
# -------------------------
# Train set: Avg. loss: 0.0042, Balanced Accuracy: 0.9333333373069763 (93%)
# Test set: Avg. loss: 0.1334, Balanced Accuracy: 0.6499999761581421 (65%)
# -------------------------
# Epoch 40: 100%|██████████| 2/2 [00:01<00:00,  1.58batch/s, accuracy=0.992, loss=0.000713]
# Epoch 41: 100%|██████████| 2/2 [00:00<00:00,  2.88batch/s, accuracy=0.983, loss=0.00162]
# Epoch 42: 100%|██████████| 2/2 [00:00<00:00,  2.92batch/s, accuracy=0.975, loss=0.00107]
# Epoch 43: 100%|██████████| 2/2 [00:00<00:00,  2.99batch/s, accuracy=1, loss=0.00088]
# Epoch 44: 100%|██████████| 2/2 [00:00<00:00,  2.93batch/s, accuracy=0.992, loss=0.000654]
# Epoch 45:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 45
# lr:  0.000994402569870922
# -------------------------
# Train set: Avg. loss: 0.0017, Balanced Accuracy: 0.9666666984558105 (97%)
# Test set: Avg. loss: 0.1239, Balanced Accuracy: 0.6499999761581421 (65%)
# -------------------------
# Epoch 45: 100%|██████████| 2/2 [00:01<00:00,  1.55batch/s, accuracy=0.992, loss=0.000976]
# Epoch 46: 100%|██████████| 2/2 [00:00<00:00,  3.00batch/s, accuracy=0.975, loss=0.000969]
# Epoch 47: 100%|██████████| 2/2 [00:00<00:00,  2.90batch/s, accuracy=0.975, loss=0.000767]
# Epoch 48: 100%|██████████| 2/2 [00:00<00:00,  2.91batch/s, accuracy=0.975, loss=0.00102]
# Epoch 49: 100%|██████████| 2/2 [00:00<00:00,  2.98batch/s, accuracy=0.992, loss=0.00105]
# Epoch 50:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 50
# lr:  0.0007694497527671312
# -------------------------
# Train set: Avg. loss: 0.0010, Balanced Accuracy: 0.9833333492279053 (98%)
# Test set: Avg. loss: 0.1168, Balanced Accuracy: 0.6499999761581421 (65%)
# -------------------------
# Epoch 50: 100%|██████████| 2/2 [00:01<00:00,  1.69batch/s, accuracy=1, loss=0.000446]
# Train set: Avg. loss: 0.0048, Balanced Accuracy: 0.9333333373069763 (93%)
# Val set: Avg. loss: 0.1837, Balanced Accuracy: 0.6499999761581421 (65%)
# Test set: Avg. loss: 0.0718, Balanced Accuracy: 0.699999988079071 (70%)
# Epoch 0:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 0
# lr:  0.01
# -------------------------
# Train set: Avg. loss: 0.0118, Balanced Accuracy: 0.5083333253860474 (51%)
# Test set: Avg. loss: 0.0363, Balanced Accuracy: 0.4000000059604645 (40%)
# Saving best model weights with balanced accuracy:  0.4000000059604645
# -------------------------
# Epoch 0: 100%|██████████| 2/2 [00:01<00:00,  1.10batch/s, accuracy=0.533, loss=0.0111]
# Epoch 1: 100%|██████████| 2/2 [00:00<00:00,  2.15batch/s, accuracy=0.75, loss=0.0102]
# Epoch 2: 100%|██████████| 2/2 [00:00<00:00,  2.14batch/s, accuracy=0.825, loss=0.0104]
# Epoch 3: 100%|██████████| 2/2 [00:00<00:00,  2.52batch/s, accuracy=0.775, loss=0.0107]
# Epoch 4: 100%|██████████| 2/2 [00:00<00:00,  2.11batch/s, accuracy=0.892, loss=0.00746]
# Epoch 5:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 5
# lr:  0.007737809374999999
# -------------------------
# Train set: Avg. loss: 0.0191, Balanced Accuracy: 0.7333333492279053 (73%)
# Test set: Avg. loss: 0.1960, Balanced Accuracy: 0.550000011920929 (55%)
# Saving best model weights with balanced accuracy:  0.550000011920929
# -------------------------
# Epoch 5: 100%|██████████| 2/2 [00:01<00:00,  1.10batch/s, accuracy=0.883, loss=0.00676]
# Epoch 6: 100%|██████████| 2/2 [00:00<00:00,  2.20batch/s, accuracy=0.858, loss=0.00443]
# Epoch 7: 100%|██████████| 2/2 [00:00<00:00,  2.37batch/s, accuracy=0.883, loss=0.00523]
# Epoch 8: 100%|██████████| 2/2 [00:00<00:00,  2.03batch/s, accuracy=0.875, loss=0.00396]
# Epoch 9: 100%|██████████| 2/2 [00:00<00:00,  2.17batch/s, accuracy=0.917, loss=0.00361]
# Epoch 10:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 10
# lr:  0.005987369392383786
# -------------------------
# Train set: Avg. loss: 0.0171, Balanced Accuracy: 0.7166666984558105 (72%)
# Test set: Avg. loss: 0.2049, Balanced Accuracy: 0.6499999761581421 (65%)
# Saving best model weights with balanced accuracy:  0.6499999761581421
# -------------------------
# Epoch 10: 100%|██████████| 2/2 [00:01<00:00,  1.15batch/s, accuracy=0.908, loss=0.00291]
# Epoch 11: 100%|██████████| 2/2 [00:00<00:00,  2.36batch/s, accuracy=0.933, loss=0.00416]
# Epoch 12: 100%|██████████| 2/2 [00:00<00:00,  2.21batch/s, accuracy=0.917, loss=0.00378]
# Epoch 13: 100%|██████████| 2/2 [00:00<00:00,  2.15batch/s, accuracy=0.967, loss=0.00179]
# Epoch 14: 100%|██████████| 2/2 [00:00<00:00,  2.19batch/s, accuracy=0.967, loss=0.00203]
# Epoch 15:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 15
# lr:  0.00463291230159753
# -------------------------
# Train set: Avg. loss: 0.0063, Balanced Accuracy: 0.8666666746139526 (87%)
# Test set: Avg. loss: 0.1600, Balanced Accuracy: 0.6499999761581421 (65%)
# -------------------------
# Epoch 15: 100%|██████████| 2/2 [00:01<00:00,  1.25batch/s, accuracy=0.95, loss=0.00166]
# Epoch 16: 100%|██████████| 2/2 [00:00<00:00,  2.14batch/s, accuracy=0.958, loss=0.00288]
# Epoch 17: 100%|██████████| 2/2 [00:00<00:00,  2.24batch/s, accuracy=0.958, loss=0.00148]
# Epoch 18: 100%|██████████| 2/2 [00:00<00:00,  2.64batch/s, accuracy=0.983, loss=0.00152]
# Epoch 19: 100%|██████████| 2/2 [00:00<00:00,  2.04batch/s, accuracy=0.942, loss=0.00247]
# Epoch 20:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 20
# lr:  0.0035848592240854188
# -------------------------
# Train set: Avg. loss: 0.0041, Balanced Accuracy: 0.9166666269302368 (92%)
# Test set: Avg. loss: 0.1288, Balanced Accuracy: 0.699999988079071 (70%)
# Saving best model weights with balanced accuracy:  0.699999988079071
# -------------------------
# Epoch 20: 100%|██████████| 2/2 [00:01<00:00,  1.12batch/s, accuracy=0.958, loss=0.00165]
# Epoch 21: 100%|██████████| 2/2 [00:00<00:00,  2.02batch/s, accuracy=0.975, loss=0.00132]
# Epoch 22: 100%|██████████| 2/2 [00:00<00:00,  2.04batch/s, accuracy=0.958, loss=0.0024]
# Epoch 23: 100%|██████████| 2/2 [00:00<00:00,  2.04batch/s, accuracy=0.975, loss=0.00188]
# Epoch 24: 100%|██████████| 2/2 [00:00<00:00,  2.31batch/s, accuracy=0.975, loss=0.00096]
# Epoch 25:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 25
# lr:  0.0027738957312183374
# -------------------------
# Train set: Avg. loss: 0.0045, Balanced Accuracy: 0.925000011920929 (93%)
# Test set: Avg. loss: 0.1183, Balanced Accuracy: 0.699999988079071 (70%)
# -------------------------
# Epoch 25: 100%|██████████| 2/2 [00:01<00:00,  1.22batch/s, accuracy=0.992, loss=0.000978]
# Epoch 26: 100%|██████████| 2/2 [00:00<00:00,  2.01batch/s, accuracy=0.992, loss=0.00128]
# Epoch 27: 100%|██████████| 2/2 [00:00<00:00,  2.05batch/s, accuracy=0.983, loss=0.000865]
# Epoch 28: 100%|██████████| 2/2 [00:00<00:00,  2.35batch/s, accuracy=0.975, loss=0.00141]
# Epoch 29: 100%|██████████| 2/2 [00:00<00:00,  2.08batch/s, accuracy=0.992, loss=0.00102]
# Epoch 30:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 30
# lr:  0.0021463876394293723
# -------------------------
# Train set: Avg. loss: 0.0045, Balanced Accuracy: 0.9333333373069763 (93%)
# Test set: Avg. loss: 0.1119, Balanced Accuracy: 0.6499999761581421 (65%)
# -------------------------
# Epoch 30: 100%|██████████| 2/2 [00:01<00:00,  1.04batch/s, accuracy=0.95, loss=0.00199]
# Epoch 31: 100%|██████████| 2/2 [00:00<00:00,  2.10batch/s, accuracy=1, loss=0.000625]
# Epoch 32: 100%|██████████| 2/2 [00:00<00:00,  2.44batch/s, accuracy=1, loss=0.000745]
# Epoch 33: 100%|██████████| 2/2 [00:00<00:00,  2.15batch/s, accuracy=0.983, loss=0.00163]
# Epoch 34: 100%|██████████| 2/2 [00:00<00:00,  2.23batch/s, accuracy=0.992, loss=0.000544]
# Epoch 35:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 35
# lr:  0.0016608338398760713
# -------------------------
# Train set: Avg. loss: 0.0015, Balanced Accuracy: 0.9666666984558105 (97%)
# Test set: Avg. loss: 0.1089, Balanced Accuracy: 0.699999988079071 (70%)
# -------------------------
# Epoch 35: 100%|██████████| 2/2 [00:01<00:00,  1.17batch/s, accuracy=0.983, loss=0.000951]
# Epoch 36: 100%|██████████| 2/2 [00:00<00:00,  2.48batch/s, accuracy=1, loss=0.000953]
# Epoch 37: 100%|██████████| 2/2 [00:00<00:00,  2.07batch/s, accuracy=0.967, loss=0.00168]
# Epoch 38: 100%|██████████| 2/2 [00:00<00:00,  2.16batch/s, accuracy=0.992, loss=0.000658]
# Epoch 39: 100%|██████████| 2/2 [00:00<00:00,  2.24batch/s, accuracy=1, loss=0.000529]
# Epoch 40:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 40
# lr:  0.0012851215656510308
# -------------------------
# Train set: Avg. loss: 0.0012, Balanced Accuracy: 0.9666666984558105 (97%)
# Test set: Avg. loss: 0.1062, Balanced Accuracy: 0.699999988079071 (70%)
# -------------------------
# Epoch 40: 100%|██████████| 2/2 [00:01<00:00,  1.20batch/s, accuracy=1, loss=0.000665]
# Epoch 41: 100%|██████████| 2/2 [00:00<00:00,  2.08batch/s, accuracy=0.992, loss=0.000806]
# Epoch 42: 100%|██████████| 2/2 [00:00<00:00,  2.70batch/s, accuracy=0.983, loss=0.00176]
# Epoch 43: 100%|██████████| 2/2 [00:00<00:00,  2.52batch/s, accuracy=1, loss=0.000611]
# Epoch 44: 100%|██████████| 2/2 [00:00<00:00,  2.16batch/s, accuracy=1, loss=0.000577]
# Epoch 45:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 45
# lr:  0.000994402569870922
# -------------------------
# Train set: Avg. loss: 0.0014, Balanced Accuracy: 0.9750000238418579 (98%)
# Test set: Avg. loss: 0.1000, Balanced Accuracy: 0.699999988079071 (70%)
# -------------------------
# Epoch 45: 100%|██████████| 2/2 [00:01<00:00,  1.08batch/s, accuracy=1, loss=0.000475]
# Epoch 46: 100%|██████████| 2/2 [00:00<00:00,  3.18batch/s, accuracy=1, loss=0.000526]
# Epoch 47: 100%|██████████| 2/2 [00:00<00:00,  2.15batch/s, accuracy=1, loss=0.000697]
# Epoch 48: 100%|██████████| 2/2 [00:01<00:00,  1.67batch/s, accuracy=1, loss=0.000389]
# Epoch 49: 100%|██████████| 2/2 [00:01<00:00,  1.65batch/s, accuracy=1, loss=0.000575]
# Epoch 50:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 50
# lr:  0.0007694497527671312
# -------------------------
# Train set: Avg. loss: 0.0007, Balanced Accuracy: 0.9750000238418579 (98%)
# Test set: Avg. loss: 0.0957, Balanced Accuracy: 0.699999988079071 (70%)
# -------------------------
# Epoch 50: 100%|██████████| 2/2 [00:02<00:00,  1.11s/batch, accuracy=1, loss=0.000338]
# Train set: Avg. loss: 0.0031, Balanced Accuracy: 0.9166666269302368 (92%)
# Val set: Avg. loss: 0.1288, Balanced Accuracy: 0.699999988079071 (70%)
# Test set: Avg. loss: 0.0277, Balanced Accuracy: 0.800000011920929 (80%)
# Epoch 0:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 0
# lr:  0.01
# -------------------------
# Train set: Avg. loss: 0.0121, Balanced Accuracy: 0.40833333134651184 (41%)
# Test set: Avg. loss: 0.0357, Balanced Accuracy: 0.44999998807907104 (45%)
# Saving best model weights with balanced accuracy:  0.44999998807907104
# -------------------------
# Epoch 0: 100%|██████████| 2/2 [00:02<00:00,  1.08s/batch, accuracy=0.433, loss=0.0116]
# Epoch 1: 100%|██████████| 2/2 [00:01<00:00,  1.80batch/s, accuracy=0.683, loss=0.012]
# Epoch 2: 100%|██████████| 2/2 [00:01<00:00,  1.83batch/s, accuracy=0.658, loss=0.016]
# Epoch 3: 100%|██████████| 2/2 [00:00<00:00,  2.41batch/s, accuracy=0.783, loss=0.0112]
# Epoch 4: 100%|██████████| 2/2 [00:00<00:00,  2.18batch/s, accuracy=0.8, loss=0.00743]
# Epoch 5:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 5
# lr:  0.007737809374999999
# -------------------------
# Train set: Avg. loss: 0.0404, Balanced Accuracy: 0.5916666984558105 (59%)
# Test set: Avg. loss: 0.2310, Balanced Accuracy: 0.4000000059604645 (40%)
# -------------------------
# Epoch 5: 100%|██████████| 2/2 [00:01<00:00,  1.39batch/s, accuracy=0.817, loss=0.0102]
# Epoch 6: 100%|██████████| 2/2 [00:00<00:00,  2.19batch/s, accuracy=0.842, loss=0.00704]
# Epoch 7: 100%|██████████| 2/2 [00:00<00:00,  2.24batch/s, accuracy=0.833, loss=0.00643]
# Epoch 8: 100%|██████████| 2/2 [00:00<00:00,  2.63batch/s, accuracy=0.9, loss=0.00319]
# Epoch 9: 100%|██████████| 2/2 [00:00<00:00,  2.27batch/s, accuracy=0.908, loss=0.00388]
# Epoch 10:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 10
# lr:  0.005987369392383786
# -------------------------
# Train set: Avg. loss: 0.0059, Balanced Accuracy: 0.8166666626930237 (82%)
# Test set: Avg. loss: 0.1622, Balanced Accuracy: 0.5 (50%)
# Saving best model weights with balanced accuracy:  0.5
# -------------------------
# Epoch 10: 100%|██████████| 2/2 [00:01<00:00,  1.23batch/s, accuracy=0.933, loss=0.00336]
# Epoch 11: 100%|██████████| 2/2 [00:00<00:00,  2.01batch/s, accuracy=0.917, loss=0.00488]
# Epoch 12: 100%|██████████| 2/2 [00:00<00:00,  2.72batch/s, accuracy=0.933, loss=0.00271]
# Epoch 13: 100%|██████████| 2/2 [00:00<00:00,  2.23batch/s, accuracy=0.942, loss=0.00222]
# Epoch 14: 100%|██████████| 2/2 [00:00<00:00,  2.25batch/s, accuracy=0.95, loss=0.00232]
# Epoch 15:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 15
# lr:  0.00463291230159753
# -------------------------
# Train set: Avg. loss: 0.0102, Balanced Accuracy: 0.8166666626930237 (82%)
# Test set: Avg. loss: 0.1935, Balanced Accuracy: 0.5 (50%)
# -------------------------
# Epoch 15: 100%|██████████| 2/2 [00:01<00:00,  1.23batch/s, accuracy=0.958, loss=0.00191]
# Epoch 16: 100%|██████████| 2/2 [00:00<00:00,  2.61batch/s, accuracy=0.942, loss=0.00206]
# Epoch 17: 100%|██████████| 2/2 [00:00<00:00,  2.72batch/s, accuracy=0.975, loss=0.00167]
# Epoch 18: 100%|██████████| 2/2 [00:00<00:00,  2.39batch/s, accuracy=0.958, loss=0.00139]
# Epoch 19: 100%|██████████| 2/2 [00:00<00:00,  2.17batch/s, accuracy=0.958, loss=0.0017]
# Epoch 20:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 20
# lr:  0.0035848592240854188
# -------------------------
# Train set: Avg. loss: 0.0045, Balanced Accuracy: 0.9416666626930237 (94%)
# Test set: Avg. loss: 0.1788, Balanced Accuracy: 0.6000000238418579 (60%)
# Saving best model weights with balanced accuracy:  0.6000000238418579
# -------------------------
# Epoch 20: 100%|██████████| 2/2 [00:01<00:00,  1.28batch/s, accuracy=0.983, loss=0.00105]
# Epoch 21: 100%|██████████| 2/2 [00:00<00:00,  2.35batch/s, accuracy=0.992, loss=0.000867]
# Epoch 22: 100%|██████████| 2/2 [00:00<00:00,  2.31batch/s, accuracy=0.967, loss=0.00115]
# Epoch 23: 100%|██████████| 2/2 [00:00<00:00,  2.37batch/s, accuracy=0.983, loss=0.00106]
# Epoch 24: 100%|██████████| 2/2 [00:00<00:00,  2.95batch/s, accuracy=0.958, loss=0.00106]
# Epoch 25:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 25
# lr:  0.0027738957312183374
# -------------------------
# Train set: Avg. loss: 0.0027, Balanced Accuracy: 0.9416666626930237 (94%)
# Test set: Avg. loss: 0.1638, Balanced Accuracy: 0.6000000238418579 (60%)
# -------------------------
# Epoch 25: 100%|██████████| 2/2 [00:01<00:00,  1.18batch/s, accuracy=0.975, loss=0.00108]
# Epoch 26: 100%|██████████| 2/2 [00:00<00:00,  2.30batch/s, accuracy=0.992, loss=0.00084]
# Epoch 27: 100%|██████████| 2/2 [00:00<00:00,  2.36batch/s, accuracy=0.992, loss=0.00101]
# Epoch 28: 100%|██████████| 2/2 [00:00<00:00,  2.31batch/s, accuracy=0.983, loss=0.000929]
# Epoch 29: 100%|██████████| 2/2 [00:00<00:00,  2.50batch/s, accuracy=1, loss=0.000765]
# Epoch 30:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 30
# lr:  0.0021463876394293723
# -------------------------
# Train set: Avg. loss: 0.0036, Balanced Accuracy: 0.9416666626930237 (94%)
# Test set: Avg. loss: 0.1579, Balanced Accuracy: 0.6000000238418579 (60%)
# -------------------------
# Epoch 30: 100%|██████████| 2/2 [00:01<00:00,  1.20batch/s, accuracy=0.992, loss=0.000731]
# Epoch 31: 100%|██████████| 2/2 [00:00<00:00,  2.44batch/s, accuracy=1, loss=0.000725]
# Epoch 32: 100%|██████████| 2/2 [00:00<00:00,  2.36batch/s, accuracy=0.983, loss=0.000621]
# Epoch 33: 100%|██████████| 2/2 [00:00<00:00,  2.28batch/s, accuracy=0.992, loss=0.000664]
# Epoch 34: 100%|██████████| 2/2 [00:00<00:00,  2.49batch/s, accuracy=0.992, loss=0.000785]
# Epoch 35:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 35
# lr:  0.0016608338398760713
# -------------------------
# Train set: Avg. loss: 0.0018, Balanced Accuracy: 0.9666666984558105 (97%)
# Test set: Avg. loss: 0.1515, Balanced Accuracy: 0.6000000238418579 (60%)
# -------------------------
# Epoch 35: 100%|██████████| 2/2 [00:01<00:00,  1.14batch/s, accuracy=1, loss=0.000477]
# Epoch 36: 100%|██████████| 2/2 [00:00<00:00,  2.19batch/s, accuracy=0.992, loss=0.000863]
# Epoch 37: 100%|██████████| 2/2 [00:00<00:00,  2.29batch/s, accuracy=1, loss=0.000619]
# Epoch 38: 100%|██████████| 2/2 [00:00<00:00,  2.52batch/s, accuracy=0.992, loss=0.000651]
# Epoch 39: 100%|██████████| 2/2 [00:00<00:00,  2.25batch/s, accuracy=0.983, loss=0.000723]
# Epoch 40:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 40
# lr:  0.0012851215656510308
# -------------------------
# Train set: Avg. loss: 0.0009, Balanced Accuracy: 0.9750000238418579 (98%)
# Test set: Avg. loss: 0.1451, Balanced Accuracy: 0.6000000238418579 (60%)
# -------------------------
# Epoch 40: 100%|██████████| 2/2 [00:01<00:00,  1.27batch/s, accuracy=0.983, loss=0.00083]
# Epoch 41: 100%|██████████| 2/2 [00:00<00:00,  2.22batch/s, accuracy=0.958, loss=0.00127]
# Epoch 42: 100%|██████████| 2/2 [00:00<00:00,  2.43batch/s, accuracy=1, loss=0.000675]
# Epoch 43: 100%|██████████| 2/2 [00:00<00:00,  2.73batch/s, accuracy=1, loss=0.000649]
# Epoch 44: 100%|██████████| 2/2 [00:00<00:00,  2.42batch/s, accuracy=1, loss=0.000478]
# Epoch 45:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 45
# lr:  0.000994402569870922
# -------------------------
# Train set: Avg. loss: 0.0012, Balanced Accuracy: 0.9750000238418579 (98%)
# Test set: Avg. loss: 0.1402, Balanced Accuracy: 0.6000000238418579 (60%)
# -------------------------
# Epoch 45: 100%|██████████| 2/2 [00:01<00:00,  1.38batch/s, accuracy=1, loss=0.000579]
# Epoch 46: 100%|██████████| 2/2 [00:00<00:00,  2.81batch/s, accuracy=0.983, loss=0.000597]
# Epoch 47: 100%|██████████| 2/2 [00:00<00:00,  3.09batch/s, accuracy=1, loss=0.000838]
# Epoch 48: 100%|██████████| 2/2 [00:00<00:00,  2.31batch/s, accuracy=0.992, loss=0.00114]
# Epoch 49: 100%|██████████| 2/2 [00:00<00:00,  2.07batch/s, accuracy=0.992, loss=0.000704]
# Epoch 50:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 50
# lr:  0.0007694497527671312
# -------------------------
# Train set: Avg. loss: 0.0008, Balanced Accuracy: 0.9833333492279053 (98%)
# Test set: Avg. loss: 0.1357, Balanced Accuracy: 0.6000000238418579 (60%)
# -------------------------
# Epoch 50: 100%|██████████| 2/2 [00:01<00:00,  1.32batch/s, accuracy=1, loss=0.000477]
# Train set: Avg. loss: 0.0050, Balanced Accuracy: 0.9416666626930237 (94%)
# Val set: Avg. loss: 0.1788, Balanced Accuracy: 0.6000000238418579 (60%)
# Test set: Avg. loss: 0.0868, Balanced Accuracy: 0.6000000238418579 (60%)
# Subject:  1  Session:  2
# Error in file:  /network/lustre/iss02/aramis/projects/cracknetworks/sub-01/ses-02/EEG/Train-[2022.04.04-16.15.17].edf
# 'Event name "OVTK_GDF_Left" could not be found. The following events are present in the data: OVTK_StimulationId_ExperimentStart, OVTK_StimulationId_BaselineStart/OVTK_StimulationId_Beep'
# Error in file:  /network/lustre/iss02/aramis/projects/cracknetworks/sub-01/ses-02/EEG/Train-[2022.04.04-16.14.01].edf
# 'Event name "OVTK_GDF_Left" could not be found. The following events are present in the data: OVTK_StimulationId_ExperimentStart, OVTK_StimulationId_BaselineStart/OVTK_StimulationId_Beep'
# Error in file:  /network/lustre/iss02/aramis/projects/cracknetworks/sub-01/ses-02/EEG/Test-[2022.04.04-16.52.15].edf
# 'Event name "OVTK_GDF_Left" could not be found. The following events are present in the data: OVTK_GDF_Feedback_Continuous, OVTK_GDF_Right, OVTK_StimulationId_ExperimentStart, OVTK_StimulationId_BaselineStart/OVTK_StimulationId_Beep, OVTK_StimulationId_BaselineStop/OVTK_StimulationId_Beep, OVTK_GDF_Cross_On_Screen/OVTK_GDF_Start_Of_Trial/OVTK_StimulationId_Beep, OVTK_GDF_End_Of_Trial/OVTK_StimulationId_VisualStimulationStar'
# Epoch 0:   0%|          | 0/1 [00:00<?, ?batch/s]
# Epoch 0
# lr:  0.01
# -------------------------
# Train set: Avg. loss: 0.0073, Balanced Accuracy: 0.5400000214576721 (54%)
# Test set: Avg. loss: 0.0370, Balanced Accuracy: 0.45000001788139343 (45%)
# Saving best model weights with balanced accuracy:  0.45000001788139343
# -------------------------
# Epoch 0: 100%|██████████| 1/1 [00:01<00:00,  1.28s/batch, accuracy=0.42, loss=0.00758]
# Epoch 1: 100%|██████████| 1/1 [00:00<00:00,  1.85batch/s, accuracy=0.58, loss=0.00687]
# Epoch 2: 100%|██████████| 1/1 [00:00<00:00,  1.84batch/s, accuracy=0.86, loss=0.00395]
# Epoch 3: 100%|██████████| 1/1 [00:00<00:00,  1.98batch/s, accuracy=0.86, loss=0.00385]
# Epoch 4: 100%|██████████| 1/1 [00:00<00:00,  2.18batch/s, accuracy=0.9, loss=0.00285]
# Epoch 5:   0%|          | 0/1 [00:00<?, ?batch/s]
# Epoch 5
# lr:  0.007737809374999999
# -------------------------
# Train set: Avg. loss: 0.0373, Balanced Accuracy: 0.5 (50%)
# Test set: Avg. loss: 0.3044, Balanced Accuracy: 0.5 (50%)
# Saving best model weights with balanced accuracy:  0.5
# -------------------------
# Epoch 5: 100%|██████████| 1/1 [00:01<00:00,  1.01s/batch, accuracy=0.94, loss=0.00206]
# Epoch 6: 100%|██████████| 1/1 [00:00<00:00,  2.19batch/s, accuracy=0.92, loss=0.00201]
# Epoch 7: 100%|██████████| 1/1 [00:00<00:00,  2.43batch/s, accuracy=0.94, loss=0.00136]
# Epoch 8: 100%|██████████| 1/1 [00:00<00:00,  1.78batch/s, accuracy=0.95, loss=0.00132]
# Epoch 9: 100%|██████████| 1/1 [00:00<00:00,  1.64batch/s, accuracy=0.98, loss=0.000969]
# Epoch 10:   0%|          | 0/1 [00:00<?, ?batch/s]
# Epoch 10
# lr:  0.005987369392383786
# -------------------------
# Train set: Avg. loss: 0.0167, Balanced Accuracy: 0.6200000047683716 (62%)
# Test set: Avg. loss: 0.1496, Balanced Accuracy: 0.5 (50%)
# -------------------------
# Epoch 10: 100%|██████████| 1/1 [00:01<00:00,  1.26s/batch, accuracy=0.97, loss=0.000852]
# Epoch 11: 100%|██████████| 1/1 [00:00<00:00,  1.53batch/s, accuracy=0.96, loss=0.000836]
# Epoch 12: 100%|██████████| 1/1 [00:00<00:00,  1.95batch/s, accuracy=0.99, loss=0.000681]
# Epoch 13: 100%|██████████| 1/1 [00:00<00:00,  1.97batch/s, accuracy=0.97, loss=0.000617]
# Epoch 14: 100%|██████████| 1/1 [00:00<00:00,  2.08batch/s, accuracy=0.99, loss=0.000455]
# Epoch 15:   0%|          | 0/1 [00:00<?, ?batch/s]
# Epoch 15
# lr:  0.00463291230159753
# -------------------------
# Train set: Avg. loss: 0.0126, Balanced Accuracy: 0.6200000047683716 (62%)
# Test set: Avg. loss: 0.1218, Balanced Accuracy: 0.6000000238418579 (60%)
# Saving best model weights with balanced accuracy:  0.6000000238418579
# -------------------------
# Epoch 15: 100%|██████████| 1/1 [00:00<00:00,  1.01batch/s, accuracy=0.98, loss=0.000403]
# Epoch 16: 100%|██████████| 1/1 [00:00<00:00,  2.23batch/s, accuracy=1, loss=0.000339]
# Epoch 17: 100%|██████████| 1/1 [00:00<00:00,  2.09batch/s, accuracy=0.99, loss=0.000392]
# Epoch 18: 100%|██████████| 1/1 [00:00<00:00,  2.43batch/s, accuracy=1, loss=0.0002]
# Epoch 19: 100%|██████████| 1/1 [00:00<00:00,  1.62batch/s, accuracy=1, loss=0.000201]
# Epoch 20:   0%|          | 0/1 [00:00<?, ?batch/s]
# Epoch 20
# lr:  0.0035848592240854188
# -------------------------
# Train set: Avg. loss: 0.0103, Balanced Accuracy: 0.6700000166893005 (67%)
# Test set: Avg. loss: 0.1014, Balanced Accuracy: 0.6000000238418579 (60%)
# -------------------------
# Epoch 20: 100%|██████████| 1/1 [00:01<00:00,  1.23s/batch, accuracy=1, loss=0.00026]
# Epoch 21: 100%|██████████| 1/1 [00:00<00:00,  1.60batch/s, accuracy=1, loss=0.000244]
# Epoch 22: 100%|██████████| 1/1 [00:00<00:00,  1.73batch/s, accuracy=1, loss=0.000131]
# Epoch 23: 100%|██████████| 1/1 [00:00<00:00,  1.99batch/s, accuracy=1, loss=0.000215]
# Epoch 24: 100%|██████████| 1/1 [00:00<00:00,  2.12batch/s, accuracy=1, loss=0.000193]
# Epoch 25:   0%|          | 0/1 [00:00<?, ?batch/s]
# Epoch 25
# lr:  0.0027738957312183374
# -------------------------
# Train set: Avg. loss: 0.0073, Balanced Accuracy: 0.7400000095367432 (74%)
# Test set: Avg. loss: 0.0783, Balanced Accuracy: 0.6000000238418579 (60%)
# -------------------------
# Epoch 25: 100%|██████████| 1/1 [00:01<00:00,  1.02s/batch, accuracy=1, loss=0.000185]
# Epoch 26: 100%|██████████| 1/1 [00:00<00:00,  2.09batch/s, accuracy=1, loss=0.00015]
# Epoch 27: 100%|██████████| 1/1 [00:00<00:00,  2.19batch/s, accuracy=1, loss=0.000106]
# Epoch 28: 100%|██████████| 1/1 [00:00<00:00,  1.88batch/s, accuracy=1, loss=0.000143]
# Epoch 29: 100%|██████████| 1/1 [00:00<00:00,  2.19batch/s, accuracy=1, loss=0.000196]
# Epoch 30:   0%|          | 0/1 [00:00<?, ?batch/s]
# Epoch 30
# lr:  0.0021463876394293723
# -------------------------
# Train set: Avg. loss: 0.0050, Balanced Accuracy: 0.7899999618530273 (79%)
# Test set: Avg. loss: 0.0631, Balanced Accuracy: 0.699999988079071 (70%)
# Saving best model weights with balanced accuracy:  0.699999988079071
# -------------------------
# Epoch 30: 100%|██████████| 1/1 [00:01<00:00,  1.07s/batch, accuracy=1, loss=8.51e-5]
# Epoch 31: 100%|██████████| 1/1 [00:00<00:00,  2.29batch/s, accuracy=1, loss=0.000148]
# Epoch 32: 100%|██████████| 1/1 [00:00<00:00,  2.22batch/s, accuracy=1, loss=0.000106]
# Epoch 33: 100%|██████████| 1/1 [00:00<00:00,  1.53batch/s, accuracy=1, loss=9.3e-5]
# Epoch 34: 100%|██████████| 1/1 [00:00<00:00,  1.64batch/s, accuracy=1, loss=0.000146]
# Epoch 35:   0%|          | 0/1 [00:00<?, ?batch/s]
# Epoch 35
# lr:  0.0016608338398760713
# -------------------------
# Train set: Avg. loss: 0.0027, Balanced Accuracy: 0.8600000143051147 (86%)
# Test set: Avg. loss: 0.0443, Balanced Accuracy: 0.75 (75%)
# Saving best model weights with balanced accuracy:  0.75
# -------------------------
# Epoch 35: 100%|██████████| 1/1 [00:01<00:00,  1.02s/batch, accuracy=1, loss=9.41e-5]
# Epoch 36: 100%|██████████| 1/1 [00:00<00:00,  2.13batch/s, accuracy=1, loss=0.000101]
# Epoch 37: 100%|██████████| 1/1 [00:00<00:00,  2.34batch/s, accuracy=1, loss=0.000101]
# Epoch 38: 100%|██████████| 1/1 [00:00<00:00,  2.48batch/s, accuracy=1, loss=8.14e-5]
# Epoch 39: 100%|██████████| 1/1 [00:00<00:00,  1.73batch/s, accuracy=1, loss=7.35e-5]
# Epoch 40:   0%|          | 0/1 [00:00<?, ?batch/s]
# Epoch 40
# lr:  0.0012851215656510308
# -------------------------
# Train set: Avg. loss: 0.0016, Balanced Accuracy: 0.8999999761581421 (90%)
# Test set: Avg. loss: 0.0336, Balanced Accuracy: 0.75 (75%)
# -------------------------
# Epoch 40: 100%|██████████| 1/1 [00:01<00:00,  1.16s/batch, accuracy=1, loss=0.000138]
# Epoch 41: 100%|██████████| 1/1 [00:00<00:00,  1.69batch/s, accuracy=1, loss=9.47e-5]
# Epoch 42: 100%|██████████| 1/1 [00:00<00:00,  1.32batch/s, accuracy=1, loss=5.76e-5]
# Epoch 43: 100%|██████████| 1/1 [00:00<00:00,  1.52batch/s, accuracy=1, loss=5.3e-5]
# Epoch 44: 100%|██████████| 1/1 [00:00<00:00,  1.39batch/s, accuracy=1, loss=0.000119]
# Epoch 45:   0%|          | 0/1 [00:00<?, ?batch/s]
# Epoch 45
# lr:  0.000994402569870922
# -------------------------
# Train set: Avg. loss: 0.0011, Balanced Accuracy: 0.949999988079071 (95%)
# Test set: Avg. loss: 0.0292, Balanced Accuracy: 0.75 (75%)
# -------------------------
# Epoch 45: 100%|██████████| 1/1 [00:01<00:00,  1.42s/batch, accuracy=1, loss=7.12e-5]
# Epoch 46: 100%|██████████| 1/1 [00:00<00:00,  1.64batch/s, accuracy=1, loss=9.54e-5]
# Epoch 47: 100%|██████████| 1/1 [00:00<00:00,  1.24batch/s, accuracy=1, loss=0.00012]
# Epoch 48: 100%|██████████| 1/1 [00:00<00:00,  1.40batch/s, accuracy=1, loss=0.000108]
# Epoch 49: 100%|██████████| 1/1 [00:00<00:00,  1.72batch/s, accuracy=1, loss=7.6e-5]
# Epoch 50:   0%|          | 0/1 [00:00<?, ?batch/s]
# Epoch 50
# lr:  0.0007694497527671312
# -------------------------
# Train set: Avg. loss: 0.0008, Balanced Accuracy: 0.9600000381469727 (96%)
# Test set: Avg. loss: 0.0258, Balanced Accuracy: 0.75 (75%)
# -------------------------
# Epoch 50: 100%|██████████| 1/1 [00:01<00:00,  1.40s/batch, accuracy=1, loss=0.000132]
# Train set: Avg. loss: 0.0027, Balanced Accuracy: 0.8600000143051147 (86%)
# Val set: Avg. loss: 0.0443, Balanced Accuracy: 0.75 (75%)
# Test set: Avg. loss: 0.0410, Balanced Accuracy: 0.800000011920929 (80%)
# Epoch 0:   0%|          | 0/1 [00:00<?, ?batch/s]
# Epoch 0
# lr:  0.01
# -------------------------
# Train set: Avg. loss: 0.0073, Balanced Accuracy: 0.44999998807907104 (45%)
# Test set: Avg. loss: 0.0399, Balanced Accuracy: 0.4000000059604645 (40%)
# Saving best model weights with balanced accuracy:  0.4000000059604645
# -------------------------
# Epoch 0: 100%|██████████| 1/1 [00:01<00:00,  1.50s/batch, accuracy=0.46, loss=0.00729]
# Epoch 1: 100%|██████████| 1/1 [00:00<00:00,  1.37batch/s, accuracy=0.59, loss=0.00638]
# Epoch 2: 100%|██████████| 1/1 [00:00<00:00,  1.34batch/s, accuracy=0.73, loss=0.00667]
# Epoch 3: 100%|██████████| 1/1 [00:00<00:00,  1.31batch/s, accuracy=0.78, loss=0.00507]
# Epoch 4: 100%|██████████| 1/1 [00:00<00:00,  1.57batch/s, accuracy=0.82, loss=0.00426]
# Epoch 5:   0%|          | 0/1 [00:00<?, ?batch/s]
# Epoch 5
# lr:  0.007737809374999999
# -------------------------
# Train set: Avg. loss: 0.0406, Balanced Accuracy: 0.5199999809265137 (52%)
# Test set: Avg. loss: 0.3331, Balanced Accuracy: 0.5 (50%)
# Saving best model weights with balanced accuracy:  0.5
# -------------------------
# Epoch 5: 100%|██████████| 1/1 [00:01<00:00,  1.43s/batch, accuracy=0.88, loss=0.00288]
# Epoch 6: 100%|██████████| 1/1 [00:00<00:00,  1.29batch/s, accuracy=0.92, loss=0.00228]
# Epoch 7: 100%|██████████| 1/1 [00:00<00:00,  1.32batch/s, accuracy=0.92, loss=0.00229]
# Epoch 8: 100%|██████████| 1/1 [00:00<00:00,  1.33batch/s, accuracy=0.93, loss=0.00243]
# Epoch 9: 100%|██████████| 1/1 [00:00<00:00,  1.64batch/s, accuracy=0.94, loss=0.00215]
# Epoch 10:   0%|          | 0/1 [00:00<?, ?batch/s]
# Epoch 10
# lr:  0.005987369392383786
# -------------------------
# Train set: Avg. loss: 0.0381, Balanced Accuracy: 0.5299999713897705 (53%)
# Test set: Avg. loss: 0.3040, Balanced Accuracy: 0.5 (50%)
# -------------------------
# Epoch 10: 100%|██████████| 1/1 [00:01<00:00,  1.46s/batch, accuracy=0.94, loss=0.00178]
# Epoch 11: 100%|██████████| 1/1 [00:00<00:00,  1.43batch/s, accuracy=0.97, loss=0.00153]
# Epoch 12: 100%|██████████| 1/1 [00:00<00:00,  1.39batch/s, accuracy=0.95, loss=0.00147]
# Epoch 13: 100%|██████████| 1/1 [00:00<00:00,  1.37batch/s, accuracy=0.97, loss=0.0015]
# Epoch 14: 100%|██████████| 1/1 [00:00<00:00,  1.40batch/s, accuracy=0.94, loss=0.00163]
# Epoch 15:   0%|          | 0/1 [00:00<?, ?batch/s]
# Epoch 15
# lr:  0.00463291230159753
# -------------------------
# Train set: Avg. loss: 0.0121, Balanced Accuracy: 0.6599999666213989 (66%)
# Test set: Avg. loss: 0.1193, Balanced Accuracy: 0.6000000238418579 (60%)
# Saving best model weights with balanced accuracy:  0.6000000238418579
# -------------------------
# Epoch 15: 100%|██████████| 1/1 [00:01<00:00,  1.47s/batch, accuracy=0.98, loss=0.000924]
# Epoch 16: 100%|██████████| 1/1 [00:00<00:00,  1.53batch/s, accuracy=0.96, loss=0.0012]
# Epoch 17: 100%|██████████| 1/1 [00:00<00:00,  1.52batch/s, accuracy=0.97, loss=0.001]
# Epoch 18: 100%|██████████| 1/1 [00:00<00:00,  1.30batch/s, accuracy=0.97, loss=0.00114]
# Epoch 19: 100%|██████████| 1/1 [00:00<00:00,  1.44batch/s, accuracy=0.98, loss=0.00101]
# Epoch 20:   0%|          | 0/1 [00:00<?, ?batch/s]
# Epoch 20
# lr:  0.0035848592240854188
# -------------------------
# Train set: Avg. loss: 0.0083, Balanced Accuracy: 0.7400000095367432 (74%)
# Test set: Avg. loss: 0.1002, Balanced Accuracy: 0.699999988079071 (70%)
# Saving best model weights with balanced accuracy:  0.699999988079071
# -------------------------
# Epoch 20: 100%|██████████| 1/1 [00:01<00:00,  1.42s/batch, accuracy=0.99, loss=0.000828]
# Epoch 21: 100%|██████████| 1/1 [00:00<00:00,  1.85batch/s, accuracy=0.97, loss=0.000785]
# Epoch 22: 100%|██████████| 1/1 [00:00<00:00,  1.30batch/s, accuracy=0.98, loss=0.000769]
# Epoch 23: 100%|██████████| 1/1 [00:00<00:00,  1.30batch/s, accuracy=0.96, loss=0.000885]
# Epoch 24: 100%|██████████| 1/1 [00:00<00:00,  1.42batch/s, accuracy=0.98, loss=0.000713]
# Epoch 25:   0%|          | 0/1 [00:00<?, ?batch/s]
# Epoch 25
# lr:  0.0027738957312183374
# -------------------------
# Train set: Avg. loss: 0.0055, Balanced Accuracy: 0.8300000429153442 (83%)
# Test set: Avg. loss: 0.0834, Balanced Accuracy: 0.75 (75%)
# Saving best model weights with balanced accuracy:  0.75
# -------------------------
# Epoch 25: 100%|██████████| 1/1 [00:01<00:00,  1.44s/batch, accuracy=0.96, loss=0.000808]
# Epoch 26: 100%|██████████| 1/1 [00:00<00:00,  1.26batch/s, accuracy=0.97, loss=0.000769]
# Epoch 27: 100%|██████████| 1/1 [00:00<00:00,  1.49batch/s, accuracy=0.99, loss=0.000681]
# Epoch 28: 100%|██████████| 1/1 [00:00<00:00,  1.43batch/s, accuracy=0.99, loss=0.000552]
# Epoch 29: 100%|██████████| 1/1 [00:00<00:00,  1.38batch/s, accuracy=0.99, loss=0.00053]
# Epoch 30:   0%|          | 0/1 [00:00<?, ?batch/s]
# Epoch 30
# lr:  0.0021463876394293723
# -------------------------
# Train set: Avg. loss: 0.0032, Balanced Accuracy: 0.8899999856948853 (89%)
# Test set: Avg. loss: 0.0623, Balanced Accuracy: 0.800000011920929 (80%)
# Saving best model weights with balanced accuracy:  0.800000011920929
# -------------------------
# Epoch 30: 100%|██████████| 1/1 [00:01<00:00,  1.44s/batch, accuracy=0.96, loss=0.000766]
# Epoch 31: 100%|██████████| 1/1 [00:00<00:00,  1.36batch/s, accuracy=0.98, loss=0.000479]
# Epoch 32: 100%|██████████| 1/1 [00:00<00:00,  1.38batch/s, accuracy=0.99, loss=0.000421]
# Epoch 33: 100%|██████████| 1/1 [00:00<00:00,  1.40batch/s, accuracy=0.97, loss=0.000834]
# Epoch 34: 100%|██████████| 1/1 [00:00<00:00,  1.39batch/s, accuracy=1, loss=0.000354]
# Epoch 35:   0%|          | 0/1 [00:00<?, ?batch/s]
# Epoch 35
# lr:  0.0016608338398760713
# -------------------------
# Train set: Avg. loss: 0.0024, Balanced Accuracy: 0.8999999761581421 (90%)
# Test set: Avg. loss: 0.0524, Balanced Accuracy: 0.800000011920929 (80%)
# -------------------------
# Epoch 35: 100%|██████████| 1/1 [00:01<00:00,  1.41s/batch, accuracy=0.99, loss=0.000529]
# Epoch 36: 100%|██████████| 1/1 [00:00<00:00,  1.39batch/s, accuracy=0.98, loss=0.000518]
# Epoch 37: 100%|██████████| 1/1 [00:00<00:00,  1.23batch/s, accuracy=0.98, loss=0.000528]
# Epoch 38: 100%|██████████| 1/1 [00:00<00:00,  1.28batch/s, accuracy=1, loss=0.000352]
# Epoch 39: 100%|██████████| 1/1 [00:00<00:00,  1.54batch/s, accuracy=0.99, loss=0.000423]
# Epoch 40:   0%|          | 0/1 [00:00<?, ?batch/s]
# Epoch 40
# lr:  0.0012851215656510308
# -------------------------
# Train set: Avg. loss: 0.0016, Balanced Accuracy: 0.9199999570846558 (92%)
# Test set: Avg. loss: 0.0424, Balanced Accuracy: 0.75 (75%)
# -------------------------
# Epoch 40: 100%|██████████| 1/1 [00:01<00:00,  1.30s/batch, accuracy=0.98, loss=0.000578]
# Epoch 41: 100%|██████████| 1/1 [00:00<00:00,  1.40batch/s, accuracy=1, loss=0.00037]
# Epoch 42: 100%|██████████| 1/1 [00:00<00:00,  1.79batch/s, accuracy=0.99, loss=0.000387]
# Epoch 43: 100%|██████████| 1/1 [00:00<00:00,  1.41batch/s, accuracy=1, loss=0.000301]
# Epoch 44: 100%|██████████| 1/1 [00:00<00:00,  1.22batch/s, accuracy=0.99, loss=0.00049]
# Epoch 45:   0%|          | 0/1 [00:00<?, ?batch/s]
# Epoch 45
# lr:  0.000994402569870922
# -------------------------
# Train set: Avg. loss: 0.0010, Balanced Accuracy: 0.9700000286102295 (97%)
# Test set: Avg. loss: 0.0359, Balanced Accuracy: 0.75 (75%)
# -------------------------
# Epoch 45: 100%|██████████| 1/1 [00:01<00:00,  1.37s/batch, accuracy=1, loss=0.000307]
# Epoch 46: 100%|██████████| 1/1 [00:00<00:00,  1.60batch/s, accuracy=0.99, loss=0.000267]
# Epoch 47: 100%|██████████| 1/1 [00:00<00:00,  1.35batch/s, accuracy=0.99, loss=0.000276]
# Epoch 48: 100%|██████████| 1/1 [00:00<00:00,  1.37batch/s, accuracy=1, loss=0.000236]
# Epoch 49: 100%|██████████| 1/1 [00:00<00:00,  1.49batch/s, accuracy=0.99, loss=0.000373]
# Epoch 50:   0%|          | 0/1 [00:00<?, ?batch/s]
# Epoch 50
# lr:  0.0007694497527671312
# -------------------------
# Train set: Avg. loss: 0.0007, Balanced Accuracy: 0.9800000190734863 (98%)
# Test set: Avg. loss: 0.0330, Balanced Accuracy: 0.800000011920929 (80%)
# -------------------------
# Epoch 50: 100%|██████████| 1/1 [00:01<00:00,  1.45s/batch, accuracy=0.99, loss=0.000503]
# Train set: Avg. loss: 0.0032, Balanced Accuracy: 0.8899999856948853 (89%)
# Val set: Avg. loss: 0.0623, Balanced Accuracy: 0.800000011920929 (80%)
# Test set: Avg. loss: 0.0938, Balanced Accuracy: 0.800000011920929 (80%)
# Epoch 0:   0%|          | 0/1 [00:00<?, ?batch/s]
# Epoch 0
# lr:  0.01
# -------------------------
# Train set: Avg. loss: 0.0075, Balanced Accuracy: 0.48000001907348633 (48%)
# Test set: Avg. loss: 0.0342, Balanced Accuracy: 0.5 (50%)
# Saving best model weights with balanced accuracy:  0.5
# -------------------------
# Epoch 0: 100%|██████████| 1/1 [00:01<00:00,  1.52s/batch, accuracy=0.48, loss=0.00714]
# Epoch 1: 100%|██████████| 1/1 [00:00<00:00,  1.62batch/s, accuracy=0.61, loss=0.00712]
# Epoch 2: 100%|██████████| 1/1 [00:00<00:00,  1.50batch/s, accuracy=0.77, loss=0.00449]
# Epoch 3: 100%|██████████| 1/1 [00:00<00:00,  1.32batch/s, accuracy=0.87, loss=0.00394]
# Epoch 4: 100%|██████████| 1/1 [00:00<00:00,  1.37batch/s, accuracy=0.85, loss=0.00423]
# Epoch 5:   0%|          | 0/1 [00:00<?, ?batch/s]
# Epoch 5
# lr:  0.007737809374999999
# -------------------------
# Train set: Avg. loss: 0.0390, Balanced Accuracy: 0.5799999833106995 (58%)
# Test set: Avg. loss: 0.3541, Balanced Accuracy: 0.5 (50%)
# -------------------------
# Epoch 5: 100%|██████████| 1/1 [00:01<00:00,  1.51s/batch, accuracy=0.88, loss=0.00245]
# Epoch 6: 100%|██████████| 1/1 [00:00<00:00,  1.21batch/s, accuracy=0.89, loss=0.0025]
# Epoch 7: 100%|██████████| 1/1 [00:00<00:00,  1.93batch/s, accuracy=0.94, loss=0.00181]
# Epoch 8: 100%|██████████| 1/1 [00:00<00:00,  1.70batch/s, accuracy=0.96, loss=0.00164]
# Epoch 9: 100%|██████████| 1/1 [00:00<00:00,  1.27batch/s, accuracy=0.96, loss=0.00168]
# Epoch 10:   0%|          | 0/1 [00:00<?, ?batch/s]
# Epoch 10
# lr:  0.005987369392383786
# -------------------------
# Train set: Avg. loss: 0.0218, Balanced Accuracy: 0.6399999856948853 (64%)
# Test set: Avg. loss: 0.1777, Balanced Accuracy: 0.6499999761581421 (65%)
# Saving best model weights with balanced accuracy:  0.6499999761581421
# -------------------------
# Epoch 10: 100%|██████████| 1/1 [00:01<00:00,  1.37s/batch, accuracy=0.94, loss=0.0019]
# Epoch 11: 100%|██████████| 1/1 [00:00<00:00,  1.33batch/s, accuracy=0.94, loss=0.00148]
# Epoch 12: 100%|██████████| 1/1 [00:00<00:00,  1.27batch/s, accuracy=0.96, loss=0.00118]
# Epoch 13: 100%|██████████| 1/1 [00:00<00:00,  2.04batch/s, accuracy=0.96, loss=0.00108]
# Epoch 14: 100%|██████████| 1/1 [00:00<00:00,  2.34batch/s, accuracy=0.96, loss=0.00123]
# Epoch 15:   0%|          | 0/1 [00:00<?, ?batch/s]
# Epoch 15
# lr:  0.00463291230159753
# -------------------------
# Train set: Avg. loss: 0.0118, Balanced Accuracy: 0.7799999713897705 (78%)
# Test set: Avg. loss: 0.0990, Balanced Accuracy: 0.699999988079071 (70%)
# Saving best model weights with balanced accuracy:  0.699999988079071
# -------------------------
# Epoch 15: 100%|██████████| 1/1 [00:01<00:00,  1.09s/batch, accuracy=0.96, loss=0.000898]
# Epoch 16: 100%|██████████| 1/1 [00:00<00:00,  2.14batch/s, accuracy=0.94, loss=0.0014]
# Epoch 17: 100%|██████████| 1/1 [00:00<00:00,  2.06batch/s, accuracy=0.94, loss=0.00125]
# Epoch 18: 100%|██████████| 1/1 [00:00<00:00,  2.03batch/s, accuracy=0.93, loss=0.00135]
# Epoch 19: 100%|██████████| 1/1 [00:00<00:00,  2.41batch/s, accuracy=0.96, loss=0.000911]
# Epoch 20:   0%|          | 0/1 [00:00<?, ?batch/s]
# Epoch 20
# lr:  0.0035848592240854188
# -------------------------
# Train set: Avg. loss: 0.0080, Balanced Accuracy: 0.800000011920929 (80%)
# Test set: Avg. loss: 0.0687, Balanced Accuracy: 0.699999988079071 (70%)
# -------------------------
# Epoch 20: 100%|██████████| 1/1 [00:01<00:00,  1.23s/batch, accuracy=0.98, loss=0.000727]
# Epoch 21: 100%|██████████| 1/1 [00:00<00:00,  1.54batch/s, accuracy=0.98, loss=0.000863]
# Epoch 22: 100%|██████████| 1/1 [00:00<00:00,  1.58batch/s, accuracy=0.99, loss=0.000571]
# Epoch 23: 100%|██████████| 1/1 [00:00<00:00,  1.63batch/s, accuracy=0.96, loss=0.00111]
# Epoch 24: 100%|██████████| 1/1 [00:00<00:00,  1.94batch/s, accuracy=0.96, loss=0.000934]
# Epoch 25:   0%|          | 0/1 [00:00<?, ?batch/s]
# Epoch 25
# lr:  0.0027738957312183374
# -------------------------
# Train set: Avg. loss: 0.0048, Balanced Accuracy: 0.8600000143051147 (86%)
# Test set: Avg. loss: 0.0453, Balanced Accuracy: 0.75 (75%)
# Saving best model weights with balanced accuracy:  0.75
# -------------------------
# Epoch 25: 100%|██████████| 1/1 [00:01<00:00,  1.06s/batch, accuracy=0.98, loss=0.000761]
# Epoch 26: 100%|██████████| 1/1 [00:00<00:00,  1.86batch/s, accuracy=0.99, loss=0.000573]
# Epoch 27: 100%|██████████| 1/1 [00:00<00:00,  2.10batch/s, accuracy=0.99, loss=0.000534]
# Epoch 28: 100%|██████████| 1/1 [00:00<00:00,  2.26batch/s, accuracy=0.99, loss=0.000554]
# Epoch 29: 100%|██████████| 1/1 [00:00<00:00,  2.07batch/s, accuracy=0.97, loss=0.000505]
# Epoch 30:   0%|          | 0/1 [00:00<?, ?batch/s]
# Epoch 30
# lr:  0.0021463876394293723
# -------------------------
# Train set: Avg. loss: 0.0032, Balanced Accuracy: 0.9300000071525574 (93%)
# Test set: Avg. loss: 0.0288, Balanced Accuracy: 0.8500000238418579 (85%)
# Saving best model weights with balanced accuracy:  0.8500000238418579
# -------------------------
# Epoch 30: 100%|██████████| 1/1 [00:00<00:00,  1.03batch/s, accuracy=0.99, loss=0.000424]
# Epoch 31: 100%|██████████| 1/1 [00:00<00:00,  1.78batch/s, accuracy=0.99, loss=0.000466]
# Epoch 32: 100%|██████████| 1/1 [00:00<00:00,  1.62batch/s, accuracy=0.98, loss=0.000598]
# Epoch 33: 100%|██████████| 1/1 [00:00<00:00,  1.55batch/s, accuracy=0.99, loss=0.000436]
# Epoch 34: 100%|██████████| 1/1 [00:00<00:00,  1.61batch/s, accuracy=0.99, loss=0.000316]
# Epoch 35:   0%|          | 0/1 [00:00<?, ?batch/s]
# Epoch 35
# lr:  0.0016608338398760713
# -------------------------
# Train set: Avg. loss: 0.0022, Balanced Accuracy: 0.9300000071525574 (93%)
# Test set: Avg. loss: 0.0175, Balanced Accuracy: 0.8999999761581421 (90%)
# Saving best model weights with balanced accuracy:  0.8999999761581421
# -------------------------
# Epoch 35: 100%|██████████| 1/1 [00:01<00:00,  1.07s/batch, accuracy=0.98, loss=0.000613]
# Epoch 36: 100%|██████████| 1/1 [00:00<00:00,  1.76batch/s, accuracy=0.99, loss=0.000466]
# Epoch 37: 100%|██████████| 1/1 [00:00<00:00,  1.88batch/s, accuracy=0.99, loss=0.000528]
# Epoch 38: 100%|██████████| 1/1 [00:00<00:00,  1.99batch/s, accuracy=0.98, loss=0.000422]
# Epoch 39: 100%|██████████| 1/1 [00:00<00:00,  2.20batch/s, accuracy=0.99, loss=0.00045]
# Epoch 40:   0%|          | 0/1 [00:00<?, ?batch/s]
# Epoch 40
# lr:  0.0012851215656510308
# -------------------------
# Train set: Avg. loss: 0.0017, Balanced Accuracy: 0.9200000166893005 (92%)
# Test set: Avg. loss: 0.0169, Balanced Accuracy: 0.8999999761581421 (90%)
# -------------------------
# ...
# Epoch 0
# lr:  0.01
# -------------------------
# Train set: Avg. loss: 0.0117, Balanced Accuracy: 0.4583333432674408 (46%)
# Test set: Avg. loss: 0.0330, Balanced Accuracy: 0.44999998807907104 (45%)
# Saving best model weights with balanced accuracy:  0.44999998807907104
# -------------------------
# Epoch 0: 100%|██████████| 2/2 [00:01<00:00,  1.47batch/s, accuracy=0.5, loss=0.0126]
# Epoch 1: 100%|██████████| 2/2 [00:00<00:00,  3.11batch/s, accuracy=0.8, loss=0.00754]
# Epoch 2: 100%|██████████| 2/2 [00:00<00:00,  2.90batch/s, accuracy=0.842, loss=0.00889]
# Epoch 3: 100%|██████████| 2/2 [00:00<00:00,  3.06batch/s, accuracy=0.808, loss=0.00699]
# Epoch 4: 100%|██████████| 2/2 [00:00<00:00,  3.03batch/s, accuracy=0.9, loss=0.00346]
# Epoch 5:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 5
# lr:  0.007737809374999999
# -------------------------
# Train set: Avg. loss: 0.0876, Balanced Accuracy: 0.5 (50%)
# Test set: Avg. loss: 0.4168, Balanced Accuracy: 0.5 (50%)
# Saving best model weights with balanced accuracy:  0.5
# -------------------------
# Epoch 5: 100%|██████████| 2/2 [00:01<00:00,  1.59batch/s, accuracy=0.892, loss=0.0051]
# Epoch 6: 100%|██████████| 2/2 [00:00<00:00,  3.05batch/s, accuracy=0.933, loss=0.00227]
# Epoch 7: 100%|██████████| 2/2 [00:00<00:00,  3.00batch/s, accuracy=0.95, loss=0.00276]
# Epoch 8: 100%|██████████| 2/2 [00:00<00:00,  3.00batch/s, accuracy=0.958, loss=0.00207]
# Epoch 9: 100%|██████████| 2/2 [00:00<00:00,  2.89batch/s, accuracy=1, loss=0.000649]
# Epoch 10:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 10
# lr:  0.005987369392383786
# -------------------------
# Train set: Avg. loss: 0.0982, Balanced Accuracy: 0.5 (50%)
# Test set: Avg. loss: 0.4827, Balanced Accuracy: 0.5 (50%)
# -------------------------
# Epoch 10: 100%|██████████| 2/2 [00:01<00:00,  1.52batch/s, accuracy=0.992, loss=0.000608]
# Epoch 11: 100%|██████████| 2/2 [00:00<00:00,  3.02batch/s, accuracy=0.992, loss=0.000523]
# Epoch 12: 100%|██████████| 2/2 [00:00<00:00,  3.09batch/s, accuracy=1, loss=0.000279]
# Epoch 13: 100%|██████████| 2/2 [00:00<00:00,  3.09batch/s, accuracy=0.992, loss=0.000604]
# Epoch 14: 100%|██████████| 2/2 [00:00<00:00,  3.11batch/s, accuracy=0.992, loss=0.000212]
# Epoch 15:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 15
# lr:  0.00463291230159753
# -------------------------
# Train set: Avg. loss: 0.0688, Balanced Accuracy: 0.5249999761581421 (52%)
# Test set: Avg. loss: 0.4194, Balanced Accuracy: 0.5 (50%)
# -------------------------
# Epoch 15: 100%|██████████| 2/2 [00:01<00:00,  1.47batch/s, accuracy=1, loss=0.000122]
# Epoch 16: 100%|██████████| 2/2 [00:00<00:00,  3.08batch/s, accuracy=0.983, loss=0.000397]
# Epoch 17: 100%|██████████| 2/2 [00:00<00:00,  2.95batch/s, accuracy=1, loss=0.000186]
# Epoch 18: 100%|██████████| 2/2 [00:00<00:00,  3.07batch/s, accuracy=1, loss=0.000395]
# Epoch 19: 100%|██████████| 2/2 [00:00<00:00,  3.09batch/s, accuracy=1, loss=0.000133]
# Epoch 20:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 20
# lr:  0.0035848592240854188
# -------------------------
# Train set: Avg. loss: 0.0503, Balanced Accuracy: 0.5583333373069763 (56%)
# Test set: Avg. loss: 0.3089, Balanced Accuracy: 0.550000011920929 (55%)
# Saving best model weights with balanced accuracy:  0.550000011920929
# -------------------------
# Epoch 20: 100%|██████████| 2/2 [00:01<00:00,  1.56batch/s, accuracy=1, loss=0.000104]
# Epoch 21: 100%|██████████| 2/2 [00:00<00:00,  3.02batch/s, accuracy=1, loss=0.000323]
# Epoch 22: 100%|██████████| 2/2 [00:00<00:00,  3.09batch/s, accuracy=1, loss=8.25e-5]
# Epoch 23: 100%|██████████| 2/2 [00:00<00:00,  3.12batch/s, accuracy=1, loss=0.000124]
# Epoch 24: 100%|██████████| 2/2 [00:00<00:00,  3.06batch/s, accuracy=1, loss=0.000195]
# Epoch 25:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 25
# lr:  0.0027738957312183374
# -------------------------
# Train set: Avg. loss: 0.0272, Balanced Accuracy: 0.7083333134651184 (71%)
# Test set: Avg. loss: 0.2172, Balanced Accuracy: 0.550000011920929 (55%)
# -------------------------
# Epoch 25: 100%|██████████| 2/2 [00:01<00:00,  1.57batch/s, accuracy=1, loss=7.97e-5]
# Epoch 26: 100%|██████████| 2/2 [00:00<00:00,  3.08batch/s, accuracy=1, loss=0.000358]
# Epoch 27: 100%|██████████| 2/2 [00:00<00:00,  4.41batch/s, accuracy=0.992, loss=0.000744]
# Epoch 28: 100%|██████████| 2/2 [00:00<00:00,  3.08batch/s, accuracy=0.992, loss=0.000169]
# Epoch 29: 100%|██████████| 2/2 [00:00<00:00,  3.06batch/s, accuracy=1, loss=9.94e-5]
# Epoch 30:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 30
# lr:  0.0021463876394293723
# -------------------------
# Train set: Avg. loss: 0.0130, Balanced Accuracy: 0.8500000238418579 (85%)
# Test set: Avg. loss: 0.1428, Balanced Accuracy: 0.6000000238418579 (60%)
# Saving best model weights with balanced accuracy:  0.6000000238418579
# -------------------------
# Epoch 30: 100%|██████████| 2/2 [00:01<00:00,  1.59batch/s, accuracy=1, loss=0.000119]
# Epoch 31: 100%|██████████| 2/2 [00:00<00:00,  3.09batch/s, accuracy=1, loss=7.69e-5]
# Epoch 32: 100%|██████████| 2/2 [00:00<00:00,  3.00batch/s, accuracy=1, loss=0.000283]
# Epoch 33: 100%|██████████| 2/2 [00:00<00:00,  3.01batch/s, accuracy=1, loss=7.79e-5]
# Epoch 34: 100%|██████████| 2/2 [00:00<00:00,  3.07batch/s, accuracy=0.992, loss=0.00152]
# Epoch 35:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 35
# lr:  0.0016608338398760713
# -------------------------
# Train set: Avg. loss: 0.0036, Balanced Accuracy: 0.9083333015441895 (91%)
# Test set: Avg. loss: 0.0998, Balanced Accuracy: 0.699999988079071 (70%)
# Saving best model weights with balanced accuracy:  0.699999988079071
# -------------------------
# Epoch 35: 100%|██████████| 2/2 [00:01<00:00,  1.61batch/s, accuracy=1, loss=0.000112]
# Epoch 36: 100%|██████████| 2/2 [00:00<00:00,  3.08batch/s, accuracy=1, loss=0.000312]
# Epoch 37: 100%|██████████| 2/2 [00:00<00:00,  3.07batch/s, accuracy=1, loss=4.05e-5]
# Epoch 38: 100%|██████████| 2/2 [00:00<00:00,  3.05batch/s, accuracy=1, loss=2.7e-5]
# Epoch 39: 100%|██████████| 2/2 [00:00<00:00,  3.11batch/s, accuracy=0.992, loss=0.000958]
# Epoch 40:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 40
# lr:  0.0012851215656510308
# -------------------------
# Train set: Avg. loss: 0.0019, Balanced Accuracy: 0.9416666626930237 (94%)
# Test set: Avg. loss: 0.0852, Balanced Accuracy: 0.699999988079071 (70%)
# -------------------------
# Epoch 40: 100%|██████████| 2/2 [00:01<00:00,  1.57batch/s, accuracy=1, loss=2.63e-5]
# Epoch 41: 100%|██████████| 2/2 [00:00<00:00,  3.12batch/s, accuracy=1, loss=7.11e-5]
# Epoch 42: 100%|██████████| 2/2 [00:00<00:00,  3.04batch/s, accuracy=1, loss=6.63e-5]
# Epoch 43: 100%|██████████| 2/2 [00:00<00:00,  3.05batch/s, accuracy=1, loss=0.000131]
# Epoch 44: 100%|██████████| 2/2 [00:00<00:00,  3.08batch/s, accuracy=1, loss=4.85e-5]
# Epoch 45:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 45
# lr:  0.000994402569870922
# -------------------------
# Train set: Avg. loss: 0.0017, Balanced Accuracy: 0.9666666984558105 (97%)
# Test set: Avg. loss: 0.0719, Balanced Accuracy: 0.75 (75%)
# Saving best model weights with balanced accuracy:  0.75
# -------------------------
# Epoch 45: 100%|██████████| 2/2 [00:01<00:00,  1.60batch/s, accuracy=1, loss=3.11e-5]
# Epoch 46: 100%|██████████| 2/2 [00:00<00:00,  3.17batch/s, accuracy=1, loss=8.73e-5]
# Epoch 47: 100%|██████████| 2/2 [00:00<00:00,  3.10batch/s, accuracy=1, loss=4.42e-5]
# Epoch 48: 100%|██████████| 2/2 [00:00<00:00,  3.07batch/s, accuracy=1, loss=3.91e-5]
# Epoch 49: 100%|██████████| 2/2 [00:00<00:00,  3.08batch/s, accuracy=1, loss=5.25e-5]
# Epoch 50:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 50
# lr:  0.0007694497527671312
# -------------------------
# Train set: Avg. loss: 0.0012, Balanced Accuracy: 0.9833333492279053 (98%)
# Test set: Avg. loss: 0.0610, Balanced Accuracy: 0.75 (75%)
# -------------------------
# Epoch 50: 100%|██████████| 2/2 [00:01<00:00,  1.55batch/s, accuracy=1, loss=5.66e-5]
# Train set: Avg. loss: 0.0009, Balanced Accuracy: 0.9666666984558105 (97%)
# Val set: Avg. loss: 0.0719, Balanced Accuracy: 0.75 (75%)
# Test set: Avg. loss: 0.0237, Balanced Accuracy: 0.8999999761581421 (90%)
# Epoch 0:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 0
# lr:  0.01
# -------------------------
# Train set: Avg. loss: 0.0112, Balanced Accuracy: 0.5250000357627869 (53%)
# Test set: Avg. loss: 0.0349, Balanced Accuracy: 0.45000001788139343 (45%)
# Saving best model weights with balanced accuracy:  0.45000001788139343
# -------------------------
# Epoch 0: 100%|██████████| 2/2 [00:01<00:00,  1.46batch/s, accuracy=0.542, loss=0.0116]
# Epoch 1: 100%|██████████| 2/2 [00:00<00:00,  3.36batch/s, accuracy=0.808, loss=0.00723]
# Epoch 2: 100%|██████████| 2/2 [00:00<00:00,  3.09batch/s, accuracy=0.8, loss=0.00928]
# Epoch 3: 100%|██████████| 2/2 [00:00<00:00,  3.14batch/s, accuracy=0.833, loss=0.00553]
# Epoch 4: 100%|██████████| 2/2 [00:00<00:00,  3.01batch/s, accuracy=0.817, loss=0.00721]
# Epoch 5:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 5
# lr:  0.007737809374999999
# -------------------------
# Train set: Avg. loss: 0.1435, Balanced Accuracy: 0.5 (50%)
# Test set: Avg. loss: 0.5127, Balanced Accuracy: 0.5 (50%)
# Saving best model weights with balanced accuracy:  0.5
# -------------------------
# Epoch 5: 100%|██████████| 2/2 [00:01<00:00,  1.57batch/s, accuracy=0.883, loss=0.00525]
# Epoch 6: 100%|██████████| 2/2 [00:00<00:00,  3.02batch/s, accuracy=0.9, loss=0.00347]
# Epoch 7: 100%|██████████| 2/2 [00:00<00:00,  3.01batch/s, accuracy=0.917, loss=0.00375]
# Epoch 8: 100%|██████████| 2/2 [00:00<00:00,  3.00batch/s, accuracy=0.917, loss=0.00418]
# Epoch 9: 100%|██████████| 2/2 [00:00<00:00,  3.03batch/s, accuracy=0.933, loss=0.00261]
# Epoch 10:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 10
# lr:  0.005987369392383786
# -------------------------
# Train set: Avg. loss: 0.1389, Balanced Accuracy: 0.5 (50%)
# Test set: Avg. loss: 0.5581, Balanced Accuracy: 0.5 (50%)
# -------------------------
# Epoch 10: 100%|██████████| 2/2 [00:01<00:00,  1.57batch/s, accuracy=0.958, loss=0.00138]
# Epoch 11: 100%|██████████| 2/2 [00:00<00:00,  3.05batch/s, accuracy=0.942, loss=0.00252]
# Epoch 12: 100%|██████████| 2/2 [00:00<00:00,  3.04batch/s, accuracy=0.992, loss=0.0012]
# Epoch 13: 100%|██████████| 2/2 [00:00<00:00,  3.04batch/s, accuracy=0.983, loss=0.00184]
# Epoch 14: 100%|██████████| 2/2 [00:00<00:00,  2.90batch/s, accuracy=0.967, loss=0.00132]
# Epoch 15:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 15
# lr:  0.00463291230159753
# -------------------------
# Train set: Avg. loss: 0.1385, Balanced Accuracy: 0.5 (50%)
# Test set: Avg. loss: 0.4949, Balanced Accuracy: 0.5 (50%)
# -------------------------
# Epoch 15: 100%|██████████| 2/2 [00:01<00:00,  1.56batch/s, accuracy=0.992, loss=0.000767]
# Epoch 16: 100%|██████████| 2/2 [00:00<00:00,  3.03batch/s, accuracy=0.992, loss=0.000478]
# Epoch 17: 100%|██████████| 2/2 [00:00<00:00,  4.46batch/s, accuracy=0.992, loss=0.000674]
# Epoch 18: 100%|██████████| 2/2 [00:00<00:00,  3.07batch/s, accuracy=1, loss=0.000491]
# Epoch 19: 100%|██████████| 2/2 [00:00<00:00,  3.13batch/s, accuracy=0.983, loss=0.000843]
# Epoch 20:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 20
# lr:  0.0035848592240854188
# -------------------------
# Train set: Avg. loss: 0.0820, Balanced Accuracy: 0.5083333253860474 (51%)
# Test set: Avg. loss: 0.3847, Balanced Accuracy: 0.5 (50%)
# -------------------------
# Epoch 20: 100%|██████████| 2/2 [00:01<00:00,  1.76batch/s, accuracy=1, loss=0.000383]
# Epoch 21: 100%|██████████| 2/2 [00:00<00:00,  3.04batch/s, accuracy=0.992, loss=0.000531]
# Epoch 22: 100%|██████████| 2/2 [00:00<00:00,  2.97batch/s, accuracy=1, loss=0.000621]
# Epoch 23: 100%|██████████| 2/2 [00:00<00:00,  3.02batch/s, accuracy=1, loss=0.000148]
# Epoch 24: 100%|██████████| 2/2 [00:00<00:00,  3.01batch/s, accuracy=1, loss=0.000208]
# Epoch 25:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 25
# lr:  0.0027738957312183374
# -------------------------
# Train set: Avg. loss: 0.0389, Balanced Accuracy: 0.574999988079071 (57%)
# Test set: Avg. loss: 0.2589, Balanced Accuracy: 0.5 (50%)
# -------------------------
# Epoch 25: 100%|██████████| 2/2 [00:01<00:00,  1.58batch/s, accuracy=1, loss=0.000171]
# Epoch 26: 100%|██████████| 2/2 [00:00<00:00,  3.04batch/s, accuracy=0.992, loss=0.000429]
# Epoch 27: 100%|██████████| 2/2 [00:00<00:00,  3.03batch/s, accuracy=0.983, loss=0.00121]
# Epoch 28: 100%|██████████| 2/2 [00:00<00:00,  3.07batch/s, accuracy=1, loss=8e-5]
# Epoch 29: 100%|██████████| 2/2 [00:00<00:00,  2.97batch/s, accuracy=0.992, loss=0.000695]
# Epoch 30:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 30
# lr:  0.0021463876394293723
# -------------------------
# Train set: Avg. loss: 0.0205, Balanced Accuracy: 0.6499999761581421 (65%)
# Test set: Avg. loss: 0.1887, Balanced Accuracy: 0.550000011920929 (55%)
# Saving best model weights with balanced accuracy:  0.550000011920929
# -------------------------
# Epoch 30: 100%|██████████| 2/2 [00:01<00:00,  1.55batch/s, accuracy=1, loss=0.000141]
# Epoch 31: 100%|██████████| 2/2 [00:00<00:00,  3.08batch/s, accuracy=1, loss=0.000121]
# Epoch 32: 100%|██████████| 2/2 [00:00<00:00,  3.07batch/s, accuracy=0.992, loss=0.000116]
# Epoch 33: 100%|██████████| 2/2 [00:00<00:00,  3.10batch/s, accuracy=1, loss=9.85e-5]
# Epoch 34: 100%|██████████| 2/2 [00:00<00:00,  3.05batch/s, accuracy=1, loss=0.00012]
# Epoch 35:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 35
# lr:  0.0016608338398760713
# -------------------------
# Train set: Avg. loss: 0.0164, Balanced Accuracy: 0.7166666984558105 (72%)
# Test set: Avg. loss: 0.1548, Balanced Accuracy: 0.6499999761581421 (65%)
# Saving best model weights with balanced accuracy:  0.6499999761581421
# -------------------------
# Epoch 35: 100%|██████████| 2/2 [00:01<00:00,  1.51batch/s, accuracy=1, loss=6.64e-5]
# Epoch 36: 100%|██████████| 2/2 [00:00<00:00,  3.02batch/s, accuracy=1, loss=0.000142]
# Epoch 37: 100%|██████████| 2/2 [00:00<00:00,  3.04batch/s, accuracy=0.992, loss=0.000908]
# Epoch 38: 100%|██████████| 2/2 [00:00<00:00,  3.01batch/s, accuracy=1, loss=7.84e-5]
# Epoch 39: 100%|██████████| 2/2 [00:00<00:00,  3.01batch/s, accuracy=1, loss=2.51e-5]
# Epoch 40:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 40
# lr:  0.0012851215656510308
# -------------------------
# Train set: Avg. loss: 0.0076, Balanced Accuracy: 0.8416666984558105 (84%)
# Test set: Avg. loss: 0.1192, Balanced Accuracy: 0.6499999761581421 (65%)
# -------------------------
# Epoch 40: 100%|██████████| 2/2 [00:01<00:00,  1.56batch/s, accuracy=1, loss=5.39e-5]
# Epoch 41: 100%|██████████| 2/2 [00:00<00:00,  3.08batch/s, accuracy=1, loss=0.000263]
# Epoch 42: 100%|██████████| 2/2 [00:00<00:00,  3.03batch/s, accuracy=1, loss=7.51e-5]
# Epoch 43: 100%|██████████| 2/2 [00:00<00:00,  3.03batch/s, accuracy=1, loss=0.000162]
# Epoch 44: 100%|██████████| 2/2 [00:00<00:00,  3.05batch/s, accuracy=1, loss=6.66e-5]
# Epoch 45:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 45
# lr:  0.000994402569870922
# -------------------------
# Train set: Avg. loss: 0.0022, Balanced Accuracy: 0.9166666269302368 (92%)
# Test set: Avg. loss: 0.0974, Balanced Accuracy: 0.699999988079071 (70%)
# Saving best model weights with balanced accuracy:  0.699999988079071
# -------------------------
# Epoch 45: 100%|██████████| 2/2 [00:01<00:00,  1.58batch/s, accuracy=1, loss=4.72e-5]
# Epoch 46: 100%|██████████| 2/2 [00:00<00:00,  3.34batch/s, accuracy=1, loss=4.81e-5]
# Epoch 47: 100%|██████████| 2/2 [00:00<00:00,  3.43batch/s, accuracy=1, loss=0.000207]
# Epoch 48: 100%|██████████| 2/2 [00:00<00:00,  3.04batch/s, accuracy=1, loss=0.000402]
# Epoch 49: 100%|██████████| 2/2 [00:00<00:00,  3.06batch/s, accuracy=1, loss=4.06e-5]
# Epoch 50:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 50
# lr:  0.0007694497527671312
# -------------------------
# Train set: Avg. loss: 0.0013, Balanced Accuracy: 0.9666666984558105 (97%)
# Test set: Avg. loss: 0.0798, Balanced Accuracy: 0.699999988079071 (70%)
# -------------------------
# Epoch 50: 100%|██████████| 2/2 [00:01<00:00,  1.59batch/s, accuracy=1, loss=0.000115]
# Train set: Avg. loss: 0.0019, Balanced Accuracy: 0.9166666269302368 (92%)
# Val set: Avg. loss: 0.0974, Balanced Accuracy: 0.699999988079071 (70%)
# Test set: Avg. loss: 0.0080, Balanced Accuracy: 0.949999988079071 (95%)

# %%
with open('../dicts_results/intra_subject_classification/braccio_runs_eegnet_F1_4_F2_16_D_2.pkl', 'wb') as f:
    pickle.dump(dict_crossval, f)

# %% [markdown]
# # ATCNet

# %%
# Define the subject and the session
num_sessions = [1,2,3]
num_subjects = [1,2,3,5,6,7,8,10,11,13,14]  
dict_crossval = {"test_balanced_accuracy":np.zeros((11,3,3)), "test_loss":np.zeros((11,3,3)), "val_balanced_accuracy":np.zeros((11,3,3)), "val_loss":np.zeros((11,3,3)), "train_balanced_accuracy":np.zeros((11,3,3)), "train_loss":np.zeros((11,3,3))}

for i in range(len(num_subjects)):
    for num_session in num_sessions:
    
        num_subject = num_subjects[i]
        print("Subject: ", num_subject, " Session: ", num_session)

        # Define the path to the data and the train and test files
        if num_subject < 10:
            subject_number = "0" + str(num_subject)
        else:
            subject_number = str(num_subject)
        session_number = "0" + str(num_session)
        folder_path = "/network/lustre/iss02/aramis/projects/cracknetworks/sub-{}/ses-{}/EEG/".format(subject_number, session_number)
        files = [folder_path + f for f in os.listdir(folder_path) if f.endswith('.edf') and not(f.startswith("._"))]
        list_train_files = files[:-2]
        list_val_files = files[-2:-1]
        list_test_files = files[-1:]

        # Define the channels
        list_name_channels = ["CP1","CP3","CP5","C1","C3","C5","C2","CP2","Cz","FCz","C4","CP4"]
        list_idx_channels = [list_all_ch_names.index(ch) for ch in list_name_channels]

        # Define the labels
        labels = ['OVTK_GDF_Left', 'OVTK_GDF_Right']

        # Define the parameters of the dataset
        feature_type = ["time","band_psd","band_coh"]
        dict_preprocessing = {"polynomial_degree":10,"tmin":0,"tmax":4,"seq_length":2001}
        dict_features = {"type_psd":"welch","fs":500,"nfft":300,"noverlap":150,"nperseg":300,"filter_order":19,"fmin":4,"fmax":30}

        # Create the dataset
        try : 
            subject_trainset = dataset.EEG_Dataset(files_list = list_train_files, list_idx_channels = list_idx_channels, list_labels = labels, feature_type = feature_type, dict_preprocessing = dict_preprocessing, dict_features = dict_features)
            subject_valset = dataset.EEG_Dataset(files_list = list_val_files, list_idx_channels = list_idx_channels, list_labels = labels, feature_type = feature_type, dict_preprocessing = dict_preprocessing, dict_features = dict_features)
            subject_testset = dataset.EEG_Dataset(files_list = list_test_files, list_idx_channels = list_idx_channels, list_labels = labels, feature_type = feature_type, dict_preprocessing = dict_preprocessing, dict_features = dict_features)

            subject_trainset.transform_dataset_numpy_to_torch()
            subject_trainset.features["time"] = subject_trainset.features["time"].unsqueeze(1)
            subject_testset.transform_dataset_numpy_to_torch()
            subject_testset.features["time"] = subject_testset.features["time"].unsqueeze(1)
            subject_valset.transform_dataset_numpy_to_torch()
            subject_valset.features["time"] = subject_valset.features["time"].unsqueeze(1)
            trainloader = torch.utils.data.DataLoader(subject_trainset, batch_size=16, shuffle=True, num_workers=2)
            valloader = torch.utils.data.DataLoader(subject_valset, batch_size=32, shuffle=True, num_workers=2)
            testloader = torch.utils.data.DataLoader(subject_testset, batch_size=32, shuffle=True, num_workers=2)

            feature_type = "time"
            device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
            criterion = torch.nn.CrossEntropyLoss()

            for num_trial in range(3):
                feature_type = "time"
                device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
                criterion = torch.nn.CrossEntropyLoss()
                model = models.ATCNet(in_channels=1,
                            num_classes=2,
                            num_windows=5,
                            num_electrodes=12,
                            chunk_size=2001,
                            filter_size=250,)
                model.to(device)
                optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
                scheduler1 = torch.optim.lr_scheduler.MultiplicativeLR(optimizer, lr_lambda=lambda epoch: 0.95)
                scheduler2 = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=3, factor=0.5)
                scheduler_dict = {"MultiplicativeLR":scheduler1} #, "ReduceLROnPlateau":scheduler2}
                logs = training.train_model(model, trainloader, valloader, device, criterion, feature_type, 51, optimizer, scheduler_dict, print_epoch = 5)

                model.load_state_dict(logs["best_model_weights"])
                model.eval()
                train_balanced_accuracy, train_loss = training.evaluate_classification_model(model,trainloader,device,criterion,feature_type,dataset="Train")
                val_balanced_accuracy, val_loss = training.evaluate_classification_model(model,valloader,device,criterion,feature_type,dataset="Val")
                test_balanced_accuracy, test_loss = training.evaluate_classification_model(model,testloader,device,criterion,feature_type,dataset="Test")
                dict_crossval["test_balanced_accuracy"][i,num_session-1,num_trial] = test_balanced_accuracy
                dict_crossval["test_loss"][i,num_session-1,num_trial] = test_loss
                dict_crossval["val_balanced_accuracy"][i,num_session-1,num_trial] = val_balanced_accuracy
                dict_crossval["val_loss"][i,num_session-1,num_trial] = val_loss
                dict_crossval["train_balanced_accuracy"][i,num_session-1,num_trial] = train_balanced_accuracy
                dict_crossval["train_loss"][i,num_session-1,num_trial] = train_loss
        except:
            print("Error in subject ", num_subject, " session ", num_session)
            continue
# Out:
# Subject:  1  Session:  1
# /home/aurelien.stumpf/Development/BCI_Classification/eeg_env/lib/python3.8/site-packages/torch/nn/modules/conv.py:456: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at ../aten/src/ATen/native/Convolution.cpp:1031.)
#   return F.conv2d(input, weight, bias, self.stride,
# Epoch 0:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 0
# lr:  0.001
# -------------------------
# Train set: Avg. loss: 0.0117, Balanced Accuracy: 0.5166666507720947 (52%)
# Test set: Avg. loss: 0.0352, Balanced Accuracy: 0.4000000059604645 (40%)
# Saving best model weights with balanced accuracy:  0.4000000059604645
# -------------------------
# Epoch 0: 100%|██████████| 2/2 [00:02<00:00,  1.08s/batch, accuracy=0.542, loss=0.0112]
# Epoch 1: 100%|██████████| 2/2 [00:00<00:00,  2.02batch/s, accuracy=0.717, loss=0.0106]
# Epoch 2: 100%|██████████| 2/2 [00:00<00:00,  2.11batch/s, accuracy=0.717, loss=0.00977]
# Epoch 3: 100%|██████████| 2/2 [00:00<00:00,  2.07batch/s, accuracy=0.775, loss=0.00897]
# Epoch 4: 100%|██████████| 2/2 [00:01<00:00,  1.95batch/s, accuracy=0.817, loss=0.00933]
# Epoch 5:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 5
# lr:  0.0007737809374999998
# -------------------------
# Train set: Avg. loss: 0.0095, Balanced Accuracy: 0.8416666984558105 (84%)
# Test set: Avg. loss: 0.0319, Balanced Accuracy: 0.6000000238418579 (60%)
# Saving best model weights with balanced accuracy:  0.6000000238418579
# -------------------------
# Epoch 5: 100%|██████████| 2/2 [00:01<00:00,  1.32batch/s, accuracy=0.833, loss=0.00922]
# Epoch 6: 100%|██████████| 2/2 [00:00<00:00,  2.01batch/s, accuracy=0.817, loss=0.00884]
# Epoch 7: 100%|██████████| 2/2 [00:01<00:00,  1.95batch/s, accuracy=0.833, loss=0.00891]
# Epoch 8: 100%|██████████| 2/2 [00:00<00:00,  2.01batch/s, accuracy=0.842, loss=0.00826]
# Epoch 9: 100%|██████████| 2/2 [00:01<00:00,  1.98batch/s, accuracy=0.85, loss=0.00778]
# Epoch 10:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 10
# lr:  0.0005987369392383785
# -------------------------
# Train set: Avg. loss: 0.0081, Balanced Accuracy: 0.8833333253860474 (88%)
# Test set: Avg. loss: 0.0316, Balanced Accuracy: 0.6499999761581421 (65%)
# Saving best model weights with balanced accuracy:  0.6499999761581421
# -------------------------
# Epoch 10: 100%|██████████| 2/2 [00:01<00:00,  1.35batch/s, accuracy=0.858, loss=0.00804]
# Epoch 11: 100%|██████████| 2/2 [00:00<00:00,  2.03batch/s, accuracy=0.875, loss=0.00824]
# Epoch 12: 100%|██████████| 2/2 [00:00<00:00,  2.16batch/s, accuracy=0.858, loss=0.0084]
# Epoch 13: 100%|██████████| 2/2 [00:01<00:00,  2.00batch/s, accuracy=0.9, loss=0.0078]
# Epoch 14: 100%|██████████| 2/2 [00:00<00:00,  2.02batch/s, accuracy=0.883, loss=0.00743]
# Epoch 15:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 15
# lr:  0.00046329123015975297
# -------------------------
# Train set: Avg. loss: 0.0080, Balanced Accuracy: 0.8999999761581421 (90%)
# Test set: Avg. loss: 0.0314, Balanced Accuracy: 0.6499999761581421 (65%)
# -------------------------
# Epoch 15: 100%|██████████| 2/2 [00:01<00:00,  1.34batch/s, accuracy=0.867, loss=0.00829]
# Epoch 16: 100%|██████████| 2/2 [00:00<00:00,  2.01batch/s, accuracy=0.883, loss=0.00787]
# Epoch 17: 100%|██████████| 2/2 [00:01<00:00,  1.96batch/s, accuracy=0.892, loss=0.00822]
# Epoch 18: 100%|██████████| 2/2 [00:01<00:00,  1.99batch/s, accuracy=0.883, loss=0.0077]
# Epoch 19: 100%|██████████| 2/2 [00:01<00:00,  1.98batch/s, accuracy=0.9, loss=0.00725]
# Epoch 20:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 20
# lr:  0.0003584859224085418
# -------------------------
# Train set: Avg. loss: 0.0071, Balanced Accuracy: 0.8999999761581421 (90%)
# Test set: Avg. loss: 0.0312, Balanced Accuracy: 0.7000000476837158 (70%)
# Saving best model weights with balanced accuracy:  0.7000000476837158
# -------------------------
# Epoch 20: 100%|██████████| 2/2 [00:01<00:00,  1.30batch/s, accuracy=0.9, loss=0.0071]
# Epoch 21: 100%|██████████| 2/2 [00:00<00:00,  2.03batch/s, accuracy=0.9, loss=0.00783]
# Epoch 22: 100%|██████████| 2/2 [00:00<00:00,  2.02batch/s, accuracy=0.892, loss=0.00775]
# Epoch 23: 100%|██████████| 2/2 [00:00<00:00,  2.02batch/s, accuracy=0.925, loss=0.00746]
# Epoch 24: 100%|██████████| 2/2 [00:00<00:00,  2.02batch/s, accuracy=0.917, loss=0.00743]
# Epoch 25:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 25
# lr:  0.00027738957312183364
# -------------------------
# Train set: Avg. loss: 0.0072, Balanced Accuracy: 0.9249999523162842 (92%)
# Test set: Avg. loss: 0.0314, Balanced Accuracy: 0.7000000476837158 (70%)
# -------------------------
# Epoch 25: 100%|██████████| 2/2 [00:01<00:00,  1.31batch/s, accuracy=0.917, loss=0.00749]
# Epoch 26: 100%|██████████| 2/2 [00:01<00:00,  1.94batch/s, accuracy=0.933, loss=0.00723]
# Epoch 27: 100%|██████████| 2/2 [00:01<00:00,  1.99batch/s, accuracy=0.917, loss=0.00712]
# Epoch 28: 100%|██████████| 2/2 [00:00<00:00,  2.01batch/s, accuracy=0.933, loss=0.00763]
# Epoch 29: 100%|██████████| 2/2 [00:01<00:00,  1.97batch/s, accuracy=0.942, loss=0.00691]
# Epoch 30:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 30
# lr:  0.00021463876394293716
# -------------------------
# Train set: Avg. loss: 0.0070, Balanced Accuracy: 0.9416666626930237 (94%)
# Test set: Avg. loss: 0.0313, Balanced Accuracy: 0.7000000476837158 (70%)
# -------------------------
# Epoch 30: 100%|██████████| 2/2 [00:01<00:00,  1.30batch/s, accuracy=0.942, loss=0.00736]
# Epoch 31: 100%|██████████| 2/2 [00:00<00:00,  2.25batch/s, accuracy=0.933, loss=0.00709]
# Epoch 32: 100%|██████████| 2/2 [00:00<00:00,  2.07batch/s, accuracy=0.925, loss=0.00726]
# Epoch 33: 100%|██████████| 2/2 [00:00<00:00,  2.03batch/s, accuracy=0.925, loss=0.00753]
# Epoch 34: 100%|██████████| 2/2 [00:00<00:00,  2.00batch/s, accuracy=0.917, loss=0.00717]
# Epoch 35:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 35
# lr:  0.00016608338398760707
# -------------------------
# Train set: Avg. loss: 0.0067, Balanced Accuracy: 0.9416666626930237 (94%)
# Test set: Avg. loss: 0.0314, Balanced Accuracy: 0.7000000476837158 (70%)
# -------------------------
# Epoch 35: 100%|██████████| 2/2 [00:01<00:00,  1.33batch/s, accuracy=0.933, loss=0.00724]
# Epoch 36: 100%|██████████| 2/2 [00:00<00:00,  2.01batch/s, accuracy=0.917, loss=0.00714]
# Epoch 37: 100%|██████████| 2/2 [00:00<00:00,  2.02batch/s, accuracy=0.933, loss=0.00716]
# Epoch 38: 100%|██████████| 2/2 [00:00<00:00,  2.02batch/s, accuracy=0.942, loss=0.00716]
# Epoch 39: 100%|██████████| 2/2 [00:00<00:00,  2.03batch/s, accuracy=0.942, loss=0.00694]
# Epoch 40:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 40
# lr:  0.00012851215656510304
# -------------------------
# Train set: Avg. loss: 0.0066, Balanced Accuracy: 0.949999988079071 (95%)
# Test set: Avg. loss: 0.0315, Balanced Accuracy: 0.7000000476837158 (70%)
# -------------------------
# Epoch 40: 100%|██████████| 2/2 [00:01<00:00,  1.31batch/s, accuracy=0.925, loss=0.00765]
# Epoch 41: 100%|██████████| 2/2 [00:00<00:00,  2.04batch/s, accuracy=0.925, loss=0.00704]
# Epoch 42: 100%|██████████| 2/2 [00:00<00:00,  2.05batch/s, accuracy=0.925, loss=0.00718]
# Epoch 43: 100%|██████████| 2/2 [00:00<00:00,  2.01batch/s, accuracy=0.942, loss=0.00689]
# Epoch 44: 100%|██████████| 2/2 [00:01<00:00,  1.99batch/s, accuracy=0.95, loss=0.00675]
# Epoch 45:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 45
# lr:  9.944025698709218e-05
# -------------------------
# Train set: Avg. loss: 0.0068, Balanced Accuracy: 0.949999988079071 (95%)
# Test set: Avg. loss: 0.0316, Balanced Accuracy: 0.7000000476837158 (70%)
# -------------------------
# Epoch 45: 100%|██████████| 2/2 [00:01<00:00,  1.32batch/s, accuracy=0.958, loss=0.00712]
# Epoch 46: 100%|██████████| 2/2 [00:00<00:00,  2.04batch/s, accuracy=0.95, loss=0.0069]
# Epoch 47: 100%|██████████| 2/2 [00:00<00:00,  2.03batch/s, accuracy=0.95, loss=0.00711]
# Epoch 48: 100%|██████████| 2/2 [00:00<00:00,  2.01batch/s, accuracy=0.95, loss=0.0073]
# Epoch 49: 100%|██████████| 2/2 [00:00<00:00,  2.02batch/s, accuracy=0.95, loss=0.00694]
# Epoch 50:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 50
# lr:  7.69449752767131e-05
# -------------------------
# Train set: Avg. loss: 0.0064, Balanced Accuracy: 0.9583333134651184 (96%)
# Test set: Avg. loss: 0.0317, Balanced Accuracy: 0.7000000476837158 (70%)
# -------------------------
# Epoch 50: 100%|██████████| 2/2 [00:01<00:00,  1.29batch/s, accuracy=0.958, loss=0.00749]
# Train set: Avg. loss: 0.0071, Balanced Accuracy: 0.8999999761581421 (90%)
# Val set: Avg. loss: 0.0312, Balanced Accuracy: 0.7000000476837158 (70%)
# Test set: Avg. loss: 0.0270, Balanced Accuracy: 0.75 (75%)
# Epoch 0:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 0
# lr:  0.001
# -------------------------
# Train set: Avg. loss: 0.0118, Balanced Accuracy: 0.4416666626930237 (44%)
# Test set: Avg. loss: 0.0361, Balanced Accuracy: 0.3500000238418579 (35%)
# Saving best model weights with balanced accuracy:  0.3500000238418579
# -------------------------
# Epoch 0: 100%|██████████| 2/2 [00:01<00:00,  1.21batch/s, accuracy=0.483, loss=0.0115]
# Epoch 1: 100%|██████████| 2/2 [00:00<00:00,  2.03batch/s, accuracy=0.625, loss=0.0111]
# Epoch 2: 100%|██████████| 2/2 [00:00<00:00,  2.16batch/s, accuracy=0.725, loss=0.0104]
# Epoch 3: 100%|██████████| 2/2 [00:00<00:00,  2.08batch/s, accuracy=0.783, loss=0.0101]
# Epoch 4: 100%|██████████| 2/2 [00:00<00:00,  2.15batch/s, accuracy=0.792, loss=0.00966]
# Epoch 5:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 5
# lr:  0.0007737809374999998
# -------------------------
# Train set: Avg. loss: 0.0097, Balanced Accuracy: 0.7916666269302368 (79%)
# Test set: Avg. loss: 0.0323, Balanced Accuracy: 0.550000011920929 (55%)
# Saving best model weights with balanced accuracy:  0.550000011920929
# -------------------------
# Epoch 5: 100%|██████████| 2/2 [00:01<00:00,  1.38batch/s, accuracy=0.825, loss=0.00964]
# Epoch 6: 100%|██████████| 2/2 [00:00<00:00,  2.02batch/s, accuracy=0.808, loss=0.00942]
# Epoch 7: 100%|██████████| 2/2 [00:00<00:00,  2.05batch/s, accuracy=0.775, loss=0.00899]
# Epoch 8: 100%|██████████| 2/2 [00:00<00:00,  2.52batch/s, accuracy=0.85, loss=0.0091]
# Epoch 9: 100%|██████████| 2/2 [00:00<00:00,  2.04batch/s, accuracy=0.817, loss=0.00926]
# Epoch 10:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 10
# lr:  0.0005987369392383785
# -------------------------
# Train set: Avg. loss: 0.0085, Balanced Accuracy: 0.875 (88%)
# Test set: Avg. loss: 0.0312, Balanced Accuracy: 0.6499999761581421 (65%)
# Saving best model weights with balanced accuracy:  0.6499999761581421
# -------------------------
# Epoch 10: 100%|██████████| 2/2 [00:01<00:00,  1.36batch/s, accuracy=0.808, loss=0.00876]
# Epoch 11: 100%|██████████| 2/2 [00:00<00:00,  2.06batch/s, accuracy=0.858, loss=0.00882]
# Epoch 12: 100%|██████████| 2/2 [00:00<00:00,  2.04batch/s, accuracy=0.842, loss=0.0086]
# Epoch 13: 100%|██████████| 2/2 [00:00<00:00,  2.04batch/s, accuracy=0.833, loss=0.00837]
# Epoch 14: 100%|██████████| 2/2 [00:00<00:00,  2.05batch/s, accuracy=0.867, loss=0.00816]
# Epoch 15:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 15
# lr:  0.00046329123015975297
# -------------------------
# Train set: Avg. loss: 0.0080, Balanced Accuracy: 0.875 (88%)
# Test set: Avg. loss: 0.0302, Balanced Accuracy: 0.6499999761581421 (65%)
# -------------------------
# Epoch 15: 100%|██████████| 2/2 [00:01<00:00,  1.23batch/s, accuracy=0.858, loss=0.00799]
# Epoch 16: 100%|██████████| 2/2 [00:00<00:00,  2.03batch/s, accuracy=0.875, loss=0.00817]
# Epoch 17: 100%|██████████| 2/2 [00:00<00:00,  2.29batch/s, accuracy=0.892, loss=0.00803]
# Epoch 18: 100%|██████████| 2/2 [00:00<00:00,  2.05batch/s, accuracy=0.867, loss=0.00832]
# Epoch 19: 100%|██████████| 2/2 [00:00<00:00,  2.29batch/s, accuracy=0.842, loss=0.00821]
# Epoch 20:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 20
# lr:  0.0003584859224085418
# -------------------------
# Train set: Avg. loss: 0.0076, Balanced Accuracy: 0.8833333253860474 (88%)
# Test set: Avg. loss: 0.0298, Balanced Accuracy: 0.7000000476837158 (70%)
# Saving best model weights with balanced accuracy:  0.7000000476837158
# -------------------------
# Epoch 20: 100%|██████████| 2/2 [00:01<00:00,  1.30batch/s, accuracy=0.883, loss=0.00763]
# Epoch 21: 100%|██████████| 2/2 [00:00<00:00,  2.01batch/s, accuracy=0.908, loss=0.00768]
# Epoch 22: 100%|██████████| 2/2 [00:01<00:00,  1.99batch/s, accuracy=0.892, loss=0.00803]
# Epoch 23: 100%|██████████| 2/2 [00:01<00:00,  1.98batch/s, accuracy=0.9, loss=0.00763]
# Epoch 24: 100%|██████████| 2/2 [00:00<00:00,  2.03batch/s, accuracy=0.883, loss=0.00775]
# Epoch 25:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 25
# lr:  0.00027738957312183364
# -------------------------
# Train set: Avg. loss: 0.0074, Balanced Accuracy: 0.9166666269302368 (92%)
# Test set: Avg. loss: 0.0300, Balanced Accuracy: 0.7000000476837158 (70%)
# -------------------------
# Epoch 25: 100%|██████████| 2/2 [00:01<00:00,  1.32batch/s, accuracy=0.9, loss=0.00737]
# Epoch 26: 100%|██████████| 2/2 [00:00<00:00,  2.19batch/s, accuracy=0.908, loss=0.00805]
# Epoch 27: 100%|██████████| 2/2 [00:00<00:00,  2.06batch/s, accuracy=0.917, loss=0.00765]
# Epoch 28: 100%|██████████| 2/2 [00:00<00:00,  2.06batch/s, accuracy=0.9, loss=0.00763]
# Epoch 29: 100%|██████████| 2/2 [00:00<00:00,  2.33batch/s, accuracy=0.908, loss=0.00744]
# Epoch 30:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 30
# lr:  0.00021463876394293716
# -------------------------
# Train set: Avg. loss: 0.0068, Balanced Accuracy: 0.9333333373069763 (93%)
# Test set: Avg. loss: 0.0301, Balanced Accuracy: 0.7000000476837158 (70%)
# -------------------------
# Epoch 30: 100%|██████████| 2/2 [00:01<00:00,  1.35batch/s, accuracy=0.908, loss=0.00752]
# Epoch 31: 100%|██████████| 2/2 [00:01<00:00,  2.00batch/s, accuracy=0.9, loss=0.00749]
# Epoch 32: 100%|██████████| 2/2 [00:01<00:00,  2.00batch/s, accuracy=0.917, loss=0.00766]
# Epoch 33: 100%|██████████| 2/2 [00:00<00:00,  2.04batch/s, accuracy=0.908, loss=0.00761]
# Epoch 34: 100%|██████████| 2/2 [00:00<00:00,  2.04batch/s, accuracy=0.933, loss=0.00741]
# Epoch 35:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 35
# lr:  0.00016608338398760707
# -------------------------
# Train set: Avg. loss: 0.0076, Balanced Accuracy: 0.9333333373069763 (93%)
# Test set: Avg. loss: 0.0299, Balanced Accuracy: 0.7000000476837158 (70%)
# -------------------------
# Epoch 35: 100%|██████████| 2/2 [00:01<00:00,  1.32batch/s, accuracy=0.9, loss=0.00777]
# Epoch 36: 100%|██████████| 2/2 [00:00<00:00,  2.00batch/s, accuracy=0.917, loss=0.00727]
# Epoch 37: 100%|██████████| 2/2 [00:00<00:00,  2.04batch/s, accuracy=0.933, loss=0.00734]
# Epoch 38: 100%|██████████| 2/2 [00:01<00:00,  2.00batch/s, accuracy=0.908, loss=0.00728]
# Epoch 39: 100%|██████████| 2/2 [00:00<00:00,  2.02batch/s, accuracy=0.925, loss=0.00725]
# Epoch 40:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 40
# lr:  0.00012851215656510304
# -------------------------
# Train set: Avg. loss: 0.0070, Balanced Accuracy: 0.9333333373069763 (93%)
# Test set: Avg. loss: 0.0298, Balanced Accuracy: 0.7000000476837158 (70%)
# -------------------------
# Epoch 40: 100%|██████████| 2/2 [00:01<00:00,  1.32batch/s, accuracy=0.933, loss=0.00727]
# Epoch 41: 100%|██████████| 2/2 [00:01<00:00,  1.95batch/s, accuracy=0.925, loss=0.00746]
# Epoch 42: 100%|██████████| 2/2 [00:01<00:00,  1.95batch/s, accuracy=0.933, loss=0.00763]
# Epoch 43: 100%|██████████| 2/2 [00:00<00:00,  2.17batch/s, accuracy=0.942, loss=0.00727]
# Epoch 44: 100%|██████████| 2/2 [00:01<00:00,  1.99batch/s, accuracy=0.908, loss=0.0072]
# Epoch 45:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 45
# lr:  9.944025698709218e-05
# -------------------------
# Train set: Avg. loss: 0.0067, Balanced Accuracy: 0.9416666626930237 (94%)
# Test set: Avg. loss: 0.0296, Balanced Accuracy: 0.7000000476837158 (70%)
# -------------------------
# Epoch 45: 100%|██████████| 2/2 [00:01<00:00,  1.29batch/s, accuracy=0.925, loss=0.00704]
# Epoch 46: 100%|██████████| 2/2 [00:00<00:00,  2.03batch/s, accuracy=0.942, loss=0.0074]
# Epoch 47: 100%|██████████| 2/2 [00:01<00:00,  2.00batch/s, accuracy=0.925, loss=0.00713]
# Epoch 48: 100%|██████████| 2/2 [00:00<00:00,  2.01batch/s, accuracy=0.958, loss=0.00723]
# Epoch 49: 100%|██████████| 2/2 [00:00<00:00,  2.36batch/s, accuracy=0.925, loss=0.00702]
# Epoch 50:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 50
# lr:  7.69449752767131e-05
# -------------------------
# Train set: Avg. loss: 0.0066, Balanced Accuracy: 0.9416666626930237 (94%)
# Test set: Avg. loss: 0.0295, Balanced Accuracy: 0.7000000476837158 (70%)
# -------------------------
# Epoch 50: 100%|██████████| 2/2 [00:01<00:00,  1.30batch/s, accuracy=0.958, loss=0.0069]
# Train set: Avg. loss: 0.0076, Balanced Accuracy: 0.8833333253860474 (88%)
# Val set: Avg. loss: 0.0298, Balanced Accuracy: 0.7000000476837158 (70%)
# Test set: Avg. loss: 0.0285, Balanced Accuracy: 0.75 (75%)
# Epoch 0:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 0
# lr:  0.001
# -------------------------
# Train set: Avg. loss: 0.0116, Balanced Accuracy: 0.40833333134651184 (41%)
# Test set: Avg. loss: 0.0346, Balanced Accuracy: 0.550000011920929 (55%)
# Saving best model weights with balanced accuracy:  0.550000011920929
# -------------------------
# Epoch 0: 100%|██████████| 2/2 [00:01<00:00,  1.19batch/s, accuracy=0.467, loss=0.0112]
# Epoch 1: 100%|██████████| 2/2 [00:00<00:00,  2.03batch/s, accuracy=0.683, loss=0.0103]
# Epoch 2: 100%|██████████| 2/2 [00:00<00:00,  2.04batch/s, accuracy=0.725, loss=0.0096]
# Epoch 3: 100%|██████████| 2/2 [00:00<00:00,  2.05batch/s, accuracy=0.767, loss=0.00941]
# Epoch 4: 100%|██████████| 2/2 [00:00<00:00,  2.05batch/s, accuracy=0.808, loss=0.0093]
# Epoch 5:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 5
# lr:  0.0007737809374999998
# -------------------------
# Train set: Avg. loss: 0.0101, Balanced Accuracy: 0.7250000238418579 (73%)
# Test set: Avg. loss: 0.0323, Balanced Accuracy: 0.6499999761581421 (65%)
# Saving best model weights with balanced accuracy:  0.6499999761581421
# -------------------------
# Epoch 5: 100%|██████████| 2/2 [00:01<00:00,  1.29batch/s, accuracy=0.825, loss=0.0099]
# Epoch 6: 100%|██████████| 2/2 [00:01<00:00,  1.98batch/s, accuracy=0.808, loss=0.00857]
# Epoch 7: 100%|██████████| 2/2 [00:00<00:00,  2.02batch/s, accuracy=0.817, loss=0.00864]
# Epoch 8: 100%|██████████| 2/2 [00:01<00:00,  1.89batch/s, accuracy=0.842, loss=0.0087]
# Epoch 9: 100%|██████████| 2/2 [00:01<00:00,  1.95batch/s, accuracy=0.817, loss=0.00842]
# Epoch 10:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 10
# lr:  0.0005987369392383785
# -------------------------
# Train set: Avg. loss: 0.0088, Balanced Accuracy: 0.8250000476837158 (83%)
# Test set: Avg. loss: 0.0304, Balanced Accuracy: 0.699999988079071 (70%)
# Saving best model weights with balanced accuracy:  0.699999988079071
# -------------------------
# Epoch 10: 100%|██████████| 2/2 [00:01<00:00,  1.32batch/s, accuracy=0.842, loss=0.00861]
# Epoch 11: 100%|██████████| 2/2 [00:00<00:00,  2.04batch/s, accuracy=0.808, loss=0.00832]
# Epoch 12: 100%|██████████| 2/2 [00:00<00:00,  2.04batch/s, accuracy=0.842, loss=0.00836]
# Epoch 13: 100%|██████████| 2/2 [00:00<00:00,  2.00batch/s, accuracy=0.85, loss=0.00887]
# Epoch 14: 100%|██████████| 2/2 [00:00<00:00,  2.20batch/s, accuracy=0.833, loss=0.00906]
# Epoch 15:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 15
# lr:  0.00046329123015975297
# -------------------------
# Train set: Avg. loss: 0.0080, Balanced Accuracy: 0.8500000238418579 (85%)
# Test set: Avg. loss: 0.0301, Balanced Accuracy: 0.75 (75%)
# Saving best model weights with balanced accuracy:  0.75
# -------------------------
# Epoch 15: 100%|██████████| 2/2 [00:01<00:00,  1.38batch/s, accuracy=0.842, loss=0.00887]
# Epoch 16: 100%|██████████| 2/2 [00:00<00:00,  2.01batch/s, accuracy=0.858, loss=0.00761]
# Epoch 17: 100%|██████████| 2/2 [00:01<00:00,  1.98batch/s, accuracy=0.85, loss=0.00801]
# Epoch 18: 100%|██████████| 2/2 [00:01<00:00,  1.97batch/s, accuracy=0.867, loss=0.0082]
# Epoch 19: 100%|██████████| 2/2 [00:00<00:00,  2.06batch/s, accuracy=0.858, loss=0.00791]
# Epoch 20:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 20
# lr:  0.0003584859224085418
# -------------------------
# Train set: Avg. loss: 0.0077, Balanced Accuracy: 0.8583333492279053 (86%)
# Test set: Avg. loss: 0.0303, Balanced Accuracy: 0.7000000476837158 (70%)
# -------------------------
# Epoch 20: 100%|██████████| 2/2 [00:01<00:00,  1.27batch/s, accuracy=0.842, loss=0.00794]
# Epoch 21: 100%|██████████| 2/2 [00:00<00:00,  2.06batch/s, accuracy=0.883, loss=0.00812]
# Epoch 22: 100%|██████████| 2/2 [00:00<00:00,  2.05batch/s, accuracy=0.85, loss=0.00839]
# Epoch 23: 100%|██████████| 2/2 [00:00<00:00,  2.07batch/s, accuracy=0.85, loss=0.00774]
# Epoch 24: 100%|██████████| 2/2 [00:00<00:00,  2.06batch/s, accuracy=0.875, loss=0.00835]
# Epoch 25:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 25
# lr:  0.00027738957312183364
# -------------------------
# Train set: Avg. loss: 0.0075, Balanced Accuracy: 0.875 (88%)
# Test set: Avg. loss: 0.0303, Balanced Accuracy: 0.7000000476837158 (70%)
# -------------------------
# Epoch 25: 100%|██████████| 2/2 [00:01<00:00,  1.33batch/s, accuracy=0.867, loss=0.00818]
# Epoch 26: 100%|██████████| 2/2 [00:00<00:00,  2.03batch/s, accuracy=0.883, loss=0.00778]
# Epoch 27: 100%|██████████| 2/2 [00:00<00:00,  2.10batch/s, accuracy=0.883, loss=0.0074]
# Epoch 28: 100%|██████████| 2/2 [00:00<00:00,  2.04batch/s, accuracy=0.883, loss=0.00783]
# Epoch 29: 100%|██████████| 2/2 [00:00<00:00,  2.01batch/s, accuracy=0.908, loss=0.00775]
# Epoch 30:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 30
# lr:  0.00021463876394293716
# -------------------------
# Train set: Avg. loss: 0.0072, Balanced Accuracy: 0.8833333253860474 (88%)
# Test set: Avg. loss: 0.0303, Balanced Accuracy: 0.7000000476837158 (70%)
# -------------------------
# Epoch 30: 100%|██████████| 2/2 [00:01<00:00,  1.36batch/s, accuracy=0.9, loss=0.0079]
# Epoch 31: 100%|██████████| 2/2 [00:00<00:00,  2.03batch/s, accuracy=0.9, loss=0.00752]
# Epoch 32: 100%|██████████| 2/2 [00:01<00:00,  1.99batch/s, accuracy=0.9, loss=0.0077]
# Epoch 33: 100%|██████████| 2/2 [00:01<00:00,  1.96batch/s, accuracy=0.9, loss=0.00777]
# Epoch 34: 100%|██████████| 2/2 [00:01<00:00,  1.99batch/s, accuracy=0.892, loss=0.00769]
# Epoch 35:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 35
# lr:  0.00016608338398760707
# -------------------------
# Train set: Avg. loss: 0.0072, Balanced Accuracy: 0.8999999761581421 (90%)
# Test set: Avg. loss: 0.0305, Balanced Accuracy: 0.7000000476837158 (70%)
# -------------------------
# Epoch 35: 100%|██████████| 2/2 [00:01<00:00,  1.37batch/s, accuracy=0.9, loss=0.00778]
# Epoch 36: 100%|██████████| 2/2 [00:00<00:00,  2.12batch/s, accuracy=0.883, loss=0.00781]
# Epoch 37: 100%|██████████| 2/2 [00:00<00:00,  2.01batch/s, accuracy=0.9, loss=0.0076]
# Epoch 38: 100%|██████████| 2/2 [00:00<00:00,  2.24batch/s, accuracy=0.908, loss=0.00739]
# Epoch 39: 100%|██████████| 2/2 [00:00<00:00,  2.04batch/s, accuracy=0.9, loss=0.00773]
# Epoch 40:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 40
# lr:  0.00012851215656510304
# -------------------------
# Train set: Avg. loss: 0.0073, Balanced Accuracy: 0.9083333015441895 (91%)
# Test set: Avg. loss: 0.0305, Balanced Accuracy: 0.7000000476837158 (70%)
# -------------------------
# Epoch 40: 100%|██████████| 2/2 [00:01<00:00,  1.31batch/s, accuracy=0.917, loss=0.00742]
# Epoch 41: 100%|██████████| 2/2 [00:00<00:00,  2.03batch/s, accuracy=0.883, loss=0.00769]
# Epoch 42: 100%|██████████| 2/2 [00:00<00:00,  2.02batch/s, accuracy=0.933, loss=0.00783]
# Epoch 43: 100%|██████████| 2/2 [00:00<00:00,  2.05batch/s, accuracy=0.917, loss=0.00763]
# Epoch 44: 100%|██████████| 2/2 [00:00<00:00,  2.01batch/s, accuracy=0.925, loss=0.00755]
# Epoch 45:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 45
# lr:  9.944025698709218e-05
# -------------------------
# Train set: Avg. loss: 0.0075, Balanced Accuracy: 0.9166666269302368 (92%)
# Test set: Avg. loss: 0.0307, Balanced Accuracy: 0.7000000476837158 (70%)
# -------------------------
# Epoch 45: 100%|██████████| 2/2 [00:01<00:00,  1.30batch/s, accuracy=0.892, loss=0.00743]
# Epoch 46: 100%|██████████| 2/2 [00:00<00:00,  2.02batch/s, accuracy=0.917, loss=0.00763]
# Epoch 47: 100%|██████████| 2/2 [00:00<00:00,  2.02batch/s, accuracy=0.892, loss=0.00757]
# Epoch 48: 100%|██████████| 2/2 [00:01<00:00,  1.99batch/s, accuracy=0.9, loss=0.00746]
# Epoch 49: 100%|██████████| 2/2 [00:00<00:00,  2.01batch/s, accuracy=0.917, loss=0.00713]
# Epoch 50:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 50
# lr:  7.69449752767131e-05
# -------------------------
# Train set: Avg. loss: 0.0071, Balanced Accuracy: 0.9249999523162842 (92%)
# Test set: Avg. loss: 0.0307, Balanced Accuracy: 0.7000000476837158 (70%)
# -------------------------
# Epoch 50: 100%|██████████| 2/2 [00:01<00:00,  1.33batch/s, accuracy=0.917, loss=0.00717]
# Train set: Avg. loss: 0.0081, Balanced Accuracy: 0.8500000238418579 (85%)
# Val set: Avg. loss: 0.0301, Balanced Accuracy: 0.75 (75%)
# Test set: Avg. loss: 0.0270, Balanced Accuracy: 0.75 (75%)
# Subject:  1  Session:  2
# Error in file:  /network/lustre/iss02/aramis/projects/cracknetworks/sub-01/ses-02/EEG/Train-[2022.04.04-16.15.17].edf
# 'Event name "OVTK_GDF_Left" could not be found. The following events are present in the data: OVTK_StimulationId_ExperimentStart, OVTK_StimulationId_BaselineStart/OVTK_StimulationId_Beep'
# Error in file:  /network/lustre/iss02/aramis/projects/cracknetworks/sub-01/ses-02/EEG/Train-[2022.04.04-16.14.01].edf
# 'Event name "OVTK_GDF_Left" could not be found. The following events are present in the data: OVTK_StimulationId_ExperimentStart, OVTK_StimulationId_BaselineStart/OVTK_StimulationId_Beep'
# Error in file:  /network/lustre/iss02/aramis/projects/cracknetworks/sub-01/ses-02/EEG/Test-[2022.04.04-16.52.15].edf
# 'Event name "OVTK_GDF_Left" could not be found. The following events are present in the data: OVTK_GDF_Feedback_Continuous, OVTK_GDF_Right, OVTK_StimulationId_ExperimentStart, OVTK_StimulationId_BaselineStart/OVTK_StimulationId_Beep, OVTK_StimulationId_BaselineStop/OVTK_StimulationId_Beep, OVTK_GDF_Cross_On_Screen/OVTK_GDF_Start_Of_Trial/OVTK_StimulationId_Beep, OVTK_GDF_End_Of_Trial/OVTK_StimulationId_VisualStimulationStar'
# Epoch 0:   0%|          | 0/1 [00:00<?, ?batch/s]
# Epoch 0
# lr:  0.001
# -------------------------
# Train set: Avg. loss: 0.0069, Balanced Accuracy: 0.49000000953674316 (49%)
# Test set: Avg. loss: 0.0341, Balanced Accuracy: 0.6499999761581421 (65%)
# Saving best model weights with balanced accuracy:  0.6499999761581421
# -------------------------
# Epoch 0: 100%|██████████| 1/1 [00:01<00:00,  1.41s/batch, accuracy=0.57, loss=0.00691]
# Epoch 1: 100%|██████████| 1/1 [00:00<00:00,  1.24batch/s, accuracy=0.65, loss=0.00659]
# Epoch 2: 100%|██████████| 1/1 [00:00<00:00,  1.29batch/s, accuracy=0.75, loss=0.00617]
# Epoch 3: 100%|██████████| 1/1 [00:00<00:00,  1.33batch/s, accuracy=0.8, loss=0.006]
# Epoch 4: 100%|██████████| 1/1 [00:00<00:00,  1.30batch/s, accuracy=0.84, loss=0.00571]
# Epoch 5:   0%|          | 0/1 [00:00<?, ?batch/s]
# Epoch 5
# lr:  0.0007737809374999998
# -------------------------
# Train set: Avg. loss: 0.0061, Balanced Accuracy: 0.6399999856948853 (64%)
# Test set: Avg. loss: 0.0326, Balanced Accuracy: 0.550000011920929 (55%)
# -------------------------
# Epoch 5: 100%|██████████| 1/1 [00:01<00:00,  1.26s/batch, accuracy=0.83, loss=0.00568]
# Epoch 6: 100%|██████████| 1/1 [00:00<00:00,  1.27batch/s, accuracy=0.87, loss=0.00539]
# Epoch 7: 100%|██████████| 1/1 [00:00<00:00,  1.33batch/s, accuracy=0.87, loss=0.0053]
# Epoch 8: 100%|██████████| 1/1 [00:00<00:00,  1.29batch/s, accuracy=0.89, loss=0.00527]
# Epoch 9: 100%|██████████| 1/1 [00:00<00:00,  1.28batch/s, accuracy=0.89, loss=0.00522]
# Epoch 10:   0%|          | 0/1 [00:00<?, ?batch/s]
# Epoch 10
# lr:  0.0005987369392383785
# -------------------------
# Train set: Avg. loss: 0.0056, Balanced Accuracy: 0.7200000286102295 (72%)
# Test set: Avg. loss: 0.0324, Balanced Accuracy: 0.6000000238418579 (60%)
# -------------------------
# Epoch 10: 100%|██████████| 1/1 [00:01<00:00,  1.23s/batch, accuracy=0.88, loss=0.00505]
# Epoch 11: 100%|██████████| 1/1 [00:00<00:00,  1.30batch/s, accuracy=0.88, loss=0.00499]
# Epoch 12: 100%|██████████| 1/1 [00:00<00:00,  1.33batch/s, accuracy=0.9, loss=0.0051]
# Epoch 13: 100%|██████████| 1/1 [00:00<00:00,  1.30batch/s, accuracy=0.89, loss=0.00499]
# Epoch 14: 100%|██████████| 1/1 [00:00<00:00,  1.32batch/s, accuracy=0.91, loss=0.00485]
# Epoch 15:   0%|          | 0/1 [00:00<?, ?batch/s]
# Epoch 15
# lr:  0.00046329123015975297
# -------------------------
# Train set: Avg. loss: 0.0051, Balanced Accuracy: 0.8700000047683716 (87%)
# Test set: Avg. loss: 0.0308, Balanced Accuracy: 0.6000000238418579 (60%)
# -------------------------
# Epoch 15: 100%|██████████| 1/1 [00:01<00:00,  1.22s/batch, accuracy=0.9, loss=0.00485]
# Epoch 16: 100%|██████████| 1/1 [00:00<00:00,  1.31batch/s, accuracy=0.92, loss=0.00465]
# Epoch 17: 100%|██████████| 1/1 [00:00<00:00,  1.30batch/s, accuracy=0.91, loss=0.00477]
# Epoch 18: 100%|██████████| 1/1 [00:00<00:00,  1.28batch/s, accuracy=0.91, loss=0.00472]
# Epoch 19: 100%|██████████| 1/1 [00:00<00:00,  1.57batch/s, accuracy=0.91, loss=0.00464]
# Epoch 20:   0%|          | 0/1 [00:00<?, ?batch/s]
# Epoch 20
# lr:  0.0003584859224085418
# -------------------------
# Train set: Avg. loss: 0.0047, Balanced Accuracy: 0.9099999666213989 (91%)
# Test set: Avg. loss: 0.0288, Balanced Accuracy: 0.699999988079071 (70%)
# Saving best model weights with balanced accuracy:  0.699999988079071
# -------------------------
# Epoch 20: 100%|██████████| 1/1 [00:01<00:00,  1.26s/batch, accuracy=0.93, loss=0.00462]
# Epoch 21: 100%|██████████| 1/1 [00:00<00:00,  1.32batch/s, accuracy=0.92, loss=0.00464]
# Epoch 22: 100%|██████████| 1/1 [00:00<00:00,  1.33batch/s, accuracy=0.91, loss=0.0045]
# Epoch 23: 100%|██████████| 1/1 [00:00<00:00,  1.38batch/s, accuracy=0.92, loss=0.00455]
# Epoch 24: 100%|██████████| 1/1 [00:00<00:00,  1.27batch/s, accuracy=0.92, loss=0.00441]
# Epoch 25:   0%|          | 0/1 [00:00<?, ?batch/s]
# Epoch 25
# lr:  0.00027738957312183364
# -------------------------
# Train set: Avg. loss: 0.0044, Balanced Accuracy: 0.9300000071525574 (93%)
# Test set: Avg. loss: 0.0274, Balanced Accuracy: 0.75 (75%)
# Saving best model weights with balanced accuracy:  0.75
# -------------------------
# Epoch 25: 100%|██████████| 1/1 [00:01<00:00,  1.25s/batch, accuracy=0.94, loss=0.00436]
# Epoch 26: 100%|██████████| 1/1 [00:00<00:00,  1.32batch/s, accuracy=0.92, loss=0.00445]
# Epoch 27: 100%|██████████| 1/1 [00:00<00:00,  1.31batch/s, accuracy=0.93, loss=0.00437]
# Epoch 28: 100%|██████████| 1/1 [00:00<00:00,  1.30batch/s, accuracy=0.93, loss=0.00442]
# Epoch 29: 100%|██████████| 1/1 [00:00<00:00,  1.31batch/s, accuracy=0.95, loss=0.00434]
# Epoch 30:   0%|          | 0/1 [00:00<?, ?batch/s]
# Epoch 30
# lr:  0.00021463876394293716
# -------------------------
# Train set: Avg. loss: 0.0042, Balanced Accuracy: 0.9500000476837158 (95%)
# Test set: Avg. loss: 0.0264, Balanced Accuracy: 0.800000011920929 (80%)
# Saving best model weights with balanced accuracy:  0.800000011920929
# -------------------------
# Epoch 30: 100%|██████████| 1/1 [00:01<00:00,  1.30s/batch, accuracy=0.92, loss=0.0044]
# Epoch 31: 100%|██████████| 1/1 [00:00<00:00,  1.28batch/s, accuracy=0.96, loss=0.00429]
# Epoch 32: 100%|██████████| 1/1 [00:00<00:00,  1.31batch/s, accuracy=0.95, loss=0.00428]
# Epoch 33: 100%|██████████| 1/1 [00:00<00:00,  1.41batch/s, accuracy=0.93, loss=0.0043]
# Epoch 34: 100%|██████████| 1/1 [00:00<00:00,  1.30batch/s, accuracy=0.95, loss=0.00436]
# Epoch 35:   0%|          | 0/1 [00:00<?, ?batch/s]
# Epoch 35
# lr:  0.00016608338398760707
# -------------------------
# Train set: Avg. loss: 0.0041, Balanced Accuracy: 0.9700000286102295 (97%)
# Test set: Avg. loss: 0.0257, Balanced Accuracy: 0.8500000238418579 (85%)
# Saving best model weights with balanced accuracy:  0.8500000238418579
# -------------------------
# Epoch 35: 100%|██████████| 1/1 [00:01<00:00,  1.13s/batch, accuracy=0.97, loss=0.00421]
# Epoch 36: 100%|██████████| 1/1 [00:00<00:00,  1.32batch/s, accuracy=0.96, loss=0.0042]
# Epoch 37: 100%|██████████| 1/1 [00:00<00:00,  1.36batch/s, accuracy=0.96, loss=0.00425]
# Epoch 38: 100%|██████████| 1/1 [00:00<00:00,  1.31batch/s, accuracy=0.96, loss=0.00426]
# Epoch 39: 100%|██████████| 1/1 [00:00<00:00,  1.31batch/s, accuracy=0.95, loss=0.00422]
# Epoch 40:   0%|          | 0/1 [00:00<?, ?batch/s]
# Epoch 40
# lr:  0.00012851215656510304
# -------------------------
# Train set: Avg. loss: 0.0040, Balanced Accuracy: 0.9800000190734863 (98%)
# Test set: Avg. loss: 0.0253, Balanced Accuracy: 0.8500000238418579 (85%)
# -------------------------
# Epoch 40: 100%|██████████| 1/1 [00:01<00:00,  1.26s/batch, accuracy=0.96, loss=0.00421]
# Epoch 41: 100%|██████████| 1/1 [00:00<00:00,  1.31batch/s, accuracy=0.98, loss=0.00417]
# Epoch 42: 100%|██████████| 1/1 [00:00<00:00,  1.33batch/s, accuracy=0.97, loss=0.00423]
# Epoch 43: 100%|██████████| 1/1 [00:00<00:00,  1.35batch/s, accuracy=0.95, loss=0.00415]
# Epoch 44: 100%|██████████| 1/1 [00:00<00:00,  1.30batch/s, accuracy=0.96, loss=0.00421]
# Epoch 45:   0%|          | 0/1 [00:00<?, ?batch/s]
# Epoch 45
# lr:  9.944025698709218e-05
# -------------------------
# Train set: Avg. loss: 0.0040, Balanced Accuracy: 0.9800000190734863 (98%)
# Test set: Avg. loss: 0.0250, Balanced Accuracy: 0.8500000238418579 (85%)
# -------------------------
# Epoch 45: 100%|██████████| 1/1 [00:01<00:00,  1.24s/batch, accuracy=0.96, loss=0.00417]
# Epoch 46: 100%|██████████| 1/1 [00:00<00:00,  1.32batch/s, accuracy=0.96, loss=0.00421]
# Epoch 47: 100%|██████████| 1/1 [00:00<00:00,  1.30batch/s, accuracy=0.96, loss=0.00419]
# Epoch 48: 100%|██████████| 1/1 [00:00<00:00,  1.43batch/s, accuracy=0.97, loss=0.00419]
# Epoch 49: 100%|██████████| 1/1 [00:00<00:00,  1.28batch/s, accuracy=0.96, loss=0.00414]
# Epoch 50:   0%|          | 0/1 [00:00<?, ?batch/s]
# Epoch 50
# lr:  7.69449752767131e-05
# -------------------------
# Train set: Avg. loss: 0.0039, Balanced Accuracy: 0.9800000190734863 (98%)
# Test set: Avg. loss: 0.0249, Balanced Accuracy: 0.8500000238418579 (85%)
# -------------------------
# Epoch 50: 100%|██████████| 1/1 [00:01<00:00,  1.28s/batch, accuracy=0.96, loss=0.00416]
# Train set: Avg. loss: 0.0041, Balanced Accuracy: 0.9700000286102295 (97%)
# Val set: Avg. loss: 0.0257, Balanced Accuracy: 0.8500000238418579 (85%)
# Test set: Avg. loss: 0.0266, Balanced Accuracy: 0.8999999761581421 (90%)
# Epoch 0:   0%|          | 0/1 [00:00<?, ?batch/s]
# Epoch 0
# lr:  0.001
# -------------------------
# Train set: Avg. loss: 0.0069, Balanced Accuracy: 0.550000011920929 (55%)
# Test set: Avg. loss: 0.0346, Balanced Accuracy: 0.45000001788139343 (45%)
# Saving best model weights with balanced accuracy:  0.45000001788139343
# -------------------------
# Epoch 0: 100%|██████████| 1/1 [00:01<00:00,  1.35s/batch, accuracy=0.5, loss=0.00697]
# Epoch 1: 100%|██████████| 1/1 [00:00<00:00,  1.19batch/s, accuracy=0.61, loss=0.00673]
# Epoch 2: 100%|██████████| 1/1 [00:00<00:00,  1.27batch/s, accuracy=0.69, loss=0.00642]
# Epoch 3: 100%|██████████| 1/1 [00:00<00:00,  1.30batch/s, accuracy=0.76, loss=0.00608]
# Epoch 4: 100%|██████████| 1/1 [00:00<00:00,  1.32batch/s, accuracy=0.79, loss=0.00598]
# Epoch 5:   0%|          | 0/1 [00:00<?, ?batch/s]
# Epoch 5
# lr:  0.0007737809374999998
# -------------------------
# Train set: Avg. loss: 0.0061, Balanced Accuracy: 0.8299999833106995 (83%)
# Test set: Avg. loss: 0.0330, Balanced Accuracy: 0.5 (50%)
# Saving best model weights with balanced accuracy:  0.5
# -------------------------
# Epoch 5: 100%|██████████| 1/1 [00:01<00:00,  1.29s/batch, accuracy=0.83, loss=0.00578]
# Epoch 6: 100%|██████████| 1/1 [00:00<00:00,  1.29batch/s, accuracy=0.84, loss=0.00567]
# Epoch 7: 100%|██████████| 1/1 [00:00<00:00,  1.30batch/s, accuracy=0.84, loss=0.0056]
# Epoch 8: 100%|██████████| 1/1 [00:00<00:00,  1.32batch/s, accuracy=0.86, loss=0.00545]
# Epoch 9: 100%|██████████| 1/1 [00:00<00:00,  1.32batch/s, accuracy=0.88, loss=0.00539]
# Epoch 10:   0%|          | 0/1 [00:00<?, ?batch/s]
# Epoch 10
# lr:  0.0005987369392383785
# -------------------------
# Train set: Avg. loss: 0.0056, Balanced Accuracy: 0.8500000238418579 (85%)
# Test set: Avg. loss: 0.0311, Balanced Accuracy: 0.6000000238418579 (60%)
# Saving best model weights with balanced accuracy:  0.6000000238418579
# -------------------------
# Epoch 10: 100%|██████████| 1/1 [00:01<00:00,  1.28s/batch, accuracy=0.85, loss=0.00537]
# Epoch 11: 100%|██████████| 1/1 [00:00<00:00,  1.28batch/s, accuracy=0.87, loss=0.00531]
# Epoch 12: 100%|██████████| 1/1 [00:00<00:00,  1.48batch/s, accuracy=0.9, loss=0.00504]
# Epoch 13: 100%|██████████| 1/1 [00:00<00:00,  1.33batch/s, accuracy=0.88, loss=0.00507]
# Epoch 14: 100%|██████████| 1/1 [00:00<00:00,  1.26batch/s, accuracy=0.88, loss=0.00501]
# Epoch 15:   0%|          | 0/1 [00:00<?, ?batch/s]
# Epoch 15
# lr:  0.00046329123015975297
# -------------------------
# Train set: Avg. loss: 0.0051, Balanced Accuracy: 0.8600000143051147 (86%)
# Test set: Avg. loss: 0.0295, Balanced Accuracy: 0.75 (75%)
# Saving best model weights with balanced accuracy:  0.75
# -------------------------
# Epoch 15: 100%|██████████| 1/1 [00:01<00:00,  1.24s/batch, accuracy=0.89, loss=0.00501]
# Epoch 16: 100%|██████████| 1/1 [00:00<00:00,  1.30batch/s, accuracy=0.88, loss=0.00492]
# Epoch 17: 100%|██████████| 1/1 [00:00<00:00,  1.31batch/s, accuracy=0.91, loss=0.00486]
# Epoch 18: 100%|██████████| 1/1 [00:00<00:00,  1.30batch/s, accuracy=0.91, loss=0.00486]
# Epoch 19: 100%|██████████| 1/1 [00:00<00:00,  1.32batch/s, accuracy=0.9, loss=0.0047]
# Epoch 20:   0%|          | 0/1 [00:00<?, ?batch/s]
# Epoch 20
# lr:  0.0003584859224085418
# -------------------------
# Train set: Avg. loss: 0.0047, Balanced Accuracy: 0.9099999666213989 (91%)
# Test set: Avg. loss: 0.0283, Balanced Accuracy: 0.800000011920929 (80%)
# Saving best model weights with balanced accuracy:  0.800000011920929
# -------------------------
# Epoch 20: 100%|██████████| 1/1 [00:01<00:00,  1.15s/batch, accuracy=0.89, loss=0.00482]
# Epoch 21: 100%|██████████| 1/1 [00:00<00:00,  1.32batch/s, accuracy=0.91, loss=0.00473]
# Epoch 22: 100%|██████████| 1/1 [00:00<00:00,  1.27batch/s, accuracy=0.93, loss=0.00456]
# Epoch 23: 100%|██████████| 1/1 [00:00<00:00,  1.31batch/s, accuracy=0.94, loss=0.00458]
# Epoch 24: 100%|██████████| 1/1 [00:00<00:00,  1.28batch/s, accuracy=0.94, loss=0.00453]
# Epoch 25:   0%|          | 0/1 [00:00<?, ?batch/s]
# Epoch 25
# lr:  0.00027738957312183364
# -------------------------
# Train set: Avg. loss: 0.0045, Balanced Accuracy: 0.9399999976158142 (94%)
# Test set: Avg. loss: 0.0273, Balanced Accuracy: 0.800000011920929 (80%)
# -------------------------
# Epoch 25: 100%|██████████| 1/1 [00:01<00:00,  1.25s/batch, accuracy=0.93, loss=0.00458]
# Epoch 26: 100%|██████████| 1/1 [00:00<00:00,  1.33batch/s, accuracy=0.92, loss=0.00462]
# Epoch 27: 100%|██████████| 1/1 [00:00<00:00,  1.29batch/s, accuracy=0.92, loss=0.00463]
# Epoch 28: 100%|██████████| 1/1 [00:00<00:00,  1.32batch/s, accuracy=0.94, loss=0.00452]
# Epoch 29: 100%|██████████| 1/1 [00:00<00:00,  1.30batch/s, accuracy=0.94, loss=0.00448]
# Epoch 30:   0%|          | 0/1 [00:00<?, ?batch/s]
# Epoch 30
# lr:  0.00021463876394293716
# -------------------------
# Train set: Avg. loss: 0.0043, Balanced Accuracy: 0.9600000381469727 (96%)
# Test set: Avg. loss: 0.0266, Balanced Accuracy: 0.800000011920929 (80%)
# -------------------------
# Epoch 30: 100%|██████████| 1/1 [00:01<00:00,  1.23s/batch, accuracy=0.98, loss=0.00441]
# Epoch 31: 100%|██████████| 1/1 [00:00<00:00,  1.30batch/s, accuracy=0.93, loss=0.00451]
# Epoch 32: 100%|██████████| 1/1 [00:00<00:00,  1.29batch/s, accuracy=0.96, loss=0.00436]
# Epoch 33: 100%|██████████| 1/1 [00:00<00:00,  1.30batch/s, accuracy=0.96, loss=0.00432]
# Epoch 34: 100%|██████████| 1/1 [00:00<00:00,  1.30batch/s, accuracy=0.97, loss=0.00438]
# Epoch 35:   0%|          | 0/1 [00:00<?, ?batch/s]
# Epoch 35
# lr:  0.00016608338398760707
# -------------------------
# Train set: Avg. loss: 0.0042, Balanced Accuracy: 0.9700000286102295 (97%)
# Test set: Avg. loss: 0.0261, Balanced Accuracy: 0.800000011920929 (80%)
# -------------------------
# Epoch 35: 100%|██████████| 1/1 [00:01<00:00,  1.22s/batch, accuracy=0.97, loss=0.00427]
# Epoch 36: 100%|██████████| 1/1 [00:00<00:00,  1.32batch/s, accuracy=0.96, loss=0.00438]
# Epoch 37: 100%|██████████| 1/1 [00:00<00:00,  1.30batch/s, accuracy=0.98, loss=0.0043]
# Epoch 38: 100%|██████████| 1/1 [00:00<00:00,  1.31batch/s, accuracy=0.97, loss=0.00431]
# Epoch 39: 100%|██████████| 1/1 [00:00<00:00,  1.31batch/s, accuracy=0.96, loss=0.00428]
# Epoch 40:   0%|          | 0/1 [00:00<?, ?batch/s]
# Epoch 40
# lr:  0.00012851215656510304
# -------------------------
# Train set: Avg. loss: 0.0041, Balanced Accuracy: 0.9800000190734863 (98%)
# Test set: Avg. loss: 0.0257, Balanced Accuracy: 0.800000011920929 (80%)
# -------------------------
# Epoch 40: 100%|██████████| 1/1 [00:01<00:00,  1.24s/batch, accuracy=0.95, loss=0.00438]
# Epoch 41: 100%|██████████| 1/1 [00:00<00:00,  1.31batch/s, accuracy=0.96, loss=0.00427]
# Epoch 42: 100%|██████████| 1/1 [00:00<00:00,  1.34batch/s, accuracy=0.96, loss=0.00421]
# Epoch 43: 100%|██████████| 1/1 [00:00<00:00,  1.50batch/s, accuracy=0.96, loss=0.00429]
# Epoch 44: 100%|██████████| 1/1 [00:00<00:00,  1.30batch/s, accuracy=0.96, loss=0.00424]
# Epoch 45:   0%|          | 0/1 [00:00<?, ?batch/s]
# Epoch 45
# lr:  9.944025698709218e-05
# -------------------------
# Train set: Avg. loss: 0.0040, Balanced Accuracy: 0.9800000190734863 (98%)
# Test set: Avg. loss: 0.0253, Balanced Accuracy: 0.800000011920929 (80%)
# -------------------------
# Epoch 45: 100%|██████████| 1/1 [00:01<00:00,  1.07s/batch, accuracy=0.97, loss=0.00424]
# Epoch 46: 100%|██████████| 1/1 [00:00<00:00,  1.31batch/s, accuracy=0.95, loss=0.00434]
# Epoch 47: 100%|██████████| 1/1 [00:00<00:00,  1.32batch/s, accuracy=0.95, loss=0.00426]
# Epoch 48: 100%|██████████| 1/1 [00:00<00:00,  1.30batch/s, accuracy=0.97, loss=0.00423]
# Epoch 49: 100%|██████████| 1/1 [00:00<00:00,  1.31batch/s, accuracy=0.97, loss=0.00423]
# Epoch 50:   0%|          | 0/1 [00:00<?, ?batch/s]
# Epoch 50
# lr:  7.69449752767131e-05
# -------------------------
# Train set: Avg. loss: 0.0040, Balanced Accuracy: 0.9800000190734863 (98%)
# Test set: Avg. loss: 0.0251, Balanced Accuracy: 0.800000011920929 (80%)
# -------------------------
# Epoch 50: 100%|██████████| 1/1 [00:01<00:00,  1.27s/batch, accuracy=0.97, loss=0.00433]
# Train set: Avg. loss: 0.0047, Balanced Accuracy: 0.9099999666213989 (91%)
# Val set: Avg. loss: 0.0283, Balanced Accuracy: 0.800000011920929 (80%)
# Test set: Avg. loss: 0.0272, Balanced Accuracy: 0.8999999761581421 (90%)
# Epoch 0:   0%|          | 0/1 [00:00<?, ?batch/s]
# Epoch 0
# lr:  0.001
# -------------------------
# Train set: Avg. loss: 0.0074, Balanced Accuracy: 0.4399999976158142 (44%)
# Test set: Avg. loss: 0.0374, Balanced Accuracy: 0.44999998807907104 (45%)
# Saving best model weights with balanced accuracy:  0.44999998807907104
# -------------------------
# Epoch 0: 100%|██████████| 1/1 [00:01<00:00,  1.35s/batch, accuracy=0.46, loss=0.00722]
# Epoch 1: 100%|██████████| 1/1 [00:00<00:00,  1.30batch/s, accuracy=0.67, loss=0.0066]
# Epoch 2: 100%|██████████| 1/1 [00:00<00:00,  1.30batch/s, accuracy=0.73, loss=0.00639]
# Epoch 3: 100%|██████████| 1/1 [00:00<00:00,  1.30batch/s, accuracy=0.85, loss=0.00587]
# Epoch 4: 100%|██████████| 1/1 [00:00<00:00,  1.31batch/s, accuracy=0.9, loss=0.00557]
# Epoch 5:   0%|          | 0/1 [00:00<?, ?batch/s]
# Epoch 5
# lr:  0.0007737809374999998
# -------------------------
# Train set: Avg. loss: 0.0060, Balanced Accuracy: 0.8100000023841858 (81%)
# Test set: Avg. loss: 0.0324, Balanced Accuracy: 0.6499999761581421 (65%)
# Saving best model weights with balanced accuracy:  0.6499999761581421
# -------------------------
# Epoch 5: 100%|██████████| 1/1 [00:01<00:00,  1.25s/batch, accuracy=0.87, loss=0.00559]
# Epoch 6: 100%|██████████| 1/1 [00:00<00:00,  1.33batch/s, accuracy=0.92, loss=0.00539]
# Epoch 7: 100%|██████████| 1/1 [00:00<00:00,  1.34batch/s, accuracy=0.87, loss=0.00539]
# Epoch 8: 100%|██████████| 1/1 [00:00<00:00,  1.30batch/s, accuracy=0.91, loss=0.00517]
# Epoch 9: 100%|██████████| 1/1 [00:00<00:00,  1.32batch/s, accuracy=0.89, loss=0.0051]
# Epoch 10:   0%|          | 0/1 [00:00<?, ?batch/s]
# Epoch 10
# lr:  0.0005987369392383785
# -------------------------
# Train set: Avg. loss: 0.0052, Balanced Accuracy: 0.8600000143051147 (86%)
# Test set: Avg. loss: 0.0305, Balanced Accuracy: 0.699999988079071 (70%)
# Saving best model weights with balanced accuracy:  0.699999988079071
# -------------------------
# Epoch 10: 100%|██████████| 1/1 [00:01<00:00,  1.27s/batch, accuracy=0.92, loss=0.00493]
# Epoch 11: 100%|██████████| 1/1 [00:00<00:00,  1.31batch/s, accuracy=0.92, loss=0.00479]
# Epoch 12: 100%|██████████| 1/1 [00:00<00:00,  1.32batch/s, accuracy=0.93, loss=0.00478]
# Epoch 13: 100%|██████████| 1/1 [00:00<00:00,  1.34batch/s, accuracy=0.91, loss=0.00485]
# Epoch 14: 100%|██████████| 1/1 [00:00<00:00,  1.30batch/s, accuracy=0.92, loss=0.00461]
# Epoch 15:   0%|          | 0/1 [00:00<?, ?batch/s]
# Epoch 15
# lr:  0.00046329123015975297
# -------------------------
# Train set: Avg. loss: 0.0047, Balanced Accuracy: 0.9200000166893005 (92%)
# Test set: Avg. loss: 0.0293, Balanced Accuracy: 0.75 (75%)
# Saving best model weights with balanced accuracy:  0.75
# -------------------------
# Epoch 15: 100%|██████████| 1/1 [00:01<00:00,  1.27s/batch, accuracy=0.94, loss=0.00463]
# Epoch 16: 100%|██████████| 1/1 [00:00<00:00,  1.33batch/s, accuracy=0.94, loss=0.00463]
# Epoch 17: 100%|██████████| 1/1 [00:00<00:00,  1.31batch/s, accuracy=0.93, loss=0.00451]
# Epoch 18: 100%|██████████| 1/1 [00:00<00:00,  1.66batch/s, accuracy=0.94, loss=0.00448]
# Epoch 19: 100%|██████████| 1/1 [00:00<00:00,  1.30batch/s, accuracy=0.93, loss=0.00444]
# Epoch 20:   0%|          | 0/1 [00:00<?, ?batch/s]
# Epoch 20
# lr:  0.0003584859224085418
# -------------------------
# Train set: Avg. loss: 0.0044, Balanced Accuracy: 0.9399999976158142 (94%)
# Test set: Avg. loss: 0.0283, Balanced Accuracy: 0.75 (75%)
# -------------------------
# Epoch 20: 100%|██████████| 1/1 [00:01<00:00,  1.13s/batch, accuracy=0.93, loss=0.00438]
# Epoch 21: 100%|██████████| 1/1 [00:00<00:00,  1.34batch/s, accuracy=0.94, loss=0.0044]
# Epoch 22: 100%|██████████| 1/1 [00:00<00:00,  1.32batch/s, accuracy=0.93, loss=0.00443]
# Epoch 23: 100%|██████████| 1/1 [00:00<00:00,  1.29batch/s, accuracy=0.93, loss=0.00448]
# Epoch 24: 100%|██████████| 1/1 [00:00<00:00,  1.34batch/s, accuracy=0.93, loss=0.00442]
# Epoch 25:   0%|          | 0/1 [00:00<?, ?batch/s]
# Epoch 25
# lr:  0.00027738957312183364
# -------------------------
# Train set: Avg. loss: 0.0042, Balanced Accuracy: 0.9399999976158142 (94%)
# Test set: Avg. loss: 0.0278, Balanced Accuracy: 0.75 (75%)
# -------------------------
# Epoch 25: 100%|██████████| 1/1 [00:01<00:00,  1.23s/batch, accuracy=0.94, loss=0.00438]
# Epoch 26: 100%|██████████| 1/1 [00:00<00:00,  1.27batch/s, accuracy=0.94, loss=0.0043]
# Epoch 27: 100%|██████████| 1/1 [00:00<00:00,  1.30batch/s, accuracy=0.94, loss=0.00432]
# Epoch 28: 100%|██████████| 1/1 [00:00<00:00,  1.33batch/s, accuracy=0.95, loss=0.00426]
# Epoch 29: 100%|██████████| 1/1 [00:00<00:00,  1.32batch/s, accuracy=0.94, loss=0.00426]
# Epoch 30:   0%|          | 0/1 [00:00<?, ?batch/s]
# Epoch 30
# lr:  0.00021463876394293716
# -------------------------
# Train set: Avg. loss: 0.0041, Balanced Accuracy: 0.9500000476837158 (95%)
# Test set: Avg. loss: 0.0275, Balanced Accuracy: 0.75 (75%)
# -------------------------
# Epoch 30: 100%|██████████| 1/1 [00:01<00:00,  1.19s/batch, accuracy=0.94, loss=0.00422]
# Epoch 31: 100%|██████████| 1/1 [00:00<00:00,  1.51batch/s, accuracy=0.94, loss=0.00427]
# Epoch 32: 100%|██████████| 1/1 [00:00<00:00,  1.28batch/s, accuracy=0.95, loss=0.00424]
# Epoch 33: 100%|██████████| 1/1 [00:00<00:00,  1.30batch/s, accuracy=0.95, loss=0.00429]
# Epoch 34: 100%|██████████| 1/1 [00:00<00:00,  1.33batch/s, accuracy=0.93, loss=0.00419]
# Epoch 35:   0%|          | 0/1 [00:00<?, ?batch/s]
# Epoch 35
# lr:  0.00016608338398760707
# -------------------------
# Train set: Avg. loss: 0.0040, Balanced Accuracy: 0.9500000476837158 (95%)
# Test set: Avg. loss: 0.0272, Balanced Accuracy: 0.75 (75%)
# -------------------------
# Epoch 35: 100%|██████████| 1/1 [00:01<00:00,  1.23s/batch, accuracy=0.94, loss=0.00425]
# Epoch 36: 100%|██████████| 1/1 [00:00<00:00,  1.36batch/s, accuracy=0.95, loss=0.00422]
# Epoch 37: 100%|██████████| 1/1 [00:00<00:00,  1.30batch/s, accuracy=0.94, loss=0.0043]
# Epoch 38: 100%|██████████| 1/1 [00:00<00:00,  1.30batch/s, accuracy=0.95, loss=0.00416]
# ...
# Test set: Avg. loss: 0.0337, Balanced Accuracy: 0.44999998807907104 (45%)
# Saving best model weights with balanced accuracy:  0.44999998807907104
# -------------------------
# Epoch 0: 100%|██████████| 2/2 [00:01<00:00,  1.84batch/s, accuracy=0.592, loss=0.0111]
# Epoch 1: 100%|██████████| 2/2 [00:00<00:00,  3.44batch/s, accuracy=0.775, loss=0.0103]
# Epoch 2: 100%|██████████| 2/2 [00:00<00:00,  3.32batch/s, accuracy=0.767, loss=0.00937]
# Epoch 3: 100%|██████████| 2/2 [00:00<00:00,  3.34batch/s, accuracy=0.8, loss=0.00949]
# Epoch 4: 100%|██████████| 2/2 [00:00<00:00,  3.15batch/s, accuracy=0.8, loss=0.00902]
# Epoch 5:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 5
# lr:  0.0007737809374999998
# -------------------------
# Train set: Avg. loss: 0.0094, Balanced Accuracy: 0.800000011920929 (80%)
# Test set: Avg. loss: 0.0312, Balanced Accuracy: 0.6499999761581421 (65%)
# Saving best model weights with balanced accuracy:  0.6499999761581421
# -------------------------
# Epoch 5: 100%|██████████| 2/2 [00:00<00:00,  2.18batch/s, accuracy=0.8, loss=0.00886]
# Epoch 6: 100%|██████████| 2/2 [00:00<00:00,  3.49batch/s, accuracy=0.808, loss=0.00901]
# Epoch 7: 100%|██████████| 2/2 [00:00<00:00,  3.51batch/s, accuracy=0.817, loss=0.00849]
# Epoch 8: 100%|██████████| 2/2 [00:00<00:00,  3.22batch/s, accuracy=0.833, loss=0.00825]
# Epoch 9: 100%|██████████| 2/2 [00:00<00:00,  3.15batch/s, accuracy=0.817, loss=0.0087]
# Epoch 10:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 10
# lr:  0.0005987369392383785
# -------------------------
# Train set: Avg. loss: 0.0079, Balanced Accuracy: 0.8416666984558105 (84%)
# Test set: Avg. loss: 0.0306, Balanced Accuracy: 0.6499999761581421 (65%)
# -------------------------
# Epoch 10: 100%|██████████| 2/2 [00:01<00:00,  1.86batch/s, accuracy=0.833, loss=0.00792]
# Epoch 11: 100%|██████████| 2/2 [00:00<00:00,  3.26batch/s, accuracy=0.85, loss=0.00789]
# Epoch 12: 100%|██████████| 2/2 [00:00<00:00,  3.20batch/s, accuracy=0.858, loss=0.0076]
# Epoch 13: 100%|██████████| 2/2 [00:00<00:00,  3.21batch/s, accuracy=0.9, loss=0.00787]
# Epoch 14: 100%|██████████| 2/2 [00:00<00:00,  3.22batch/s, accuracy=0.917, loss=0.00749]
# Epoch 15:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 15
# lr:  0.00046329123015975297
# -------------------------
# Train set: Avg. loss: 0.0077, Balanced Accuracy: 0.9083333015441895 (91%)
# Test set: Avg. loss: 0.0300, Balanced Accuracy: 0.699999988079071 (70%)
# Saving best model weights with balanced accuracy:  0.699999988079071
# -------------------------
# Epoch 15: 100%|██████████| 2/2 [00:00<00:00,  2.11batch/s, accuracy=0.908, loss=0.00716]
# Epoch 16: 100%|██████████| 2/2 [00:00<00:00,  3.21batch/s, accuracy=0.925, loss=0.00732]
# Epoch 17: 100%|██████████| 2/2 [00:00<00:00,  4.29batch/s, accuracy=0.908, loss=0.0074]
# Epoch 18: 100%|██████████| 2/2 [00:00<00:00,  3.26batch/s, accuracy=0.908, loss=0.00749]
# Epoch 19: 100%|██████████| 2/2 [00:00<00:00,  3.34batch/s, accuracy=0.908, loss=0.00698]
# Epoch 20:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 20
# lr:  0.0003584859224085418
# -------------------------
# Train set: Avg. loss: 0.0074, Balanced Accuracy: 0.9333332777023315 (93%)
# Test set: Avg. loss: 0.0292, Balanced Accuracy: 0.699999988079071 (70%)
# -------------------------
# Epoch 20: 100%|██████████| 2/2 [00:01<00:00,  1.92batch/s, accuracy=0.942, loss=0.00751]
# Epoch 21: 100%|██████████| 2/2 [00:00<00:00,  3.29batch/s, accuracy=0.942, loss=0.00722]
# Epoch 22: 100%|██████████| 2/2 [00:00<00:00,  3.32batch/s, accuracy=0.925, loss=0.00697]
# Epoch 23: 100%|██████████| 2/2 [00:00<00:00,  3.45batch/s, accuracy=0.967, loss=0.00685]
# Epoch 24: 100%|██████████| 2/2 [00:00<00:00,  3.35batch/s, accuracy=0.925, loss=0.00662]
# Epoch 25:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 25
# lr:  0.00027738957312183364
# -------------------------
# Train set: Avg. loss: 0.0063, Balanced Accuracy: 0.9666666984558105 (97%)
# Test set: Avg. loss: 0.0289, Balanced Accuracy: 0.6499999761581421 (65%)
# -------------------------
# Epoch 25: 100%|██████████| 2/2 [00:01<00:00,  1.95batch/s, accuracy=0.917, loss=0.0071]
# Epoch 26: 100%|██████████| 2/2 [00:00<00:00,  3.32batch/s, accuracy=0.95, loss=0.00659]
# Epoch 27: 100%|██████████| 2/2 [00:00<00:00,  3.25batch/s, accuracy=0.942, loss=0.00696]
# Epoch 28: 100%|██████████| 2/2 [00:00<00:00,  3.52batch/s, accuracy=0.975, loss=0.00671]
# Epoch 29: 100%|██████████| 2/2 [00:00<00:00,  3.43batch/s, accuracy=0.917, loss=0.00659]
# Epoch 30:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 30
# lr:  0.00021463876394293716
# -------------------------
# Train set: Avg. loss: 0.0060, Balanced Accuracy: 0.9583333730697632 (96%)
# Test set: Avg. loss: 0.0287, Balanced Accuracy: 0.6499999761581421 (65%)
# -------------------------
# Epoch 30: 100%|██████████| 2/2 [00:01<00:00,  1.97batch/s, accuracy=0.983, loss=0.00651]
# Epoch 31: 100%|██████████| 2/2 [00:00<00:00,  3.40batch/s, accuracy=0.967, loss=0.00713]
# Epoch 32: 100%|██████████| 2/2 [00:00<00:00,  3.21batch/s, accuracy=0.967, loss=0.00639]
# Epoch 33: 100%|██████████| 2/2 [00:00<00:00,  3.29batch/s, accuracy=0.958, loss=0.00635]
# Epoch 34: 100%|██████████| 2/2 [00:00<00:00,  3.25batch/s, accuracy=0.975, loss=0.00652]
# Epoch 35:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 35
# lr:  0.00016608338398760707
# -------------------------
# Train set: Avg. loss: 0.0061, Balanced Accuracy: 0.9750000238418579 (98%)
# Test set: Avg. loss: 0.0282, Balanced Accuracy: 0.6499999761581421 (65%)
# -------------------------
# Epoch 35: 100%|██████████| 2/2 [00:01<00:00,  1.92batch/s, accuracy=0.958, loss=0.00647]
# Epoch 36: 100%|██████████| 2/2 [00:00<00:00,  3.30batch/s, accuracy=0.975, loss=0.00635]
# Epoch 37: 100%|██████████| 2/2 [00:00<00:00,  3.24batch/s, accuracy=0.983, loss=0.00636]
# Epoch 38: 100%|██████████| 2/2 [00:00<00:00,  5.23batch/s, accuracy=0.967, loss=0.00624]
# Epoch 39: 100%|██████████| 2/2 [00:00<00:00,  3.22batch/s, accuracy=0.975, loss=0.00694]
# Epoch 40:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 40
# lr:  0.00012851215656510304
# -------------------------
# Train set: Avg. loss: 0.0059, Balanced Accuracy: 0.9833333492279053 (98%)
# Test set: Avg. loss: 0.0278, Balanced Accuracy: 0.699999988079071 (70%)
# -------------------------
# Epoch 40: 100%|██████████| 2/2 [00:01<00:00,  1.91batch/s, accuracy=0.992, loss=0.00624]
# Epoch 41: 100%|██████████| 2/2 [00:00<00:00,  3.24batch/s, accuracy=0.958, loss=0.00644]
# Epoch 42: 100%|██████████| 2/2 [00:00<00:00,  3.19batch/s, accuracy=0.992, loss=0.00618]
# Epoch 43: 100%|██████████| 2/2 [00:00<00:00,  3.29batch/s, accuracy=0.975, loss=0.00603]
# Epoch 44: 100%|██████████| 2/2 [00:00<00:00,  3.30batch/s, accuracy=0.975, loss=0.00637]
# Epoch 45:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 45
# lr:  9.944025698709218e-05
# -------------------------
# Train set: Avg. loss: 0.0059, Balanced Accuracy: 0.9833333492279053 (98%)
# Test set: Avg. loss: 0.0276, Balanced Accuracy: 0.7000000476837158 (70%)
# Saving best model weights with balanced accuracy:  0.7000000476837158
# -------------------------
# Epoch 45: 100%|██████████| 2/2 [00:01<00:00,  1.97batch/s, accuracy=0.983, loss=0.00617]
# Epoch 46: 100%|██████████| 2/2 [00:00<00:00,  3.23batch/s, accuracy=0.958, loss=0.00622]
# Epoch 47: 100%|██████████| 2/2 [00:00<00:00,  3.27batch/s, accuracy=0.975, loss=0.00654]
# Epoch 48: 100%|██████████| 2/2 [00:00<00:00,  3.35batch/s, accuracy=0.983, loss=0.00597]
# Epoch 49: 100%|██████████| 2/2 [00:00<00:00,  3.34batch/s, accuracy=0.975, loss=0.00618]
# Epoch 50:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 50
# lr:  7.69449752767131e-05
# -------------------------
# Train set: Avg. loss: 0.0059, Balanced Accuracy: 0.9833333492279053 (98%)
# Test set: Avg. loss: 0.0275, Balanced Accuracy: 0.6499999761581421 (65%)
# -------------------------
# Epoch 50: 100%|██████████| 2/2 [00:01<00:00,  1.98batch/s, accuracy=0.983, loss=0.00607]
# Train set: Avg. loss: 0.0059, Balanced Accuracy: 0.9833333492279053 (98%)
# Val set: Avg. loss: 0.0276, Balanced Accuracy: 0.7000000476837158 (70%)
# Test set: Avg. loss: 0.0205, Balanced Accuracy: 0.949999988079071 (95%)
# Epoch 0:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 0
# lr:  0.001
# -------------------------
# Train set: Avg. loss: 0.0115, Balanced Accuracy: 0.49166667461395264 (49%)
# Test set: Avg. loss: 0.0345, Balanced Accuracy: 0.550000011920929 (55%)
# Saving best model weights with balanced accuracy:  0.550000011920929
# -------------------------
# Epoch 0: 100%|██████████| 2/2 [00:01<00:00,  1.76batch/s, accuracy=0.525, loss=0.0116]
# Epoch 1: 100%|██████████| 2/2 [00:00<00:00,  3.21batch/s, accuracy=0.692, loss=0.0108]
# Epoch 2: 100%|██████████| 2/2 [00:00<00:00,  3.17batch/s, accuracy=0.792, loss=0.0102]
# Epoch 3: 100%|██████████| 2/2 [00:00<00:00,  3.38batch/s, accuracy=0.8, loss=0.01]
# Epoch 4: 100%|██████████| 2/2 [00:00<00:00,  3.21batch/s, accuracy=0.858, loss=0.00949]
# Epoch 5:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 5
# lr:  0.0007737809374999998
# -------------------------
# Train set: Avg. loss: 0.0094, Balanced Accuracy: 0.8500000238418579 (85%)
# Test set: Avg. loss: 0.0316, Balanced Accuracy: 0.7000000476837158 (70%)
# Saving best model weights with balanced accuracy:  0.7000000476837158
# -------------------------
# Epoch 5: 100%|██████████| 2/2 [00:00<00:00,  2.05batch/s, accuracy=0.833, loss=0.00939]
# Epoch 6: 100%|██████████| 2/2 [00:00<00:00,  3.38batch/s, accuracy=0.875, loss=0.00901]
# Epoch 7: 100%|██████████| 2/2 [00:00<00:00,  3.25batch/s, accuracy=0.85, loss=0.00908]
# Epoch 8: 100%|██████████| 2/2 [00:00<00:00,  3.25batch/s, accuracy=0.867, loss=0.00844]
# Epoch 9: 100%|██████████| 2/2 [00:00<00:00,  3.22batch/s, accuracy=0.867, loss=0.00889]
# Epoch 10:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 10
# lr:  0.0005987369392383785
# -------------------------
# Train set: Avg. loss: 0.0085, Balanced Accuracy: 0.8916666507720947 (89%)
# Test set: Avg. loss: 0.0306, Balanced Accuracy: 0.6499999761581421 (65%)
# -------------------------
# Epoch 10: 100%|██████████| 2/2 [00:01<00:00,  1.71batch/s, accuracy=0.858, loss=0.00852]
# Epoch 11: 100%|██████████| 2/2 [00:00<00:00,  3.18batch/s, accuracy=0.883, loss=0.00817]
# Epoch 12: 100%|██████████| 2/2 [00:00<00:00,  3.23batch/s, accuracy=0.867, loss=0.00813]
# Epoch 13: 100%|██████████| 2/2 [00:00<00:00,  3.40batch/s, accuracy=0.858, loss=0.00811]
# Epoch 14: 100%|██████████| 2/2 [00:00<00:00,  3.29batch/s, accuracy=0.908, loss=0.00809]
# Epoch 15:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 15
# lr:  0.00046329123015975297
# -------------------------
# Train set: Avg. loss: 0.0078, Balanced Accuracy: 0.9083333015441895 (91%)
# Test set: Avg. loss: 0.0305, Balanced Accuracy: 0.6499999761581421 (65%)
# -------------------------
# Epoch 15: 100%|██████████| 2/2 [00:01<00:00,  1.85batch/s, accuracy=0.9, loss=0.00788]
# Epoch 16: 100%|██████████| 2/2 [00:00<00:00,  3.34batch/s, accuracy=0.9, loss=0.00752]
# Epoch 17: 100%|██████████| 2/2 [00:00<00:00,  3.20batch/s, accuracy=0.908, loss=0.00801]
# Epoch 18: 100%|██████████| 2/2 [00:00<00:00,  3.03batch/s, accuracy=0.908, loss=0.00776]
# Epoch 19: 100%|██████████| 2/2 [00:00<00:00,  3.29batch/s, accuracy=0.917, loss=0.0076]
# Epoch 20:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 20
# lr:  0.0003584859224085418
# -------------------------
# Train set: Avg. loss: 0.0077, Balanced Accuracy: 0.9333333373069763 (93%)
# Test set: Avg. loss: 0.0307, Balanced Accuracy: 0.6499999761581421 (65%)
# -------------------------
# Epoch 20: 100%|██████████| 2/2 [00:01<00:00,  1.79batch/s, accuracy=0.925, loss=0.00765]
# Epoch 21: 100%|██████████| 2/2 [00:00<00:00,  3.20batch/s, accuracy=0.917, loss=0.00744]
# Epoch 22: 100%|██████████| 2/2 [00:00<00:00,  3.18batch/s, accuracy=0.967, loss=0.0072]
# Epoch 23: 100%|██████████| 2/2 [00:00<00:00,  3.26batch/s, accuracy=0.933, loss=0.00739]
# Epoch 24: 100%|██████████| 2/2 [00:00<00:00,  3.12batch/s, accuracy=0.95, loss=0.00707]
# Epoch 25:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 25
# lr:  0.00027738957312183364
# -------------------------
# Train set: Avg. loss: 0.0071, Balanced Accuracy: 0.9500000476837158 (95%)
# Test set: Avg. loss: 0.0305, Balanced Accuracy: 0.6499999761581421 (65%)
# -------------------------
# Epoch 25: 100%|██████████| 2/2 [00:00<00:00,  2.02batch/s, accuracy=0.933, loss=0.00674]
# Epoch 26: 100%|██████████| 2/2 [00:00<00:00,  3.53batch/s, accuracy=0.933, loss=0.00708]
# Epoch 27: 100%|██████████| 2/2 [00:00<00:00,  3.32batch/s, accuracy=0.942, loss=0.00717]
# Epoch 28: 100%|██████████| 2/2 [00:00<00:00,  3.24batch/s, accuracy=0.958, loss=0.0071]
# Epoch 29: 100%|██████████| 2/2 [00:00<00:00,  3.24batch/s, accuracy=0.958, loss=0.00677]
# Epoch 30:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 30
# lr:  0.00021463876394293716
# -------------------------
# Train set: Avg. loss: 0.0065, Balanced Accuracy: 0.9500000476837158 (95%)
# Test set: Avg. loss: 0.0300, Balanced Accuracy: 0.6499999761581421 (65%)
# -------------------------
# Epoch 30: 100%|██████████| 2/2 [00:01<00:00,  1.91batch/s, accuracy=0.958, loss=0.00707]
# Epoch 31: 100%|██████████| 2/2 [00:00<00:00,  3.21batch/s, accuracy=0.933, loss=0.00714]
# Epoch 32: 100%|██████████| 2/2 [00:00<00:00,  3.24batch/s, accuracy=0.967, loss=0.00659]
# Epoch 33: 100%|██████████| 2/2 [00:00<00:00,  3.32batch/s, accuracy=0.958, loss=0.00677]
# Epoch 34: 100%|██████████| 2/2 [00:00<00:00,  3.40batch/s, accuracy=0.958, loss=0.00652]
# Epoch 35:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 35
# lr:  0.00016608338398760707
# -------------------------
# Train set: Avg. loss: 0.0068, Balanced Accuracy: 0.9583333730697632 (96%)
# Test set: Avg. loss: 0.0296, Balanced Accuracy: 0.6499999761581421 (65%)
# -------------------------
# Epoch 35: 100%|██████████| 2/2 [00:01<00:00,  1.90batch/s, accuracy=0.975, loss=0.00674]
# Epoch 36: 100%|██████████| 2/2 [00:00<00:00,  3.21batch/s, accuracy=0.958, loss=0.00656]
# Epoch 37: 100%|██████████| 2/2 [00:00<00:00,  3.20batch/s, accuracy=0.95, loss=0.0067]
# Epoch 38: 100%|██████████| 2/2 [00:00<00:00,  3.21batch/s, accuracy=0.933, loss=0.00671]
# Epoch 39: 100%|██████████| 2/2 [00:00<00:00,  3.20batch/s, accuracy=0.967, loss=0.00641]
# Epoch 40:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 40
# lr:  0.00012851215656510304
# -------------------------
# Train set: Avg. loss: 0.0062, Balanced Accuracy: 0.9583333730697632 (96%)
# Test set: Avg. loss: 0.0290, Balanced Accuracy: 0.6000000238418579 (60%)
# -------------------------
# Epoch 40: 100%|██████████| 2/2 [00:01<00:00,  1.89batch/s, accuracy=0.942, loss=0.00684]
# Epoch 41: 100%|██████████| 2/2 [00:00<00:00,  3.26batch/s, accuracy=0.958, loss=0.00692]
# Epoch 42: 100%|██████████| 2/2 [00:00<00:00,  3.11batch/s, accuracy=0.967, loss=0.00632]
# Epoch 43: 100%|██████████| 2/2 [00:00<00:00,  3.33batch/s, accuracy=0.967, loss=0.00671]
# Epoch 44: 100%|██████████| 2/2 [00:00<00:00,  3.13batch/s, accuracy=0.967, loss=0.00665]
# Epoch 45:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 45
# lr:  9.944025698709218e-05
# -------------------------
# Train set: Avg. loss: 0.0064, Balanced Accuracy: 0.9583333730697632 (96%)
# Test set: Avg. loss: 0.0286, Balanced Accuracy: 0.699999988079071 (70%)
# -------------------------
# Epoch 45: 100%|██████████| 2/2 [00:01<00:00,  1.80batch/s, accuracy=0.975, loss=0.00683]
# Epoch 46: 100%|██████████| 2/2 [00:00<00:00,  4.85batch/s, accuracy=0.967, loss=0.00685]
# Epoch 47: 100%|██████████| 2/2 [00:00<00:00,  3.19batch/s, accuracy=0.95, loss=0.00657]
# Epoch 48: 100%|██████████| 2/2 [00:00<00:00,  3.12batch/s, accuracy=0.967, loss=0.00658]
# Epoch 49: 100%|██████████| 2/2 [00:00<00:00,  3.11batch/s, accuracy=0.958, loss=0.00637]
# Epoch 50:   0%|          | 0/2 [00:00<?, ?batch/s]
# Epoch 50
# lr:  7.69449752767131e-05
# -------------------------
# Train set: Avg. loss: 0.0061, Balanced Accuracy: 0.9666666984558105 (97%)
# Test set: Avg. loss: 0.0284, Balanced Accuracy: 0.699999988079071 (70%)
# -------------------------
# Epoch 50: 100%|██████████| 2/2 [00:01<00:00,  1.78batch/s, accuracy=0.975, loss=0.00637]
# Train set: Avg. loss: 0.0097, Balanced Accuracy: 0.8500000238418579 (85%)
# Val set: Avg. loss: 0.0316, Balanced Accuracy: 0.7000000476837158 (70%)
# Test set: Avg. loss: 0.0337, Balanced Accuracy: 0.550000011920929 (55%)

# %%
with open('../dicts_results/intra_subject_classification/braccio_atcnet_runs_numwins_5_filtersize_250.pkl', 'wb') as f:
    pickle.dump(dict_crossval, f)

# %% [markdown]
# # LDA / SVM

# %%
# Define the subject and the session
num_sessions = [1,2,3]
num_subjects = [1,2,3,5,6,7,8,10,11,13,14]  
dict_crossval = {"lda_balanced_accuracy":np.zeros((11,3)), "svm_balanced_accuracy":np.zeros((11,3)), "svm_rbf_balanced_accuracy":np.zeros((11,3))}

for i in range(len(num_subjects)):
    for num_session in num_sessions:
    
        num_subject = num_subjects[i]
        print("Subject: ", num_subject, " Session: ", num_session)

        # Define the path to the data and the train and test files
        if num_subject < 10:
            subject_number = "0" + str(num_subject)
        else:
            subject_number = str(num_subject)
        session_number = "0" + str(num_session)
        folder_path = "/network/lustre/iss02/aramis/projects/cracknetworks/sub-{}/ses-{}/EEG/".format(subject_number, session_number)
        files = [folder_path + f for f in os.listdir(folder_path) if f.endswith('.edf') and not(f.startswith("._"))]
        list_train_files = files[:-2]
        list_val_files = files[-2:-1]
        list_test_files = files[-1:]

        # Define the channels
        list_name_channels = ["CP1","CP3","CP5","C1","C3","C5","C2","CP2","Cz","FCz","C4","CP4"]
        list_idx_channels = [list_all_ch_names.index(ch) for ch in list_name_channels]

        # Define the labels
        labels = ['OVTK_GDF_Left', 'OVTK_GDF_Right']

        # Define the parameters of the dataset
        feature_type = ["time","band_psd","band_coh"]
        dict_preprocessing = {"polynomial_degree":10,"tmin":0,"tmax":4,"seq_length":2001}
        dict_features = {"type_psd":"welch","fs":500,"nfft":300,"noverlap":150,"nperseg":300,"filter_order":19,"fmin":4,"fmax":30}

        # Create the dataset
        try : 
            subject_trainset = dataset.EEG_Dataset(files_list = list_train_files, list_idx_channels = list_idx_channels, list_labels = labels, feature_type = feature_type, dict_preprocessing = dict_preprocessing, dict_features = dict_features)
            subject_testset = dataset.EEG_Dataset(files_list = list_test_files, list_idx_channels = list_idx_channels, list_labels = labels, feature_type = feature_type, dict_preprocessing = dict_preprocessing, dict_features = dict_features)

            subject_trainset.transform_dataset_numpy_to_torch()
            subject_trainset.features["time"] = subject_trainset.features["time"].unsqueeze(1)
            subject_testset.transform_dataset_numpy_to_torch()
            subject_testset.features["time"] = subject_testset.features["time"].unsqueeze(1)
            trainloader = torch.utils.data.DataLoader(subject_trainset, batch_size=100, shuffle=True, num_workers=2)
            testloader = torch.utils.data.DataLoader(subject_testset, batch_size=100, shuffle=True, num_workers=2)

            feature_type = "time"
            device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
            criterion = torch.nn.CrossEntropyLoss()

            X_train = subject_trainset.features["band_psd"].reshape(subject_trainset.features["band_psd"].shape[0], -1)
            y_train = subject_trainset.labels
            X_test = subject_testset.features["band_psd"].reshape(subject_testset.features["band_psd"].shape[0], -1)
            y_test = subject_testset.labels

            # Train LDA classifier
            lda_clf = LinearDiscriminantAnalysis()
            lda_clf.fit(X_train, y_train)
            y_pred = lda_clf.predict(X_test)
            balanced_acc = 0.5*(np.mean(y_pred[y_test == 0] == 0) + np.mean(y_pred[y_test == 1] == 1))
            dict_crossval["lda_balanced_accuracy"][i,num_session-1] = balanced_acc
            print("LDA accuracy: ", balanced_acc)

            # Train SVM classifier
            svm_clf = SVC(kernel='linear')
            svm_clf.fit(X_train, y_train)
            y_pred = svm_clf.predict(X_test)
            balanced_acc = 0.5*(np.mean(y_pred[y_test == 0] == 0) + np.mean(y_pred[y_test == 1] == 1))
            dict_crossval["svm_balanced_accuracy"][i,num_session-1] = balanced_acc
            print("SVM accuracy: ", balanced_acc)

            # Train SVM classifier
            svm_clf = SVC(kernel='rbf')
            svm_clf.fit(X_train, y_train)
            y_pred = svm_clf.predict(X_test)
            balanced_acc = 0.5*(np.mean(y_pred[y_test == 0] == 0) + np.mean(y_pred[y_test == 1] == 1))
            dict_crossval["svm_rbf_balanced_accuracy"][i,num_session-1] = balanced_acc
            print("SVM rbf accuracy: ", balanced_acc)

            dict_crossval["test_balanced_accuracy"][i,num_session-1] = test_balanced_accuracy
            dict_crossval["test_loss"][i,num_session-1] = test_loss
            dict_crossval["train_balanced_accuracy"][i,num_session-1] = train_balanced_accuracy
            dict_crossval["train_loss"][i,num_session-1] = train_loss
        except Exception as e:
            print("Error in subject ", num_subject, " session ", num_session)
            print(e)
            continue
# Out:
# Subject:  1  Session:  1
# LDA accuracy:  0.8
# SVM accuracy:  0.85
# SVM rbf accuracy:  0.8500000000000001
# Error in subject  1  session  1
# 'test_balanced_accuracy'
# Subject:  1  Session:  2
# Error in file:  /network/lustre/iss02/aramis/projects/cracknetworks/sub-01/ses-02/EEG/Train-[2022.04.04-16.15.17].edf
# 'Event name "OVTK_GDF_Left" could not be found. The following events are present in the data: OVTK_StimulationId_ExperimentStart, OVTK_StimulationId_BaselineStart/OVTK_StimulationId_Beep'
# Error in file:  /network/lustre/iss02/aramis/projects/cracknetworks/sub-01/ses-02/EEG/Train-[2022.04.04-16.14.01].edf
# 'Event name "OVTK_GDF_Left" could not be found. The following events are present in the data: OVTK_StimulationId_ExperimentStart, OVTK_StimulationId_BaselineStart/OVTK_StimulationId_Beep'
# Error in file:  /network/lustre/iss02/aramis/projects/cracknetworks/sub-01/ses-02/EEG/Test-[2022.04.04-16.52.15].edf
# 'Event name "OVTK_GDF_Left" could not be found. The following events are present in the data: OVTK_GDF_Feedback_Continuous, OVTK_GDF_Right, OVTK_StimulationId_ExperimentStart, OVTK_StimulationId_BaselineStart/OVTK_StimulationId_Beep, OVTK_StimulationId_BaselineStop/OVTK_StimulationId_Beep, OVTK_GDF_Cross_On_Screen/OVTK_GDF_Start_Of_Trial/OVTK_StimulationId_Beep, OVTK_GDF_End_Of_Trial/OVTK_StimulationId_VisualStimulationStar'
# LDA accuracy:  0.5
# SVM accuracy:  0.8
# SVM rbf accuracy:  0.8500000000000001
# Error in subject  1  session  2
# 'test_balanced_accuracy'
# Subject:  1  Session:  3
# LDA accuracy:  0.5
# SVM accuracy:  0.6499999999999999
# SVM rbf accuracy:  0.7
# Error in subject  1  session  3
# 'test_balanced_accuracy'
# Subject:  2  Session:  1
# LDA accuracy:  0.5
# SVM accuracy:  0.7
# SVM rbf accuracy:  0.6
# Error in subject  2  session  1
# 'test_balanced_accuracy'
# Subject:  2  Session:  2
# LDA accuracy:  0.7
# SVM accuracy:  0.75
# SVM rbf accuracy:  0.6000000000000001
# Error in subject  2  session  2
# 'test_balanced_accuracy'
# Subject:  2  Session:  3
# LDA accuracy:  0.65
# SVM accuracy:  0.8
# SVM rbf accuracy:  0.75
# Error in subject  2  session  3
# 'test_balanced_accuracy'
# Subject:  3  Session:  1
# Error in file:  /network/lustre/iss02/aramis/projects/cracknetworks/sub-03/ses-01/EEG/Test-[2022.03.15-16.39.19].edf
# could not convert string to float: './.).(-*'
# LDA accuracy:  0.4
# SVM accuracy:  0.7
# SVM rbf accuracy:  0.55
# Error in subject  3  session  1
# 'test_balanced_accuracy'
# Subject:  3  Session:  2
# LDA accuracy:  0.6499999999999999
# SVM accuracy:  0.85
# SVM rbf accuracy:  0.8
# Error in subject  3  session  2
# 'test_balanced_accuracy'
# Subject:  3  Session:  3
# LDA accuracy:  0.65
# SVM accuracy:  0.55
# SVM rbf accuracy:  0.65
# Error in subject  3  session  3
# 'test_balanced_accuracy'
# Subject:  5  Session:  1
# LDA accuracy:  0.6
# SVM accuracy:  0.7
# SVM rbf accuracy:  0.75
# Error in subject  5  session  1
# 'test_balanced_accuracy'
# Subject:  5  Session:  2
# LDA accuracy:  0.75
# SVM accuracy:  0.8500000000000001
# SVM rbf accuracy:  0.9
# Error in subject  5  session  2
# 'test_balanced_accuracy'
# Subject:  5  Session:  3
# LDA accuracy:  0.6499999999999999
# SVM accuracy:  0.8
# SVM rbf accuracy:  0.6
# Error in subject  5  session  3
# 'test_balanced_accuracy'
# Subject:  6  Session:  1
# LDA accuracy:  0.5
# SVM accuracy:  0.8
# SVM rbf accuracy:  0.8
# Error in subject  6  session  1
# 'test_balanced_accuracy'
# Subject:  6  Session:  2
# Error in file:  /network/lustre/iss02/aramis/projects/cracknetworks/sub-06/ses-02/EEG/Test-[2022.05.10-16.09.32].edf
# 'Event name "OVTK_GDF_Left" could not be found. The following events are present in the data: OVTK_StimulationId_ExperimentStart, OVTK_StimulationId_BaselineStart/OVTK_StimulationId_Beep'
# LDA accuracy:  0.6
# SVM accuracy:  0.95
# SVM rbf accuracy:  0.95
# Error in subject  6  session  2
# 'test_balanced_accuracy'
# Subject:  6  Session:  3
# LDA accuracy:  0.5
# SVM accuracy:  0.5
# SVM rbf accuracy:  0.6
# Error in subject  6  session  3
# 'test_balanced_accuracy'
# Subject:  7  Session:  1
# LDA accuracy:  0.6499999999999999
# SVM accuracy:  0.6499999999999999
# SVM rbf accuracy:  0.7
# Error in subject  7  session  1
# 'test_balanced_accuracy'
# Subject:  7  Session:  2
# LDA accuracy:  0.7
# SVM accuracy:  0.85
# SVM rbf accuracy:  0.55
# Error in subject  7  session  2
# 'test_balanced_accuracy'
# Subject:  7  Session:  3
# LDA accuracy:  0.5
# SVM accuracy:  0.8
# SVM rbf accuracy:  0.7
# Error in subject  7  session  3
# 'test_balanced_accuracy'
# Subject:  8  Session:  1
# LDA accuracy:  0.8
# SVM accuracy:  0.9
# SVM rbf accuracy:  0.9
# Error in subject  8  session  1
# 'test_balanced_accuracy'
# Subject:  8  Session:  2
# Error in file:  /network/lustre/iss02/aramis/projects/cracknetworks/sub-08/ses-02/EEG/Test-[2022.05.18-15.56.08].edf
# 'Event name "OVTK_GDF_Left" could not be found. The following events are present in the data: OVTK_StimulationId_ExperimentStart, OVTK_StimulationId_BaselineStart/OVTK_StimulationId_Beep'
# LDA accuracy:  0.5
# SVM accuracy:  1.0
# SVM rbf accuracy:  0.95
# Error in subject  8  session  2
# 'test_balanced_accuracy'
# Subject:  8  Session:  3
# LDA accuracy:  0.55
# SVM accuracy:  0.7
# SVM rbf accuracy:  0.6499999999999999
# Error in subject  8  session  3
# 'test_balanced_accuracy'
# Subject:  10  Session:  1
# LDA accuracy:  0.5
# SVM accuracy:  0.55
# SVM rbf accuracy:  0.5
# Error in subject  10  session  1
# 'test_balanced_accuracy'
# Subject:  10  Session:  2
# Error in file:  /network/lustre/iss02/aramis/projects/cracknetworks/sub-10/ses-02/EEG/Test-[2022.07.19-16.20.04].edf
# 'Event name "OVTK_GDF_Left" could not be found. The following events are present in the data: OVTK_StimulationId_ExperimentStart, OVTK_StimulationId_BaselineStart/OVTK_StimulationId_Beep'
# LDA accuracy:  0.65
# SVM accuracy:  0.8
# SVM rbf accuracy:  0.5
# Error in subject  10  session  2
# 'test_balanced_accuracy'
# Subject:  10  Session:  3
# LDA accuracy:  0.55
# SVM accuracy:  0.75
# SVM rbf accuracy:  0.5
# Error in subject  10  session  3
# 'test_balanced_accuracy'
# Subject:  11  Session:  1
# LDA accuracy:  0.8500000000000001
# SVM accuracy:  1.0
# SVM rbf accuracy:  0.5
# Error in subject  11  session  1
# 'test_balanced_accuracy'
# Subject:  11  Session:  2
# LDA accuracy:  0.44999999999999996
# SVM accuracy:  0.65
# SVM rbf accuracy:  0.5
# Error in subject  11  session  2
# 'test_balanced_accuracy'
# Subject:  11  Session:  3
# Error in file:  /network/lustre/iss02/aramis/projects/cracknetworks/sub-11/ses-03/EEG/Test-[2022.07.04-16.11.03].edf
# 'Event name "OVTK_GDF_Left" could not be found. The following events are present in the data: OVTK_StimulationId_ExperimentStart'
# Error in subject  11  session  3
# need at least one array to concatenate
# Subject:  13  Session:  1
# Error in file:  /network/lustre/iss02/aramis/projects/cracknetworks/sub-13/ses-01/EEG/Test-[2022.06.23-15.46.51].edf
# 'Event name "OVTK_GDF_Left" could not be found. The following events are present in the data: OVTK_StimulationId_ExperimentStart, OVTK_StimulationId_BaselineStart/OVTK_StimulationId_Beep'
# LDA accuracy:  0.7
# SVM accuracy:  0.75
# SVM rbf accuracy:  0.7
# Error in subject  13  session  1
# 'test_balanced_accuracy'
# Subject:  13  Session:  2
# LDA accuracy:  1.0
# SVM accuracy:  0.95
# SVM rbf accuracy:  0.75
# Error in subject  13  session  2
# 'test_balanced_accuracy'
# Subject:  13  Session:  3
# LDA accuracy:  0.8
# SVM accuracy:  0.8
# SVM rbf accuracy:  0.5
# Error in subject  13  session  3
# 'test_balanced_accuracy'
# Subject:  14  Session:  1
# LDA accuracy:  0.6
# SVM accuracy:  0.65
# SVM rbf accuracy:  0.75
# Error in subject  14  session  1
# 'test_balanced_accuracy'
# Subject:  14  Session:  2
# LDA accuracy:  0.65
# SVM accuracy:  0.85
# SVM rbf accuracy:  0.8
# Error in subject  14  session  2
# 'test_balanced_accuracy'
# Subject:  14  Session:  3
# LDA accuracy:  0.8500000000000001
# SVM accuracy:  0.95
# SVM rbf accuracy:  0.5
# Error in subject  14  session  3
# 'test_balanced_accuracy'

# %%
with open('../dicts_results/intra_subject_classification/braccio_runs_classical.pkl', 'wb') as f:
    pickle.dump(dict_crossval, f)
